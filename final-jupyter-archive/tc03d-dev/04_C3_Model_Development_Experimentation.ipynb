# %% [markdown]
# # Machine Learning Experimentation on the C3 AI Suite

# %% [markdown]
# In this notebook we will cover:
# - Best practices for experimenting with and tuning machine learning pipelines at scale
# - Performing hyperparameter optimization using the `MLAutoTuner`
# - Preparing a trained and tuned pipeline for production deployment as an `MLModel`

# %% [markdown]
# ## Table of Contents

# %% [markdown]
# * [Machine Learning Experimentation on the C3 AI Suite](#1)
#     * [1. Import packages and Helper Functions](#1.1)
#     * [2. Create Train, Test and Validation segments](#1.3)
#     * [3. Define how to retrieve features, label, mask](#1.4)
#     * [4. Define Machine Learning Pipeline](#1.5)
#     * [5. Define Hyperparameter Search Space](#1.6)
#     * [6. Define Scoring Metric](#1.7)
#     * [7. Define the Validation Technique](#1.8)
#     * [8. Define the Hyperparameter Search Technique](#1.9)
#     * [9. Define the Execution Criteria](#1.10)
#     * [10. Put it all together in MLAutoTunerSearchSpec](#1.11)
#     * [11. Submit a MLAutoTuner search job](#1.12)
#     * [12. Score and Analyze Results](#1.13)

# %% [markdown]
# ### Step 1. Import the necessary packages <a class="anchor" id="1.1">

# %%
import pandas as pd
import numpy as np 
import collections
from datetime import datetime
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (10,6)
# %matplotlib inline

# %% [markdown]
# ### Step 2: Create Train, Test and Validation segments <a class="anchor" id="1.3">

# %% [markdown]
# Determine which C3 Type you are using as the subject of your ML experiments ( = which Type your features and metrics are defined on).

# %%
subject_type_name = "SmartBulb"

# %% [markdown]
# Here we're creating our traing, validation and test segments:

# %%
training_segment = c3.MLPopulationSegment(
    subjectFilter="!(contains(id, 'SMBLB1') || contains(id, 'SMBLB2'))", # Which subjects to include in the group
#     mlProject=project, # use this to attach your model experimentation to an existing ML Project for traceability
    name="TrainingBulbs",
).upsert()

# %%
validation_segment = c3.MLPopulationSegment(
    subjectFilter="contains(id, 'SMBLB1')", # Which subjects to include in the group
#     mlProject=project, # use this to attach your model experimentation to an existing ML Project for traceability
    name="ValidationBulbs",
).upsert()

# %%
test_segment = c3.MLPopulationSegment(
    subjectFilter="contains(id, 'SMBLB2')", # Which subjects to include in the group
#     mlProject=project, # use this to attach your model experimentation to an existing ML Project for traceability
    name="TestingBulbs",
).upsert()

# %% [markdown]
# ### Step 3: Define how to retrieve features, label, mask <a class="anchor" id="1.4">

# %%
pd.DataFrame(c3.SmartBulb.listMetrics().toJson())
# Out:
#               type                       name  \
# 0     SimpleMetric              AverageLumens
# 1     SimpleMetric               AveragePower
# 2     SimpleMetric         AverageTemperature
# 3     SimpleMetric             AverageVoltage
# 4   CompoundMetric                  DayOfWeek
# 5   CompoundMetric              DayOfWeekDemo
# 6   CompoundMetric                  DayOfYear
# 7   CompoundMetric                 DaysInYear
# 8   CompoundMetric          DurationOnInHours
# 9   CompoundMetric              HasEverFailed
# 10  CompoundMetric                    Holiday
# 11  CompoundMetric                  HourOfDay
# 12  CompoundMetric                 HourOfWeek
# 13  CompoundMetric                IsDefective
# 14    SimpleMetric      MLProjectContribution
# 15    SimpleMetric        MLProjectPrediction
# 16  CompoundMetric                MonthOfYear
# 17  CompoundMetric              NonWorkingDay
# 18  CompoundMetric               NumberOfDays
# 19  CompoundMetric              NumberOfHours
# 20  CompoundMetric  NumberOfSecondsInInterval
# 21    SimpleMetric            PowerGridStatus
# 22    SimpleMetric                     Status
# 23  CompoundMetric          WillFailNextMonth
#
#                                            expression  \
# 0                    avg(avg(normalized.data.lumens))
# 1                     avg(avg(normalized.data.power))
# 2               avg(avg(normalized.data.temperature))
# 3                   avg(avg(normalized.data.voltage))
# 4                 timeComponent('DAYOFWEEK', start())
# 5                 timeComponent('DAYOFWEEK', start())
# 6                 timeComponent('DAYOFYEAR', start())
# 7   timeComponent('YEAR', start()) % 4 != 0 || (ti...
# 8            rolling('SUM',sum(eval('HOUR', Status)))
# 9                  rolling('SUM',IsDefective) ? 1 : 0
# 10                             holiday(identity(1.0))
# 11                     timeComponent('HOUR', start())
# 12                 ((DayOfWeek - 1) * 24) + HourOfDay
# 13  or(eval('HOUR', AverageLumens == 0 && Status =...
# 14             avg(avg(normalized.data.contribution))
# 15                    avg(avg(normalized.data.value))
# 16                    timeComponent('MONTH', start())
# 17  Holiday || timeComponent('DAYOFWEEK', start())...
# 18               (end() - start()) / period(1, 'DAY')
# 19              (end() - start()) / period(1, 'HOUR')
# 20      treatAsUnit('second', (end() - start())/1000)
# 21                                                NaN
# 22                   max(max(normalized.data.status))
# 23                  window('MAX', IsDefective, 0, 30)
#
#                                                  meta  \
# 0   {'type': 'Meta', 'tenantTagId': 152, 'tenant':...
# 1   {'type': 'Meta', 'tenantTagId': 152, 'tenant':...
# 2   {'type': 'Meta', 'tenantTagId': 152, 'tenant':...
# 3   {'type': 'Meta', 'tenantTagId': 152, 'tenant':...
# 4   {'type': 'Meta', 'fetchInclude': '[id,name,uni...
# 5   {'type': 'Meta', 'fetchInclude': '[id,name,uni...
# 6   {'type': 'Meta', 'fetchInclude': '[id,name,uni...
# 7   {'type': 'Meta', 'fetchInclude': '[id,name,uni...
# 8   {'type': 'Meta', 'fetchInclude': '[id,name,uni...
# 9   {'type': 'Meta', 'fetchInclude': '[id,name,uni...
# 10  {'type': 'Meta', 'fetchInclude': '[id,name,uni...
# 11  {'type': 'Meta', 'fetchInclude': '[id,name,uni...
# 12  {'type': 'Meta', 'fetchInclude': '[id,name,uni...
# 13  {'type': 'Meta', 'fetchInclude': '[id,name,uni...
# 14  {'type': 'Meta', 'tenantTagId': 152, 'tenant':...
# 15  {'type': 'Meta', 'tenantTagId': 152, 'tenant':...
# 16  {'type': 'Meta', 'fetchInclude': '[id,name,uni...
# 17  {'type': 'Meta', 'fetchInclude': '[id,name,uni...
# 18  {'type': 'Meta', 'fetchInclude': '[id,name,uni...
# 19  {'type': 'Meta', 'fetchInclude': '[id,name,uni...
# 20  {'type': 'Meta', 'fetchInclude': '[id,name,uni...
# 21  {'type': 'Meta', 'tenantTagId': 152, 'tenant':...
# 22  {'type': 'Meta', 'tenantTagId': 152, 'tenant':...
# 23  {'type': 'Meta', 'fetchInclude': '[id,name,uni...
#
#                                  id  version  \
# 0           AverageLumens_SmartBulb        1
# 1            AveragePower_SmartBulb        1
# 2      AverageTemperature_SmartBulb        1
# 3          AverageVoltage_SmartBulb        1
# 4                         DayOfWeek        1
# 5                     DayOfWeekDemo        1
# 6                         DayOfYear        1
# 7                        DaysInYear        1
# 8                 DurationOnInHours        1
# 9                     HasEverFailed        1
# 10                          Holiday        1
# 11                        HourOfDay        1
# 12                       HourOfWeek        1
# 13                      IsDefective        1
# 14  MLProjectContribution_MLSubject        1
# 15    MLProjectPrediction_MLSubject        1
# 16                      MonthOfYear        1
# 17                    NonWorkingDay        1
# 18                     NumberOfDays        1
# 19                    NumberOfHours        1
# 20        NumberOfSecondsInInterval        1
# 21        PowerGridStatus_SmartBulb        1
# 22                 Status_SmartBulb        1
# 23                WillFailNextMonth        1
#
#                                          srcType  \
# 0   {'type': 'TypeRef', 'typeName': 'SmartBulb'}
# 1   {'type': 'TypeRef', 'typeName': 'SmartBulb'}
# 2   {'type': 'TypeRef', 'typeName': 'SmartBulb'}
# 3   {'type': 'TypeRef', 'typeName': 'SmartBulb'}
# 4                                            NaN
# 5                                            NaN
# 6                                            NaN
# 7                                            NaN
# 8                                            NaN
# 9                                            NaN
# 10                                           NaN
# 11                                           NaN
# 12                                           NaN
# 13                                           NaN
# 14  {'type': 'TypeRef', 'typeName': 'MLSubject'}
# 15  {'type': 'TypeRef', 'typeName': 'MLSubject'}
# 16                                           NaN
# 17                                           NaN
# 18                                           NaN
# 19                                           NaN
# 20                                           NaN
# 21  {'type': 'TypeRef', 'typeName': 'SmartBulb'}
# 22  {'type': 'TypeRef', 'typeName': 'SmartBulb'}
# 23                                           NaN
#
#                                                  path  \
# 0                                    bulbMeasurements
# 1                                    bulbMeasurements
# 2                                    bulbMeasurements
# 3                                    bulbMeasurements
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14  projectSubjects.(mlProject.id == projectId).ti...
# 15  projectSubjects.(mlProject.id == projectId).ti...
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21               fixtureHistory.to.apartment.building
# 22                                   bulbMeasurements
# 23                                                NaN
#
#                                             variables  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14  [{'type': 'MetricVariable', 'name': 'projectId...
# 15  [{'type': 'MetricVariable', 'name': 'projectId...
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
#
#                                                tsDecl
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21  {'type': 'TSDecl', 'data': 'gridStatusSet', 't...
# 22                                                NaN
# 23                                                NaN

# %% [markdown]
# Construct an `EvalMetricsDatasetMLDataSourceSpec` which is a specification for how we wish to construct our dataset for model training.

# %%
# List of C3 metric (SimpleMetric or Compound) names
features = [
                "AverageTemperature",
                "AveragePower",
]

# We will use this to discard data AFTER a bulb has failed
mask = 'HasEverFailed'
label = 'WillFailNextMonth'
train_start_date = "2016-01-01" # datetime string for start of training period
train_end_date = "2021-01-01" # datetime string for end of training period
time_series_interval = "DAY" # string specifying interval of data (See Interval type for more info)

source_spec = c3.EvalMetricsDatasetMLDataSourceSpec(
    name="training_smartbulb",
    srcType=subject_type_name,
    features=features,
    maskMetric=mask,
    target=label,
    start=train_start_date,
    end=train_end_date,
    interval=time_series_interval
).upsert()

# %% [markdown]
# Here we use the `EvalMetricsDatasetMLDataSourceSpec` defined above and generate training, validation and test datasets in a distributed fashion. These features are evaluated and persisted on the platform and the client is given a reference to these datasets. We will use the reference to the generated datasets to do the remainder of our experimentation and will not pull this dataset into our relatively memory constrained client (jupyter).
#
# This allows us to easily scale to very large datasets limited only by filesystem storage!

# %%
training_dataset_generation_job = source_spec.inputAndTargetDataByReference(sourceFilter=training_segment.get().subjectFilter)

validation_dataset_generation_job = source_spec.inputAndTargetDataByReference(sourceFilter=validation_segment.get().subjectFilter)

test_dataset_generation_job = source_spec.inputAndTargetDataByReference(sourceFilter=test_segment.get().subjectFilter)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-919ccc98954e> in <module>
# ----> 1 training_dataset_generation_job = source_spec.inputAndTargetDataByReference(sourceFilter=training_segment.get().subjectFilter)
#       2
#       3 validation_dataset_generation_job = source_spec.inputAndTargetDataByReference(sourceFilter=validation_segment.get().subjectFilter)
#       4
#       5 test_dataset_generation_job = source_spec.inputAndTargetDataByReference(sourceFilter=test_segment.get().subjectFilter)
#
# Z10ac078826d8534179d455db1588a325M_/TypeSystemBase.py in cls__getattr__(self, key)
#
# Z10ac078826d8534179d455db1588a325M_/TypeSystemBase.py in cls__getattr__(self, key)
#
# AttributeError: 'EvalMetricsDatasetMLDataSourceSpec' object has no attribute 'inputAndTargetDataByReference'

# %% [markdown]
# We wait until the dataset generation jobs are complete:
#
# **Note** - `fst` and `snd` represent the jobs for features and target generation respectively

# %%
training_dataset_generation_job.fst.waitForCompletion()
validation_dataset_generation_job.fst.waitForCompletion()
test_dataset_generation_job.fst.waitForCompletion()
training_dataset_generation_job.snd.waitForCompletion()
validation_dataset_generation_job.snd.waitForCompletion()
test_dataset_generation_job.snd.waitForCompletion()

# %% [markdown]
# Now we can easily construct the X's and y's for our supervised learning problem and get a handle to these generated datasets without pulling the data into our Jupyter client and materializing them:
#
# **Note** - We are accessing the `default` collection since we haven't declared a grouping field for our dataset generation job. We can optionally specify this grouping field and only get a handle to a dataset that is grouped by a certain field.

# %%
X_train_dataset_ref = training_dataset_generation_job.fst.results()["default"][0]
y_train_dataset_ref = training_dataset_generation_job.snd.results()["default"][0]

X_val_dataset_ref = validation_dataset_generation_job.fst.results()["default"][0]
y_val_dataset_ref = validation_dataset_generation_job.snd.results()["default"][0]

X_test_dataset_ref = test_dataset_generation_job.fst.results()["default"][0]
y_test_dataset_ref = test_dataset_generation_job.snd.results()["default"][0]

# %% [markdown]
# **Note** the structure of the `Dataset` object. It's just a reference to the persisted features!

# %%
X_train_dataset_ref

# %% [markdown]
# ### Step 4: Define Machine Learning Pipeline <a class="anchor" id="1.5">

# %% [markdown]
# Define the machine learning pipeline that we wish to tune:

# %%
standardScaler = c3.SklearnPipe(
                    name="standardScaler",
                    technique=c3.SklearnTechnique(
                        # This tells ML pipeline to import sklearn.preprocessing.StandardScaler.
                        name="preprocessing.StandardScaler",
                        # This tells ML pipeline to call "transform" method on sklearn.preprocessing.StandardScaler when we invoke the C3 action process() later.
                        processingFunctionName="transform"
                    )
                 )


preprocess_pipeline = c3.MLSerialPipeline(
                        name="preprocessPipeline",
                        steps=[c3.MLStep(name="standardScaler",
                                         pipe=standardScaler),
                              ]
)


classifier = c3.SklearnPipe(
                    name="rfc",
                    technique=c3.SklearnTechnique(
                        name="ensemble.RandomForestClassifier",
                        processingFunctionName="predict",
                    )
)


serialPipeline = c3.MLSerialPipeline(
                name="randomForestPipeline2",
                steps=[c3.MLStep(name="preprocess",
                                 pipe=preprocess_pipeline),
                       c3.MLStep(name="classifier",
                                 pipe=classifier)],
                scoringMetrics=c3.MLScoringMetric.toScoringMetricMap(scoringMetricList=[c3.MLAccuracyMetric(), c3.MLPrecisionMetric()])
             ).upsert()

# %% [markdown]
# Or retrieve a previously upserted pipeline:

# %%
# # If you would like to use an MLPipeline you created earlier, e.g. in the previous module, you would fetch the
# # id and use it here

# serialPipeline = c3.MLSerialPipeline.get('unique_id_of_previously_upserted_pipeline')

# %%
serialPipeline

# %% [markdown]
# ### Step 5. Define Hyperparameter Search Space <a class="anchor" id="1.6">

# %% [markdown]
# Note the syntax for specifying hyperparameter space to search over:
#
# `MLStepName__hyperparameter`

# %%
hyperparam_space = {
                        "classifier__n_estimators": c3.IntegerRangeParamSpace(start=500, stop=1000, stepSize=100),
                        "classifier__max_depth": c3.IntegerRangeParamSpace(start=2, stop=5, stepSize=1)
                    }

# %% [markdown]
# ### Step 6. Define Scoring Metric <a class="anchor" id="1.7">

# %% [markdown]
# Define the scoring metric to be used for validation:

# %%
scoring_metric = c3.MLF1ScoreMetric()
scoring_metric.category()

# %% [markdown]
# ### Step 7. Define the Validation Technique <a class="anchor" id="1.8">

# %% [markdown]
# Types of supported cross-validation techniques:

# %%
c3.MetadataStore.tag().typesThatMixin("MLValidationTechnique")

# %% [markdown]
# We will use `MLCustomHoldoutTechnique`

# %%
val_technique = c3.MLCustomHoldoutTechnique(
    customInputValidate=X_val_dataset_ref,
    customTargetOutputValidate=y_val_dataset_ref,
    validationMetric="f1_score", 
    scoringMetrics={
        "f1_score": scoring_metric
    },
)

# %% [markdown]
# ### Step 8. Define the Hyperparameter Search Technique <a class="anchor" id="1.9">

# %% [markdown]
# We will use a simple `Grid` search algorithm which can be parallelized across the c3 cluster. Try to find out what other algorithms we support!

# %%
hyp_technique = c3.MLHyperParamSearchTechniqueChocolate(
    algorithm="Grid"
)
hyp_technique.isSerial()

# %% [markdown]
# ### Step 9. Define the Execution Criteria <a class="anchor" id="1.10">

# %%
exec_spec = c3.MLHyperParamExecSpec(
    keepAllTrainedPipes=True,
    checkAutoEarlyStop=True,
    targetScore=0.97
)

# %% [markdown]
# ### Step 10. Put it all together in MLAutoTunerSearchSpec <a class="anchor" id="1.11">

# %% [markdown]
# **Note** - You should change the `maxIterations` field here to account for your search space

# %%
search_spec = c3.MLAutoTunerSearchSpec(
    validationTechnique=val_technique,
    hyperParamSearchTechnique=hyp_technique,
    executionSpec=exec_spec,
    maxConcurrentIterations=100,
    maxIterations=1,
    maxSearchTime=600,
    refit=True
)

# %% [markdown]
# ### Step 11. Submit a MLAutoTuner search job <a class="anchor" id="1.12">

# %%
auto_tuner = c3.MLAutoTuner(name="MyUniqueMLAutoTunerName").search(
                            # mlProject=project,
                            pipe=serialPipeline.get(),
                            hyperparameterSpace=hyperparam_space,
                            input=X_train_dataset_ref,
                            targetOutput=y_train_dataset_ref,
                            spec=search_spec
)

# %%
auto_tuner.get('MyUniqueMLAutoTunerName')

# %%
def check_auto_tuner_status(auto_tuner):
    import pandas as pd
    from IPython.display import clear_output
    clear_output()
    if auto_tuner.get("completedIterations").completedIterations is None:
        display(f"Status: {auto_tuner.state()}")
    else:
        completed_iterations = auto_tuner.get("completedIterations").completedIterations
        results = [i["validationFoldsResults"][0] for i in completed_iterations.toJson()]
        for iteration, res in zip(completed_iterations, results):
            res["HP"] = iteration.hyperParameters.toJson()
        df = pd.json_normalize(results)
        df["timeElapsed"] = [iteration.endTimestamp - iteration.startTimestamp for iteration in completed_iterations]
        display(f"Status: {auto_tuner.state()}")
        display(df[[col for col in df.columns if "Scores" in col or "HP" in col] + ["timeElapsed"]])
        if auto_tuner.state() == "completed":
            display("********** BEST MODEL RESULT RETRAINED ON TRAIN + VAL DATASETS **********")
            display(auto_tuner.bestResult())
            return True
    return False

while True:
    import time
    if check_auto_tuner_status(auto_tuner):
        break
    time.sleep(20)

# %%
auto_tuner.errors()

# %% [markdown]
# ### Step 12. Score and Analyze Results <a class="anchor" id="1.13">

# %% [markdown]
# We can retrieve the best fit model that has been retrained on both the training and validation set:

# %%
retrievedPipeline = auto_tuner.get().retrainedPipe.get()

# %%
train_score = retrievedPipeline.score(input=X_train_dataset_ref, targetOutput=y_train_dataset_ref)
test_score = retrievedPipeline.score(input=X_test_dataset_ref, targetOutput=y_test_dataset_ref)
print(f'train score = {train_score}')
print(f'test score = {test_score}')

# %% [markdown]
# We can generate predictions on the platform. Note the returned predictions are c3 `Dataset`s.

# %%
y_pred_train = retrievedPipeline.process(input=X_train_dataset_ref)
y_pred_test = retrievedPipeline.process(input=X_test_dataset_ref)

# %% [markdown]
# We convert back to a pandas dataframe.

# %%
y_pred_train_df = c3.Dataset.toPandas(y_pred_train)
y_pred_test_df = c3.Dataset.toPandas(y_pred_test)

# %% [markdown]
# Now we declare a plotting method that will plot the precision and recall curve along with the average precision

# %%
from sklearn.metrics import roc_curve, auc
from matplotlib import pyplot as plt
from sklearn.metrics import precision_recall_curve, average_precision_score

def plot_prec(y_pred_test, y_true_test, y_pred_train, y_true_train, fp=None, save=False):
    
    prec, rec, thresholds = precision_recall_curve(y_true=y_true_test, probas_pred=y_pred_test)
    avg_prec_test = average_precision_score(y_true=y_true_test, y_score=y_pred_test) 
    lw = 1
    plt.figure(figsize=[6, 6])
    plt.plot(rec, prec, color='darkorange',
         lw=lw, label='Precision-Recall curve(average precision = %0.2f), Testing' % avg_prec_test)
    
    prec, rec, thresholds = precision_recall_curve(y_true=y_true_train, probas_pred=y_pred_train)
    avg_prec_train = average_precision_score(y_true=y_true_train, y_score=y_pred_train) 
    lw = 1
    
    plt.plot(rec, prec, color='blue',
         lw=lw, label='Precision-Recall curve(average precision = %0.2f), Training' % avg_prec_train)
    
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.title('Precision-Recall curve')
    plt.legend(loc="lower right")
    if save:
        plt.savefig(fp)
    plt.show()
    return avg_prec_test, avg_prec_train

# %% [markdown]
# We can use the helper method to plot the precision recall curve for the training and test set

# %%
y_true_train_df = c3.Dataset.toPandas(y_train_dataset_ref)
y_true_test_df = c3.Dataset.toPandas(y_test_dataset_ref)

# %%
test_avg_prec, train_avg_prec = plot_prec(y_pred_test=y_pred_test_df,
                                          y_true_test=y_true_test_df,
                                          y_pred_train=y_pred_train_df,
                                          y_true_train=y_true_train_df)

# %%
print(f'Average Precision Train: {train_avg_prec}')
print(f'Average Precision Test: {test_avg_prec}')

# %% [markdown]
# ### Step 13. Create MLModel for Deployment <a class="anchor" id="1.14">

# %% [markdown]
# Now, we iterate over the above steps until we're satisfied with the generalizability of our machine learning pipeline.

# %% [markdown]
# Ocne you're satisfied with the results and you have your model acheiving a good F1 score, you can uncomment and execute the following cell to create an `MLModel` from the trained and tuned pipeline which is now ready to be deployed directly in production using the [C3 AI Model Deployment Framework ](https://developer.c3.ai/docs/7.29.0/topic/modelDeployment)!

# %%
# ml_model = c3.MLModel.createFromPipeline(
#     pipeline=retrievedPipeline.get(), 
#     trainingDataSourceSpec=source_spec.get(),
#     spec=c3.MLModelCreateSpec(
#         predictionDataSourceSpec=source_spec.get(),
#         # mlProject=project # for the DS course, this line should stay commented out;
#                             # you would use it to to attach your model experimentation to an existing ML Project for traceability
#     )
# ).upsert(spec=c3.UpsertSpec(returnInclude="this"))

# %% [markdown]
# ### Get the id of your created MLModel in this cell. You will deploy it in the Capstone notebook and see how your model performs against a "LIVE" model.

# %%
# ml_model

ml_model.id

# %%
help(c3.EvalMetricsDatasetMLDataSourceSpec)
# Out:
# <div id="type:EvalMetricsDatasetMLDataSourceSpec" class="structure type root beta private">
# <h1 class="type root">Type <span class="name">EvalMetricsDatasetMLDataSourceSpec</span></h1>
# <div class="description">
# <p><code>EvalMetricsDatasetMLDataSourceSpec</code> is a SupervisedMLDataSourceSpec which creates training input and target
# Datasets by evaluating metrics according to the user-provided definitions for the spec.
# </p>
# <p>See EvalMetricsMLPartialDataSourceSpec to see what values will be used for the EvalMetricsSpec#start
# and EvalMetricsSpec#end fields given various combinations of <a class="data-field documentation" data-to-id="data-field:EvalMetricsDatasetMLDataSourceSpec.start" title="field EvalMetricsDatasetMLDataSourceSpec#start" href="#data-field:EvalMetricsDatasetMLDataSourceSpec.start">start</a>, <a class="data-field documentation" data-to-id="data-field:EvalMetricsDatasetMLDataSourceSpec.end" title="field EvalMetricsDatasetMLDataSourceSpec#end" href="#data-field:EvalMetricsDatasetMLDataSourceSpec.end">end</a>, <a class="data-field documentation" data-to-id="data-field:EvalMetricsDatasetMLDataSourceSpec.startPath" title="field EvalMetricsDatasetMLDataSourceSpec#startPath" href="#data-field:EvalMetricsDatasetMLDataSourceSpec.startPath">startPath</a>,
# <a class="data-field documentation" data-to-id="data-field:EvalMetricsDatasetMLDataSourceSpec.endPath" title="field EvalMetricsDatasetMLDataSourceSpec#endPath" href="#data-field:EvalMetricsDatasetMLDataSourceSpec.endPath">endPath</a>, and <a class="data-field documentation" data-to-id="data-field:EvalMetricsDatasetMLDataSourceSpec.intervalsFromStartToEnd" title="field EvalMetricsDatasetMLDataSourceSpec#intervalsFromStartToEnd" href="#data-field:EvalMetricsDatasetMLDataSourceSpec.intervalsFromStartToEnd">intervalsFromStartToEnd</a>.
# </p>
# <p>For this type, the field <code>maskMetric</code> will behave as following:
# If specified, all data samples (each data sample corresponds to a source + time) where <code>maskMetric</code> is non-zero
# will be removed from the data.  To illustrate, if you put the data in a Dataset, the rows where the values
# in the maskMetric column (column with the maskMetric as its index) are non-zero will be removed.
# This field is usually used to remove data samples where the training labels are missing (where the "metric"
# computes whether the label is missing).</p>
# </div>
# <p class="beta-info">Beta</p><p class="private-info">Private</p><div class="mixes"><p>Mixes:</p>
# <ul class="mixes">
# <li class="mixes">Persistable&lt;EvalMetricsDatasetMLDataSourceSpec&gt;</li>
# <li class="mixes">Extendable</li>
# <li class="mixes">AbstractEvalMetricsMLDataSourceSpec&lt;Dataset, Dataset&gt;</li>
# </ul></div>
# <div class="declaration"><p>Declaration</p><pre class="declaration">/**
#  * `EvalMetricsDatasetMLDataSourceSpec` is a {@link SupervisedMLDataSourceSpec} which creates training input and target
#  * {@link Dataset}s by evaluating metrics according to the user-provided definitions for the spec.
#  *
#  * See {@link EvalMetricsMLPartialDataSourceSpec} to see what values will be used for the {@link EvalMetricsSpec#start}
#  * and {@link EvalMetricsSpec#end} fields given various combinations of {@link start}, {@link end}, {@link startPath},
#  * {@link endPath}, and {@link intervalsFromStartToEnd}.
#  *
#  * For this type, the field `maskMetric` will behave as following:
#  * If specified, all data samples (each data sample corresponds to a source + time) where `maskMetric` is non-zero
#  * will be removed from the data.  To illustrate, if you put the data in a {@link Dataset}, the rows where the values
#  * in the maskMetric column (column with the maskMetric as its index) are non-zero will be removed.
#  * This field is usually used to remove data samples where the training labels are missing (where the "metric"
#  * computes whether the label is missing).
#  */
# @beta
# extendable entity type EvalMetricsDatasetMLDataSourceSpec extends AbstractEvalMetricsMLDataSourceSpec&lt;Dataset, Dataset&gt; type key 'DS'
# </pre></div><div class="annotationDoc"><div class="annotations"><p>Annotations:</p>
# <ul class="annotations">
# <li class="annotation">@db</li>
# <li class="annotation">@beta</li>
# </ul></div>
# <pre class="annotation annotation-decl code nohighlight"><code>@db(persistable=true, extendable=true, typeKey='DS')
# @beta
# </code></pre>
# </div><div class="use"><p>Used by:</p>
# <ul class="use">
# <li class="use">EvalMetricsMLDataSourceSpec</li>
# <li class="use">MLTestDataSourceSpecTimeseries</li>
# </ul></div>
# <h2 class="section data-section">Fields</h2>
# <div id="data-field:EvalMetricsDatasetMLDataSourceSpec.persistedInputDataset" class="structure data-field">
# <h3><span class="name">persistedInputDataset</span>: PersistedTrainingDataset</h3>
# <p class="description">The persisted input dataset, if any, for this spec. When data is persisted, a copy of the spec is made and attached
# to the trained pipeline. See MLPipeline#dataSourceSpec.</p>
# <div class="declaration"><p>Declaration</p><pre class="declaration">/**
#  * The persisted input dataset, if any, for this spec. When data is persisted, a copy of the spec is made and attached
#  * to the trained pipeline. See {@link MLPipeline#dataSourceSpec}.
#  */
# persistedInputDataset: PersistedTrainingDataset
# </pre></div></div>
# <div id="data-field:EvalMetricsDatasetMLDataSourceSpec.persistedTargetDataset" class="structure data-field">
# <h3><span class="name">persistedTargetDataset</span>: PersistedTrainingDataset</h3>
# <p class="description">The persisted target dataset, if any, for this spec. When data is persisted, a copy of the spec is made and
# attached to the trained pipeline. See MLPipeline#dataSourceSpec.</p>
# <div class="declaration"><p>Declaration</p><pre class="declaration">/**
#  * The persisted target dataset, if any, for this spec. When data is persisted, a copy of the spec is made and
#  * attached to the trained pipeline. See {@link MLPipeline#dataSourceSpec}.
#  */
# persistedTargetDataset: PersistedTrainingDataset
# </pre></div></div>
# <h2 class="section data-section inherited">Fields from Persistable</h2>
# <div id="data-field:EvalMetricsDatasetMLDataSourceSpec.versionEdits" class="structure data-field inherited private">
# <h3><span class="name">versionEdits</span>: [ VersionEdit ] <span class="attributes"><span class="private">private</span><span class="inherited">inherited</span></span></h3>
# <div class="description">
# <p>Version history.  Only populated when version history is enabled.  Used for retrieving earlier versions of an Obj.
# </p>
# <p>Completely and automatically managed by the system.</p>
# </div>
# <p class="private-info">Private</p><p class="inherited-from">Inherited from Persistable&lt;EvalMetricsDatasetMLDataSourceSpec&gt;</p>
# <div class="declaration"><p>Declaration</p><pre class="declaration">versionEdits: [VersionEdit]
# </pre></div><p class="see">See Ann.Db.versionHistory</p>
# </div>
# <div id="data-field:EvalMetricsDatasetMLDataSourceSpec.name" class="structure data-field inherited">
# <h3><span class="name">name</span>: string <span class="attributes"><span class="inherited">inherited</span></span></h3>
# <p class="description">Name of the Obj instance</p>
# <p class="inherited-from">Inherited from Persistable&lt;EvalMetricsDatasetMLDataSourceSpec&gt;</p>
# <div class="declaration"><p>Declaration</p><pre class="declaration">name: string
# </pre></div></div>
# <div id="data-field:EvalMetricsDatasetMLDataSourceSpec.meta" class="structure data-field inherited">
# <h3><span class="name">meta</span>: Meta <span class="attributes"><span class="inherited">inherited</span></span></h3>
# <p class="description">Various system fields.</p>
# <p class="inherited-from">Inherited from Persistable&lt;EvalMetricsDatasetMLDataSourceSpec&gt;</p>
# <div class="declaration"><p>Declaration</p><pre class="declaration">meta: Meta
# </pre></div></div>
# <div id="data-field:EvalMetricsDatasetMLDataSourceSpec.version" class="structure data-field inherited">
# <h3><span class="name">version</span>: int <span class="attributes"><span class="inherited">inher

# %%
help(c3.MLPopulationSegment)
# Out:
# <div id="type:MLPopulationSegment" class="structure type root private">
# <h1 class="type root">Type <span class="name">MLPopulationSegment</span></h1>
# <div class="description">
# <p>An <a class="type documentation" data-to-id="type:MLPopulationSegment" title="type MLPopulationSegment" href="#type:MLPopulationSegment">MLPopulationSegment</a> represents a subset of all MLSubjects for this MLProject.
# </p>
# <a name="description"></a><h3 id="section:1.1">Description</h3>
# <p>A given MLProjectSubject belongs to a <a class="type documentation" data-to-id="type:MLPopulationSegment" title="type MLPopulationSegment" href="#type:MLPopulationSegment">MLPopulationSegment</a> if its
# subject satisfies the segment's <a class="data-field documentation" data-to-id="data-field:MLPopulationSegment.subjectFilter" title="field MLPopulationSegment#subjectFilter" href="#data-field:MLPopulationSegment.subjectFilter">subjectFilter</a>.
# A single MLSubject can satisfy the filter of multiple <a class="type documentation" data-to-id="type:MLPopulationSegment" title="type MLPopulationSegment" href="#type:MLPopulationSegment">MLPopulationSegment</a>, but will be
# assigned to the one with highest priority among these candidates.
# This belonging is materialized on the field MLProjectSubject#predictionSegment, which is populated with
# the correct value when calling MLProject#assignSegments.
# For a given MLProject, no two <a class="type documentation" data-to-id="type:MLPopulationSegment" title="type MLPopulationSegment" href="#type:MLPopulationSegment">segments</a> can have the same <a class="data-field documentation" data-to-id="data-field:MLPopulationSegment.priority" title="field MLPopulationSegment#priority" href="#data-field:MLPopulationSegment.priority">priority</a>.
# </p>
# <p>Once models have been created, they can be assigned to a <a class="type documentation" data-to-id="type:MLPopulationSegment" title="type MLPopulationSegment" href="#type:MLPopulationSegment">MLPopulationSegment</a> by creating
# MLPredictionConfiguration for this segment with MLPredictionConfiguration#predictionModels
# containing MLModel#configuration.
# These can then be deployed by calling <a class="method-field documentation" data-to-id="method-field:MLPopulationSegment.updateModels" title="field MLPopulationSegment#updateModels" href="#method-field:MLPopulationSegment.updateModels">updateModels</a>, which will create the
# relations between the project-subjects and the
# models with a status set to the
# model configuration's status.
# A MLModel can be created and deployed for a @ MLPopulationSegment from a trained pipeline using
# MLModel#createForSegment.
# </p>
# <a name="common-operations-on-an-predictive-maintenance-project-for-wind-turbines"></a><h3 id="section:1.2">Common operations on an "Predictive-Maintenance" project for wind turbines</h3>
# <p>Note: Refer to the documentation for the set up of this MLProject and its
# project subjects.
# </p>
# <p>Create a <a class="type documentation" data-to-id="type:MLPopulationSegment" title="type MLPopulationSegment" href="#type:MLPopulationSegment">MLPopulationSegment</a> for an existing MLProject and assign it to MLProjectSubject.
# </p>
# <p>We now can define a segment for our project</p>
# <pre class="code lang-Python"><code> segment = c3.MLPopulationSegment(
#       id="greaterThan4Blades",
#       priority=1,
#       subjectFilter="numBlades &gt; 4",
#       mlProject=mlProject).upsert(spec=c3.UpsertSpec(returnInclude='this'))
#  job = mlProject.assignSegments()
#  _ = job.waitForCompletion()</code></pre>
# <p>We can check the assigned project subjects by filtering on MLProjectSubjectBase#predictionSegment.
# </p>
# <pre class="code lang-Python"><code> project_subjects = c3.WindTurbineProjectSubjectDemo.fetch({
#       filter: c3.Filter().eq("mlProject",project).and_().eq("predictionSegment",segment)
#   }).objs</code></pre>
# <p>Let's now deploy a MLSerialPipeline in a MLModel. In the next snippets, <code>pipeline</code>
# refers to a trained pipeline, and <code>training_data_source_spec</code> is a MLDataSourceSpec that
# can generate the training dataset.
# </p>
# <p>A MLModel can be created and deployed for a segment from a trained pipeline using:</p>
# <pre class="code lang-Python"><code> update_job = c3.MLModel.createForSegment(trainedPipeline, segment, training_data_source_spec);
#  _ = update_job.waitForCompletion();</code></pre>
# <p>Alternatively, a MLModel can be trained for a <a class="type documentation" data-to-id="type:MLPopulationSegment" title="type MLPopulationSegment" href="#type:MLPopulationSegment">MLPopulationSegment</a> through:</p>
# <pre class="code lang-Python"><code> model = c3.MLModel.createFromPipeline(pipeline,
# training_data_source_spec,
# c3.MLModelCreateSpec(
# predictionDataSourceSpec=training_data_source_spec,
# approach=c3.MLModelSelectionApproach.MODEL_PER_SEGMENT
# ))
#  training_job = segment.train(model)
#  _ = training_job.waitForCompletion()</code></pre>
# <p>We can retrieved the trained models by filtering on MLModel#configuration.
# </p>
# <pre class="code lang-Python"><code> trained_model = c3.MLModel.fetch({
#       filter: c3.Filter().eq("pipeline.trainingStatus","TRAINED").and_().eq(
#          "configuration.id",training_job.trainedModelConfiguration.id)
#   }).objs[0] // retrieve model trained by this job,</code></pre>
# <p>A model can be assigned to a <a class="type documentation" data-to-id="type:MLPopulationSegment" title="type MLPopulationSegment" href="#type:MLPopulationSegment">MLPopulationSegment</a> and deployed through:</p>
# <pre class="code lang-Python"><code> prediction_configuration = segment.deployModels([trained_model.configuration])
#  job = segment.updateModels()
#  _ = job.waitForCompletion()
#  created_relations = c3.MLProjectSubjectToModelRelation.fetch({
#       'filter': c3.Filter().eq("from.predictionSegment",segment)
#   }).objs</code></pre>
# <p>Once a MLModel is deployed, prediction and interpretation functions can be called on the
# <a class="type documentation" data-to-id="type:MLPopulationSegment" title="type MLPopulationSegment" href="#type:MLPopulationSegment">MLPopulationSegment</a>, launching a MLPredictionJob.</p>
# <pre class="code lang-Python"><code> prediction_job = segment.predict()
#  interpretation_job = segment.interpret()
#  _ = prediction_job.waitForCompletion()
#  _ = interpretation_job.waitForCompletion()
#  prediction_series = c3.MLProjectSubjectTimedPredictionSeries.fetch({
#       filter: c3.Filter().eq("from.predictionSegment",segment)
#   }).objs</code></pre>
# <p>A new MLModel can be deployed in replacement of the previous through:</p>
# <pre class="code lang-Python"><code> newModel = c3.MLModel.createFromPipeline(pipeline,
#                                        training_data_source_spec,
#                                        c3.MLModelCreateSpec(
#                                           predictionDataSourceSpec=training_data_source_spec,
#                                           approach=c3.MLModelSelectionApproach.MODEL_PER_SUBJECT
#                                        ))
#  new_prediction_configuration = c3.MLPredictionConfiguration(
#       predictionModels= [newModel.configuration],
#       segment= segment,
#       status= c3.MLProjectSubjectModelStatus(
#                 isPrimary= True,
#                 label= c3.MLModelLabel.LIVE,
#                 timestamp= c3.DateTime.now())
#  ).upsert()
#  job = segment.replacePredictionConfiguration(prediction_configuration,new_prediction_configuration)
#  _ = job.waitForCompletion();</code></pre>
# <p>One or several MLModels deployed within a MLPredictionConfiguration can be retrained using:</p>
# <pre class="code lang-Python"><code> training_job = segment.retrainInPredictionConfiguration(prediction_configuration,
#                                                           [0],
#                                                           [new_training_data_source_spec])[0]
#  _ = training_job.waitForCompletion();
#  trained_model = c3.MLModel.fetch({
#          'filter': c3.Filter().eq("pipeline.trainingStatus","TRAINED").and_().intersects("configuration.id",
