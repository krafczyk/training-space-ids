# %% [markdown]
# # Set kernel to: `py-pythonEnv`
# If this kernel is not available, see the Kernel Installation Instructions section located in at the [bottom](#apdx)  of this Notebook.

# %% [markdown]
# # Import libraries used in this notebook:

# %%
from datetime import datetime
import pandas as pd

# %% [markdown]
# # Table of Contents

# %% [markdown]
# * [C3 Python Basics](#1)
#     * [Fetch and Filter in Python](#1.1)
#         * [A. Common Comands](#1.1A)
#         * [B. View Type Dcumentation](#1.1B)
#         * [C. Fetch Method in Python](#1.1C)
#         * [D. Evaluate Method in Python](#1.1D)
#         * [E. Other Useful Operations](#1.1E)
#     * [CRUD operations in Python](#1.2)
#     * [Prototype Methods in Python](#1.3)
#         * [A. Write code](#1.3A)
#         * [A. Test code](#1.3B)
#     * [AsyncActions](#1.4)
#
# [Appendix - Kernel Installation Instructions](#apdx)

# %% [markdown]
# # C3 Python Basics <a class="anchor" id="1">

# %% [markdown]
# We can access the C3 Type system and the data provisioned on a given Tenant and Tag using the C3 Python SDK.

# %%
c3
# Out:
# c3.TypeSystemBase(connection=ServerConnection(url='https://dev-dti.c3dti.ai', auth='XXXX', tenant='dev', tag='tc03d'))

# %% [markdown]
# If you are running this notebook within the training environments on your tag, the c3 variable connection is already set up for you. If you are running the notebook locally and would like to connect remotely to the c3 environment, you will have to configure this variable yourself using [c3Remote](https://developer.c3.ai/docs/7.28.0/guide/guide-ml-ds/ds-c3-remote).

# %% [markdown]
# ## 1. Fetching and Filtering Data in Python <a class="anchor" id="1.1">

# %% [markdown]
# ### A. Comon Commands <a class="anchor" id="1.1A">
# Some useful operations/commands for Jupyter Notebooks and the JS Console.

# %% [markdown]
# #### Generic Type System Calls:
# -  `c3.Type.method(...)`
#
# | Use Case | Jupyter Notebook Command | JS Console Command |
# | --- | --- | --- |
# |View Documentation on `MyType` | help(c3.MyType) | c3ShowType(MyType) |
#     |View Documentation on a `MyType` method | help(c3.MyType.myMethod) | N/A |
# | Find the number `MyType` records| c3.MyType.fetchCount() | c3Count(MyType) |
# | Fetch `MyType` records| c3.MyType.fetch()| MyType.fetch() |
# | Fetch `MyType` records in a table| pd.DataFrame(c3.MyType.fetch().objs.toJson()) ${^\dagger}$ | c3Grid(MyType.fetch())|
# | Fetch `MyType` records in a table with filters | c3.MyType.fetch(spec={'filter':" ... "})${^\ddagger}$ | c3Grid(MyType.fetch({filter: " ... "})) |
#
# > ${^\dagger}$ - Instead of using a C3 function, you can use a `pandas` `DataFrame`.
#
# > ${^\ddagger}$ - Notice the extra single-quote around `filter`, and assigning the variable `spec` in the JSON-object, this is the `FetchSpec`. Run `help(c3.FetchSpec)` in Jupyter for more details.

# %% [markdown]
# ### B. View Type Dcumentation:<a class="anchor" id="1.1B">
#
# We can view Type documentation directly in our Jupyter notebook (as well as in the console as you saw earlier).
#
# Use `help(c3.MyType)` to see Type Documentation.

# %%
help(c3.FetchSpec)
# Out:
# <div id="type:FetchSpec" class="structure type root">
# <h1 class="type root">Type <span class="name">FetchSpec</span></h1>
# <p class="description">Specification of which Objs to bring back and which fields to bring back in them for a Persistable#fetch call.</p>
# <p class="mixes">Mixes FetchFilterSpec</p>
# <div class="declaration"><p>Declaration</p><pre class="declaration">/**
#  * Specification of which Objs to bring back and which fields to bring back in them for a {@link Persistable.fetch} call.
#  */
# type FetchSpec mixes FetchFilterSpec
# </pre></div><div class="use"><p>Used by:</p>
# <ul class="use">
# <li class="use">FetchStreamSpec</li>
# <li class="use">MarketplacePackageRecursiveFetchSpec</li>
# <li class="use">MarketplaceRecursiveFetchSpec</li>
# <li class="use">MultiLocaleFetchSpec</li>
# <li class="use">PerfMetricRawMetricsSpec</li>
# <li class="use">QueueAdminFetchSpec</li>
# <li class="use">AdminGroup#allRoles</li>
# <li class="use">AdminGroup#allUsers</li>
# <li class="use">ApplicationAlert#fetchSourceObjectSpecificAlerts</li>
# <li class="use">ApplicationAlertSourcePreference#getPreferences</li>
# <li class="use">AsyncAction#allFailed</li>
# <li class="use">ClusterReporter#fetchAlerts</li>
# <li class="use">DataIntegrationUtil#fetchSourceFilesWithFileNames</li>
# <li class="use">DataModelUtil#getSampleDataGridData</li>
# <li class="use">DataMonitoringUtil#fetchSourceCollectionNotificationLogs</li>
# <li class="use">DataMonitoringUtil#fetchSourceFileErrors</li>
# <li class="use">DataMonitoringUtil#fetchSourceFileObjectsCreatedInfo</li>
# <li class="use">DataMonitoringUtil#fetchSourceFiles</li>
# <li class="use">DataProfileDetailsPageUtil#getQualityTabGridData</li>
# <li class="use">DataProfileGridUtil#getDataProfileGridRows</li>
# <li class="use">DataProfilePageSampleDataAndDataProfileGridUtil#getSampleDataGridData</li>
# <li class="use">DataProfilePageUtil#profileHistoryGridData</li>
# <li class="use">DeploymentUiHelper#fetch</li>
# <li class="use">EnvReport#remoteFetchEnvLogs</li>
# <li class="use">ExternalMapping#fetchTransformedExternalMappings</li>
# <li class="use">FetchHelper#applyFetchTransforms</li>
# <li class="use">FetchSourceSpec#createNdArraySourceSpec</li>
# <li class="use">Fetchable#fetch</li>
# <li class="use">GenericFileData#fetch</li>
# <li class="use">GitHubAPI#getCommitDetails</li>
# <li class="use">GuardInstance#fetch</li>
# <li class="use">JupyterNotebookVersion#fetchVersions</li>
# <li class="use">MLAsset#customFetch</li>
# <li class="use">MLAsset#fetchByType</li>
# <li class="use">MLAsset#getRecentAssets</li>
# <li class="use">MLAsset#sortAssets</li>
# <li class="use">MLAutoTunerResult#fetch</li>
# <li class="use">MLConfigurationsHelper#fetch</li>
# <li class="use">MLModel#fetchGrid</li>
# <li class="use">MarketplacePackage#fetchPackagesWithServerVersion</li>
# <li class="use">MarketplacePackage#mergeFetchResults</li>
# <li class="use">MarketplacePackageUtil#fetchMarketplaceObjects</li>
# <li class="use">MarketplacePackageUtil#fetchMarketplacePackagePurchases</li>
# <li class="use">MetadataUtil#getMetadataIssues</li>
# <li class="use">NlpCorpus#fetchLexemes</li>
# <li class="use">NotebooksHelper#fetch</li>
# <li class="use">NotebooksHelper#fetchNotebookMarkup</li>
# <li class="use">NotificationLog#fetchVisibleLogs</li>
# <li class="use">PackageManager#fetchAppsBuilds</li>
# <li class="use">PackageManager#fetchBranches</li>
# <li class="use">PackageManager#fetchFileCodeAnalysisResult</li>
# <li class="use">PackageManager#fetchMetadataRepositoryStores</li>
# <li class="use">PackageManager#fetchPackageBuildCodeAnalysisResult</li>
# <li class="use">PackageManager#fetchPackageStores</li>
# <li class="use">PackageManager#fetchRepositoryBuilds</li>
# <li class="use">Persistable#profileData</li>
# <li class="use">PersistableFetchable#fetchOvi</li>
# <li class="use">ResourceProfileHelper#fetchProfile</li>
# <li class="use">ResourceProfileHelper#fetchProfiles</li>
# <li class="use">Role#allGroups</li>
# <li class="use">Role#allUsers</li>
# <li class="use">RuntimeHelper#getRepositoriesByRuntime</li>
# <li class="use">RuntimeHelper#getRuntimesAsArray</li>
# <li class="use">RuntimeLibrary#getLibraries</li>
# <li class="use">SampleDataUtil#getSampleData</li>
# <li class="use">SampleDataUtil#readSourceCollectionData</li>
# <li class="use">SegmentsHelper#fetch</li>
# <li class="use">SegmentsHelper#getMergeableSegments</li>
# <li class="use">SourceCollectionNotificationLogsProxy#fetch</li>
# <li class="use">SourceCollectionStatNotification#getSourceCollectionNotifications</li>
# <li class="use">SourceFileFetchProxy#fetch</li>
# <li class="use">SourceFileStatNotification#getSourceFileNotifications</li>
# <li class="use">SourceSystemInfo#fetchSourceSystemInfo</li>
# <li class="use">SqlInvalidationQueueEntry#fetch</li>
# <li class="use">Tag#tags</li>
# <li class="use">Tenant#tenants</li>
# <li class="use">Tenant#tenantsTags</li>
# <li class="use">TestApiEntityType#fetchOtherType</li>
# <li class="use">TestApiEntityType#fetchOtherTypeAsArray</li>
# <li class="use">TestApiEntityType#fetchThisType</li>
# <li class="use">UiMetadataUtil#getUiComponents</li>
# <li class="use">UiMetadataUtil#getUiComponentsWithPages</li>
# <li class="use">UiMetadataUtil#getUiDesignerableComponentsWithPages</li>
# <li class="use">UserApplicationAlertSourcePreference#getPreferences</li>
# <li class="use">VADProject#fetchDetails</li>
# <li class="use">VanityUrlStatNotification#getVanityUrlNotifications</li>
# <li class="use">Versionable#allVersions</li>
# </ul></div>
# <h2 class="section data-section">Fields</h2>
# <div id="data-field:FetchSpec.include" class="structure data-field">
# <h3><span class="name">include</span>: string</h3>
# <div class="description">
# <p>Specifies which fields to bring back values for in the returned Obj instances.  Include specifications are
# logically a list of field paths.  The following examples illustrate the supported ways to specify them:
# </p>
# <ul>
# <li>Simple list of fields - "[field1, field2, field3]"
# </li>
# <li>List of fields involving references and non-reference fields - "[refField1.name, refField1.refField2.name]"
# </li>
# <li>Same as above with Obj notation - "[{refField1: [name, {refField2: [name]}]}]"
# </li>
# <li>
# <p>Using array/mapp '[index/key]' references
# </p>
# <p>[arrayField[1]] - Array element with key '1'
# </p>
# <p>[mappField['k1']] - Mapp element with key 'k1'
# </p>
# <p>[fkeyArrayField[1] - Fkey array element at offset '1'
# </p>
# <p>[arrayField[1].(name == 'foo')] Array element with key '1' if it matches name filter
# </p>
# <p>[arrayField.(name == 'foo')[1]] array element with offset '1' that matches name filter
# </p>
# </li>
# <li>Return all fields in obj - Either not specified or "[this]"  Note that for external references, only the ids are
# returned unless an explicit include indicates that data from the reference should be returned (see below).
# Also, fkey fields (e.g. fields defined like arry: SomeType(fkeyField)) are also only brought back if specifically
# included.
# </li>
# <li>Using dot query to filter arry/mapp results - "[refArry.(name == 'foo')]" or "[{refArry: [id]}.(name == 'foo')]"</li>
# </ul>
# </div>
# <div class="declaration"><p>Declaration</p><pre class="declaration">/**
#  * Specifies which fields to bring back values for in the returned Obj instances.  Include specifications are
#  * logically a list of field paths.  The following examples illustrate the supported ways to specify them:
#  *
#  * - Simple list of fields - "[field1, field2, field3]"
#  *
#  * - List of fields involving references and non-reference fields - "[refField1.name, refField1.refField2.name]"
#  *
#  * - Same as above with Obj notation - "[{refField1: [name, {refField2: [name]}]}]"
#  *
#  * - Using array/mapp '[index/key]' references
#  *
#  *   [arrayField[1]] - Array element with key '1'
#  *
#  *   [mappField['k1']] - Mapp element with key 'k1'
#  *
#  *   [fkeyArrayField[1] - Fkey array element at offset '1'
#  *
#  *   [arrayField[1].(name == 'foo')] Array element with key '1' if it matches name filter
#  *
#  *   [arrayField.(name == 'foo')[1]] array element with offset '1' that matches name filter
#  *
#  * - Return all fields in obj - Either not specified or "[this]"  Note t

# %%
help(c3.MyEntityType) # view the documentation on an entity Type of your choice from the Entity Relation Diagram
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-e4bdb6c38fee> in <module>
# ----> 1 help(c3.MyEntityType) # view the documentation on an entity Type of your choice from the Entity Relation Diagram
#
# Z10ac078826d8534179d455db1588a325M_/TypeSystemBase.py in __getattr__(self, item)
#
# Z10ac078826d8534179d455db1588a325M_/TypeSystemBase.py in __getattr__(self, item)
#
# Z10ac078826d8534179d455db1588a325M_/TypeSystemBase.py in _load_type_closure(self, type_name)
#
# Z10ac078826d8534179d455db1588a325M_/TypeSystemBase.py in _get_type_closure(self, type_name)
#
# Z10ac078826d8534179d455db1588a325M_/TypeSystemBase.py in _request_closure(self, type_name)
#
# Z10ac078826d8534179d455db1588a325M_/ServerConnection.py in _request_type_closure(self, type_name, client_side_type_inference)
#
# AttributeError: Type 'MyEntityType' not found for tenant 'dev' tag 'tc03d'

# %% [markdown]
# #### View Method Documentation:
# Use `help(c3.MyType.myMethod)` to view documentation for a specific method on a Type.

# %%
help(c3.Persistable.fetch)
# Out:
# <div id="method-field:Persistable.fetch" class="structure method-field root inherited">
# <h1><span class="name">fetch</span>(spec): FetchResult&lt;mixing Persistable&gt; <span class="attributes"><span class="static">static</span><span class="inherited">inherited</span></span></h1>
# <p class="description">Fetches multiple obj instances based on a specification.  Only objs that the caller is authorized to fetch will be
# returned.</p>
# <p class="inherited-from">Inherited from Fetchable</p>
# <p class="auth-group">Auth Group <code>read</code></p>
# <div class="parameters"><h2>Parameters:</h2>
# <ol>
# <li class="parameter optional"><span class="name">spec</span>: FetchSpec
# <p class="description">Specification of what data to fetch.  If not specified, no filtering will be applied and a default limit
# of 2000 will be applied.</p>
# </li>
# </ol></div>
# <div class="returns"><h2>Returns FetchResult&lt;mixing Persistable&gt; <span class="attributes"><span class="required">required</span></span></h2>
# <p class="description">Requested objs.</p>
# </div><div class="declaration"><p>Declaration</p><pre class="declaration">fetch: function(spec: FetchSpec): !FetchResult&lt;mixing Persistable&gt;
# </pre></div></div>

# %% [markdown]
# ### C. Fetch Method in Python <a class='anchor' id='1.1C'>

# %% [markdown]
# To view what records exist for a given Type, we can execute a `.fetch()` query on entity (Persistable aka Entity) Types. Why Persistable/Entity Types? Because by definition, those are the Types that have a datatable attached to them.

# %% [markdown]
# #### Simple Fetch:
# Use `c3.MyType.fetch()` to get data with the standard fields

# %%
c3.City.fetch()
# Out:
# c3.FetchResult<City>(
#  objs=c3.Arry<City>([c3.City(
#          id='EPA',
#          name='East Palo Alto',
#          meta=c3.Meta(
#                 tenantTagId=152,
#                 tenant='dev',
#                 tag='tc03d',
#                 created=datetime.datetime(2022, 6, 19, 22, 56, 57, tzinfo=datetime.timezone.utc),
#                 createdBy='provisioner',
#                 updated=datetime.datetime(2022, 6, 19, 22, 56, 57, tzinfo=datetime.timezone.utc),
#                 updatedBy='provisioner',
#                 timestamp=datetime.datetime(2022, 6, 19, 22, 56, 57, tzinfo=datetime.timezone.utc),
#                 fetchInclude='[]',
#                 fetchType='City'),
#          version=1,
#          latitude=37.4688,
#          longitude=-122.1411),
#         c3.City(
#          id='MPK',
#          name='Menlo Park',
#          meta=c3.Meta(
#                 tenantTagId=152,
#                 tenant='dev',
#                 tag='tc03d',
#                 created=datetime.datetime(2022, 6, 19, 22, 56, 57, tzinfo=datetime.timezone.utc),
#                 createdBy='provisioner',
#                 updated=datetime.datetime(2022, 6, 19, 22, 56, 57, tzinfo=datetime.timezone.utc),
#                 updatedBy='provisioner',
#                 timestamp=datetime.datetime(2022, 6, 19, 22, 56, 57, tzinfo=datetime.timezone.utc),
#                 fetchInclude='[]',
#                 fetchType='City'),
#          version=1,
#          latitude=37.453,
#          longitude=-122.1817),
#         c3.City(
#          id='RWC',
#          name='Redwood City',
#          meta=c3.Meta(
#                 tenantTagId=152,
#                 tenant='dev',
#                 tag='tc03d',
#                 created=datetime.datetime(2022, 6, 19, 22, 56, 57, tzinfo=datetime.timezone.utc),
#                 createdBy='provisioner',
#                 updated=datetime.datetime(2022, 6, 19, 22, 56, 57, tzinfo=datetime.timezone.utc),
#                 updatedBy='provisioner',
#                 timestamp=datetime.datetime(2022, 6, 19, 22, 56, 57, tzinfo=datetime.timezone.utc),
#                 fetchInclude='[]',
#                 fetchType='City'),
#          version=1,
#          latitude=37.4848,
#          longitude=-122.2281),
#         c3.City(
#          id='SCL',
#          name='San Carlos',
#          meta=c3.Meta(
#                 tenantTagId=152,
#                 tenant='dev',
#                 tag='tc03d',
#                 created=datetime.datetime(2022, 6, 19, 22, 56, 57, tzinfo=datetime.timezone.utc),
#                 createdBy='provisioner',
#                 updated=datetime.datetime(2022, 6, 19, 22, 56, 57, tzinfo=datetime.timezone.utc),
#                 updatedBy='provisioner',
#                 timestamp=datetime.datetime(2022, 6, 19, 22, 56, 57, tzinfo=datetime.timezone.utc),
#                 fetchInclude='[]',
#                 fetchType='City'),
#          version=1,
#          latitude=37.5072,
#          longitude=-122.2605)]),
#  count=4,
#  hasMore=False)

# %%
c3.MyChosenEntityType.fetch()# fetch another entity Type of your choice from the Entity Relation Diagram
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_2536/98230568.py in <module>
# ----> 1 c3.MyChosenEntityType.fetch()# fetch another entity Type of your choice from the Entity Relation Diagram
#
# Z10ac078826d8534179d455db1588a325M_/TypeSystemBase.py in __getattr__(self, item)
#
# Z10ac078826d8534179d455db1588a325M_/TypeSystemBase.py in __getattr__(self, item)
#
# Z10ac078826d8534179d455db1588a325M_/TypeSystemBase.py in _load_type_closure(self, type_name)
#
# Z10ac078826d8534179d455db1588a325M_/TypeSystemBase.py in _get_type_closure(self, type_name)
#
# Z10ac078826d8534179d455db1588a325M_/TypeSystemBase.py in _request_closure(self, type_name)
#
# Z10ac078826d8534179d455db1588a325M_/ServerConnection.py in _request_type_closure(self, type_name, client_side_type_inference)
#
# AttributeError: Type 'MyChosenEntityType' not found for tenant 'dev' tag 'tc03d'

# %% [markdown]
# #### Fetch and Dislpay in a Pandas DataFrame:
# Use `.objs.toJson()` to get a fetch result in an array for a json and wrap that with `pd.DataFrame` to plot a table as a pandas dataframe.

# %%
myFetchResult = c3.City.fetch()

pd.DataFrame(myFetchResult.objs.toJson())
# Out:
#    type   id            name  \
# 0  City  EPA  East Palo Alto
# 1  City  MPK      Menlo Park
# 2  City  RWC    Redwood City
# 3  City  SCL      San Carlos
#
#                                                 meta  version  latitude  \
# 0  {'type': 'Meta', 'tenantTagId': 152, 'tenant':...        1   37.4688
# 1  {'type': 'Meta', 'tenantTagId': 152, 'tenant':...        1   37.4530
# 2  {'type': 'Meta', 'tenantTagId': 152, 'tenant':...        1   37.4848
# 3  {'type': 'Meta', 'tenantTagId': 152, 'tenant':...        1   37.5072
#
#    longitude
# 0  -122.1411
# 1  -122.1817
# 2  -122.2281
# 3  -122.2605

# %% [markdown]
# #### Fetch Count:
# There are additional fetch-related methods, such as `c3.MyType.fetchCount()`, that you can explore in the documentation.

# %%
c3.City.fetchCount()
# Out:
# 4

# %% [markdown]
# #### Fancy Fetches:
# You can refine your fetch query to only return certain records by using a fetchSpec. This allows you, for example, to limit the number of results, filter the data to be returned, or order the data by a particular column (see `help(c3.FetchSpec)` to read about more options).

# %%
help(c3.ExpressionEngineFunction)

# %%
myFetchResult = c3.City.fetch(spec={
#                                       'limit': 2,
#                                       'include': 'latitude',
#                                       'include': 'buildings',
#                                       'order': "ascending(latitude)",
                                      'filter': "contains(name, 'e')"
                                 })

pd.DataFrame(myFetchResult.objs.toJson())
# Out:
#    type   id          name                                               meta  \
# 0  City  MPK    Menlo Park  {'type': 'Meta', 'tenantTagId': 152, 'tenant':...
# 1  City  RWC  Redwood City  {'type': 'Meta', 'tenantTagId': 152, 'tenant':...
#
#    version  latitude  longitude
# 0        1   37.4530  -122.1817
# 1        1   37.4848  -122.2281

# %% [markdown]
# ### Use This Space for "CHALLENGE: Fetch and Filter in Jupyter"
#
#     Add additional cells as needed.

# %% [markdown]
# ### D. Evaluate Method in Python <a class="anchor" id="1.1D">

# %% [markdown]
# The `evaluate` method can be used similarly to a fetch. It returns tuples, so in order to view the results, you will have to access the tuples instead of the objs.

# %% [markdown]
# Use `c3.MyType.evaluate(spec={'projection':"myField, myFunction"}).tuples`

# %%
c3.City.evaluate(spec = {
                             'projection':"name, latitude, longitude",
#                              'filter': "id == 'RWC'",#" && myOtherField == 'myOtherString'",
#                              'group':"name",
                             "order":"ascending(name)",
                             #'limit': 10,
                             #'offset': 5
                        }).tuples
# Out:
# c3.Arry<Tuple>([c3.Tuple(
#   cells=c3.Arry<Cell>([c3.Cell(str='East Palo Alto'),
#           c3.Cell(number=37.4688),
#           c3.Cell(number=-122.1411)])),
#  c3.Tuple(
#   cells=c3.Arry<Cell>([c3.Cell(str='Menlo Park'),
#           c3.Cell(number=37.453),
#           c3.Cell(number=-122.1817)])),
#  c3.Tuple(
#   cells=c3.Arry<Cell>([c3.Cell(str='Redwood City'),
#           c3.Cell(number=37.4848),
#           c3.Cell(number=-122.2281)])),
#  c3.Tuple(
#   cells=c3.Arry<Cell>([c3.Cell(str='San Carlos'),
#           c3.Cell(number=37.5072),
#           c3.Cell(number=-122.2605)]))])

# %% [markdown]
# Additionally, with `evaluate`, you can navigate between Types when fetching data, so that you can pull data from more distant (i.e. not directly connected) Types. Compare using a `fetch` to using `evaluate`:

# %%
viewBuildingsInTheCity = c3.City.fetch(spec={
#                                       'limit': -1,
                                      'include': 'buildings',
#                                       'order': "ascending(latitude)",
#                                       'filter': "contains(name, 'e')"
                                 })

pd.DataFrame(viewBuildingsInTheCity.objs.toJson())
# Out:
#    type   id                                               meta  version  \
# 0  City  EPA  {'type': 'Meta', 'fetchInclude': '[{buildings:...        1
# 1  City  MPK  {'type': 'Meta', 'fetchInclude': '[{buildings:...        1
# 2  City  RWC  {'type': 'Meta', 'fetchInclude': '[{buildings:...        1
# 3  City  SCL  {'type': 'Meta', 'fetchInclude': '[{buildings:...        1
#
#                                            buildings
# 0  [{'type': 'Building', 'id': 'bld3', 'meta': {'...
# 1  [{'type': 'Building', 'id': 'bld5', 'meta': {'...
# 2  [{'type': 'Building', 'id': 'bld1', 'meta': {'...
# 3  [{'type': 'Building', 'id': 'bld7', 'meta': {'...

# %%
viewApartmentsInTheCity = c3.City.evaluate(spec={
                                                'projection': 'buildings.apartments',
                                                'filter': "contains(name, 'San')"
                                 })

viewApartmentsInTheCity.tuples
# Out:
# c3.Arry<Tuple>([c3.Tuple(
#   cells=c3.Arry<Cell>([c3.Cell(
#            obj=c3.Apartment(
#                  id='apt20',
#                  meta=c3.Meta(
#                         fetchInclude='[id,building,version]',
#                         fetchType='Apartment'),
#                  version=1,
#                  building=c3.Building(id='bld7')))])),
#  c3.Tuple(
#   cells=c3.Arry<Cell>([c3.Cell(
#            obj=c3.Apartment(
#                  id='apt21',
#                  meta=c3.Meta(
#                         fetchInclude='[id,building,version]',
#                         fetchType='Apartment'),
#                  version=1,
#                  building=c3.Building(id='bld7')))])),
#  c3.Tuple(
#   cells=c3.Arry<Cell>([c3.Cell(
#            obj=c3.Apartment(
#                  id='apt22',
#                  meta=c3.Meta(
#                         fetchInclude='[id,building,version]',
#                         fetchType='Apartment'),
#                  version=1,
#                  building=c3.Building(id='bld7')))])),
#  c3.Tuple(
#   cells=c3.Arry<Cell>([c3.Cell(
#            obj=c3.Apartment(
#                  id='apt23',
#                  meta=c3.Meta(
#                         fetchInclude='[id,building,version]',
#                         fetchType='Apartment'),
#                  version=1,
#                  building=c3.Building(id='bld8')))])),
#  c3.Tuple(
#   cells=c3.Arry<Cell>([c3.Cell(
#            obj=c3.Apartment(
#                  id='apt24',
#                  meta=c3.Meta(
#                         fetchInclude='[id,building,version]',
#                         fetchType='Apartment'),
#                  version=1,
#                  building=c3.Building(id='bld8')))])),
#  c3.Tuple(
#   cells=c3.Arry<Cell>([c3.Cell(
#            obj=c3.Apartment(
#                  id='apt25',
#                  meta=c3.Meta(
#                         fetchInclude='[id,building,version]',
#                         fetchType='Apartment'),
#                  version=1,
#                  building=c3.Building(id='bld8')))]))])

# %% [markdown]
# We've written a helper function for you to convert these tuples to a pandas dataframe.

# %%
def evaluate_projection(c3_type, projection_dict, column_name = [], ignore_ref = True):
    """
    evaluate_projection(c3_type, projection_dict, column_name = [])
    evalaute_projection_data unpack data from evalaute projection to pandas dataframe
    parameters
    ----------
    c3_type : c3.Type
        Type to evalaute projection
    projection_dict : dict
        A dictionary contain projection details 
    column_name : [string], default = []
        A list of string contains column name for projection. If not specified, 
        the function extract columns name from column header. 
    ignore_ref : bool, default = True
        if ignore_ref is True, the return data frame will unpack the reference column. In other words,
        instead of getting c3.PhysicalAsset(id: "abcd"), you will get "abcd"
    returns
    -------
    df : pandas dataframe
        output of evalaute projection 
    examples
    --------
    >>> projection_dict = {'projection': "assetId, count())",
                             'group': 'assetId',
                             'filter': "startsWith(workOrderType, '{}')".format('correction')}
    >>> c3_type = c3.WorkOrder 
    >>> evaluate_projection(c3_type, projection_dict)
        assetId    count()
    0   ABHDG        5
    1   UUYSH101B   10
    """
    import pandas as pd
    import warnings 
    import re
    #Input check#
    if not isinstance(c3_type, c3.Type):
        raise ValueError("The input c3_type is not c3.Type (e.g., c3.PhysicalAsset)")
    if len(column_name) != 0:
        nCol = len(projection_dict['projection'].split(","))
        if nCol != len(column_name):
            raise ValueError("Number of column names in column_name are not equal to number of projections")
    if not "projection" in projection_dict:
        raise ValueError("projection_dict must contain 'projection' as one of the key")
    #### Evaluate projection ####
    data = c3_type.evaluate(projection_dict)
    if data.count == 0:
        warnings.warn("No output from evalaute projection")
        return pd.DataFrame([])
    N = len(data.tuples[0].cells)          #number of projection's columns 
    #one line of unpack data 
    df = pd.DataFrame([[x.cells[i].value() for x in data.tuples] for i in range(N)]).transpose()
    #unpack reference columns (Forien key column)
    if ignore_ref == True:
        for i in range(N):
            if "c3." in str(type(df.iloc[0, i])):
                df[i] = df[i].apply(lambda x: [list(x) for x in zip(*x.__dict__.items())][-1][0])    
    #Renaming column 
    if len(column_name) == 0:
        r = re.compile(r'(?:[^,(]|\([^)]*\))+')
        column_name = r.findall(projection_dict['projection'])
    rename_dict = {k: v for (k, v) in zip(range(N), column_name)}
    df.rename(rename_dict, axis = 1, inplace = True) 
    return df

# %%
projection_dict = {
                    'projection': 'buildings.apartments',
                    'filter': "contains(name, 'San')"
                  }
c3_type = c3.City

# %%
evaluate_projection(c3_type, projection_dict)
# Out:
#   buildings.apartments
# 0                apt20
# 1                apt21
# 2                apt22
# 3                apt23
# 4                apt24
# 5                apt25

# %% [markdown]
# In addition, queries with `evaluate` can also be used to show the results of transformations, e.g. mathematical operations, on a field.

# %%
projection_dict = {
                         'projection':"name, latitude, cos(latitude), longitude, 3*longitude",
#                          'filter': "contains(name,'a')",
                         #'group':"myField",
#                          "order":"ascending(name)",
                         #'limit': 10,
                         #'offset': 5
                  }
c3_type = c3.City

# %%
evaluate_projection(c3_type, projection_dict)
# Out:
#              name  latitude  cos(latitude)  longitude  3*longitude
# 0  East Palo Alto   37.4688       0.973595  -122.1411    -366.4233
# 1      Menlo Park    37.453       0.969867  -122.1817    -366.5451
# 2    Redwood City   37.4848       0.977123  -122.2281    -366.6843
# 3      San Carlos   37.5072       0.981641  -122.2605    -366.7815

# %% [markdown]
# **WARNING** `evaluate` displays some odd behavior when returning projected nested arrays. If the results contain multiple "levels" (e.g one City [top level] has many Buildings [nested level], which have many Apartments [nested-nested-level]), then the projection will "cut off" at the top level. Compare the following `evaluation`s:

# %%
projection_dict = {
                    'projection': 'name, buildings, buildings.apartments',
#                     'filter': "contains(name, 'e')"
                  }
c3_type = c3.City

# %%
evaluate_projection(c3_type, projection_dict)
# only returning the "top level", so the first Building in the City and the first Apartment in that Building

# %%
projection_dict = {
                    'projection': 'buildings.apartments',
#                     'filter': "contains(name, 'e')"
                  }
c3_type = c3.City

# %%
evaluate_projection(c3_type, projection_dict)
# returning all of the Apartments that are in a City (all of them)

# %% [markdown]
# ### Use This Space for "CHALLENGE: Evaluate Method in Jupyter"
#
#     Add additional cells as needed.
#
#     Hint: You may want to run `help(c3.MyEntityType)` or use the ERD if you're not sure what the fields on a Type
#     are called!

# %%
help(c3.SmartBulbMeasurement)
# Out:
# <div id="type:SmartBulbMeasurement" class="structure type root">
# <h1 class="type root">Type <span class="name">SmartBulbMeasurement</span></h1>
# <p class="description">SmartBulbMeasurement.c3typ
# A measurement taken from a single SmartBulb</p>
# <div class="mixes"><p>Mixes:</p>
# <ul class="mixes">
# <li class="mixes">Persistable&lt;SmartBulbMeasurement&gt;</li>
# <li class="mixes">TimedDataPoint&lt;SmartBulbMeasurementSeries&gt;</li>
# </ul></div>
# <div class="declaration"><p>Declaration</p><pre class="declaration">/**
#  * SmartBulbMeasurement.c3typ
#  * A measurement taken from a single {@link SmartBulb}
#  */
# @db(datastore='cassandra',
#     partitionKeyField='parent',
#     persistenceOrder='start',
#     persistDuplicates=false,
#     compactType=true)
# entity type SmartBulbMeasurement mixes TimedDataPoint&lt;SmartBulbMeasurementSeries&gt; schema name 'SMRT_BLB_MSRMNT'
# </pre></div><div class="annotationDoc"><div class="annotations"><p>Annotations:</p>
# <ul class="annotations">
# <li class="annotation">@db</li>
# <li class="annotation">@schema</li>
# </ul></div>
# <pre class="annotation annotation-decl code nohighlight"><code>@db(datastore='cassandra',
#     partitionKeyField='parent',
#     persistenceOrder='start',
#     persistDuplicates=false,
#     compactType=true,
#     persistable=true)
# @schema(name='SMRT_BLB_MSRMNT')
# </code></pre>
# </div><p class="use">Used by TransformSourceSmartBulbMeasurementToSmartBulbMeasurement</p>
# <h2 class="section data-section">Fields</h2>
# <div id="data-field:SmartBulbMeasurement.status" class="structure data-field">
# <h3><span class="name">status</span>: int</h3>
# <p class="description">The status of the smart bulb (on or off)</p>
# <div class="declaration"><p>Declaration</p><pre class="declaration">// The status of the smart bulb (on or off)
# @ts(treatment='previous')
# status: int
# </pre></div><div class="annotationDoc"><p class="annotation">Annotation @ts</p>
# <pre class="annotation annotation-decl code nohighlight"><code>@ts(treatment='previous')
# </code></pre>
# </div></div>
# <div id="data-field:SmartBulbMeasurement.power" class="structure data-field">
# <h3><span class="name">power</span>: double</h3>
# <p class="description">The measured power (P=IV or current <em> voltage)</em></p>
# <div class="declaration"><p>Declaration</p><pre class="declaration">// The measured power (P=IV or current * voltage)
# @ts(unitPath='parent.smartBulb.powerUOM', treatment='sum')
# power: double
# </pre></div><div class="annotationDoc"><p class="annotation">Annotation @ts</p>
# <pre class="annotation annotation-decl code nohighlight"><code>@ts(unitPath='parent.smartBulb.powerUOM', treatment='sum')
# </code></pre>
# </div></div>
# <div id="data-field:SmartBulbMeasurement.lumens" class="structure data-field">
# <h3><span class="name">lumens</span>: double</h3>
# <p class="description">The measured light output</p>
# <div class="declaration"><p>Declaration</p><pre class="declaration">// The measured light output
# @ts(unitPath='parent.smartBulb.lumensUOM', treatment='avg')
# lumens: double
# </pre></div><div class="annotationDoc"><p class="annotation">Annotation @ts</p>
# <pre class="annotation annotation-decl code nohighlight"><code>@ts(unitPath='parent.smartBulb.lumensUOM', treatment='avg')
# </code></pre>
# </div></div>
# <div id="data-field:SmartBulbMeasurement.voltage" class="structure data-field">
# <h3><span class="name">voltage</span>: double</h3>
# <p class="description">The measured voltage.</p>
# <div class="declaration"><p>Declaration</p><pre class="declaration">// The measured voltage.
# @ts(unitPath='parent.smartBulb.voltageUOM', treatment='avg')
# voltage: double
# </pre></div><div class="annotationDoc"><p class="annotation">Annotation @ts</p>
# <pre class="annotation annotation-decl code nohighlight"><code>@ts(unitPath='parent.smartBulb.voltageUOM', treatment='avg')
# </code></pre>
# </div></div>
# <div id="data-field:SmartBulbMeasurement.temperature" class="structure data-field">
# <h3><span class="name">temperature</span>: double</h3>
# <p class="description">The measured temperature.</p>
# <div class="declaration"><p>Declaration</p><pre class="declaration">// The measured temperature.
# @ts(unitPath='parent.smartBulb.temperatureUOM', treatment='avg')
# temperature: double
# </pre></div><div class="annotationDoc"><p class="annotation">Annotation @ts</p>
# <pre class="annotation annotation-decl code nohighlight"><code>@ts(unitPath='parent.smartBulb.temperatureUOM', treatment='avg')
# </code></pre>
# </div></div>
# <h2 class="section data-section inherited">Fields from Persistable</h2>
# <div id="data-field:SmartBulbMeasurement.id" class="structure data-field inherited">
# <h3><span class="name">id</span>: string <span class="attributes"><span class="inherited">inherited</span></span></h3>
# <p class="description">Unique id that can either be manually specified or automatically generated during object creation.  Can't be
# changed once instance is persisted.</p>
# <p class="inherited-from">Inherited from Persistable&lt;SmartBulbMeasurement&gt;</p>
# <div class="declaration"><p>Declaration</p><pre class="declaration">id: string
# </pre></div></div>
# <div id="data-field:SmartBulbMeasurement.versionEdits" class="structure data-field inherited private">
# <h3><span class="name">versionEdits</span>: [ VersionEdit ] <span class="attributes"><span class="private">private</span><span class="inherited">inherited</span></span></h3>
# <div class="description">
# <p>Version history.  Only populated when version history is enabled.  Used for retrieving earlier versions of an Obj.
# </p>
# <p>Completely and automatically managed by the system.</p>
# </div>
# <p class="private-info">Private</p><p class="inherited-from">Inherited from Persistable&lt;SmartBulbMeasurement&gt;</p>
# <div class="declaration"><p>Declaration</p><pre class="declaration">versionEdits: [VersionEdit]
# </pre></div><p class="see">See Ann.Db.versionHistory</p>
# </div>
# <div id="data-field:SmartBulbMeasurement.name" class="structure data-field inherited">
# <h3><span class="name">name</span>: string <span class="attributes"><span class="inherited">inherited</span></span></h3>
# <p class="description">Name of the Obj instance</p>
# <p class="inherited-from">Inherited from Persistable&lt;SmartBulbMeasurement&gt;</p>
# <div class="declaration"><p>Declaration</p><pre class="declaration">name: string
# </pre></div></div>
# <div id="data-field:SmartBulbMeasurement.meta" class="structure data-field inherited">
# <h3><span class="name">meta</span>: Meta <span class="attributes"><span class="inherited">inherited</span></span></h3>
# <p class="description">Various system fields.</p>
# <p class="inherited-from">Inherited from Persistable&lt;SmartBulbMeasurement&gt;</p>
# <div class="declaration"><p>Declaration</p><pre class="declaration">meta: Meta
# </pre></div></div>
# <div id="data-field:SmartBulbMeasurement.version" class="structure data-field inherited">
# <h3><span class="name">version</span>: int <span class="attributes"><span class="inherited">inherited</span></span></h3>
# <div class="description">
# <p>Version number used for optimistic concurrency.  Automatically managed by the system.
# </p>
# <p>Updating an Obj with a null or 0 value for version will cause the concurrency check to be skipped and should only
# be done with great caution.</p>
# </div>
# <p class="inherited-from">Inherited from Persistable&lt;SmartBulbMeasurement&gt;</p>
# <div class="declaration"><p>Declaration</p><pre class="declaration">version: int
# </pre></div></div>
# <h2 class="section data-section inherited">Fields from TimedDataPointFields</h2>
# <div id="data-field:SmartBulbMeasurement.start" class="structure data-field inherited">
# <h3><span class="name">start</span>: datetime <span class="attributes"><span class="required">required</span><span class="inherited">inherited</span></span></h3>
# <p class="description">start date for the data point</p>
# <p class="inherited-from">Inherited from TimedDataPointFields</p>
# <div class="declaration"><p>Declaration</p><pre class="declaration">start: datetime
# </pre></div></div>
# <div id="data-field:SmartBulbMeasurement.outlierCode" class="structure data-field inh

# %%
projection_dict = {
                    "projection": "field1, field2"
                  }
c3_type = c3.MyType

evaluate_projection(c3_type, projection_dict)
# Out:
# 500 - NotClassified - c3.love.util.query.Query_processAsProjectionExpr [8226.412]
# message: "Invalid projection 'field1': Invalid field: 'field1'"
# JSON: {"spec": {"type": "EvaluateSpec", "projection": "field1, field2", "offset": 0, "limit": 2000, "sqlId": -1, "timeZone": "NONE"}}
# ---------------------------------------------------------------------------
# C3RuntimeException                        Traceback (most recent call last)
# /tmp/ipykernel_2536/3671128879.py in <module>
#       4 c3_type = c3.SmartBulbMeasurement
#       5
# ----> 6 evaluate_projection(c3_type, projection_dict)
#
# /tmp/ipykernel_2536/788143230.py in evaluate_projection(c3_type, projection_dict, column_name, ignore_ref)
#      43         raise ValueError("projection_dict must contain 'projection' as one of the key")
#      44     #### Evaluate projection ####
# ---> 45     data = c3_type.evaluate(projection_dict)
#      46     if data.count == 0:
#      47         warnings.warn("No output from evalaute projection")
#
# Z10ac078826d8534179d455db1588a325M_.TypeSystemBase in evaluate(_cls_f7f11c950a4e, spec)
#
# Z10ac078826d8534179d455db1588a325M_/TypeSystemBase.py in _c3_static_impl(_cls, typesys, ___args, method_name, defined_class_name, _overload_idx)
#
# Z10ac078826d8534179d455db1588a325M_/TypeSystemBase.py in _box_and_request_json(self, type_name, method_name, payload, validate_args, declared_type_name, current_class)
#
# Z10ac078826d8534179d455db1588a325M_/TypeSystemBase.py in _request_json(self, type_name, method_name, payload)
#
# Z10ac078826d8534179d455db1588a325M_/ServerConnection.py in _request_json(self, type_name, action_name, payload, extra_headers, encoder, client_side_type_inference)
#
# C3RuntimeException: 500 - NotClassified - c3.love.util.query.Query_processAsProjectionExpr [8226.412]
# message: "Invalid projection 'field1': Invalid field: 'field1'"
# JSON: {"spec": {"type": "EvaluateSpec", "projection": "field1, field2", "offset": 0, "limit": 2000, "sqlId": -1, "timeZone": "NONE"}}

# %%
c3.SmartBulbMeasurement.evaluate(spec = {
                    "projection": "temperature, status, voltage",
                    'limit': 10
                  })
# Out:
# c3.EvaluateResult(count=0, hasMore=False)

# %%
projection_dict = {
                    "projection": "fixtureHistory, bulbNumber",
#                     'filter': "contains(name, 'e')",
                    "limit":10
                  }
c3_type = c3.SmartBulb
evaluate_projection(c3_type, projection_dict)
# Out:
#                 fixtureHistory  bulbNumber
# 0  c3.SmartBulb(id='SMBLB100')       False
# 1    c3.SmartBulb(id='SMBLB1')       False
# 2   c3.SmartBulb(id='SMBLB10')       False
# 3   c3.SmartBulb(id='SMBLB11')       False
# 4   c3.SmartBulb(id='SMBLB12')       False
# 5   c3.SmartBulb(id='SMBLB13')       False
# 6   c3.SmartBulb(id='SMBLB15')       False
# 7   c3.SmartBulb(id='SMBLB16')       False
# 8   c3.SmartBulb(id='SMBLB17')       False
# 9    c3.SmartBulb(id='SMBLB2')       False

# %% [markdown]
# ## 2. CRUD Operations in Python <a class="anchor" id="1.2">

# %% [markdown]
# We have seen how to fetch data records and how to view those results in a pandas DataFrame

# %%
# c3.MyEntityType.fetch()
pd.DataFrame(c3.MyType.fetch().objs.toJson())

# %% [markdown]
# As a Data Scientist, it's unlikely you'll be creating or editing individual records by hand often; however, it's important to understand how the C3 platform manipulates records and data for when these operations are integrated into platform or custom methods later.

# %% [markdown]
# ##### Create Method

# %% [markdown]
# An entity (Persistable) type only requires a unique id when creating a new record. We can create new records in this type using the `.create()` method and passing it an UpsertSpec. If no unique id is specified, one is created.

# %%
c3.MyType.create(this={
                         'id':'UniqueId1',
                         'name': 'Name1'
                      })

# %% [markdown]
# We can now view the record that we just created using the `.get()` method and passing it the record id.

# %%
MyEntityInstance = c3.MyType.get('UniqueId1')

# %%
MyEntityInstance.id

# %% [markdown]
# ##### What's the difference between `get()` and `fetch()`?

# %% [markdown]
# `fetch()` returns a set of records from a datatable and does not require any parameters (although you *can* include a fetch spec). `get()` requires an id as a parameter and will then return the data for only that specified record/the specific instance.

# %% [markdown]
# ##### Merge Method

# %% [markdown]
# If we want to make changes to an existing record and to only update certain fields on a created record, we can use the `merge()` method

# %%
MyEntityInstance.latitude = 32.7
MyEntityInstance.longitude = None

# %%
MyEntityInstance.merge()

# %% [markdown]
# Note that you do not have to use the `get()` method to make updates to records, but rather you can pass in a MergeSpec and simply merge new fields directly:

# %%
c3.MyType.merge(this={
                             'id': 'UniqueId1',
                             'name': 'Name1',
                             'latitude': 32.7,
                             'longitude': -101.1
                   })

# %%
pd.DataFrame(c3.MyType.fetch().objs.toJson())

# %% [markdown]
# ##### Upsert and Update Methods

# %% [markdown]
# There are 2 additional methods available to create or edit existing records: `upsert()` and `update()`. Their syntax is the same as that for `create()` and `merge()`. How they work:
#
# * `upsert()` will update the record if it exists or create it if it doesn't. If you do not specify the id, `upsert()` will create a new record with a new id.
# * `update()` requires the record to already exist and requires an id to be passed in or it will throw an error.
#
# Both methods require you to specify values for all required fields in the upsert/update spec or they will throw an error.
#
# **BEWARE:** if you do not specify **all** existing fields in the specs for these two methods, they will overwrite any missing/unspecified (non-required) fields with null!!!
#
# For that reason, we suggest you use `create()` to create new records and `merge()` to update existing records unless you wish to run the risk of overwriting fields with null.

# %% [markdown]
# ##### Remove Method

# %% [markdown]
# Now if we want to delete the record that we've just created, we can use the `remove()` method.

# %%
MyEntityTypeInstanceToDelete = c3.MyType.get('UniqueId')

# %%
MyEntityTypeInstanceToDelete.remove()

# %% [markdown]
# ##### Batching Methods

# %% [markdown]
# All the **CRUD** operations we demonstrated above can also be performed on a batch of data. To do so, simply leave out the `this` argument and pass in a list of UpsertSpecs/MergeSpecs.

# %%
c3.MyType.createBatch([
                {"id": "UniqueId1",
                 "name": "Name1"},
                {"id": "UniqueId2",
                 "name": "Name2"},
                {"id": "UniqueId3",
                 "name": "Name3"}
    ])

# %%
# view your updated data here
pd.DataFrame(c3.MyType.fetch().objs.toJson())

# %%
c3.MyType.removeBatch([
                {"id": "UniqueId1",
                 "name": "Name1"},
                {"id": "UniqueId2",
                 "name": "Name2"},
                {"id": "UniqueId3",
                 "name": "Name3"}
    ])

# %%
# view your updated data here
pd.DataFrame(c3.MyType.fetch().objs.toJson())

# %% [markdown]
# ### Use This Space for "CHALLENGE: CRUD Operations"
#
#     Add additional cells as needed.

# %%
import networkx
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_2909/1829148656.py in <module>
# ----> 1 import networkx
#
# ModuleNotFoundError: No module named 'networkx'

# %% [markdown]
# ## 3. Prototype Methods in Python <a class="anchor" id="1.3">

# %% [markdown]
# ### A. Write Code <a class="anchor" id="1.3A">

# %% [markdown]
# Provsion running code in package.
#
# Declare Python methods in types with this syntax:
#
# ``` py
# // Method takes myInput (a string) and returns a double
# @py(env='myActionRuntime')
# myPythonMethod: function(myInput: string): double
# ```

# %% [markdown]
# The .py file needs its own package imports.

# %% [markdown]
# ### Use This Space for "CHALLENGE: Build Methods"

# %%
import pandas as pd
import datetime as dt

def convert_dates_to_common_format(input_date):
        
        # if the date is a datetime, we need to strip timezone information
        if isinstance(input_date, dt.datetime):
            date = input_date.replace(tzinfo=None)
        # if the date is a string, we need to convert it to a datetime
        elif isinstance(input_date, str):
            date = dt.datetime.strptime(input_date, "%Y-%m-%dT%H:%M:%S")
        
        return date

def abs_day_diff(input_date_1, input_date_2):
    # Convert dates and subtract using the convert_dates_to_common_format funtion
    date_1 = convert_dates_to_common_format(input_date_1)
    date_2 = convert_dates_to_common_format(input_date_2)
    
    return abs((date_1 - date_2).days) / 365.

def lifeSpanInYears(bulbId):
    # Get startDate from SmartBulbMeasurement
    bulb = c3.SmartBulb.get(this={'id': bulbId})
    startDate = bulb.startDate
    
    # Get data from SmartBulbMeasurement
    limitSpec = -1
    defectFilter = "status == 1 && lumens == 0 && parent.id == '" + 'SBMS_serialNo_' + bulb.id + "'"
    smartbulbmeasurement_objs = c3.SmartBulbMeasurement.fetch(spec={'limit':limitSpec,
                                                                    'filter':defectFilter}).objs
    smartbulbmeasurement_pd = pd.DataFrame(smartbulbmeasurement_objs.toJson())
    
    # get endDate from filtered measurements
    smartbulbmeasurement_pd.sort_values(by='start',ascending=False)
    endDate = str(smartbulbmeasurement_pd[['start']].iloc[0].values[0])
    
    # return endDate - startDate from using abs_day_diff function
    return abs_day_diff(startDate, endDate)

# %%
lifeSpanInYears('SMBLB1')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_2536/1792779599.py in <module>
# ----> 1 lifeSpanInYears('SMBLB1')
#
# /tmp/ipykernel_2536/1126321897.py in lifeSpanInYears(bulbId)
#      30     smartbulbmeasurement_objs = c3.SmartBulbMeasurement.fetch(spec={'limit':limitSpec,
#      31                                                                     'filter':defectFilter}).objs
# ---> 32     smartbulbmeasurement_pd = pd.DataFrame(smartbulbmeasurement_objs.toJson())
#      33
#      34     # get endDate from filtered measurements
#
# AttributeError: 'NoneType' object has no attribute 'toJson'

# %%
c3.SmartBulb.lifeSpanInYears('SMBLB1')

# %% [markdown]
# For your challenge you will build one to two additional static methods:
# -   `shortestLifeSpan: function(): string`  (**CHALLENGE**)
#
#     Returns the string sentence: f"Bulb {bulbId} has the shortest lifespan = {lifespan} years"
#
#
# -   `longestAndShortestLifespans: function(): string`  (**ADVANCED CHALLENGE**)
#
#     Returns the string sentence: f'Longest Lifespan: {longest_lifespan_bulb_id} - {longest_lifespan_bulb}, Shortest Lifespan: {shortest_lifespan_bulb_id} - {shortest_lifespan_bulb}'

# %% [markdown]
# ### Use This Space for "CHALLENGE: Build Methods"
#
#     Add additional cells as needed.

# %% [markdown]
# ### Test Code <a class="anchor" id="1.3B">

# %% [markdown]
# After provisioning, test code from the static console or Jypyter
#
# Use `c3.MyType.myPythonMethod(myInput)` to get the output of the function as it's been provisioned onto your tag.

# %% [markdown]
# ### Use This Cell to Test that Your Code Has Provisioned And Is Available on the Platform

# %% [markdown]
# ## 4. AsyncActions <a class="anchor" id="1.4">

# %% [markdown]
# The methods we just evaluated on the c3-server were executed in a synchronous fashion on a `C3 Master` server. We can just as easily call methods on types asynchronously and execute these methods on `C3 Worker` nodes.

# %%
spec = c3.AsyncActionSpec(typeName='SmartBulb', 
                          action='lifeSpanInYears', 
                          args={'bulbId': 'SMBLB1'})

action = c3.AsyncAction.submit(spec)

# %%
action.hasCompleted()

# %%
action.get().result

# %%
action.formatError()

# %% [markdown]
# Take a moment to piece together the data flow for the `AsyncAction` we just submitted. Questions to ask yourself:
# - which node did this computation execute on?
# - which c3 components were involved in making this computation possible?
# - what kinds of computation should we distribute to `C3 Worker` nodes? Examples?

# %% [markdown]
# ##### What happens if the action fails?

# %% [markdown]
# Note that the method lifeSpanInYears was defined for the SmartBulb Type. What happens if we try to run it on the Building Type?

# %%
spec = c3.AsyncActionSpec(typeName='Building', 
                          action='lifeSpanInYears', 
                          args={'bulbId': 'SMBLB1'})

action = c3.AsyncAction.submit(spec)

# %%
action.hasCompleted()

# %%
action.formatError()

# %% [markdown]
# ### Use This Space for "CHALLENGE: Execute AsyncActions"

# %% [markdown]
# # Make sure to SYNC your notebook to the server, then CLOSE AND HALT this notebook when you leave.
# To sync: go to the File menu, Save and Checkpoint your notebook, and then select "Upload Notebook to C3.ai", or select the notebook in the tree view (check the box) and hit the "Sync" button.
