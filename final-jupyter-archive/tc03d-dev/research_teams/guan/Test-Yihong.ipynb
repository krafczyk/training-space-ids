# %%
test = c3.PlanetCollector(
    **{
        "id": "test1",
        "base_url": "https://api.planet.com/basemaps/v1/mosaics/",
        "mosaic_id": "56f00cc2-6be4-4315-9603-c75d6afab225",
        "api_key": "8fb5d85cdcfc40f6b4b9d3f44227142b",
        "start_lon": -91.51307900019566,
        "start_lat": 36.970297999852846,
        "end_lon": -87.49519900023363,
        "end_lat": 42.50848099959849
    }
)

test.merge()
# Out:
# c3.PlanetCollector(
#  id='test1',
#  meta=c3.Meta(
#         created=datetime.datetime(2022, 2, 17, 22, 9, 10, tzinfo=datetime.timezone.utc),
#         updated=datetime.datetime(2022, 2, 17, 22, 9, 10, tzinfo=datetime.timezone.utc),
#         timestamp=datetime.datetime(2022, 2, 17, 22, 9, 10, tzinfo=datetime.timezone.utc)),
#  version=1)

# %%
test1 = c3.PlanetCollector.get({"id":"test1"})
res = test1.stage_planet_raw()
res
# Out:
# c3.ObjList<PlanetFile>(
#  stats=c3.Stats(
#          createdObjCount=978,
#          updatedObjCount=0,
#          removedObjCount=0,
#          failedObjCount=0,
#          objCount=978,
#          dbWait=0.0,
#          time=0.343,
#          dbTime=0.061229235,
#          objsPerSecond=2851.3119533527693,
#          dbObjsPerSecond=15972.76203107878),
#  objs=c3.Arry<PlanetFile>([c3.PlanetFile(
#          id='test1_503-1291',
#          name='503-1291',
#          meta=c3.Meta(
#                 created=datetime.datetime(2022, 2, 17, 22, 10, 32, tzinfo=datetime.timezone.utc),
#                 updated=datetime.datetime(2022, 2, 17, 22, 10, 32, tzinfo=datetime.timezone.utc),
#                 timestamp=datetime.datetime(2022, 2, 17, 22, 10, 32, tzinfo=datetime.timezone.utc)),
#          version=1),
#         c3.PlanetFile(
#          id='test1_504-1291',
#          name='504-1291',
#          meta=c3.Meta(
#                 created=datetime.datetime(2022, 2, 17, 22, 10, 32, tzinfo=datetime.timezone.utc),
#                 updated=datetime.datetime(2022, 2, 17, 22, 10, 32, tzinfo=datetime.timezone.utc),
#                 timestamp=datetime.datetime(2022, 2, 17, 22, 10, 32, tzinfo=datetime.timezone.utc)),
#          version=1),
#         c3.PlanetFile(
#          id='test1_505-1291',
#          name='505-1291',
#          meta=c3.Meta(
#                 created=datetime.datetime(2022, 2, 17, 22, 10, 32, tzinfo=datetime.timezone.utc),
#                 updated=datetime.datetime(2022, 2, 17, 22, 10, 32, tzinfo=datetime.timezone.utc),
#                 timestamp=datetime.datetime(2022, 2, 17, 22, 10, 32, tzinfo=datetime.timezone.utc)),
#          version=1),
#         c3.PlanetFile(
#          id='test1_506-1291',
#          name='506-1291',
#          meta=c3.Meta(
#                 created=datetime.datetime(2022, 2, 17, 22, 10, 32, tzinfo=datetime.timezone.utc),
#                 updated=datetime.datetime(2022, 2, 17, 22, 10, 32, tzinfo=datetime.timezone.utc),
#                 timestamp=datetime.datetime(2022, 2, 17, 22, 10, 32, tzinfo=datetime.timezone.utc)),
#          version=1),
#         c3.PlanetFile(
#          id='test1_507-1291',
#          name='507-1291',
#          meta=c3.Meta(
#                 created=datetime.datetime(2022, 2, 17, 22, 10, 32, tzinfo=datetime.timezone.utc),
#                 updated=datetime.datetime(2022, 2, 17, 22, 10, 32, tzinfo=datetime.timezone.utc),
#                 timestamp=datetime.datetime(2022, 2, 17, 22, 10, 32, tzinfo=datetime.timezone.utc)),
#          version=1),
#         c3.PlanetFile(
#          id='test1_508-1291',
#          name='508-1291',
#          meta=c3.Meta(
#                 created=datetime.datetime(2022, 2, 17, 22, 10, 32, tzinfo=datetime.timezone.utc),
#                 updated=datetime.datetime(2022, 2, 17, 22, 10, 32, tzinfo=datetime.timezone.utc),
#                 timestamp=datetime.datetime(2022, 2, 17, 22, 10, 32, tzinfo=datetime.timezone.utc)),
#          version=1),
#         c3.PlanetFile(
#          id='test1_509-1291',
#          name='509-1291',
#          meta=c3.Meta(
#                 created=datetime.datetime(2022, 2, 17, 22, 10, 32, tzinfo=datetime.timezone.utc),
#                 updated=datetime.datetime(2022, 2, 17, 22, 10, 32, tzinfo=datetime.timezone.utc),
#                 timestamp=datetime.datetime(2022, 2, 17, 22, 10, 32, tzinfo=datetime.timezone.utc)),
#          version=1),
#         c3.PlanetFile(
#          id='test1_510-1291',
#          name='510-1291',
#          meta=c3.Meta(
#                 created=datetime.datetime(2022, 2, 17, 22, 10, 32, tzinfo=datetime.timezone.utc),
#                 updated=datetime.datetime(2022, 2, 17, 22, 10, 32, tzinfo=datetime.timezone.utc),
#                 timestamp=datetime.datetime(2022, 2, 17, 22, 10, 32, tzinfo=datetime.timezone.utc)),
#          version=1),
#         c3.PlanetFile(
#          id='test1_511-1291',
#          name='511-1291',
#          meta=c3.Meta(
#                 created=datetime.datetime(2022, 2, 17, 22, 10, 32, tzinfo=datetime.timezone.utc),
#                 updated=datetime.datetime(2022, 2, 17, 22, 10, 32, tzinfo=datetime.timezone.utc),
#                 timestamp=datetime.datetime(2022, 2, 17, 22, 10, 32, tzinfo=datetime.timezone.utc)),
#          version=1),
#         c3.PlanetFile(
#          id='test1_512-1291',
#          name='512-1291',
#          meta=c3.Meta(
#                 created=datetime.datetime(2022, 2, 17, 22, 10, 32, tzinfo=datetime.timezone.utc),
#                 updated=datetime.datetime(2022, 2, 17, 22, 10, 32, tzinfo=datetime.timezone.utc),
#                 timestamp=datetime.datetime(2022, 2, 17, 22, 10, 32, tzinfo=datetime.timezone.utc)),
#          version=1),
#         c3.PlanetFile(
#          id='test1_513-1291',
#          name='513-1291',
#          meta=c3.Meta(
#                 created=datetime.datetime(2022, 2, 17, 22, 10, 32, tzinfo=datetime.timezone.utc),
#                 updated=datetime.datetime(2022, 2, 17, 22, 10, 32, tzinfo=datetime.timezone.utc),
#                 timestamp=datetime.datetime(2022, 2, 17, 22, 10, 32, tzinfo=datetime.timezone.utc)),
#          version=1),
#         c3.PlanetFile(
#          id='test1_514-1291',
#          name='514-1291',
#          meta=c3.Meta(
#                 created=datetime.datetime(2022, 2, 17, 22, 10, 32, tzinfo=datetime.timezone.utc),
#                 updated=datetime.datetime(2022, 2, 17, 22, 10, 32, tzinfo=datetime.timezone.utc),
#                 timestamp=datetime.datetime(2022, 2, 17, 22, 10, 32, tzinfo=datetime.timezone.utc)),
#          version=1),
#         c3.PlanetFile(
#          id='test1_515-1291',
#          name='515-1291',
#          meta=c3.Meta(
#                 created=datetime.datetime(2022, 2, 17, 22, 10, 32, tzinfo=datetime.timezone.utc),
#                 updated=datetime.datetime(2022, 2, 17, 22, 10, 32, tzinfo=datetime.timezone.utc),
#                 timestamp=datetime.datetime(2022, 2, 17, 22, 10, 32, tzinfo=datetime.timezone.utc)),
#          version=1),
#         c3.PlanetFile(
#          id='test1_516-1291',
#          name='516-1291',
#          meta=c3.Meta(
#                 created=datetime.datetime(2022, 2, 17, 22, 10, 32, tzinfo=datetime.timezone.utc),
#                 updated=datetime.datetime(2022, 2, 17, 22, 10, 32, tzinfo=datetime.timezone.utc),
#                 timestamp=datetime.datetime(2022, 2, 17, 22, 10, 32, tzinfo=datetime.timezone.utc)),
#          version=1),
#         c3.PlanetFile(
#          id='test1_517-1291',
#          name='517-1291',
#          meta=c3.Meta(
#                 created=datetime.datetime(2022, 2, 17, 22, 10, 32, tzinfo=datetime.timezone.utc),
#                 updated=datetime.datetime(2022, 2, 17, 22, 10, 32, tzinfo=datetime.timezone.utc),
#                 timestamp=datetime.datetime(2022, 2, 17, 22, 10, 32, tzinfo=datetime.timezone.utc)),
#          version=1),
#         c3.PlanetFile(
#          id='test1_518-1291',
#          name='518-1291',
#          meta=c3.Meta(
#                 created=datetime.datetime(2022, 2, 17, 22, 10, 32, tzinfo=datetime.timezone.utc),
#                 updated=datetime.datetime(2022, 2, 17, 22, 10, 32, tzinfo=datetime.timezone.utc),
#                 timestamp=datetime.datetime(2022, 2, 17, 22, 10, 32, tzinfo=datetime.timezone.utc)),
#          version=1),
#         c3.PlanetFile(
#          id='test1_519-1291',
#          name='519-1291',
#          meta=c3.Meta(
#                 created=datetime.datetime(2022, 2, 17, 22, 10, 32, tzinfo=datetime.timezone.utc),
#                 updated=datetime.datetime(2022, 2, 17, 22, 10, 32, tzinfo=datetime.timezone.utc),
#                 timestamp=datetime.datetime(2022, 2, 17, 22, 10, 32, tzinfo=datetime.timezone.utc)),
#          version=1),
#         c3.PlanetFile(
#          id='test1_520-1291',
#          name='520-1291',
#          meta=c3.Meta(
#                 created=datetime.datetime(2022, 2, 17, 22, 10, 32, tzinfo=datetime.timezone.utc),
#                 updated=datetime.datetime(2022, 2, 17, 22, 10, 32, tzinfo=datetime.timezone.utc),
#                 timestamp=datetime.datetime(2022, 2, 17, 22, 10, 32, tzinfo=datetime.timezone.utc)),
#          version=1),
#         c3.PlanetFile(
#          id='test1_521-1291',
#          name='521-1291',
#          meta=c3.Meta(
#                 created=datetime.datetime(2022, 2, 17, 22, 10, 32, tzinfo=datetime.timezone.utc),
#                 updated=datetime.datetime(2022, 2, 17, 22, 10, 32, tzinfo=datetime.timezone.utc),
#                 timestamp=datetime.datetime(2022, 2, 17, 22, 10, 32, tzinfo=datetime.timezone.utc)),
#          version=1),
#         c3.PlanetFile(
#          id='test1_522-1291',
#          name='522-1291',
#          meta=c3.Meta(
#                 created=datetime.datetime(2022, 2, 17, 22, 10, 32, tzinfo=datetime.timezone.utc),
#                 updated=datetime.datetime(2022, 2, 17, 22, 10, 32, tzinfo=datetime.timezone.utc),
#                 timestamp=datetime.datetime(2022, 2, 17, 22, 10, 32, tzinfo=datetime.timezone.utc)),
#          version=1),
#         c3.PlanetFile(
#          id='test1_523-1291',
#          name='523-1291',
#          meta=c3.Meta(
#                 created=datetime.datetime(2022, 2, 17, 22, 10, 32, tzinfo=datetime.timezone.utc),
#                 updated=datetime.datetime(2022, 2, 17, 22, 10, 32, tzinfo=datetime.timezone.utc),
#                 timestamp=datetime.datetime(2022, 2, 17, 22, 10, 32, tzinfo=datetime.timezone.utc)),
#          version=1),
#         c3.PlanetFile(
#          id='test1_524-1291',
#          name='524-1291',
#          meta=c3.Meta(
#                 created=datetime.datetime(2022, 2, 17, 22, 10, 32, tzinfo=datetime.timezone.utc),
#                 updated=datetime.datetime(2022, 2, 17, 22, 10, 32, tzinfo=datetime.timezone.utc),
#                 timestamp=datetime.datetime(2022, 2, 17, 22, 10, 32, tzinfo=datetime.timezone.utc)),
#          version=1),
#         c3.PlanetFile(
#          id='test1_525-1291',
#          name='525-1291',
#          meta=c3.Meta(
#                 created=datetime.datetime(2022, 2, 17, 22, 10, 32, tzinfo=datetime.timezone.utc),
#                 updated=datetime.datetime(2022, 2, 17, 22, 10, 32, tzinfo=datetime.timezone.utc),
#                 timestamp=datetime.datetime(2022, 2, 17, 22, 10, 32, tzinfo=datetime.timezone.utc)),
#    ...

# %%
import os
os.listdir("/tmp")
# Out:
# []

# %%
test_file = c3.PlanetFile.fetch({"filter": "id == 'test1_503-1255'"}).first()
test_file.download_raw_image()
# Out:
# 'yifang_guan/planet_collection/raw/test1/503-1255.tif'

# %%
test_file = c3.PlanetFile.get("test1_503-1255")
print(test_file)
test_file.preprocess_raw_image()
test_file = c3.PlanetFile.get("test1_503-1255")
test_file
# Out:
# c3.PlanetFile(
#  id='test1_503-1255',
#  name='503-1255',
#  meta=c3.Meta(
#         tenantTagId=152,
#         tenant='dev',
#         tag='tc03d',
#         created=datetime.datetime(2022, 2, 17, 22, 10, 32, tzinfo=datetime.timezone.utc),
#         createdBy='yihongj2@illinois.edu',
#         updated=datetime.datetime(2022, 3, 10, 22, 21, 21, tzinfo=datetime.timezone.utc),
#         updatedBy='yihongj2@illinois.edu',
#         timestamp=datetime.datetime(2022, 3, 10, 22, 21, 21, tzinfo=datetime.timezone.utc),
#         fetchInclude='[]',
#         fetchType='PlanetFile'),
#  version=2,
#  planet_collector=c3.PlanetCollector(id='test1'),
#  raw_image_file=c3.AzureFile(
#                   contentLength=119014639,
#                   contentLocation='fs/dti/mpodolsky/yifang_guan/planet_collection/raw/test1/503-1255.tif',
#                   contentType='application/json',
#                   eTag='"0x8DA02E44E5B332D"',
#                   lastModified=datetime.datetime(2022, 3, 10, 22, 21, 21, tzinfo=datetime.timezone.utc),
#                   contentMD5='EzGRWVTKPKJ4rQMzLJTgzA==',
#                   hasMetadata=True,
#                   url='azure://dev-dti/fs/dti/mpodolsky/yifang_guan/planet_collection/raw/test1/503-1255.tif',
#                   blobType='BLOCK_BLOB'),
#  query_url='https://api.planet.com/basemaps/v1/mosaics/56f00cc2-6be4-4315-9603-c75d6afab225/quads/503-1255/full?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b',
#  external_raw_path='yifang_guan/planet_collection/raw/test1/503-1255.tif',
#  status='raw')
# c3.PlanetFile(
#  id='test1_503-1255',
#  name='503-1255',
#  meta=c3.Meta(
#         tenantTagId=152,
#         tenant='dev',
#         tag='tc03d',
#         created=datetime.datetime(2022, 2, 17, 22, 10, 32, tzinfo=datetime.timezone.utc),
#         createdBy='yihongj2@illinois.edu',
#         updated=datetime.datetime(2022, 3, 10, 22, 25, 48, tzinfo=datetime.timezone.utc),
#         updatedBy='yihongj2@illinois.edu',
#         timestamp=datetime.datetime(2022, 3, 10, 22, 25, 48, tzinfo=datetime.timezone.utc),
#         fetchInclude='[]',
#         fetchType='PlanetFile'),
#  version=3,
#  planet_collector=c3.PlanetCollector(id='test1'),
#  raw_image_file=c3.AzureFile(
#                   contentLength=119014639,
#                   contentLocation='fs/dti/mpodolsky/yifang_guan/planet_collection/raw/test1/503-1255.tif',
#                   contentType='application/json',
#                   eTag='"0x8DA02E44E5B332D"',
#                   lastModified=datetime.datetime(2022, 3, 10, 22, 21, 21, tzinfo=datetime.timezone.utc),
#                   contentMD5='EzGRWVTKPKJ4rQMzLJTgzA==',
#                   hasMetadata=True,
#                   url='azure://dev-dti/fs/dti/mpodolsky/yifang_guan/planet_collection/raw/test1/503-1255.tif',
#                   blobType='BLOCK_BLOB'),
#  processed_image_file=c3.AzureFile(
#                         contentLength=292658990,
#                         contentLocation='fs/dti/mpodolsky/yifang_guan/planet_collection/raw/test1/503-1255-warp.tif',
#                         contentType='application/json',
#                         eTag='"0x8DA02E4ED35E326"',
#                         lastModified=datetime.datetime(2022, 3, 10, 22, 25, 48, tzinfo=datetime.timezone.utc),
#                         contentMD5='MIdiqE4p+LDwR+mWYSjtKQ==',
#                         hasMetadata=True,
#                         url='azure://dev-dti/fs/dti/mpodolsky/yifang_guan/planet_collection/raw/test1/503-1255-warp.tif',
#                         blobType='BLOCK_BLOB'),
#  query_url='https://api.planet.com/basemaps/v1/mosaics/56f00cc2-6be4-4315-9603-c75d6afab225/quads/503-1255/full?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b',
#  external_raw_path='yifang_guan/planet_collection/raw/test1/503-1255.tif',
#  external_processed_path='yifang_guan/planet_collection/raw/test1/503-1255-warp.tif',
#  status='preprocessed')

# %%
test_file.predict_image()
test_file = c3.PlanetFile.get("test1_503-1255")
test_file
# Out:
# c3.PlanetFile(
#  id='test1_503-1255',
#  name='503-1255',
#  meta=c3.Meta(
#         tenantTagId=152,
#         tenant='dev',
#         tag='tc03d',
#         created=datetime.datetime(2022, 2, 17, 22, 10, 32, tzinfo=datetime.timezone.utc),
#         createdBy='yihongj2@illinois.edu',
#         updated=datetime.datetime(2022, 3, 10, 22, 29, 17, tzinfo=datetime.timezone.utc),
#         updatedBy='yihongj2@illinois.edu',
#         timestamp=datetime.datetime(2022, 3, 10, 22, 29, 17, tzinfo=datetime.timezone.utc),
#         fetchInclude='[]',
#         fetchType='PlanetFile'),
#  version=4,
#  planet_collector=c3.PlanetCollector(id='test1'),
#  raw_image_file=c3.AzureFile(
#                   contentLength=119014639,
#                   contentLocation='fs/dti/mpodolsky/yifang_guan/planet_collection/raw/test1/503-1255.tif',
#                   contentType='application/json',
#                   eTag='"0x8DA02E44E5B332D"',
#                   lastModified=datetime.datetime(2022, 3, 10, 22, 21, 21, tzinfo=datetime.timezone.utc),
#                   contentMD5='EzGRWVTKPKJ4rQMzLJTgzA==',
#                   hasMetadata=True,
#                   url='azure://dev-dti/fs/dti/mpodolsky/yifang_guan/planet_collection/raw/test1/503-1255.tif',
#                   blobType='BLOCK_BLOB'),
#  processed_image_file=c3.AzureFile(
#                         contentLength=292658990,
#                         contentLocation='fs/dti/mpodolsky/yifang_guan/planet_collection/raw/test1/503-1255-warp.tif',
#                         contentType='application/json',
#                         eTag='"0x8DA02E4ED35E326"',
#                         lastModified=datetime.datetime(2022, 3, 10, 22, 25, 48, tzinfo=datetime.timezone.utc),
#                         contentMD5='MIdiqE4p+LDwR+mWYSjtKQ==',
#                         hasMetadata=True,
#                         url='azure://dev-dti/fs/dti/mpodolsky/yifang_guan/planet_collection/raw/test1/503-1255-warp.tif',
#                         blobType='BLOCK_BLOB'),
#  npy_result=c3.AzureFile(
#               contentLength=234100768,
#               contentLocation='fs/dti/mpodolsky/yifang_guan/planet_collection/raw/test1/503-1255.npy',
#               contentType='application/json',
#               eTag='"0x8DA02E5695E1245"',
#               lastModified=datetime.datetime(2022, 3, 10, 22, 29, 16, tzinfo=datetime.timezone.utc),
#               contentMD5='WZ+bIhQLC04WUDzIxmOUcw==',
#               hasMetadata=True,
#               url='azure://dev-dti/fs/dti/mpodolsky/yifang_guan/planet_collection/raw/test1/503-1255.npy',
#               blobType='BLOCK_BLOB'),
#  tif_result=c3.AzureFile(
#               contentLength=29295334,
#               contentLocation='fs/dti/mpodolsky/yifang_guan/planet_collection/raw/test1/503-1255-pred.tif',
#               contentType='application/json',
#               eTag='"0x8DA02E56A0E83BA"',
#               lastModified=datetime.datetime(2022, 3, 10, 22, 29, 17, tzinfo=datetime.timezone.utc),
#               contentMD5='4yD4KUDaTbmUMh35rcUAgw==',
#               hasMetadata=True,
#               url='azure://dev-dti/fs/dti/mpodolsky/yifang_guan/planet_collection/raw/test1/503-1255-pred.tif',
#               blobType='BLOCK_BLOB'),
#  query_url='https://api.planet.com/basemaps/v1/mosaics/56f00cc2-6be4-4315-9603-c75d6afab225/quads/503-1255/full?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b',
#  external_raw_path='yifang_guan/planet_collection/raw/test1/503-1255.tif',
#  external_processed_path='yifang_guan/planet_collection/raw/test1/503-1255-warp.tif',
#  external_npy_path='yifang_guan/planet_collection/raw/test1/503-1255.npy',
#  external_pred_path='yifang_guan/planet_collection/raw/test1/503-1255-pred.tif',
#  status='predicted')

# %%
c3.FileSystem.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-729bfd60d8ee> in <module>
# ----> 1 c3.FileSystem.listFile
#
# Z10ac078826d8534179d455db1588a325M_/TypeSystemBase.py in __getattr__(cls, key)
#
# AttributeError: Type "FileSystem" has no attribute "listFile"

# %%
# test_file = c3.PlanetFile.fetch({"filter": "id == 'test1_503-1275'"}).first()
# test_file.download_raw_image()
test_file = c3.PlanetFile.get("test1_503-1253")
test_file
# Out:
# c3.PlanetFile(
#  id='test1_503-1252',
#  name='503-1252',
#  meta=c3.Meta(
#         tenantTagId=152,
#         tenant='dev',
#         tag='tc03d',
#         created=datetime.datetime(2022, 2, 17, 22, 10, 32, tzinfo=datetime.timezone.utc),
#         createdBy='yihongj2@illinois.edu',
#         updated=datetime.datetime(2022, 2, 18, 1, 5, 54, tzinfo=datetime.timezone.utc),
#         updatedBy='yihongj2@illinois.edu',
#         timestamp=datetime.datetime(2022, 2, 18, 1, 5, 54, tzinfo=datetime.timezone.utc),
#         fetchInclude='[]',
#         fetchType='PlanetFile'),
#  version=4,
#  planet_collector=c3.PlanetCollector(id='test1'),
#  raw_image_file=c3.AzureFile(
#                   contentLength=107412831,
#                   contentLocation='fs/dti/mpodolsky/yifang_guan/planet_collection/raw/test1/503-1252.tif',
#                   contentType='application/json',
#                   eTag='"0x8D9F27A45070FD3"',
#                   lastModified=datetime.datetime(2022, 2, 18, 1, 2, tzinfo=datetime.timezone.utc),
#                   contentMD5='0zlKAOM8gI3iqh9HABSL/w==',
#                   hasMetadata=True,
#                   url='azure://dev-dti/fs/dti/mpodolsky/yifang_guan/planet_collection/raw/test1/503-1252.tif',
#                   blobType='BLOCK_BLOB'),
#  processed_image_file=c3.AzureFile(
#                         contentLength=295750804,
#                         contentLocation='fs/dti/mpodolsky/yifang_guan/planet_collection/raw/test1/503-1252-warp.tif',
#                         contentType='application/json',
#                         eTag='"0x8D9F27A572B7CBB"',
#                         lastModified=datetime.datetime(2022, 2, 18, 1, 2, 31, tzinfo=datetime.timezone.utc),
#                         contentMD5='jmfWEcmmD3ehmjnO+mOugQ==',
#                         hasMetadata=True,
#                         url='azure://dev-dti/fs/dti/mpodolsky/yifang_guan/planet_collection/raw/test1/503-1252-warp.tif',
#                         blobType='BLOCK_BLOB'),
#  npy_result=c3.AzureFile(
#               contentLength=236574080,
#               contentLocation='fs/dti/mpodolsky/yifang_guan/planet_collection/raw/test1/503-1252.npy',
#               contentType='application/json',
#               eTag='"0x8D9F27ACFB10813"',
#               lastModified=datetime.datetime(2022, 2, 18, 1, 5, 53, tzinfo=datetime.timezone.utc),
#               contentMD5='c41sV0CGeUVb2KCqQ9cEPg==',
#               hasMetadata=True,
#               url='azure://dev-dti/fs/dti/mpodolsky/yifang_guan/planet_collection/raw/test1/503-1252.npy',
#               blobType='BLOCK_BLOB'),
#  tif_result=c3.AzureFile(
#               contentLength=29604672,
#               contentLocation='fs/dti/mpodolsky/yifang_guan/planet_collection/raw/test1/503-1252-pred.tif',
#               contentType='application/json',
#               eTag='"0x8D9F27AD04DA662"',
#               lastModified=datetime.datetime(2022, 2, 18, 1, 5, 54, tzinfo=datetime.timezone.utc),
#               contentMD5='BCVqqZWxDyqMNntZ0cW5dw==',
#               hasMetadata=True,
#               url='azure://dev-dti/fs/dti/mpodolsky/yifang_guan/planet_collection/raw/test1/503-1252-pred.tif',
#               blobType='BLOCK_BLOB'),
#  query_url='https://api.planet.com/basemaps/v1/mosaics/56f00cc2-6be4-4315-9603-c75d6afab225/quads/503-1252/full?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b',
#  external_raw_path='yifang_guan/planet_collection/raw/test1/503-1252.tif',
#  external_processed_path='yifang_guan/planet_collection/raw/test1/503-1252-warp.tif',
#  external_npy_path='yifang_guan/planet_collection/raw/test1/503-1252.npy',
#  external_pred_path='yifang_guan/planet_collection/raw/test1/503-1252-pred.tif',
#  status='predicted')

# %%
test_file = c3.PlanetFile.get("test1_503-1250")
test_file
# Out:
# c3.PlanetFile(
#  id='test1_503-1250',
#  name='503-1250',
#  meta=c3.Meta(
#         tenantTagId=152,
#         tenant='dev',
#         tag='tc03d',
#         created=datetime.datetime(2022, 2, 17, 22, 10, 32, tzinfo=datetime.timezone.utc),
#         createdBy='yihongj2@illinois.edu',
#         updated=datetime.datetime(2022, 2, 17, 23, 5, 9, tzinfo=datetime.timezone.utc),
#         updatedBy='yihongj2@illinois.edu',
#         timestamp=datetime.datetime(2022, 2, 17, 23, 5, 9, tzinfo=datetime.timezone.utc),
#         fetchInclude='[]',
#         fetchType='PlanetFile'),
#  version=6,
#  planet_collector=c3.PlanetCollector(id='test1'),
#  raw_image_file=c3.AzureFile(
#                   contentLength=116114557,
#                   contentLocation='fs/dti/mpodolsky/yifang_guan/planet_collection/raw/test1/503-1250.tif',
#                   contentType='application/json',
#                   eTag='"0x8D9F262FD7F43E0"',
#                   lastModified=datetime.datetime(2022, 2, 17, 22, 15, 22, tzinfo=datetime.timezone.utc),
#                   contentMD5='2gaILUOvX1lKgtlPsitrew==',
#                   hasMetadata=True,
#                   url='azure://dev-dti/fs/dti/mpodolsky/yifang_guan/planet_collection/raw/test1/503-1250.tif',
#                   blobType='BLOCK_BLOB'),
#  processed_image_file=c3.AzureFile(
#                         contentLength=297711616,
#                         contentLocation='fs/dti/mpodolsky/yifang_guan/planet_collection/raw/test1/503-1250-warp.tif',
#                         contentType='application/json',
#                         eTag='"0x8D9F26434348F06"',
#                         lastModified=datetime.datetime(2022, 2, 17, 22, 24, 3, tzinfo=datetime.timezone.utc),
#                         contentMD5='yvWXnjicmIlJjgFbloUlrg==',
#                         hasMetadata=True,
#                         url='azure://dev-dti/fs/dti/mpodolsky/yifang_guan/planet_collection/raw/test1/503-1250-warp.tif',
#                         blobType='BLOCK_BLOB'),
#  npy_result=c3.File(
#               hasMetadata=False,
#               url='yifang_guan/planet_collection/raw/test1/503-1250npy'),
#  tif_result=c3.AzureFile(
#               contentLength=29800845,
#               contentLocation='fs/dti/mpodolsky/yifang_guan/planet_collection/raw/test1/503-1250-pred.tif',
#               contentType='application/json',
#               eTag='"0x8D9F269F2293112"',
#               lastModified=datetime.datetime(2022, 2, 17, 23, 5, 9, tzinfo=datetime.timezone.utc),
#               contentMD5='Y1WlasFXiR2np8XvtZwOsw==',
#               hasMetadata=True,
#               url='azure://dev-dti/fs/dti/mpodolsky/yifang_guan/planet_collection/raw/test1/503-1250-pred.tif',
#               blobType='BLOCK_BLOB'),
#  query_url='https://api.planet.com/basemaps/v1/mosaics/56f00cc2-6be4-4315-9603-c75d6afab225/quads/503-1250/full?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b',
#  external_raw_path='yifang_guan/planet_collection/raw/test1/503-1250.tif',
#  external_processed_path='yifang_guan/planet_collection/raw/test1/503-1250-warp.tif',
#  external_npy_path='yifang_guan/planet_collection/raw/test1/503-1250npy',
#  external_pred_path='yifang_guan/planet_collection/raw/test1/503-1250-pred.tif',
#  status='preprocessed')

# %%
def predict_image(this):
    # test 1: status check #
    if(this.status != 'preprocessed'):
        raise RuntimeError('Need to preprocess first')
    
    # tf imports
    from tensorflow.keras import Model
    from tensorflow.keras.layers import Conv2D, concatenate, Dropout, Input, BatchNormalization, MaxPooling2D, UpSampling2D, ReLU, Conv2DTranspose

    #====================================================def util functions
    def conv2d_block(input_tensor, n_filters, kernel_size = 3, batchnorm = True):
        """Function to add 2 convolutional layers with the parameters passed to it"""
        # first layer
        x = Conv2D(filters = n_filters, kernel_size = (kernel_size, kernel_size),\
                kernel_initializer = 'he_normal', padding = 'same')(input_tensor)
        if batchnorm:
            x = BatchNormalization()(x)
        x = ReLU()(x)

        # second layer
        x = Conv2D(filters = n_filters, kernel_size = (kernel_size, kernel_size),\
                kernel_initializer = 'he_normal', padding = 'same')(x)
        if batchnorm:
            x = BatchNormalization()(x)
        x = ReLU()(x)

        return x

    def get_unet(input_img, n_filters = 16, dropout = 0.1, batchnorm = True):
        """Function to define the UNET Model"""
        # Contracting Path
        c1 = conv2d_block(input_img, n_filters * 1, kernel_size = 3, batchnorm = batchnorm)
        p1 = MaxPooling2D((2, 2))(c1)
        p1 = Dropout(dropout)(p1)

        c2 = conv2d_block(p1, n_filters * 2, kernel_size = 3, batchnorm = batchnorm)
        p2 = MaxPooling2D((2, 2))(c2)
        p2 = Dropout(dropout)(p2)

        c3 = conv2d_block(p2, n_filters * 4, kernel_size = 3, batchnorm = batchnorm)
        p3 = MaxPooling2D((2, 2))(c3)
        p3 = Dropout(dropout)(p3)

        c4 = conv2d_block(p3, n_filters * 8, kernel_size = 3, batchnorm = batchnorm)
        p4 = MaxPooling2D((2, 2))(c4)
        p4 = Dropout(dropout)(p4)

        c5 = conv2d_block(p4, n_filters = n_filters * 16, kernel_size = 3, batchnorm = batchnorm)

        # Expansive Path
        u6 = Conv2DTranspose(n_filters * 8, (3, 3), strides = (2, 2), padding = 'same')(c5)
        u6 = concatenate([u6, c4])
        u6 = Dropout(dropout)(u6)
        c6 = conv2d_block(u6, n_filters * 8, kernel_size = 3, batchnorm = batchnorm)

        u7 = Conv2DTranspose(n_filters * 4, (3, 3), strides = (2, 2), padding = 'same')(c6)
        u7 = concatenate([u7, c3])
        u7 = Dropout(dropout)(u7)
        c7 = conv2d_block(u7, n_filters * 4, kernel_size = 3, batchnorm = batchnorm)

        u8 = Conv2DTranspose(n_filters * 2, (3, 3), strides = (2, 2), padding = 'same')(c7)
        u8 = concatenate([u8, c2])
        u8 = Dropout(dropout)(u8)
        c8 = conv2d_block(u8, n_filters * 2, kernel_size = 3, batchnorm = batchnorm)

        u9 = Conv2DTranspose(n_filters * 1, (3, 3), strides = (2, 2), padding = 'same')(c8)
        u9 = concatenate([u9, c1])
        u9 = Dropout(dropout)(u9)
        c9 = conv2d_block(u9, n_filters * 1, kernel_size = 3, batchnorm = batchnorm)

        outputs = Conv2D(1, (1, 1), activation='sigmoid')(c9)
        model = Model(input_img, outputs)
        #model.summary()
        return model

    def get_encoded_path(path):
        """
        Trim local fs url to absolute path
        e.g. from "file:///tmp/d.txt" to "/tmp/d.txt"
        """
        if path.startswith("file://"):
            return path[7:]
        return path

    def local_file(base_path):
        """
        Downloads file locally
        :param base_path: string to remote file system url
        :return: temp_path: string to local file system path
        """
        file = c3.LocalFileSystem.makeTmpFile().url
        c3.Client.copyFilesToLocalClient(srcUrlOrEncodedPath=base_path, localPath=file)
        temp_path = os.path.join(get_encoded_path(file), os.path.basename(base_path))
        return temp_path
    #=====================================================end def util functions

    # prediction params
    THRESHOLD = 0.5
    img_size = 224
    PAD = 64
    add_gcvi = True
    batch_size = 32
    
    # get UNet model
    #input_img = Input((img_size, img_size, 5), name='img')
    #model = get_unet(input_img, n_filters=32, dropout=0.15, batchnorm=True)

    # download weight and load it
    import requests
    import os
    for (name, url) in zip(['weight.tf.data-00000-of-00001', 'weight.tf.index'], 
        ['https://drive.google.com/uc?export=download&id=1u5tp5WoUiTPuVXltL1LCo_uR_YGu5Njm', 
        'https://drive.google.com/uc?export=download&id=1bhzwEFf9H7OGWw7jGr0TKnjrFnET0SWv']):
        tmp_path = "/tmp/" + name
        if os.path.isfile(tmp_path):
            print("skipping")
            continue
        with requests.get(url, stream=True) as r:
            r.raise_for_status()
            with open(tmp_path, 'wb') as f:
                for chunk in r.iter_content(chunk_size=8192):
                    f.write(chunk)
    #model.load_weights("/tmp/weight.tf")
    
    tmp_url = this.processed_image_file.url
    tmp_local = local_file(tmp_url)
    
    updated = c3.PlanetFile(**{'id':this.id})
    if(this.external_processed_path != None):
        print(updated)
        try:
            updated.status = 'predicting'

            # read tif files add gcvi band
            import rasterio
            import numpy as np
            base_img = rasterio.open(tmp_local).read()
            base_img = np.transpose(base_img, (1, 2, 0))
            base_img = base_img[:, :, :4]
            if add_gcvi:
                gcvi = base_img[:, :, 3] / base_img[:, :, 1]
                gcvi = gcvi - 1
                gcvi[gcvi > 20] = 20
                gcvi[gcvi < 0] = 0
                gcvi = np.nan_to_num(gcvi, False, 0, 0, 0)
                gcvi = np.expand_dims(gcvi, -1)
                base_img = np.concatenate([base_img, gcvi], 2) 

            # cut image into 224*224 slice for prediction
            h, w, _ = base_img.shape
            center_size = (img_size - 2*PAD)
            h_count = int(h / center_size) + 1
            w_count = int(w / center_size) + 1
            h_padded = h_count * center_size
            w_padded = w_count * center_size
            base_img = np.pad(base_img, ((0, h_padded - h), (0, w_padded-w), (0, 0)), 'constant')
            base_img = np.pad(base_img, ((PAD, PAD), (PAD, PAD), (0, 0)), 'constant')
            input_img = []
            x = 0
            while x < h_padded - PAD:
                y = 0
                while y < w_padded - PAD:
                    input_img.append(base_img[x : x + img_size, y : y + img_size, :])
                    y += center_size
                x += center_size
            input_img = np.array(input_img)
            
            # predict
            #out = model.predict(input_img, batch_size = batch_size, verbose = 1)
            print(input_img.shape)
            out = np.expand_dims(input_img[..., 0], 3)
            print(out.shape)
            
            # put prediction result back into big img
            combined = np.zeros((h_padded, w_padded))
            x = 0
            idx = 0
            while x < combined.shape[0]:
                y = 0
                while y < combined.shape[1]:
                    combined[x : x + center_size, y : y + center_size] = np.squeeze(out[idx][PAD:-PAD, PAD:-PAD, :], 2)
                    y += center_size
                    idx += 1
                x += center_size
            combined_cut = np.array(combined)
            combined_cut = combined_cut[:h, :w]
            
            # !TODO: this part is not tested
            # save npy file    
            file_name = os.path.basename(this.external_processed_path)
            npy_path = "/tmp/" + file_name.replace('-warp.tif', 'npy')
            np.save(npy_path, combined_cut)
            
            # save tif files
            meta = rasterio.open(tmp_local).meta.copy()
            meta.update({
                'count':1,
                'dtype':np.uint8
            })
            combined_cut[combined_cut > 0.5] = 1
            combined_cut[combined_cut < 1] = 0
            combined_cut = combined_cut.astype(np.uint8)
            with rasterio.open(npy_path.replace('npy', '-pred.tif'), 'w', **meta) as dest:
                dest.write(np.expand_dims(combined_cut, 0))
            
            # upload result
            updated.external_npy_path = this.external_processed_path.replace("-warp.tif", "npy")
            c3.Client.uploadLocalClientFiles(
                localPath=npy_path, 
                dstUrlOrEncodedPath=os.path.dirname(updated.external_npy_path), 
                spec={"peekForMetadata": True})
            updated.npy_result = c3.File(**{'url': updated.external_npy_path}).readMetadata()

            updated.external_pred_path = this.external_processed_path.replace("warp", "pred")
            c3.Client.uploadLocalClientFiles(
                localPath=npy_path.replace('npy', '-pred.tif'), 
                dstUrlOrEncodedPath=os.path.dirname(updated.external_pred_path), 
                spec={"peekForMetadata": True})
            updated.tif_result = c3.File(**{'url': updated.external_pred_path}).readMetadata()
            
            updated.status = 'preprocessed'
            updated.merge()
        
        except Exception as e:
            updated.status = 'error'
            updated.merge()
            raise e

    return (updated.external_npy_path, updated.external_pred_path)

# %%
test_file.status = 'preprocessed'
predict_image(test_file)
# Out:
# 2022-02-17 23:04:49.343480: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# skipping
# skipping
# c3.PlanetFile(id='test1_503-1250')
# /home/c3/.conda/envs/py-image/lib/python3.7/site-packages/ipykernel_launcher.py:141: RuntimeWarning: divide by zero encountered in true_divide
# /home/c3/.conda/envs/py-image/lib/python3.7/site-packages/ipykernel_launcher.py:141: RuntimeWarning: invalid value encountered in true_divide
# (3249, 224, 224, 5)
# (3249, 224, 224, 1)
# Exception in thread Thread-9:
# Traceback (most recent call last):
#   File "/home/c3/.conda/envs/py-image/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/home/c3/.conda/envs/py-image/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<string>", line 131, in func_wrapper
#   File "<string>", line 222, in uploader
# FileNotFoundError: [Errno 2] No such file or directory: '/tmp/503-1250npy'
# ('yifang_guan/planet_collection/raw/test1/503-1250npy',
#  'yifang_guan/planet_collection/raw/test1/503-1250-pred.tif')

# %%
test_file = c3.PlanetFile.get("test1_503-1250")
test_file
# Out:
# c3.PlanetFile(
#  id='test1_503-1250',
#  name='503-1250',
#  meta=c3.Meta(
#         tenantTagId=152,
#         tenant='dev',
#         tag='tc03d',
#         created=datetime.datetime(2022, 2, 17, 22, 10, 32, tzinfo=datetime.timezone.utc),
#         createdBy='yihongj2@illinois.edu',
#         updated=datetime.datetime(2022, 2, 17, 23, 5, 9, tzinfo=datetime.timezone.utc),
#         updatedBy='yihongj2@illinois.edu',
#         timestamp=datetime.datetime(2022, 2, 17, 23, 5, 9, tzinfo=datetime.timezone.utc),
#         fetchInclude='[]',
#         fetchType='PlanetFile'),
#  version=6,
#  planet_collector=c3.PlanetCollector(id='test1'),
#  raw_image_file=c3.AzureFile(
#                   contentLength=116114557,
#                   contentLocation='fs/dti/mpodolsky/yifang_guan/planet_collection/raw/test1/503-1250.tif',
#                   contentType='application/json',
#                   eTag='"0x8D9F262FD7F43E0"',
#                   lastModified=datetime.datetime(2022, 2, 17, 22, 15, 22, tzinfo=datetime.timezone.utc),
#                   contentMD5='2gaILUOvX1lKgtlPsitrew==',
#                   hasMetadata=True,
#                   url='azure://dev-dti/fs/dti/mpodolsky/yifang_guan/planet_collection/raw/test1/503-1250.tif',
#                   blobType='BLOCK_BLOB'),
#  processed_image_file=c3.AzureFile(
#                         contentLength=297711616,
#                         contentLocation='fs/dti/mpodolsky/yifang_guan/planet_collection/raw/test1/503-1250-warp.tif',
#                         contentType='application/json',
#                         eTag='"0x8D9F26434348F06"',
#                         lastModified=datetime.datetime(2022, 2, 17, 22, 24, 3, tzinfo=datetime.timezone.utc),
#                         contentMD5='yvWXnjicmIlJjgFbloUlrg==',
#                         hasMetadata=True,
#                         url='azure://dev-dti/fs/dti/mpodolsky/yifang_guan/planet_collection/raw/test1/503-1250-warp.tif',
#                         blobType='BLOCK_BLOB'),
#  npy_result=c3.File(
#               hasMetadata=False,
#               url='yifang_guan/planet_collection/raw/test1/503-1250npy'),
#  tif_result=c3.AzureFile(
#               contentLength=29800845,
#               contentLocation='fs/dti/mpodolsky/yifang_guan/planet_collection/raw/test1/503-1250-pred.tif',
#               contentType='application/json',
#               eTag='"0x8D9F269F2293112"',
#               lastModified=datetime.datetime(2022, 2, 17, 23, 5, 9, tzinfo=datetime.timezone.utc),
#               contentMD5='Y1WlasFXiR2np8XvtZwOsw==',
#               hasMetadata=True,
#               url='azure://dev-dti/fs/dti/mpodolsky/yifang_guan/planet_collection/raw/test1/503-1250-pred.tif',
#               blobType='BLOCK_BLOB'),
#  query_url='https://api.planet.com/basemaps/v1/mosaics/56f00cc2-6be4-4315-9603-c75d6afab225/quads/503-1250/full?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b',
#  external_raw_path='yifang_guan/planet_collection/raw/test1/503-1250.tif',
#  external_processed_path='yifang_guan/planet_collection/raw/test1/503-1250-warp.tif',
#  external_npy_path='yifang_guan/planet_collection/raw/test1/503-1250npy',
#  external_pred_path='yifang_guan/planet_collection/raw/test1/503-1250-pred.tif',
#  status='preprocessed')
