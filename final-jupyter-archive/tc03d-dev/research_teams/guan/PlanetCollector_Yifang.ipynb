# %%
## Planet collector ##

# %% [markdown]
# ## Testing using the PlanetCollector Type ##

# %%
test_PC = c3.PlanetCollector.get("test2")
if(test_PC):
    pass
else:
    test2 = c3.PlanetCollector(
        **{
            "id": "test2",
            "base_url": "GUAN1",
            "num_images": 10
        }
    )

    test2.merge()
    
    test_PC = c3.PlanetCollector.get("test2")

# %%
test_PC.stage_blob_image()
## execution queued 16:20:10 2022-04-20 ##
# Out:
# 'azure://mw-1708w1/'

# %% [markdown]
# ## Testing for PlanetCollector on Container FS ##

# %%
## testing the file system usage ##
folder_path = c3.FileSystem.inst().urlFromMountAndRelativeEncodedPath("GUAN1")
fps = c3.FileSystem.inst().listFiles(folder_path)

# %%
test = c3.FileSystem.inst()
test
# Out:
# c3.AzureFileSystem()

# %%
for fp in fps.files:
    if(".tif" in fp.contentLocation):
        print(fp.url)
# Out:
# azure://mw-1708w1/432-1279.tif
# azure://mw-1708w1/432-1280.tif
# azure://mw-1708w1/432-1281.tif
# azure://mw-1708w1/432-1282.tif
# azure://mw-1708w1/432-1283.tif
# azure://mw-1708w1/432-1284.tif
# azure://mw-1708w1/432-1285.tif
# azure://mw-1708w1/432-1286.tif
# azure://mw-1708w1/432-1287.tif
# azure://mw-1708w1/432-1288.tif
# azure://mw-1708w1/432-1289.tif
# azure://mw-1708w1/432-1290.tif
# azure://mw-1708w1/432-1291.tif
# azure://mw-1708w1/432-1292.tif
# azure://mw-1708w1/432-1293.tif
# azure://mw-1708w1/432-1294.tif
# azure://mw-1708w1/432-1295.tif
# azure://mw-1708w1/432-1296.tif
# azure://mw-1708w1/432-1297.tif
# azure://mw-1708w1/432-1298.tif
# azure://mw-1708w1/432-1299.tif
# azure://mw-1708w1/432-1300.tif
# azure://mw-1708w1/432-1301.tif
# azure://mw-1708w1/432-1302.tif
# azure://mw-1708w1/432-1303.tif
# azure://mw-1708w1/432-1304.tif
# azure://mw-1708w1/432-1305.tif
# azure://mw-1708w1/432-1306.tif
# azure://mw-1708w1/432-1307.tif
# azure://mw-1708w1/432-1308.tif
# ...

# %%
all_path = fps.files[0].url
all_path
# Out:
# 'azure://mw-1708w1/432-1279.tif'

# %%
c3file = c3.File(**{'url': all_path})

# %%
c3file.readMetadata()
# Out:
# c3.AzureFile(
#  contentLength=353109400,
#  contentLocation='432-1279.tif',
#  contentType='application/octet-stream',
#  eTag='"0x8D9EE9C21FB7840"',
#  lastModified=datetime.datetime(2022, 2, 13, 2, 54, 20, tzinfo=datetime.timezone.utc),
#  hasMetadata=True,
#  url='azure://mw-1708w1/432-1279.tif',
#  blobType='BLOCK_BLOB')

# %%
base_url = "GUAN1"

## load the list of files ##
folder_path = c3.FileSystem.inst().urlFromMountAndRelativeEncodedPath(base_url)
fps = c3.FileSystem.inst().listFiles(folder_path)

# %%
images_path = [] # in theory it will be id and file_path
for fp in fps.files:
    if(".tif" in fp.contentLocation):
        fp_id = fp.contentLocation.split("/")[-1].split(".tif")[0]
        fp_location = fp.url
        images_path.append({'id': fp_id, 'location': fp_location})

images_path
# Out:
# [{'id': '432-1279', 'location': 'azure://mw-1708w1/432-1279.tif'},
#  {'id': '432-1280', 'location': 'azure://mw-1708w1/432-1280.tif'},
#  {'id': '432-1281', 'location': 'azure://mw-1708w1/432-1281.tif'},
#  {'id': '432-1282', 'location': 'azure://mw-1708w1/432-1282.tif'},
#  {'id': '432-1283', 'location': 'azure://mw-1708w1/432-1283.tif'},
#  {'id': '432-1284', 'location': 'azure://mw-1708w1/432-1284.tif'},
#  {'id': '432-1285', 'location': 'azure://mw-1708w1/432-1285.tif'},
#  {'id': '432-1286', 'location': 'azure://mw-1708w1/432-1286.tif'},
#  {'id': '432-1287', 'location': 'azure://mw-1708w1/432-1287.tif'},
#  {'id': '432-1288', 'location': 'azure://mw-1708w1/432-1288.tif'},
#  {'id': '432-1289', 'location': 'azure://mw-1708w1/432-1289.tif'},
#  {'id': '432-1290', 'location': 'azure://mw-1708w1/432-1290.tif'},
#  {'id': '432-1291', 'location': 'azure://mw-1708w1/432-1291.tif'},
#  {'id': '432-1292', 'location': 'azure://mw-1708w1/432-1292.tif'},
# ...

# %%
images_path[0:10]
# Out:
# [{'id': '432-1279', 'location': 'azure://mw-1708w1/432-1279.tif'},
#  {'id': '432-1280', 'location': 'azure://mw-1708w1/432-1280.tif'},
#  {'id': '432-1281', 'location': 'azure://mw-1708w1/432-1281.tif'},
#  {'id': '432-1282', 'location': 'azure://mw-1708w1/432-1282.tif'},
#  {'id': '432-1283', 'location': 'azure://mw-1708w1/432-1283.tif'},
#  {'id': '432-1284', 'location': 'azure://mw-1708w1/432-1284.tif'},
#  {'id': '432-1285', 'location': 'azure://mw-1708w1/432-1285.tif'},
#  {'id': '432-1286', 'location': 'azure://mw-1708w1/432-1286.tif'},
#  {'id': '432-1287', 'location': 'azure://mw-1708w1/432-1287.tif'},
#  {'id': '432-1288', 'location': 'azure://mw-1708w1/432-1288.tif'}]

# %%
all_files = []
for i in images_path:
    PRF = c3.PlanetFile(
        **{
            "id": 'test2' + '_' + i['id'],
            "planet_collector": 'test2',
            "name": i['id'],
            "query_url": i['location'],
            "status": "preprocessed",                                       ## this happening because this new dataset is preprocessed already ##
            "processed_image_file": c3.File(**{'url': i['location']}),      ## this happening because this new dataset is preprocessed already ##
            "external_processed_path": i['location'] 
        }
    )
    all_files.append(PRF)

# %%
c3.PlanetFile.mergeBatch(objs=all_files)
# Out:
# c3.ObjList<PlanetFile>(
#  stats=c3.Stats(
#          createdObjCount=5000,
#          updatedObjCount=0,
#          removedObjCount=0,
#          failedObjCount=0,
#          objCount=5000,
#          dbWait=0.0,
#          time=3.531,
#          dbTime=1.599873659,
#          objsPerSecond=1416.029453412631,
#          dbObjsPerSecond=3125.246779252086),
#  objs=c3.Arry<PlanetFile>([c3.PlanetFile(
#          id='test2_432-1279',
#          name='432-1279',
#          meta=c3.Meta(
#                 created=datetime.datetime(2022, 4, 20, 20, 8, 7, tzinfo=datetime.timezone.utc),
#                 updated=datetime.datetime(2022, 4, 20, 20, 8, 7, tzinfo=datetime.timezone.utc),
#                 timestamp=datetime.datetime(2022, 4, 20, 20, 8, 7, tzinfo=datetime.timezone.utc)),
#          version=1),
#         c3.PlanetFile(
#          id='test2_432-1280',
#          name='432-1280',
#          meta=c3.Meta(
# ...

# %% [markdown]
# ## Archive Content ##

# %%
import os, uuid
from azure.storage.blob import BlobServiceClient, BlobClient, ContainerClient, __version__

try:
    print("Azure Blob Storage v" + __version__ + " - Python quickstart sample")

    # Quick start code goes here

except Exception as ex:
    print('Exception:')
    print(ex)
# Out:
# Azure Blob Storage v12.9.0 - Python quickstart sample

# %%
## import the token and url (expire June 30th) ##
token = "si=c3aisuite&sv=2020-08-04&sr=c&sig=MAcRXKeRQlZ9ItIr%2Flex8ICzyLEm%2FFxPQ79ZKo6xIX4%3D"
url = "https://yihongponding.blob.core.windows.net/mw-1708w1?si=c3aisuite&sv=2020-08-04&sr=c&sig=MAcRXKeRQlZ9ItIr%2Flex8ICzyLEm%2FFxPQ79ZKo6xIX4%3D"

# %%
#Only need to do this once

'''
test = c3.PlanetCollector(
    **{
        "id": "test1",
        "base_url": "https://api.planet.com/basemaps/v1/mosaics/",
        "mosaic_id": "56f00cc2-6be4-4315-9603-c75d6afab225",
        "api_key": "8fb5d85cdcfc40f6b4b9d3f44227142b",
        "start_lon": -91.51307900019566,
        "start_lat": 36.970297999852846,
        "end_lon": -87.49519900023363,
        "end_lat": 42.50848099959849
    }
)

test.merge()
'''
