# %%
import gdal as gdal

# %%
gdal.listdir()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1621/2461636840.py in <module>
# ----> 1 gdal.listdir()
#
# TypeError: listdir() missing 1 required positional argument: 'path'

# %%
from osgeo import gdal

# %%
gdal.__version__
# Out:
# '3.0.2'

# %%
gdal.__path__
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1621/3623018186.py in <module>
# ----> 1 gdal.__path__
#
# AttributeError: module 'osgeo.gdal' has no attribute '__path__'

# %%
print(gdal.PopFinderLocation())
# Out:
# None

# %%
gdal.GetConfigOption()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1621/3182050611.py in <module>
# ----> 1 gdal.GetConfigOption()
#
# ~/.conda/envs/py-image_preprocess/lib/python3.7/site-packages/osgeo/gdal.py in GetConfigOption(*args)
#    1494 def GetConfigOption(*args):
#    1495     """GetConfigOption(char const * pszKey, char const * pszDefault=None) -> char const *"""
# -> 1496     return _gdal.GetConfigOption(*args)
#    1497
#    1498 def CPLBinaryToHex(*args):
#
# TypeError: GetConfigOption() takes at least 1 argument (0 given)

# %%
gdal.GetDriverCount()
# Out:
# 217

# %%
gdal.InfoInternal()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1621/3979797763.py in <module>
# ----> 1 gdal.InfoInternal()
#
# ~/.conda/envs/py-image_preprocess/lib/python3.7/site-packages/osgeo/gdal.py in InfoInternal(*args)
#    3354 def InfoInternal(*args):
#    3355     """InfoInternal(Dataset hDataset, GDALInfoOptions infoOptions) -> retStringAndCPLFree *"""
# -> 3356     return _gdal.InfoInternal(*args)
#    3357 class GDALTranslateOptions(_object):
#    3358     """Proxy of C++ GDALTranslateOptions class."""
#
# TypeError: InfoInternal() takes exactly 2 arguments (0 given)

# %%
gdal.array_modes
# Out:
# {3: '<i2',
#  2: '<u2',
#  5: '<i4',
#  4: '<u4',
#  6: '<f4',
#  7: '<f8',
#  10: '<f4',
#  11: '<f8',
#  1: '<t8'}

# %%
help(gdal)
# Out:
# Help on module osgeo.gdal in osgeo:
#
# NAME
#     osgeo.gdal
#
# DESCRIPTION
#     # This file was automatically generated by SWIG (http://www.swig.org).
#     # Version 3.0.8
#     #
#     # Do not make changes to this file unless you know what you are doing--modify
#     # the SWIG interface file instead.
#
# CLASSES
#     builtins.object
#         AsyncReader
#         ColorEntry
#         ColorTable
#         DirEntry
#         GCP
#         GDALBuildVRTOptions
#         GDALDEMProcessingOptions
#         GDALGridOptions
#         GDALInfoOptions
#         GDALNearblackOptions
#         GDALRasterizeOptions
#         GDALTransformerInfoShadow
#         GDALTranslateOptions
#         GDALVectorTranslateOptions
#         GDALWarpAppOptions
#         MajorObject
#             Band
#             Dataset
#             Driver
#         RasterAttributeTable
#         StatBuf
#         VSILFILE
#         VirtualMem
#
#     class AsyncReader(builtins.object)
# ...

# %%
gdal.path
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1621/3611124454.py in <module>
# ----> 1 gdal.path
#
# AttributeError: module 'osgeo.gdal' has no attribute 'path'

# %%
import osgeo

# %%
osgeo.__path__
# Out:
# ['/home/c3/.conda/envs/py-image_preprocess/lib/python3.7/site-packages/osgeo']

# %%
root = osgeo.__path__[0].split('/')[0:-4]
s = '/'
root = s.join(root)

# %%
root
# Out:
# '/home/c3/.conda/envs/py-image_preprocess'

# %%
s.join(root)
# Out:
# '/home/c3/.conda/envs/py-image_preprocess'

# %%
root = osgeo.__path__[0].split('/')[0:-4]

# %%
'/'.join(root)
# Out:
# '/home/c3/.conda/envs/py-image_preprocess'

# %%
root
# Out:
# ['', 'home', 'c3', '.conda', 'envs', 'py-image_preprocess']

# %%
root = '/'.join(osgeo.__path__[0].split('/')[0:-4])

# %%
root
# Out:
# '/home/c3/.conda/envs/py-image_preprocess'
