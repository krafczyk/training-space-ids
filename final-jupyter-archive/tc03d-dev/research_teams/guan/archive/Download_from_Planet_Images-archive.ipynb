# %%
import os
import requests
from requests.auth import HTTPBasicAuth
import json
import urllib.request
from tqdm import tqdm

# %%
# authentication
BASE_URL = 'https://api.planet.com/basemaps/v1/mosaics/'
API_KEY = "8fb5d85cdcfc40f6b4b9d3f44227142b" # [from Yihong]
auth = HTTPBasicAuth(API_KEY, '')

# %%
mosaic_id = '56f00cc2-6be4-4315-9603-c75d6afab225' # should probablity convert to args
url = f'https://api.planet.com/basemaps/v1/mosaics/{mosaic_id}/quads'
bbox = '-91.51307900019566, 36.970297999852846, -87.49519900023363, 42.50848099959849' #update bbox and page_size

# %%
res = requests.get(url=url, auth=auth, params={'bbox':bbox, '_page_size':99999}) 
out = json.loads(res.text)
out
# Out:
# {'_links': {'_self': 'https://api.planet.com/basemaps/v1/mosaics/56f00cc2-6be4-4315-9603-c75d6afab225/quads?_page_size=99999&api_key=8fb5d85cdcfc40f6b4b9d3f44227142b&bbox=-91.51307900019566%2C+36.970297999852846%2C+-87.49519900023363%2C+42.50848099959849'},
#  'items': [{'_links': {'_self': 'https://api.planet.com/basemaps/v1/mosaics/56f00cc2-6be4-4315-9603-c75d6afab225/quads/503-1291?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b',
#     'download': 'https://api.planet.com/basemaps/v1/mosaics/56f00cc2-6be4-4315-9603-c75d6afab225/quads/503-1291/full?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b',
#     'items': 'https://api.planet.com/basemaps/v1/mosaics/56f00cc2-6be4-4315-9603-c75d6afab225/quads/503-1291/items?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b',
#     'thumbnail': 'https://tiles.planet.com/basemaps/v1/planet-tiles/ps_weekly_sen2_normalized_analytic_subscription_2020-08-10_2020-08-17_mosaic/gmap/11/503/756.png?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b'},
#    'bbox': [-91.58203123722404,
#     42.42345651316795,
#     -91.40624998724846,
#     42.553080284177334],
#    'id': '503-1291',
#    'percent_covered': 100},
#   {'_links': {'_self': 'https://api.planet.com/basemaps/v1/mosaics/56f00cc2-6be4-4315-9603-c75d6afab225/quads/504-1291?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b',
#     'download': 'https://api.planet.com/basemaps/v1/mosaics/56f00cc2-6be4-4315-9603-c75d6afab225/quads/504-1291/full?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b',
#     'items': 'https://api.planet.com/basemaps/v1/mosaics/56f00cc2-6be4-4315-9603-c75d6afab225/quads/504-1291/items?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b',
#     'thumbnail': 'https://tiles.planet.com/basemaps/v1/planet-tiles/ps_weekly_sen2_normalized_analytic_subscription_2020-08-10_2020-08-17_mosaic/gmap/11/504/756.png?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b'},
#    'bbox': [-91.40624998724846,
#     42.42345651316795,
#     -91.23046873727287,
#     42.553080284177334],
#    'id': '504-1291',
#    'percent_covered': 100},
#   {'_links': {'_self': 'https://api.planet.com/basemaps/v1/mosaics/56f00cc2-6be4-4315-9603-c75d6afab225/quads/505-1291?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b',
#     'download': 'https://api.planet.com/basemaps/v1/mosaics/56f00cc2-6be4-4315-9603-c75d6afab225/quads/505-1291/full?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b',
#     'items': 'https://api.planet.com/basemaps/v1/mosaics/56f00cc2-6be4-4315-9603-c75d6afab225/quads/505-1291/items?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b',
#     'thumbnail': 'https://tiles.planet.com/basemaps/v1/planet-tiles/ps_weekly_sen2_normalized_analytic_subscription_2020-08-10_2020-08-17_mosaic/gmap/11/505/756.png?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b'},
#    'bbox': [-91.23046873727286,
#     42.42345651316795,
#     -91.05468748729727,
#     42.553080284177334],
#    'id': '505-1291',
#    'percent_covered': 100},
#   {'_links': {'_self': 'https://api.planet.com/basemaps/v1/mosaics/56f00cc2-6be4-4315-9603-c75d6afab225/quads/506-1291?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b',
#     'download': 'https://api.planet.com/basemaps/v1/mosaics/56f00cc2-6be4-4315-9603-c75d6afab225/quads/506-1291/full?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b',
#     'items': 'https://api.planet.com/basemaps/v1/mosaics/56f00cc2-6be4-4315-9603-c75d6afab225/quads/506-1291/items?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b',
#     'thumbnail': 'https://tiles.planet.com/basemaps/v1/planet-tiles/ps_weekly_sen2_normalized_analytic_subscription_2020-08-10_2020-08-17_mosaic/gmap/11/506/756.png?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b'},
#    'bbox': [-91.05468748729727,
#     42.42345651316795,
#     -90.87890623732169,
#     42.553080284177334],
#    'id': '506-1291',
#    'percent_covered': 100},
#   {'_links': {'_self': 'https://api.planet.com/basemaps/v1/mosaics/56f00cc2-6be4-4315-9603-c75d6afab225/quads/507-1291?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b',
#     'download': 'https://api.planet.com/basemaps/v1/mosaics/56f00cc2-6be4-4315-9603-c75d6afab225/quads/507-1291/full?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b',
#     'items': 'https://api.planet.com/basemaps/v1/mosaics/56f00cc2-6be4-4315-9603-c75d6afab225/quads/507-1291/items?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b',
#     'thumbnail': 'https://tiles.planet.com/basemaps/v1/planet-tiles/ps_weekly_sen2_normalized_analytic_subscription_2020-08-10_2020-08-17_mosaic/gmap/11/507/756.png?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b'},
#    'bbox': [-90.87890623732169,
#     42.42345651316795,
#     -90.70312498734611,
#     42.553080284177334],
#    'id': '507-1291',
#    'percent_covered': 100},
#   {'_links': {'_self': 'https://api.planet.com/basemaps/v1/mosaics/56f00cc2-6be4-4315-9603-c75d6afab225/quads/508-1291?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b',
#     'download': 'https://api.planet.com/basemaps/v1/mosaics/56f00cc2-6be4-4315-9603-c75d6afab225/quads/508-1291/full?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b',
#     'items': 'https://api.planet.com/basemaps/v1/mosaics/56f00cc2-6be4-4315-9603-c75d6afab225/quads/508-1291/items?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b',
#     'thumbnail': 'https://tiles.planet.com/basemaps/v1/planet-tiles/ps_weekly_sen2_normalized_analytic_subscription_2020-08-10_2020-08-17_mosaic/gmap/11/508/756.png?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b'},
#    'bbox': [-90.70312498734611,
#     42.42345651316795,
#     -90.52734373737053,
#     42.553080284177334],
#    'id': '508-1291',
#    'percent_covered': 100},
#   {'_links': {'_self': 'https://api.planet.com/basemaps/v1/mosaics/56f00cc2-6be4-4315-9603-c75d6afab225/quads/509-1291?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b',
#     'download': 'https://api.planet.com/basemaps/v1/mosaics/56f00cc2-6be4-4315-9603-c75d6afab225/quads/509-1291/full?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b',
#     'items': 'https://api.planet.com/basemaps/v1/mosaics/56f00cc2-6be4-4315-9603-c75d6afab225/quads/509-1291/items?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b',
#     'thumbnail': 'https://tiles.planet.com/basemaps/v1/planet-tiles/ps_weekly_sen2_normalized_analytic_subscription_2020-08-10_2020-08-17_mosaic/gmap/11/509/756.png?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b'},
#    'bbox': [-90.52734373737053,
#     42.42345651316795,
#     -90.35156248739494,
#     42.553080284177334],
#    'id': '509-1291',
#    'percent_covered': 100},
#   {'_links': {'_self': 'https://api.planet.com/basemaps/v1/mosaics/56f00cc2-6be4-4315-9603-c75d6afab225/quads/510-1291?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b',
#     'download': 'https://api.planet.com/basemaps/v1/mosaics/56f00cc2-6be4-4315-9603-c75d6afab225/quads/510-1291/full?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b',
#     'items': 'https://api.planet.com/basemaps/v1/mosaics/56f00cc2-6be4-4315-9603-c75d6afab225/quads/510-1291/items?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b',
#     'thumbnail': 'https://tiles.planet.com/basemaps/v1/planet-tiles/ps_weekly_sen2_normalized_analytic_subscription_2020-08-10_2020-08-17_mosaic/gmap/11/510/756.png?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b'},
#    'bbox': [-90.35156248739493,
#     42.42345651316795,
#     -90.17578123741934,
#     42.553080284177334],
#    'id': '510-1291',
#    'percent_covered': 100},
#   {'_links': {'_self': 'https://api.planet.com/basemaps/v1/mosaics/56f00cc2-6be4-4315-9603-c75d6afab225/quads/511-1291?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b',
#     'download': 'https://api.planet.com/basemaps/v1/mosaics/56f00cc2-6be4-4315-9603-c75d6afab225/quads/511-1291/full?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b',
#     'items': 'https://api.planet.com/basemaps/v1/mosaics/56f00cc2-6be4-4315-9603-c75d6afab225/quads/511-1291/items?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b',
#     'thumbnail': 'https://tiles.planet.com/basemaps/v1/planet-tiles/ps_weekly_sen2_normalized_analytic_subscription_2020-08-10_2020-08-17_mosaic/gmap/11/511/756.png?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b'},
#    'bbox': [-90.17578123741934,
#     42.42345651316795,
#     -89.99999998744377,
#     42.553080284177334],
#    'id': '511-1291',
#    'percent_covered': 100},
#   {'_links': {'_self': 'https://api.planet.com/basemaps/v1/mosaics/56f00cc2-6be4-4315-9603-c75d6afab225/quads/512-1291?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b',
#     'download': 'https://api.planet.com/basemaps/v1/mosaics/56f00cc2-6be4-4315-9603-c75d6afab225/quads/512-1291/full?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b',
#     'items': 'https://api.planet.com/basemaps/v1/mosaics/56f00cc2-6be4-4315-9603-c75d6afab225/quads/512-1291/items?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b',
#     'thumbnail': 'https://tiles.planet.com/basemaps/v1/planet-tiles/ps_weekly_sen2_normalized_analytic_subscription_2020-08-10_2020-08-17_mosaic/gmap/11/512/756.png?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b'},
#    'bbox': [-89.99999998744377,
#     42.42345651316795,
#     -89.82421873746817,
#     42.553080284177334],
#    'id': '512-1291',
#    'percent_covered': 100},
#   {'_links': {'_self': 'https://api.planet.com/basemaps/v1/mosaics/56f00cc2-6be4-4315-9603-c75d6afab225/quads/513-1291?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b',
#     'download': 'https://api.planet.com/basemaps/v1/mosaics/56f00cc2-6be4-4315-9603-c75d6afab225/quads/513-1291/full?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b',
#     'items': 'https://api.planet.com/basemaps/v1/mosaics/56f00cc2-6be4-4315-9603-c75d6afab225/quads/513-1291/items?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b',
#     'thumbnail': 'https://tiles.planet.com/basemaps/v1/planet-tiles/ps_weekly_sen2_normalized_analytic_subscription_2020-08-10_2020-08-17_mosaic/gmap/11/513/756.png?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b'},
#    'bbox': [-89.82421873746817,
#     42.42345651316795,
#     -89.6484374874926,
#     42.553080284177334],
#    'id': '513-1291',
#    'percent_covered': 100},
#   {'_links': {'_self': 'https://api.planet.com/basemaps/v1/mosaics/56f00cc2-6be4-4315-9603-c75d6afab225/quads/514-1291?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b',
#     'download': 'https://api.planet.com/basemaps/v1/mosaics/56f00cc2-6be4-4315-9603-c75d6afab225/quads/514-1291/full?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b',
#     'items': 'https://api.planet.com/basemaps/v1/mosaics/56f00cc2-6be4-4315-9603-c75d6afab225/quads/514-1291/items?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b',
#     'thumbnail': 'https://tiles.planet.com/basemaps/v1/planet-tiles/ps_weekly_sen2_normalized_analytic_subscription_2020-08-10_2020-08-17_mosaic/gmap/11/514/756.png?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b'},
#    'bbox': [-89.6484374874926,
#     42.42345651316795,
#     -89.47265623751701,
#     42.553080284177334],
#    'id': '514-1291',
#    'percent_covered': 100},
#   {'_links': {'_self': 'https://api.planet.com/basemaps/v1/mosaics/56f00cc2-6be4-4315-9603-c75d6afab225/quads/515-1291?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b',
#     'download': 'https://api.planet.com/basemaps/v1/mosaics/56f00cc2-6be4-4315-9603-c75d6afab225/quads/515-1291/full?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b',
#     'items': 'https://api.planet.com/basemaps/v1/mosaics/56f00cc2-6be4-4315-9603-c75d6afab225/quads/515-1291/items?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b',
#     'thumbnail': 'https://tiles.planet.com/basemaps/v1/planet-tiles/ps_weekly_sen2_normalized_analytic_subscription_2020-08-10_2020-08-17_mosaic/gmap/11/515/756.png?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b'},
#    'bbox': [-89.472656237517,
#     42.42345651316795,
#     -89.29687498754141,
#     42.553080284177334],
#    'id': '515-1291',
#    'percent_covered': 100},
#   {'_links': {'_self': 'https://api.planet.com/basemaps/v1/mosaics/56f00cc2-6be4-4315-9603-c75d6afab225/quads/516-1291?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b',
#     'download': 'https://api.planet.com/basemaps/v1/mosaics/56f00cc2-6be4-4315-9603-c75d6afab225/quads/516-1291/full?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b',
#     'items': 'https://api.planet.com/basemaps/v1/mosaics/56f00cc2-6be4-4315-9603-c75d6afab225/quads/516-1291/items?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b',
#     'thumbnail': 'https://tiles.planet.com/basemaps/v1/planet-tiles/ps_weekly_sen2_normalized_analytic_subscription_2020-08-10_2020-08-17_mosaic/gmap/11/516/756.png?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b'},
#    'bbox': [-89.29687498754141,
#     42.42345651316795,
#     -89.12109373756584,
#     42.553080284177334],
#    'id': '516-1291',
#    'percent_covered': 100},
#   {'_links': {'_self': 'https://api.planet.com/basemaps/v1/mosaics/56f00cc2-6be4-4315-9603-c75d6afab225/quads/517-1291?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b',
#     'download': 'https://api.planet.com/basemaps/v1/mosaics/56f00cc2-6be4-4315-9603-c75d6afab225/quads/517-1291/full?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b',
#     'items': 'https://api.planet.com/basemaps/v1/mosaics/56f00cc2-6be4-4315-9603-c75d6afab225/quads/517-1291/items?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b',
#     'thumbnail': 'https://tiles.planet.com/basemaps/v1/planet-tiles/ps_weekly_sen2_normalized_analytic_subscription_2020-08-10_2020-08-17_mosaic/gmap/11/517/756.png?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b'},
#    'bbox': [-89.12109373756584,
#     42.42345651316795,
#     -88.94531248759026,
#     42.553080284177334],
#    'id': '517-1291',
#    'percent_covered': 100},
#   {'_links': {'_self': 'https://api.planet.com/basemaps/v1/mosaics/56f00cc2-6be4-4315-9603-c75d6afab225/quads/518-1291?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b',
#     'download': 'https://api.planet.com/basemaps/v1/mosaics/56f00cc2-6be4-4315-9603-c75d6afab225/quads/518-1291/full?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b',
#     'items': 'https://api.planet.com/basemaps/v1/mosaics/56f00cc2-6be4-4315-9603-c75d6afab225/quads/518-1291/items?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b',
#     'thumbnail': 'https://tiles.planet.com/basemaps/v1/planet-tiles/ps_weekly_sen2_normalized_analytic_subscription_2020-08-10_2020-08-17_mosaic/gmap/11/518/756.png?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b'},
#    'bbox': [-88.94531248759026,
#     42.42345651316795,
#     -88.76953123761467,
#     42.553080284177334],
#    'id': '518-1291',
#    'percent_covered': 100},
#   {'_links': {'_self': 'https://api.planet.com/basemaps/v1/mosaics/56f00cc2-6be4-4315-9603-c75d6afab225/quads/519-1291?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b',
#     'download': 'https://api.planet.com/basemaps/v1/mosaics/56f00cc2-6be4-4315-9603-c75d6afab225/quads/519-1291/full?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b',
#     'items': 'https://api.planet.com/basemaps/v1/mosaics/56f00cc2-6be4-4315-9603-c75d6afab225/quads/519-1291/items?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b',
#     'thumbnail': 'https://tiles.planet.com/basemaps/v1/planet-tiles/ps_weekly_sen2_normalized_analytic_subscription_2020-08-10_2020-08-17_mosaic/gmap/11/519/756.png?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b'},
#    'bbox': [-88.76953123761467,
#     42.42345651316795,
#     -88.59374998763909,
#     42.553080284177334],
#    'id': '519-1291',
#    'percent_covered': 100},
#   {'_links': {'_self': 'https://api.planet.com/basemaps/v1/mosaics/56f00cc2-6be4-4315-9603-c75d6afab225/quads/520-1291?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b',
#     'download': 'https://api.planet.com/basemaps/v1/mosaics/56f00cc2-6be4-4315-9603-c75d6afab225/quads/520-1291/full?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b',
#     'items': 'https://api.planet.com/basemaps/v1/mosaics/56f00cc2-6be4-4315-9603-c75d6afab225/quads/520-1291/items?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b',
#     'thumbnail': 'https://tiles.planet.com/basemaps/v1/planet-tiles/ps_weekly_sen2_normalized_analytic_subscription_2020-08-10_2020-08-17_mosaic/gmap/11/520/756.png?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b'},
#    'bbox': [-88.59374998763907,
#     42.42345651316795,
#     -88.41796873766349,
#     42.553080284177334],
#    'id': '520-1291',
#    'percent_covered': 100},
#   {'_links': {'_self': 'https://api.planet.com/basemaps/v1/mosaics/56f00cc2-6be4-4315-9603-c75d6afab225/quads/521-1291?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b',
#     'download': 'https://api.planet.com/basemaps/v1/mosaics/56f00cc2-6be4-4315-9603-c75d6afab225/quads/521-1291/full?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b',
#     'items': 'https://api.planet.com/basemaps/v1/mosaics/56f00cc2-6be4-4315-9603-c75d6afab225/quads/521-1291/items?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b',
#     'thumbnail': 'https://tiles.planet.com/basemaps/v1/planet-tiles/ps_weekly_sen2_normalized_analytic_subscription_2020-08-10_2020-08-17_mosaic/gmap/11/521/756.png?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b'},
#    'bbox': [-88.41796873766349,
#     42.42345651316795,
#     -88.2421874876879,
#     42.553080284177334],
#    'id': '521-1291',
#    'percent_covered': 100},
#   {'_links': {'_self': 'https://api.planet.com/basemaps/v1/mosaics/56f00cc2-6be4-4315-9603-c75d6afab225/quads/522-1291?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b',
#     'download': 'https://api.planet.com/basemaps/v1/mosaics/56f00cc2-6be4-4315-9603-c75d6afab225/quads/522-1291/full?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b',
#     'items': 'https://api.planet.com/basemaps/v1/mosaics/56f00cc2-6be4-4315-9603-c75d6afab225/quads/522-1291/items?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b',
#     'thumbnail': 'https://tiles.planet.com/basemaps/v1/planet-tiles/ps_weekly_sen2_normalized_analytic_subscription_2020-08-10_2020-08-17_mosaic/gmap/11/522/756.png?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b'},
#    'bbox': [-88.2421874876879,
#     42.42345651316795,
#     -88.06640623771233,
#     42.553080284177334],
#    'id': '522-1291',
#    'percent_covered': 100},
#   {'_links': {'_self': 'https://api.planet.com/basemaps/v1/mosaics/56f00cc2-6be4-4315-9603-c75d6afab225/quads/523-1291?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b',
#     'download': 'https://api.planet.com/basemaps/v1/mosaics/56f00cc2-6be4-4315-9603-c75d6afab225/quads/523-1291/full?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b',
#     'items': 'https://api.planet.com/basemaps/v1/mosaics/56f00cc2-6be4-4315-9603-c75d6afab225/quads/523-1291/items?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b',
#     'thumbnail': 'https://tiles.planet.com/basemaps/v1/planet-tiles/ps_weekly_sen2_normalized_analytic_subscription_2020-08-10_2020-08-17_mosaic/gmap/11/523/756.png?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b'},
#    'bbox': [-88

#   {'_links': {'_self': 'https://api.planet.com/basemaps/v1/mosaics/56f00cc2-6be4-4315-9603-c75d6afab225/quads/520-1250?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b',
#     'download': 'https://api.planet.com/basemaps/v1/mosaics/56f00cc2-6be4-4315-9603-c75d6afab225/quads/520-1250/full?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b',
#     'items': 'https://api.planet.com/basemaps/v1/mosaics/56f00cc2-6be4-4315-9603-c75d6afab225/quads/520-1250/items?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b',
#     'thumbnail': 'https://tiles.planet.com/basemaps/v1/planet-tiles/ps_weekly_sen2_normalized_analytic_subscription_2020-08-10_2020-08-17_mosaic/gmap/11/520/797.png?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b'},
#    'bbox': [-88.59374998763907,
#     36.87962060065822,
#     -88.41796873766349,
#     37.02009819698812],
#    'id': '520-1250',
#    'percent_covered': 94.32},
#   {'_links': {'_self': 'https://api.planet.com/basemaps/v1/mosaics/56f00cc2-6be4-4315-9603-c75d6afab225/quads/521-1250?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b',
#     'download': 'https://api.planet.com/basemaps/v1/mosaics/56f00cc2-6be4-4315-9603-c75d6afab225/quads/521-1250/full?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b',
#     'items': 'https://api.planet.com/basemaps/v1/mosaics/56f00cc2-6be4-4315-9603-c75d6afab225/quads/521-1250/items?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b',
#     'thumbnail': 'https://tiles.planet.com/basemaps/v1/planet-tiles/ps_weekly_sen2_normalized_analytic_subscription_2020-08-10_2020-08-17_mosaic/gmap/11/521/797.png?api_key=8fb5d85cdcfc40f6b4b9d3f44227142b'},
#    'bbox': [-88.41796873766349,
#     36.87962060065822,
#     -88.2421874876879,
#     37.02009819698812],
#    'id': '521-1250',
#    'percent_covered': 59.08}]}

# %%
## testing on Jihong's container ##
import os, uuid
from azure.storage.blob import BlobServiceClient, BlobClient, ContainerClient, __version__

connect_str = "DefaultEndpointsProtocol=https;AccountName=yihongponding;AccountKey=hnvkEWfrIeYEyLUFcYYKyjujkSWiWcPdV/mS8O5GJ51iWPAkni7opzaA7klbwIGpGY0JANb5pRjGBe1ekHbX9Q==;EndpointSuffix=core.windows.net"
blob_service_client = BlobServiceClient.from_connection_string(connect_str)
container_client = blob_service_client.get_container_client("ponding-il")

images = container_client.list_blobs()
for b in images:
    print(b.name)
# Out:
# 503-1250.tif
# 503-1291.tif

# %%
'''
for i in tqdm(out['items']):
    if i['id'] in os.listdir('dir'):
        continue
    urllib.request.urlretrieve(i['_links']['download'], f"dir/original/{i['id']}.tif")
'''

for i in tqdm(out['items']):
    if(i['id'] in images):
        print(i['id'])
    else:
        urllib.request.urlretrieve()
# Out:
# '\nfor i in tqdm(out[\'items\']):\n    if i[\'id\'] in os.listdir(\'dir\'):\n        continue\n    urllib.request.urlretrieve(i[\'_links\'][\'download\'], f"dir/original/{i[\'id\']}.tif")\n'

# %% [markdown]
# ## Saving into Azure Blob ##

# %%
import os, uuid
from azure.storage.blob import BlobServiceClient, BlobClient, ContainerClient, __version__

# %%
try:
    print("Azure Blob Storage v" + __version__ + " - Python quickstart sample")

    # Quick start code goes here

except Exception as ex:
    print('Exception:')
    print(ex)
# Out:
# Azure Blob Storage v12.9.0 - Python quickstart sample

# %%
import os, uuid
from azure.storage.blob import BlobServiceClient, BlobClient, ContainerClient, __version__

connect_str = "DefaultEndpointsProtocol=https;AccountName=yifangidsimagedatatest;AccountKey=U94rgN17/BHzZuF6TNVItpqLj5NH7Y5/G/ZloFZi21aVMIsthULdPH1KuySuZZznGoZDOTApGXMw2nmnnFvlJQ==;EndpointSuffix=core.windows.net"
container_name="image-planet"

# %%
# Create the BlobServiceClient object which will be used to create a container client
blob_service_client = BlobServiceClient.from_connection_string(
    conn_str=connect_str
)
container_client = blob_service_client.get_container_client(container_name)

blobs = container_client.list_blobs()
for b in blobs:
    print(b.name)
# Out:
# ---------------------------------------------------------------------------
# ServiceRequestError                       Traceback (most recent call last)
# /tmp/ipykernel_2723/3008272199.py in <module>
#       6
#       7 blobs = container_client.list_blobs()
# ----> 8 for b in blobs:
#       9     print(b.name)
#
# ~/.conda/envs/py-image_download/lib/python3.7/site-packages/azure/core/paging.py in __next__(self)
#     127         if self._page_iterator is None:
#     128             self._page_iterator = itertools.chain.from_iterable(self.by_page())
# --> 129         return next(self._page_iterator)
#     130
#     131     next = __next__  # Python 2 compatibility.
#
# ~/.conda/envs/py-image_download/lib/python3.7/site-packages/azure/core/paging.py in __next__(self)
#      74             raise StopIteration("End of paging")
#      75         try:
# ---> 76             self._response = self._get_next(self.continuation_token)
#      77         except AzureError as error:
#      78             if not error.continuation_token:
#
# ~/.conda/envs/py-image_download/lib/python3.7/site-packages/azure/storage/blob/_list_blobs_helper.py in _get_next_cb(self, continuation_token)
#      75                 maxresults=self.results_per_page,
#      76                 cls=return_context_and_deserialized,
# ---> 77                 use_location=self.location_mode)
#      78         except HttpResponseError as error:
#      79             process_storage_error(error)
#
# ~/.conda/envs/py-image_download/lib/python3.7/site-packages/azure/storage/blob/_generated/operations/_container_operations.py in list_blob_flat_segment(self, prefix, marker, maxresults, include, timeout, request_id_parameter, **kwargs)
#    1473
#    1474         request = self._client.get(url, query_parameters, header_parameters)
# -> 1475         pipeline_response = self._client._pipeline.run(request, stream=False, **kwargs)
#    1476         response = pipeline_response.http_response
#    1477
#
# ~/.conda/envs/py-image_download/lib/python3.7/site-packages/azure/core/pipeline/_base.py in run(self, request, **kwargs)
#     209             else _TransportRunner(self._transport)
#     210         )
# --> 211         return first_node.send(pipeline_request)  # type: ignore
#
# ~/.conda/envs/py-image_download/lib/python3.7/site-packages/azure/core/pipeline/_base.py in send(self, request)
#      69         _await_result(self._policy.on_request, request)
#      70         try:
# ---> 71             response = self.next.send(request)
#      72         except Exception:  # pylint: disable=broad-except
#      73             if not _await_result(self._policy.on_exception, request):
#
# ~/.conda/envs/py-image_download/lib/python3.7/site-packages/azure/core/pipeline/_base.py in send(self, request)
#      69         _await_result(self._policy.on_request, request)
#      70         try:
# ---> 71             response = self.next.send(request)
#      72         except Exception:  # pylint: disable=broad-except
#      73             if not _await_result(self._policy.on_exception, request):
#
# ~/.conda/envs/py-image_download/lib/python3.7/site-packages/azure/core/pipeline/_base.py in send(self, request)
#      69         _await_result(self._policy.on_request, request)
#      70         try:
# ---> 71             response = self.next.send(request)
#      72         except Exception:  # pylint: disable=broad-except
#      73             if not _await_result(self._policy.on_exception, request):
#
# ~/.conda/envs/py-image_download/lib/python3.7/site-packages/azure/core/pipeline/_base.py in send(self, request)
#      69         _await_result(self._policy.on_request, request)
#      70         try:
# ---> 71             response = self.next.send(request)
#      72         except Exception:  # pylint: disable=broad-except
#      73             if not _await_result(self._policy.on_exception, request):
#
# ~/.conda/envs/py-image_download/lib/python3.7/site-packages/azure/core/pipeline/_base.py in send(self, request)
#      69         _await_result(self._policy.on_request, request)
#      70         try:
# ---> 71             response = self.next.send(request)
#      72         except Exception:  # pylint: disable=broad-except
#      73             if not _await_result(self._policy.on_exception, request):
#
# ~/.conda/envs/py-image_download/lib/python3.7/site-packages/azure/core/pipeline/policies/_redirect.py in send(self, request)
#     156         redirect_settings = self.configure_redirects(request.context.options)
#     157         while retryable:
# --> 158             response = self.next.send(request)
#     159             redirect_location = self.get_redirect_location(response)
#     160             if redirect_location and redirect_settings['allow']:
#
# ~/.conda/envs/py-image_download/lib/python3.7/site-packages/azure/core/pipeline/_base.py in send(self, request)
#      69         _await_result(self._policy.on_request, request)
#      70         try:
# ---> 71             response = self.next.send(request)
#      72         except Exception:  # pylint: disable=broad-except
#      73             if not _await_result(self._policy.on_exception, request):
#
# ~/.conda/envs/py-image_download/lib/python3.7/site-packages/azure/storage/blob/_shared/policies.py in send(self, request)
#     513                     self.sleep(retry_settings, request.context.transport)
#     514                     continue
# --> 515                 raise err
#     516         if retry_settings['history']:
#     517             response.context['history'] = retry_settings['history']
#
# ~/.conda/envs/py-image_download/lib/python3.7/site-packages/azure/storage/blob/_shared/policies.py in send(self, request)
#     487         while retries_remaining:
#     488             try:
# --> 489                 response = self.next.send(request)
#     490                 if is_retry(response, retry_settings['mode']):
#     491                     retries_remaining = self.increment(
#
# ~/.conda/envs/py-image_download/lib/python3.7/site-packages/azure/core/pipeline/_base.py in send(self, request)
#      69         _await_result(self._policy.on_request, request)
#      70         try:
# ---> 71             response = self.next.send(request)
#      72         except Exception:  # pylint: disable=broad-except
#      73             if not _await_result(self._policy.on_exception, request):
#
# ~/.conda/envs/py-image_download/lib/python3.7/site-packages/azure/core/pipeline/_base.py in send(self, request)
#      69         _await_result(self._policy.on_request, request)
#      70         try:
# ---> 71             response = self.next.send(request)
#      72         except Exception:  # pylint: disable=broad-except
#      73             if not _await_result(self._policy.on_exception, request):
#
# ~/.conda/envs/py-image_download/lib/python3.7/site-packages/azure/core/pipeline/_base.py in send(self, request)
#      69         _await_result(self._policy.on_request, request)
#      70         try:
# ---> 71             response = self.next.send(request)
#      72         except Exception:  # pylint: disable=broad-except
#      73             if not _await_result(self._policy.on_exception, request):
#
# ~/.conda/envs/py-image_download/lib/python3.7/site-packages/azure/core/pipeline/_base.py in send(self, request)
#      69         _await_result(self._policy.on_request, request)
#      70         try:
# ---> 71             response = self.next.send(request)
#      72         except Exception:  # pylint: disable=broad-except
#      73             if not _await_result(self._policy.on_exception, request):
#
# ~/.conda/envs/py-image_download/lib/python3.7/site-packages/azure/storage/blob/_shared/policies.py in send(self, request)
#     288             request.context.options.pop('raw_response_hook', self._response_callback)
#     289
# --> 290         response = self.next.send(request)
#     291         will_retry = is_retry(response, request.context.options.get('mode'))
#     292         if not will_retry and download_stream_current is not None:
#
# ~/.conda/envs/py-image_download/lib/python3.7/site-packages/azure/core/pipeline/_base.py in send(self, request)
#      69         _await_result(self._policy.on_request, request)
#      70         try:
# ---> 71             response = self.next.send(request)
#      72         except Exception:  # pylint: disable=broad-except
#      73             if not _await_result(self._policy.on_exception, request):
#
# ~/.conda/envs/py-image_download/lib/python3.7/site-packages/azure/core/pipeline/_base.py in send(self, request)
#      69         _await_result(self._policy.on_request, request)
#      70         try:
# ---> 71             response = self.next.send(request)
#      72         except Exception:  # pylint: disable=broad-except
#      73             if not _await_result(self._policy.on_exception, request):
#
# ~/.conda/envs/py-image_download/lib/python3.7/site-packages/azure/core/pipeline/_base.py in send(self, request)
#     101         return PipelineResponse(
#     102             request.http_request,
# --> 103             self._sender.send(request.http_request, **request.context.options),
#     104             context=request.context,
#     105         )
#
# ~/.conda/envs/py-image_download/lib/python3.7/site-packages/azure/storage/blob/_shared/base_client.py in send(self, request, **kwargs)
#     331
#     332     def send(self, request, **kwargs):
# --> 333         return self._transport.send(request, **kwargs)
#     334
#     335     def open(self):
#
# ~/.conda/envs/py-image_download/lib/python3.7/site-packages/azure/core/pipeline/transport/_requests_basic.py in send(self, request, **kwargs)
#     289
#     290         if error:
# --> 291             raise error
#     292         return RequestsTransportResponse(request, response, self.connection_config.data_block_size)
#
# ServiceRequestError: <urllib3.connection.HTTPSConnection object at 0x7f2d0b120c10>: Failed to establish a new connection: [Errno -2] Name or service not known

# %%
blob_service_client

# %%
# List the blobs in the container
blob_list = container_client.list_blobs()
for blob in blob_list:
    print("\t" + blob.name)

# %%
print("Deleting blob container...")
container_client.delete_container()

# %%
## testing on Jihong's container ##
import os, uuid
from azure.storage.blob import BlobServiceClient, BlobClient, ContainerClient, __version__

connect_str = "DefaultEndpointsProtocol=https;AccountName=yihongponding;AccountKey=hnvkEWfrIeYEyLUFcYYKyjujkSWiWcPdV/mS8O5GJ51iWPAkni7opzaA7klbwIGpGY0JANb5pRjGBe1ekHbX9Q==;EndpointSuffix=core.windows.net"
blob_service_client = BlobServiceClient.from_connection_string(connect_str)
container_client = blob_service_client.get_container_client("ponding-il")

blobs = container_client.list_blobs()
for b in blobs:
    print(b.name)
# Out:
# 503-1250.tif
# 503-1291.tif
