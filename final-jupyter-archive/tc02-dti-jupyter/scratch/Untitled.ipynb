# %%
help(c3.JupyterNotebook)
# Out:
# <div id="type:JupyterNotebook" class="structure type root beta private">
# <h1 class="type root">Type <span class="name">JupyterNotebook</span></h1>
# <p class="description">Jupyter notebooks containing a mix of code and explanations</p>
# <p class="beta-info">Beta</p><p class="private-info">Private</p><div class="mixes"><p>Mixes:</p>
# <ul class="mixes">
# <li class="mixes">Persistable&lt;JupyterNotebook&gt;</li>
# <li class="mixes">JupyterContent</li>
# <li class="mixes">Versionable</li>
# </ul></div>
# <div class="declaration"><p>Declaration</p><pre class="declaration">/**
#  * Jupyter notebooks containing a mix of code and explanations
#  */
# @beta
# private entity type JupyterNotebook extends JupyterContent mixes Versionable type key 'NTBK'
# </pre></div><div class="annotationDoc"><div class="annotations"><p>Annotations:</p>
# <ul class="annotations">
# <li class="annotation">@typesys</li>
# <li class="annotation">@db</li>
# <li class="annotation">@beta</li>
# </ul></div>
# ...
