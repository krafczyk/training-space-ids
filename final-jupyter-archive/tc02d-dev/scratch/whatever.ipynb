# %%
import pandas as pd
import numpy as np

# %%
x = np.random.rand(100)
y = np.random.rand(100)

# %%
df = pd.DataFrame()

# %%
df['x'] = x
df['y'] = y

# %%
df
# Out:
#            x         y
# 0   0.197760  0.371494
# 1   0.337303  0.620865
# 2   0.183548  0.863275
# 3   0.651939  0.520914
# 4   0.269036  0.895053
# ..       ...       ...
# 95  0.521525  0.998582
# 96  0.077144  0.678043
# 97  0.669246  0.502474
# 98  0.865380  0.652041
# 99  0.284635  0.757776
#
# [100 rows x 2 columns]

# %%
dict_df = df.to_dict(orient="records")

# %%
dict_df
# Out:
# [{'x': 0.1977602029805725, 'y': 0.37149449512197896},
#  {'x': 0.3373031956818342, 'y': 0.620865340345335},
#  {'x': 0.18354774816917097, 'y': 0.8632745773517323},
#  {'x': 0.6519386730334494, 'y': 0.5209144421413883},
#  {'x': 0.26903638369922134, 'y': 0.8950531484284967},
#  {'x': 0.12704407703677179, 'y': 0.13343177368249293},
#  {'x': 0.7755514496381146, 'y': 0.749192678471754},
#  {'x': 0.9919288351234603, 'y': 0.8884248261763761},
#  {'x': 0.9512970376256802, 'y': 0.7918792104967025},
#  {'x': 0.6744287554967919, 'y': 0.45537752319121183},
#  {'x': 0.8183247993135431, 'y': 0.14806368272483594},
#  {'x': 0.8515578668936978, 'y': 0.4242709763864907},
#  {'x': 0.5124427528361832, 'y': 0.55540101663321},
#  {'x': 0.47711666933928343, 'y': 0.33265287927116904},
#  {'x': 0.7314171180524653, 'y': 0.8878748154791867},
#  {'x': 0.8040057671563505, 'y': 0.778939225888348},
#  {'x': 0.05603014099203929, 'y': 0.23112253534263116},
#  {'x': 0.19374248830879914, 'y': 0.7586899481956423},
# ...

# %%
# !nvidia-smi
# Out:
# Mon Dec 20 18:57:04 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.57.02    Driver Version: 470.57.02    CUDA Version: 11.4     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000001:00:00.0 Off |                    0 |
# | N/A   68C    P8    31W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...
