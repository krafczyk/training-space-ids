# %% [markdown]
# # Need to be included in Kernel

# %%
# not in c3, part of py-xu_1_0_1
import gym
print('Gym', gym.__version__)

# not in c3, part of py-xu_1_0_1
import tensorflow
print('Tensorflow',tensorflow.__version__)

# not in c3, part of py-xu_1_0_1
import tensorboardX
print('TensorboardX',tensorboardX.__version__)

# not in c3, part of py-xu_1_0_1
import pydot
print('Pydot', pydot.__version__)

# not in c3, part of py-xu_1_0_1
import cartopy
print('Cartopy', cartopy.__version__)

# not in c3, part of py-xu_1_0_1
import Box2D
print('Box2D', Box2D.__version__)
# Out:
# Gym 0.17.3
# Tensorflow 2.4.1
# TensorboardX 2.4
# Pydot 1.3.0
# Cartopy 0.19.0.post1
# Box2D 2.3.2

# %%
# not in c3
import libarchive
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-3eba09136965> in <module>
#       1 # not in c3
# ----> 2 import libarchive
#
# ModuleNotFoundError: No module named 'libarchive'

# %% [markdown]
# # Already in C3 Python env

# %%
# already in c3, python built-ins
import os
import random
import time
import copy
import threading
import multiprocessing
import math
import sys
import six #(python2 - python3 smoother)
import glob
import io
import base64
import IPython

# already in c3 (matplotlib)
import matplotlib
import pylab
print('Matplotlib {}'.format(matplotlib.__version__))

# already in c3
import numpy
print('Numpy',numpy.__version__)

# already in c3
import scipy
print('Scipy', scipy.__version__)
# Out:
# Matplotlib 3.3.4
# Numpy 1.19.2
# Scipy 1.5.2
