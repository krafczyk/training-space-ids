# %%
import pandas as pd

# %%
lat1 = -30.0
lat2 = 10.0
lon1 = -45.0
lon2 = 40.0
time1 = "2017-07-08T00:00:00"
time2 = "2017-07-14T23:59:59"
gstpFilter = c3.Filter() \
    .ge("latitude", lat1) \
    .and_().le("latitude", lat2) \
    .and_().ge("longitude", lon1) \
    .and_().le("longitude", lon2) \
    .and_().ge("time", time1) \
    .and_().le("time", time2)

excludeFeats = [
    'acure_carb_res_ems_asi',
    'acure_carb_res_ems_lat',
    'acure_autoconv_exp_lwp',
    'acure_volc_so2',
    'acure_scav_diam',
    'acure_anth_so2_nam',
    'acure_sig_w',
    'acure_anth_so2_chi',
    'acure_carb_ff_ems_eur',
    'acure_carb_bb_ems_rsh',
    'acure_carb_bb_ems_sam',
    'acure_carb_bb_ems_bnh',
    'acure_oxidants_o3',
    'acure_kappa_oc',
    'acure_carb_bb_ems_rnh',
    'acure_carb_ff_ems_asi',
    'acure_carb_res_ems_r',
    'acure_anth_so2',
    'acure_carb_ff_ems_chi',
    'acure_rain_frac',
    'acure_carb_ff_ems_r',
    'acure_carb_bb_ems_saf',
    'm_ci',
    'acure_carb_ff_ems_nam',
    'c_r_correl',
    'acure_carb_bb_ems_naf',
    'acure_carb_res_ems_chi',
    'acure_carb_ff_ems_mar',
    'acure_carb_res_ems_afr',
    'acure_anth_so2_asi',
    'acure_prim_moc',
    'acure_anth_so2_eur',
    'two_d_fsd_factor',
    'acure_convective_plume_scavenging',
    'ai',
    'acure_carb_ff_diam',
    'acure_carb_res_ems',
    'acure_carb_bb_ems',
    'acure_carb_res_diam',
    'acure_carb_ff_ems',
    'acure_oxidants_oh',
    'acure_cloud_ice_thresh'
]
kernelLen = 59 - len(excludeFeats)

GPR_kernel = c3.SklearnGPRKernelMatern(
    lengthScale=[1.0]*kernelLen,
    nu=0.5,
    coefficient=1.0
).build().kernel

GPR_technique = c3.GaussianProcessRegressionTechnique(
    randomState=42,
    kernel=GPR_kernel,
    centerTarget=False
)

# %%
GPR_pipe = c3.GaussianProcessRegressionPipe.get('5618d2df-b1ab-4daf-b683-b9d726d703f5')

feats = list(c3.Dataset.toPandas(GPR_pipe.getFeatures()).columns)
feats
# Out:
# ['acure_bl_nuc',
#  'acure_ait_width',
#  'acure_cloud_ph',
#  'acure_carb_bb_diam',
#  'acure_prim_so4_diam',
#  'acure_sea_spray',
#  'acure_anth_so2_r',
#  'acure_bvoc_soa',
#  'acure_dms',
#  'acure_dry_dep_ait',
#  'acure_dry_dep_acc',
#  'acure_dry_dep_so2',
#  'acure_bc_ri',
#  'bparam',
#  'acure_autoconv_exp_nd',
#  'dbsdtbs_turb_0',
#  'a_ent_1_rp']

# %%
with open("11_21_22/model_variants", "r") as f:
    synth_df = pd.read_csv(f, index_col=0)

f.close()
synthDataset = c3.Dataset.fromPython(pythonData=synth_df)
synth_df
# Out:
#       acure_bl_nuc  acure_ait_width  acure_cloud_ph  acure_carb_bb_diam  \
# 0         0.495928         0.483783        0.739855            0.811622
# 1         0.681790         0.088659        0.733079            0.688636
# 2         0.517493         0.554233        0.901933            0.152978
# 3         0.814972         0.905124        0.102670            0.474123
# 4         0.395892         0.661905        0.017672            0.979126
# ...            ...              ...             ...                 ...
# 9995      0.532886         0.482696        0.630123            0.467706
# 9996      0.210659         0.315840        0.323448            0.807423
# 9997      0.010429         0.718487        0.869637            0.671461
# 9998      0.672181         0.912903        0.360090            0.759295
# 9999      0.180303         0.253729        0.065287            0.915783
#
#       acure_prim_so4_diam  acure_sea_spray  acure_anth_so2_r  acure_bvoc_soa  \
# 0                0.743838         0.732146          0.397809        0.007556
# 1                0.248353         0.076189          0.548028        0.900369
# 2                0.490350         0.595814          0.246956        0.287136
# 3                0.297578         0.963633          0.866269        0.644769
# 4                0.168936         0.413592          0.228043        0.017543
# ...                   ...              ...               ...             ...
# 9995             0.082235         0.572218          0.574759        0.896003
# 9996             0.641276         0.710519          0.282191        0.352321
# 9997             0.811282         0.069309          0.800756        0.479554
# 9998             0.055885         0.523452          0.826977        0.162241
# 9999             0.701749         0.063576          0.731857        0.251929
#
#       acure_dms  acure_dry_dep_ait  acure_dry_dep_acc  acure_dry_dep_so2  \
# 0      0.871872           0.020369           0.445913           0.812552
# 1      0.072998           0.979556           0.061172           0.874451
# 2      0.721224           0.451212           0.438969           0.807126
# 3      0.471977           0.645122           0.029089           0.930605
# 4      0.603929           0.796231           0.005047           0.544480
# ...         ...                ...                ...                ...
# 9995   0.754205           0.521675           0.768042           0.563739
# 9996   0.400765           0.069441           0.335792           0.847048
# 9997   0.487198           0.938922           0.572681           0.853594
# 9998   0.475241           0.533150           0.109456           0.153420
# 9999   0.078698           0.642922           0.834110           0.396147
#
#       acure_bc_ri    bparam  acure_autoconv_exp_nd  dbsdtbs_turb_0  a_ent_1_rp
# 0        0.923662  0.798796               0.382977        0.873712    0.023434
# 1        0.926584  0.030118               0.948973        0.489287    0.193494
# 2        0.419010  0.360877               0.388655        0.701247    0.002141
# 3        0.769317  0.690946               0.526474        0.493059    0.819982
# 4        0.150701  0.828862               0.633274        0.687778    0.186980
# ...           ...       ...                    ...             ...         ...
# 9995     0.689028  0.862473               0.520056        0.559539    0.279039
# 9996     0.579802  0.911171               0.426114        0.206576    0.893213
# 9997     0.354888  0.296417               0.968299        0.168550    0.979873
# 9998     0.693530  0.664198               0.563799        0.909358    0.321263
# 9999     0.776536  0.805927               0.309886        0.553128    0.182918
#
# [10000 rows x 17 columns]

# %%
import sched, time

s = sched.scheduler(time.time, time.sleep)

days = [str(n).zfill(2) for n in range(1, 15)]
predict_jobs = {}
predict_dfs = {}

# %%
def start_job(
    day="01"
):

    print("Starting job " + day)
    time1 = "2017-07-" + day + "T09:00:00"
    time2 = "2017-07-" + day + "T13:59:59"
    
    gstpFilter = c3.Filter() \
        .ge("latitude", lat1) \
        .and_().le("latitude", lat2) \
        .and_().ge("longitude", lon1) \
        .and_().le("longitude", lon2) \
        .and_().ge("time", time1) \
        .and_().le("time", time2)
    
    predict_jobs[day] = c3.PredictAODGPR.makePredictionsJob(
        excludeFeats, gstpFilter, "all", synthDataset, GPR_technique, 1
    )
    
    process_job(
        day=day,
        predict_job=predict_jobs[day]
    )

    return

# %%
def process_job(
    day=None,
    predict_job=None
):
    
    while predict_job.status().status=='running':
        time.sleep(60)

    if predict_job.status().status=='completed': 
        print("Day " + day + ' complete. Saving predictions.')
        predict_dfs[day] = c3.PredictAODGPR.getPredictionsDataframeFromJob(predict_job)

        with open("11_21_22/predictions_07_" + day + "_17", "w") as f:
            f.write(predict_dfs[day].reset_index(drop=True).to_csv())
        f.close()
        
        return

    elif predict_job.status().status=='failing' or predict_job.status().status=='failed':
        print(day + 'Failing. Error: \n' + predict_job.status().errors[0].errorMsg)
        predict_job.cancel()
        
        return

# %%
def schedule_jobs(days):
    for day, idx in zip(days, range(len(days))):
        s.enter(1, 1, start_job, kwargs={'day': day})
    s.run()

# %%
schedule_jobs(days)
# Out:
# Starting job 02
# 02Failing. Error:
# wrapped IOException: Broken pipe
#
#     at java.io.FileOutputStream.writeBytes
#     ...
#     at c3.love.typesys.obj.pipe.ser.JsonObjValueReceiver.writePrimitive (JsonObjValueReceiver.java:514)
#
#   from action Lambda<function(batch: any, objs: any, job: any): any>.call
#   from env_server.js, line 132
#     130    if (C3._context.locale)
#     131      options.language = C3._context.locale;
#   > 132    return c3CallAction(target, args, options);
#     133  }
#     134
#   from typesys.js, line 1692
#     1690
#     1691          // call the server to execute this function as an action
#   > 1692          response = c3Call(this, name, args);
#     1693        }
#     1694
#   from DynMapReduce_map.js, line 16
#     14
#     15  function map(batch, objs, job, subBatch) {
#   > 16    return job.mapLambda.call(batch, objs, job, subBatch);
#     17  }
#     18
#   from DynMapReduce_map.js, line 80
#     78
#     79  if (typeof $DynMapReduce$functions.map == 'function') {
#   > 80    function map() { return $DynMapReduce$functions.map.apply(...
#     81  }
#     82
#   from DynMapReduce_map.js, line 86
#     84  if (typeof map != 'function') throw new Error('Function "map...
#     85  global$.call$DynMapReduce$map = function(batch, objs, job, s...
#   > 86    return map.call(this, batch, objs, job, subBatch);
#     87  };
#     88  })(this);
#   from action DynMapReduce.map
#   from env_server.js, line 132
#     130    if (C3._context.locale)
#     131      options.language = C3._context.locale;
#   > 132    return c3CallAction(target, args, options);
#     133  }
#     134
#   from typesys.js, line 1692
#     1690
#     1691          // call the server to execute this function as an action
#   > 1692          response = c3Call(this, name, args);
#     1693        }
#     1694
#   from DynMapReduce_map.js, line 16
#     14
#     15  function map(batch, objs, job, subBatch) {
#   > 16    return job.mapLambda.call(batch, objs, job, subBatch);
#     17  }
#     18
#   from DynMapReduce_map.js, line 80
#     78
#     79  if (typeof $DynMapReduce$functions.map == 'function') {
#   > 80    function map() { return $DynMapReduce$functions.map.apply(...
#     81  }
#     82
#   from DynMapReduce_map.js, line 86
#     84  if (typeof map != 'function') throw new Error('Function "map...
#     85  global$.call$DynMapReduce$map = function(batch, objs, job, s...
#   > 86    return map.call(this, batch, objs, job, subBatch);
#     87  };
#     88  })(this);
#   base action DynMapReduce.map
#   Broken pipe
# Starting job 03
# Day 03 complete. Saving predictions.
# 500 - NotClassified - c3.love.exceptions.C3RuntimeException_wrapIt [346.7748]
# message: "wrapped com.datastax.driver.core.exceptions.FrameTooLongException: Response frame exceeded maximum allowed length"
# JSON: {"this": {"type": "DynMapReduce", "typeIdent": "MAPRJ:DYN", "id": "3a82c970-0c14-4236-9836-bdf9f365525c", "meta": {"type": "Meta", "created": "2022-11-22T22:47:05+00:00", "updated": "2022-11-22T22:47:05+00:00", "timestamp": "2022-11-22T22:47:05+00:00"}, "version": 1}, "limit": 10000}
# ---------------------------------------------------------------------------
# C3RuntimeException                        Traceback (most recent call last)
# Z10ac078826d8534179d455db1588a325M_/TypeSystemBase.py in inline_traceback_impl(source_code, fn, ___args, cls)
#
# <string> in getPredictionsDataframeFromJob(job)
#
# Z10ac078826d8534179d455db1588a325M_.TypeSystemBase in results(this, limit)
#
# Z10ac078826d8534179d455db1588a325M_/TypeSystemBase.py in _c3_member_impl(_typesys, ___args, this_name, method_name, defined_class_name, _invoking_class, _overload_idx)
#
# Z10ac078826d8534179d455db1588a325M_/TypeSystemBase.py in _box_and_request_json(self, type_name, method_name, payload, validate_args, declared_type_name, current_class)
#
# Z10ac078826d8534179d455db1588a325M_/TypeSystemBase.py in _request_json(self, type_name, method_name, payload)
#
# Z10ac078826d8534179d455db1588a325M_/ServerConnection.py in _request_json(self, type_name, action_name, payload, extra_headers, encoder, client_side_type_inference)
#
# C3RuntimeException: 500 - NotClassified - c3.love.exceptions.C3RuntimeException_wrapIt [346.7748]
# message: "wrapped com.datastax.driver.core.exceptions.FrameTooLongException: Response frame exceeded maximum allowed length"
# JSON: {"this": {"type": "DynMapReduce", "typeIdent": "MAPRJ:DYN", "id": "3a82c970-0c14-4236-9836-bdf9f365525c", "meta": {"type": "Meta", "created": "2022-11-22T22:47:05+00:00", "updated": "2022-11-22T22:47:05+00:00", "timestamp": "2022-11-22T22:47:05+00:00"}, "version": 1}, "limit": 10000}
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-d4fed2014104> in <module>
# ----> 1 schedule_jobs(days)
#
# <ipython-input-14-f4ea2f582796> in schedule_jobs(days)
#       2     for day, idx in zip(days, range(len(days))):
#       3         s.enter(1, 1, start_job, kwargs={'day': day})
# ----> 4     s.run()
#
# /opt/conda/lib/python3.8/sched.py in run(self, blocking)
#     149                 delayfunc(time - now)
#     150             else:
# --> 151                 action(*argument, **kwargs)
#     152                 delayfunc(0)   # Let other threads run
#     153
#
# <ipython-input-12-1bcc36aa4ac5> in start_job(day)
#      19     )
#      20
# ---> 21     process_job(
#      22         day=day,
#      23         predict_job=predict_jobs[day]
#
# <ipython-input-13-6ab6665b1437> in process_job(day, predict_job)
#       9     if predict_job.status().status=='completed':
#      10         print("Day " + day + ' complete. Saving predictions.')
# ---> 11         predict_dfs[day] = c3.PredictAODGPR.getPredictionsDataframeFromJob(predict_job)
#      12
#      13         with open("11_21_22/predictions_07_" + day + "_17", "w") as f:
#
# Z10ac078826d8534179d455db1588a325M_/TypeSystemBase.py in getPredictionsDataframeFromJob(_cls_f7f11c950a4e, job)
#
# Z10ac078826d8534179d455db1588a325M_/TypeSystemBase.py in _c3_static_inline_impl(___args, source_code, py_code, method_name, _cls)
#
# Z10ac078826d8534179d455db1588a325M_/TypeSystemBase.py in inline_traceback_impl(source_code, fn, ___args, cls)
#
# TypeError: __init__() missing 6 required positional arguments: 'key', 'msg', 'codes', 'payload', 'status_code', and 'encoder'

# %%
lat1 = -30.0
lat2 = 10.0
lon1 = -45.0
lon2 = 40.0
time1 = "2017-07-01T09:00:00"
time2 = "2017-07-03T13:59:59"
gstpFilter = c3.Filter() \
    .ge("latitude", lat1) \
    .and_().le("latitude", lat2) \
    .and_().ge("longitude", lon1) \
    .and_().le("longitude", lon2) \
    .and_().ge("time", time1) \
    .and_().le("time", time2)

excludeFeats = [
    'acure_carb_res_ems_asi',
    'acure_carb_res_ems_lat',
    'acure_autoconv_exp_lwp',
    'acure_volc_so2',
    'acure_scav_diam',
    'acure_anth_so2_nam',
    'acure_sig_w',
    'acure_anth_so2_chi',
    'acure_carb_ff_ems_eur',
    'acure_carb_bb_ems_rsh',
    'acure_carb_bb_ems_sam',
    'acure_carb_bb_ems_bnh',
    'acure_oxidants_o3',
    'acure_kappa_oc',
    'acure_carb_bb_ems_rnh',
    'acure_carb_ff_ems_asi',
    'acure_carb_res_ems_r',
    'acure_anth_so2',
    'acure_carb_ff_ems_chi',
    'acure_rain_frac',
    'acure_carb_ff_ems_r',
    'acure_carb_bb_ems_saf',
    'm_ci',
    'acure_carb_ff_ems_nam',
    'c_r_correl',
    'acure_carb_bb_ems_naf',
    'acure_carb_res_ems_chi',
    'acure_carb_ff_ems_mar',
    'acure_carb_res_ems_afr',
    'acure_anth_so2_asi',
    'acure_prim_moc',
    'acure_anth_so2_eur',
    'two_d_fsd_factor',
    'acure_convective_plume_scavenging',
    'ai',
    'acure_carb_ff_diam',
    'acure_carb_res_ems',
    'acure_carb_bb_ems',
    'acure_carb_res_diam',
    'acure_carb_ff_ems',
    'acure_oxidants_oh',
    'acure_cloud_ice_thresh'
]
kernelLen = 59 - len(excludeFeats)

GPR_kernel = c3.SklearnGPRKernelMatern(lengthScale=[1.0]*kernelLen, nu=0.5, coefficient=1.0).build().kernel

GPR_technique = c3.GaussianProcessRegressionTechnique(
    randomState=42,
    kernel=GPR_kernel
)

# %%
nFeatures = kernelLen

# create synthetic data with numpy
import numpy as np

synth = np.random.rand(100, nFeatures)

# cast it into a c3.Dataset
synthDataset = c3.Dataset.fromPython(pythonData=synth)

# %%
job = c3.AODGPRModelFinder.extractLearnedParametersJob(excludeFeats, gstpFilter, "all", GPR_technique, 10)

# %%
job.status()
# Out:
# c3.MapReduceStatus(
#  started=datetime.datetime(2022, 11, 8, 18, 22, 13, tzinfo=datetime.timezone.utc),
#  startedby='jcarzon@andrew.cmu.edu',
#  status='running',
#  step='readInput')

# %%
df = c3.AODGPRModelFinder.getDataframeFromJob(job)

# %%
df

# %%
job2 = c3.PredictAODGPR.makePredictionsJob(excludeFeats, gstpFilter, "all", synthDataset, GPR_technique, 10)

# %%
job2.status()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-55bc3163db84> in <module>
# ----> 1 job2.status()
#
# NameError: name 'job2' is not defined

# %%
print(job2.status().errors[0].errorMsg)

# %%
import pandas as pd

predictions = []

if job2.status().status == "completed":
    for key, value in job2.results().items():
        for subvalue in value:
            df_m = pd.DataFrame()
            df_m["mean"] = np.array(subvalue[0]).flatten()
            df_m["mean"] += subvalue[3]
            df_m["sd"] = subvalue[1]
            df_m["modelId"] = subvalue[2]

            predictions.append(df_m)

#df = pd.concat(predictions, axis=0).reset_index(drop=True)
predictions

# %%
if job2.status().status == "completed":
    for key, value in job2.results().items():
        for subvalue in value:
            df_m = pd.DataFrame()
            df_m["mean"] = np.array(subvalue[0]).flatten()
            print(df_m)

# %%
df2 = c3.PredictAODGPR.getPredictionsDataframeFromJob(job2)

# %%
df2
# Out:
#          mean        sd                               modelId
# 0    0.324550  0.083335  6937e341-13da-447f-8ed9-3b33b6cdcf8c
# 1    0.620296  0.074768  6937e341-13da-447f-8ed9-3b33b6cdcf8c
# 2    0.377728  0.081698  6937e341-13da-447f-8ed9-3b33b6cdcf8c
# 3    0.590834  0.075627  6937e341-13da-447f-8ed9-3b33b6cdcf8c
# 4    0.339952  0.080818  6937e341-13da-447f-8ed9-3b33b6cdcf8c
# ..        ...       ...                                   ...
# 845  0.825088  0.072095  e1b530e6-cb7b-4ffe-b360-e4b451a3e579
# 846  0.384072  0.065991  e1b530e6-cb7b-4ffe-b360-e4b451a3e579
# 847  0.550648  0.069448  e1b530e6-cb7b-4ffe-b360-e4b451a3e579
# 848  0.472630  0.068938  e1b530e6-cb7b-4ffe-b360-e4b451a3e579
# 849  0.689180  0.068504  e1b530e6-cb7b-4ffe-b360-e4b451a3e579
#
# [850 rows x 3 columns]

# %%
# Put SynthDataset in job context

# %% [markdown]
# # Get parameters

# %% [markdown]
# ## Og function

# %%
def extractLearnedParametersJob(
    excFeats, gstpFilter, targetName, technique, batchSize
):
    """
    Dynamic map-reduce job to extract learned hyper parameters.
    """
    def cassandra_mapper(batch, objs, job):
        models = []
        for obj in objs:
            model = c3.AODGPRModelFinder.getPipe(
                job.context.value["excludeFeatures"],
                obj.id,
                job.context.value["targetName"],
                job.context.value["technique"]
            )
            models.append(model)
        
        return {batch: models}

    def cassandra_reducer(key, interValues, job):
        values = []
        for iv in interValues:
            for val in iv:
                for m in val:
                    pickledModel = m["trainedModel"]["model"]
                    model = c3.PythonSerialization.deserialize(serialized=pickledModel)
                    hp = model.kernel_.get_params()['k2__length_scale']
                    model_id = m["id"]

                    # find GSTP
                    dssId = m["dataSourceSpec"]["id"]
                    dss = c3.GPRDataSourceSpec.get(dssId)
                    gstpId = dss.targetSpec.filter.split(" == ")[1].replace('"', '')
                    gstp = c3.GeoSurfaceTimePoint.get(gstpId)
                    lat = gstp.latitude
                    lon = gstp.longitude
                    time = gstp.time
                    values.append((hp, model_id, lat, lon, time))

        return values

    map_lambda = c3.Lambda.fromPython(cassandra_mapper)
    reduce_lambda = c3.Lambda.fromPython(cassandra_reducer, runtime="gordon-ML_1_0_0")

    job_context = c3.MappObj(
        value={
            'excludeFeatures': excFeats,
            'targetName': targetName,
            'technique': technique
        }
    )
    job = c3.DynMapReduce.startFromSpec(
        c3.DynMapReduceSpec(
            targetType="GeoSurfaceTimePoint",       
            filter=gstpFilter, 
            mapLambda=map_lambda,
            reduceLambda=reduce_lambda,
            batchSize=batchSize,
            context=job_context
        )
    )

    return job

# %% [markdown]
# ## Proposed functions

# %%
def makePredictionsJob(
    excFeats, gstpFilter, targetName, synthDataset, technique, batchSize
):
    """
    Dynamic map-reduce job to get predictions on synthDataset.
    """
    
    def cassandra_mapper(batch, objs, job):
        models = []
        for obj in objs:
            model = c3.AODGPRModelFinder.getPipe(
                job.context.value["excludeFeatures"],
                obj.id,
                job.context.value["targetName"],
                job.context.value["technique"]
            )
            models.append(model)
        
        return {batch: models}

    def cassandra_reducer(key, interValues, job):
        values = []
        synthDataframe = c3.Dataset.toPandas(synthDataset)

        for iv in interValues:
            for val in iv:
                for m in val:

                    model_id = m["id"]

                    centered = m["technique"]["centerTarget"]
                    if centered:
                        center = m["trainedModel"].parameters["targetMean"].asfloat()
                    else:
                        center = 0

                    pickledModel = m["trainedModel"]["model"]
                    model = c3.PythonSerialization.deserialize(serialized=pickledModel)
                    mean, sd = model.predict(synthDatarame, return_std=True)
                    preds = pd.concat([pd.DataFrame(mean), pd.DataFrame(sd)], axis=1)

                    values.append((preds, synthDataset, model_id, center))
                    

        return values

    map_lambda = c3.Lambda.fromPython(cassandra_mapper)
    reduce_lambda = c3.Lambda.fromPython(cassandra_reducer, runtime="gordon-ML_1_0_0")

    job_context = c3.MappObj(
        value={
            'excludeFeatures': excFeats,
            'targetName': targetName,
            'technique': technique,
            'syntheticDataset': synthDataset
        }
    )
    job = c3.DynMapReduce.startFromSpec(
        c3.DynMapReduceSpec(
            targetType="GeoSurfaceTimePoint",       
            filter=gstpFilter, 
            mapLambda=map_lambda,
            reduceLambda=reduce_lambda,
            batchSize=batchSize,
            context=job_context
        )
    )

    return job

# %% [markdown]
# ## Break apart

# %%
pipe = c3.GaussianProcessRegressionPipe.fetch({
    "limit": 1 
}).objs[0]

filt = c3.Filter().intersects("technique.id", [pipe.technique.id]).and_().intersects("dataSourceSpec.id", [pipe.dataSourceSpec.id])
pipes = c3.GaussianProcessRegressionPipe.fetch({"filter": filt.value, "limit": -1})
objs = pipes.objs

# %%
m = objs[0]

# %%
sourceSpec = c3.GPRDataSourceSpec.get(pipe.dataSourceSpec.id)
nExcFeats = len(sourceSpec.excludeFeatures)
nFeatures = 59 - nExcFeats

# %%
nFeatures

# %%
# create synthetic data with numpy
import numpy as np

synth = np.random.rand(50, nFeatures)

# cast it into a c3.Dataset
synthDataset = c3.Dataset.fromPython(pythonData=synth)

# %%
for m in objs:
    preds = m.process(synthDataset)

# %%
preds

# %%
trainedModel.parameters['targetMean']

# %%
pickledModel = m.trainedModel.model
model = c3.PythonSerialization.deserialize(serialized=pickledModel)

# %%
mean, sd = model.predict(c3.Dataset.toPandas(synthDataset), return_std=True)

# %%
pd.concat([pd.DataFrame(mean), pd.DataFrame(sd)], axis=1)

# %%
def cassandra_mapper(batch, objs, job):
    models = []
    for obj in objs:
        model = c3.AODGPRModelFinder.getPipe(
            job.context.value["excludeFeatures"],
            obj.id,
            job.context.value["targetName"],
            job.context.value["technique"]
        )
        models.append(model)

    return {batch: models}

# %%
def cassandra_reducer(key, interValues, job):
    values = []
    for iv in interValues:
        for val in iv:
            for m in val:
                pickledModel = m["trainedModel"]["model"]
                model = c3.PythonSerialization.deserialize(serialized=pickledModel)
                hp = model.kernel_.get_params()['k2__length_scale']
                model_id = m["id"]

                # find GSTP
                dssId = m["dataSourceSpec"]["id"]
                dss = c3.GPRDataSourceSpec.get(dssId)
                gstpId = dss.targetSpec.filter.split(" == ")[1].replace('"', '')
                gstp = c3.GeoSurfaceTimePoint.get(gstpId)
                lat = gstp.latitude
                lon = gstp.longitude
                time = gstp.time
                values.append((hp, model_id, lat, lon, time))

    return values

# %%
map_lambda = c3.Lambda.fromPython(cassandra_mapper)
reduce_lambda = c3.Lambda.fromPython(cassandra_reducer, runtime="gordon-ML_1_0_0")

# %%
job_context = c3.MappObj(
    value={
        'excludeFeatures': excludeFeats,
        'targetName': "all",
        'technique': GPR_technique
    }
)

# %%
job = c3.DynMapReduce.startFromSpec(
    c3.DynMapReduceSpec(
        targetType="GeoSurfaceTimePoint",       
        filter=myFilter, 
        mapLambda=map_lambda,
        reduceLambda=reduce_lambda,
        batchSize=10,
        context=job_context
    )
)

# %%
print(job.status().errors[0].errorMsg)

# %%
sourceSpec = c3.GPRDataSourceSpec.get(pipe.dataSourceSpec.id)
excFeats = sourceSpec.excludeFeatures

# %%
targetName = sourceSpec.targetName

# %%
gstpId = "-21.875_19.688_2017-07-28T18:20:00"

# %%
gprTechnique = c3.GaussianProcessRegressionTechnique.get(pipe.technique.id)

# %%
c3.SklearnGPRKernel.get(gprTechnique.kernel.id).pickledKernel

# %%
c3.AODGPRModelFinder.getPipe(
    excFeats,
    gstpId,
    targetName,
    gprTechnique
)

# %%
GPR_technique = c3.GaussianProcessRegressionTechnique.get('BHE7')

# %%
myJob = extractLearnedParametersJob(
    excludeFeats,
    myFilter,
    "all",
    GPR_technique,
    10
)

# %%
myJob.cancel()

# %% [markdown]
# # Dataframe

# %% [markdown]
# ## Og function

# %%
def getDataframeFromJob(job):
    """
    Iterates over job result and builds dataframe.
    """
    import pandas as pd
    import numpy as np

    lengthScales = []
    ids = []
    lats = []
    lons = []
    times = []
    if job.status().status == "completed":
        for key, value in job.results().items():
            for subvalue in value:
                ls = np.array(subvalue[0]).astype(float)
                model_id = np.array([subvalue[1]]).astype(str)
                lengthScales.append(ls)
                ids.append(model_id[0])
                lats.append(np.array(subvalue[2]).astype(float))
                lons.append(np.array(subvalue[3]).astype(float))
                times.append(np.array(subvalue[4]))
                
        df = pd.DataFrame(lengthScales)
        df["modelId"] = ids
        df["latitude"] = lats
        df["longitude"] = lons
        df["time"] = times
        return df
    else:
        return False

# %% [markdown]
# ## Proposed function

# %%
def getPredictionsDataframeFromJob(job):
    """
    Iterates over job result and builds dataframe.
    """
    import pandas as pd
    import numpy as np

    predictions = []
    
    if job.status().status == "completed":
        for key, value in job.results().items():
            for subvalue in value:
                df_y = c3.Dataset.toPandas(subvalue[0])
                df_y[0] += subvalue[3]
                df_x = c3.Dataset.toPandas(subvalue[1])
                m_preds = pd.concat(
                    [df_x, df_y],
                    axis=1
                )
                m_preds["modelId"] = subvalue[2]
                predictions.append(m_preds)
                
        df = pd.concat(predictions, axis=0).reset_index(drop=True)
        return df
    else:
        return False

# %%
getDataframeFromJob(myJob)
