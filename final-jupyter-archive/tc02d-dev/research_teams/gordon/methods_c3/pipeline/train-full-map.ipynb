# %%
# %run ../Emulator.ipynb

# %%
myFeaturesNames = [
    "bparam",
    "acure_autoconv_exp_nd",
    "a_ent_1_rp",
    "acure_dry_dep_acc",
    "acure_dry_dep_ait",
    "acure_dry_dep_so2",
    "acure_bvoc_soa",
    "acure_dms",
    "acure_bl_nuc",
    "acure_ait_width",
    "acure_cloud_ph",
    "dbsdtbs_turb_0",
    "acure_bc_ri",
    "acure_sea_spray",
    "acure_carb_bb_diam",
    "acure_anth_so2_r",
    "acure_prim_so4_diam"
]

a_init = Emulator()

# %%
a = Emulator(
    region=[-45, 40, -30, 10],
    excludeFeats=list(set(a_init.__get_input_names__()) - set(myFeaturesNames)),
    start_time="2017-07-08T09:00:00",
    end_time="2017-07-31T12:59:59",
    centerTarget=False
)

# %%
job = a.train()

# %%
job.status()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-0b8abe45e471> in <module>
# ----> 1 job.status()
#
# NameError: name 'job' is not defined

# %%
job.cancel()
