# %%
from mpl_toolkits.basemap import Basemap
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-1-d9467465a3b6> in <module>
# ----> 1 from mpl_toolkits.basemap import Basemap
#
# ~/.conda/envs/py-gordon_1_0_0/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py in <module>
#     150
#     151 # create dictionary that maps epsg codes to Basemap kwargs.
# --> 152 pyproj_datadir = os.environ['PROJ_LIB']
#     153 epsgf = open(os.path.join(basemap_datadir,'epsg'))
#     154 epsg_dict={}
#
# ~/.conda/envs/py-gordon_1_0_0/lib/python3.6/os.py in __getitem__(self, key)
#     667         except KeyError:
#     668             # raise KeyError with the original key value
# --> 669             raise KeyError(key) from None
#     670         return self.decodevalue(value)
#     671
#
# KeyError: 'PROJ_LIB'

# %%
import os

# %%
os.environ["PROJ_LIB"] = "/home/c3/.conda/envs/py-gordon_1_0_0/share/basemap"

# %%
from mpl_toolkits.basemap import Basemap
