# %%
file = c3.SimulationOutputFile.fetch().objs[0]

# %%
file
# Out:
# c3.SimulationOutputFile(
#  id='0001eb59-fe4c-4c63-83a8-cda8a6e4f8ec',
#  meta=c3.Meta(
#         tenantTagId=151,
#         tenant='dev',
#         tag='tc02d',
#         created=datetime.datetime(2021, 10, 4, 16, 0, 27, tzinfo=datetime.timezone.utc),
#         createdBy='provisioner',
#         updated=datetime.datetime(2021, 10, 4, 16, 0, 27, tzinfo=datetime.timezone.utc),
#         updatedBy='provisioner',
#         timestamp=datetime.datetime(2021, 10, 4, 16, 0, 27, tzinfo=datetime.timezone.utc),
#         fetchInclude='[]',
#         fetchType='SimulationOutputFile'),
#  version=1,
#  simulationSample=c3.SimulationSample(id='EnsNo_1_SimNo_188'),
#  dateTag=datetime.datetime(2017, 8, 15, 0, 0),
#  file=c3.File(
#         url='azure://dev-dti/fs/dti/mpodolsky/gordon-group/acure_aircraft/u-bs714_ens188/bs714a.flight_track_20170815.nc'),
#  processed=False)

# %%
file.upsertFile()
# Out:
# True

# %%
files = c3.SimulationOutputFile.fetch().objs[0:2]

# %%
for file in files:
    file.upsertFile()

# %%
files = c3.SimulationOutputFile.fetch({
    "filter": 'simulationSample.id == "EnsNo_1_SimNo_188"'
}).objs[0:2]

# %%
for file in files:
    file.upsertFile()
