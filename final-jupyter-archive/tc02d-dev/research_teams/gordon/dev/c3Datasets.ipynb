# %%
def get_features_and_outputs_from_simulations(output_name, timestamp):
    """
    Reads the simulation parameter map, fetches Cassandra to obtain the correspoding output for the specified timestamp.
    Splits the data into train/test sets with, returns c3.Dataset for each one of them.
    
    
    Inputs:
    - str output_name: name of the variable in SimulationModelOutput under investigation
    - str timestamp: shape of the timestamp to fetch the timeseries, e.g. "2017-08-19T09:00:00.000"
    
    Returns:
    - c3.Dataset X_train: train set of features
    - c3.Dataset X_test: test set of features
    - c3.Dataset y_train: train set of outputs
    - c3.Dataset y_test: test set of outputs

    """
    import pandas as pd
    from sklearn.model_selection import train_test_split
    
    # fetch simulation parameters
    parameters = c3.SimulationModelParameters.fetch().objs
    parameters = parameters.toJson()
    df = pd.DataFrame(parameters)
    simulations = pd.DataFrame(df['id'])
    X = df[df.columns[5:]]
    
    # define simple metric
    metric_name = "Average_" + output_name + "_SimulationSample" 
    metric_descr = "Calculates average of " + output_name + " for a given set of SimulationSample"
    metric_expr = "avg(avg(normalized.data." + output_name + "))"
    metric = c3.SimpleMetric(id = metric_name,
                                    name = metric_name,
                                    description = metric_descr,
                                    srcType = "SimulationSample",
                                    path = "output",  # the timeseries is in the output field of SimSam
                                    expression = metric_expr
                                  )
    
    # define metric spec
    spec = c3.EvalMetricsSpec(
                                    ids = simulations['id'],
                                    expressions = [metric_name],
                                    start = timestamp,
                                    end = timestamp,
                                    interval = "SECOND" 
                                )

    # evaluate metric, cast it to pandas
    evalMetricsResult = c3.SimulationSample.evalMetricsWithMetadata(
                                                                        spec=spec,
                                                                        overrideMetrics=[metric]
                                                                    )
    y = c3.EvalMetricsResult.toPandas(result=evalMetricsResult)
    
    
    # split into train/test sets
    datasets = train_test_split(X, y, test_size=0.1, random_state=42)
    
    # cast into c3 Datasets
    X_train = c3.Dataset.fromPython(datasets[0])
    X_test = c3.Dataset.fromPython(datasets[1])
    y_train = c3.Dataset.fromPython(datasets[2])
    y_test = c3.Dataset.fromPython(datasets[3])
    
    return X_train, X_test, y_train, y_test

# %%
parameters = c3.SimulationModelParameters.fetch().objs

# %%
parameters
# Out:
# c3.Arry<SimulationModelParameters>([c3.SimulationModelParameters(
#   id='EnsNo_1_SimNo_0',
#   meta=c3.Meta(
#          tenantTagId=151,
#          tenant='dev',
#          tag='tc02d',
#          created=datetime.datetime(2021, 10, 15, 18, 7, 43, tzinfo=datetime.timezone.utc),
#          createdBy='provisioner',
#          updated=datetime.datetime(2021, 10, 15, 18, 7, 43, tzinfo=datetime.timezone.utc),
#          updatedBy='provisioner',
#          timestamp=datetime.datetime(2021, 10, 15, 18, 7, 43, tzinfo=datetime.timezone.utc),
#          fetchInclude='[]',
#          fetchType='SimulationModelParameters'),
#   version=1,
#   ensemble=c3.SimulationEnsemble(id='1'),
#   acure_bl_nuc=0.5,
#   acure_ait_width=0.65,
#   acure_cloud_ph=0.396,
#   acure_carb_ff_ems=1.0,
#   acure_carb_ff_ems_eur=0.5,
#   acure_carb_ff_ems_nam=0.5,
#   acure_carb_ff_ems_chi=0.5,
#   acure_carb_ff_ems_asi=0.5,
#   acure_carb_ff_ems_mar=0.5,
#   acure_carb_ff_ems_r=0.5,
#   acure_carb_bb_ems=1.0,
#   acure_carb_bb_ems_sam=0.5,
#   acure_carb_bb_ems_naf=0.5,
#   acure_carb_bb_ems_saf=0.5,
#   acure_carb_bb_ems_bnh=0.5,
#   acure_carb_bb_ems_rnh=0.5,
#   acure_carb_bb_ems_rsh=0.5,
#   acure_carb_res_ems=1.0,
#   acure_carb_res_ems_chi=0.5,
#   acure_carb_res_ems_asi=0.5,
#   acure_carb_res_ems_afr=0.5,
#   acure_carb_res_ems_lat=0.5,
#   acure_carb_res_ems_r=0.5,
#   acure_carb_ff_diam=0.5,
#   acure_carb_bb_diam=0.095238095,
#   acure_carb_res_diam=0.146341463,
#   acure_prim_so4_diam=1.0,
#   acure_sea_spray=0.5,
#   acure_anth_so2=1.0,
#   acure_anth_so2_chi=0.557492951,
#   acure_anth_so2_asi=0.557492951,
#   acure_anth_so2_eur=0.557492951,
#   acure_anth_so2_nam=0.557492951,
#   acure_anth_so2_r=0.557492951,
#   acure_volc_so2=0.283145598,
#   acure_bvoc_soa=0.466532506,
#   acure_dms=0.502276639,
#   acure_prim_moc=0.338358104,
#   acure_dry_dep_ait=0.5,
#   acure_dry_dep_acc=0.5,
#   acure_dry_dep_so2=0.5,
#   acure_kappa_oc=1.0,
#   acure_sig_w=0.712414374,
#   acure_rain_frac=0.0,
#   acure_cloud_ice_thresh=1.0,
#   acure_convective_plume_scavenging=1.0,
#   acure_scav_diam=1.0,
#   acure_bc_ri=0.7,
#   acure_oxidants_oh=0.576175045,
#   acure_oxidants_o3=0.576175045,
#   bparam=0.5,
#   two_d_fsd_factor=0.4,
#   c_r_correl=0.9,
#   acure_autoconv_exp_lwp=0.275862069,
#   acure_autoconv_exp_nd=0.605,
#   dbsdtbs_turb_0=0.15,
#   ai=0.514,
#   m_ci=0.333333333,
#   a_ent_1_rp=0.46),
#  c3.SimulationModelParameters(
#   id='EnsNo_1_SimNo_1',
#   meta=c3.Meta(
#          tenantTagId=151,
#          tenant='dev',
#          tag='tc02d',
#          created=datetime.datetime(2021, 10, 15, 18, 7, 43, tzinfo=datetime.timezone.utc),
#          createdBy='provisioner',
#          updated=datetime.datetime(2021, 10, 15, 18, 7, 43, tzinfo=datetime.timezone.utc),
#          updatedBy='provisioner',
#          timestamp=datetime.datetime(2021, 10, 15, 18, 7, 43, tzinfo=datetime.timezone.utc),
#          fetchInclude='[]',
#          fetchType='SimulationModelParameters'),
#   version=1,
#   ensemble=c3.SimulationEnsemble(id='1'),
#   acure_bl_nuc=0.47,
#   acure_ait_width=0.5,
#   acure_cloud_ph=0.5,
#   acure_carb_ff_ems=1.0,
#   acure_carb_ff_ems_eur=0.53,
#   acure_carb_ff_ems_nam=0.47,
#   acure_carb_ff_ems_chi=0.53,
#   acure_carb_ff_ems_asi=0.47,
#   acure_carb_ff_ems_mar=0.53,
#   acure_carb_ff_ems_r=0.47,
#   acure_carb_bb_ems=1.0,
#   acure_carb_bb_ems_sam=0.53,
#   acure_carb_bb_ems_naf=0.47,
#   acure_carb_bb_ems_saf=0.53,
#   acure_carb_bb_ems_bnh=0.47,
#   acure_carb_bb_ems_rnh=0.53,
#   acure_carb_bb_ems_rsh=0.47,
#   acure_carb_res_ems=1.0,
#   acure_carb_res_ems_chi=0.53,
#   acure_carb_res_ems_asi=0.47,
#   acure_carb_res_ems_afr=0.53,
#   acure_carb_res_ems_lat=0.47,
#   acure_carb_res_ems_r=0.53,
#   acure_carb_ff_diam=0.47,
#   acure_carb_bb_diam=0.5,
#   acure_carb_res_diam=0.5,
#   acure_prim_so4_diam=0.5,
#   acure_sea_spray=0.53,
#   acure_anth_so2=1.0,
#   acure_anth_so2_chi=0.5,
#   acure_anth_so2_asi=0.5,
#   acure_anth_so2_eur=0.5,
#   acure_anth_so2_nam=0.5,
#   acure_anth_so2_r=0.5,
#   acure_volc_so2=0.5,
#   acure_bvoc_soa=0.5,
#   acure_dms=0.47,
#   acure_prim_moc=0.5,
#   acure_dry_dep_ait=0.53,
#   acure_dry_dep_acc=0.47,
#   acure_dry_dep_so2=0.53,
#   acure_kappa_oc=0.5,
#   acure_sig_w=0.5,
#   acure_rain_frac=0.5,
#   acure_cloud_ice_thresh=0.5,
#   acure_convective_plume_scavenging=0.5,
#   acure_scav_diam=0.5,
#   acure_bc_ri=0.5,
#   acure_oxidants_oh=0.5,
#   acure_oxidants_o3=0.5,
#   bparam=0.5,
#   two_d_fsd_factor=0.5,
#   c_r_correl=0.5,
#   acure_autoconv_exp_lwp=0.5,
#   acure_autoconv_exp_nd=0.5,
#   dbsdtbs_turb_0=0.5,
#   ai=0.5,
#   m_ci=0.5,
#   a_ent_1_rp=0.5),
#  c3.SimulationModelParameters(
#   id='EnsNo_1_SimNo_10',
#   meta=c3.Meta(
#          tenantTagId=151,
#          tenant='dev',
#          tag='tc02d',
#          created=datetime.datetime(2021, 10, 15, 18, 7, 43, tzinfo=datetime.timezone.utc),
#          createdBy='provisioner',
#          updated=datetime.datetime(2021, 10, 15, 18, 7, 43, tzinfo=datetime.timezone.utc),
#          updatedBy='provisioner',
#          timestamp=datetime.datetime(2021, 10, 15, 18, 7, 43, tzinfo=datetime.timezone.utc),
#          fetchInclude='[]',
#          fetchType='SimulationModelParameters'),
#   version=1,
#   ensemble=c3.SimulationEnsemble(id='1'),
#   acure_bl_nuc=0.969887592,
#   acure_ait_width=0.083081473,
#   acure_cloud_ph=0.478473679,
#   acure_carb_ff_ems=1.0,
#   acure_carb_ff_ems_eur=0.577525476,
#   acure_carb_ff_ems_nam=0.231614821,
#   acure_carb_ff_ems_chi=0.283144817,
#   acure_carb_ff_ems_asi=0.050177825,
#   acure_carb_ff_ems_mar=0.419984352,
#   acure_carb_ff_ems_r=0.914345911,
#   acure_carb_bb_ems=1.0,
#   acure_carb_bb_ems_sam=0.716751869,
#   acure_carb_bb_ems_naf=0.437475449,
#   acure_carb_bb_ems_saf=0.398710883,
#   acure_carb_bb_ems_bnh=0.045774805,
#   acure_carb_bb_ems_rnh=0.593635537,
#   acure_carb_bb_ems_rsh=0.975775552,
#   acure_carb_res_ems=1.0,
#   acure_carb_res_ems_chi=0.184959714,
#   acure_carb_res_ems_asi=0.005871954,
#   acure_carb_res_ems_afr=0.98698883,
#   acure_carb_res_ems_lat=0.189957881,
#   acure_carb_res_ems_r=0.955635203,
#   acure_carb_ff_diam=0.4771478,
#   acure_carb_bb_diam=0.690581085,
#   acure_carb_res_diam=0.255840683,
#   acure_prim_so4_diam=0.516864447,
#   acure_sea_spray=0.989836761,
#   acure_anth_so2=1.0,
#   acure_anth_so2_chi=0.7174753,
#   acure_anth_so2_asi=0.180696493,
#   acure_anth_so2_eur=0.03466505,
#   acure_anth_so2_nam=0.327155217,
#   acure_anth_so2_r=0.232632406,
#   acure_volc_so2=0.10473585,
#   acure_bvoc_soa=0.763282867,
#   acure_dms=0.415899558,
#   acure_prim_moc=0.846613292,
#   acure_dry_dep_ait=0.031372427,
#   acure_dry_dep_acc=0.618558773,
#   acure_dry_dep_so2=0.942199242,
#   acure_kappa_oc=0.857839112,
#   acure_sig_w=0.299392421,
#   acure_rain_frac=0.589830796,
#   acure_cloud_ice_thresh=0.932973106,
#   acure_convective_plume_scavenging=0.093402781,
#   acure_scav_diam=0.906409512,
#   acure_bc_ri=0.244754948,
#   acure_oxidants_oh=0.043591375,
#   acure_oxidants_o3=0.017103552,
#   bparam=0.927093192,
#   two_d_fsd_factor=0.833904789,
#   c_r_correl=0.610920341,
#   acure_autoconv_exp_lwp=0.993935277,
#   acure_autoconv_exp_nd=0.755788467,
#   dbsdtbs_turb_0=0.7741867,
#   ai=0.960910536,
#   m_ci=0.988951537,
#   a_ent_1_rp=0.508725239),
#  c3.SimulationModelParameters(
#   id='EnsNo_1_SimNo_100',
#   meta=c3.Meta(
#          tenantTagId=151,
#          tenant='dev',
#          tag='tc02d',
#          created=datetime.datetime(2021, 10, 15, 18, 7, 43, tzinfo=datetime.timezone.utc),
#          createdBy='provisioner',
#          updated=datetime.datetime(2021, 10, 15, 18, 7, 43, tzinfo=datetime.timezone.utc),
#          updatedBy='provisioner',
#          timestamp=datetime.datetime(2021, 10, 15, 18, 7, 43, tzinfo=datetime.timezone.utc),
#          fetchInclude='[]',
#          fetchType='SimulationModelParameters'),
#   version=1,
#   ensemble=c3.SimulationEnsemble(id='1'),
#   acure_bl_nuc=0.132846924,
#   acure_ait_width=0.445265239,
#   acure_cloud_ph=0.390413663,
#   acure_carb_ff_ems=1.0,
#   acure_carb_ff_ems_eur=0.92592066,
#   acure_carb_ff_ems_nam=0.630498243,
#   acure_carb_ff_ems_chi=0.187250817,
#   acure_carb_ff_ems_asi=0.817524885,
#   acure_carb_ff_ems_mar=0.147786604,
#   acure_carb_ff_ems_r=0.462419366,
#   acure_carb_bb_ems=1.0,
#   acure_carb_bb_ems_sam=0.542292178,
#   acure_carb_bb_ems_naf=0.942645004,
#   acure_carb_bb_ems_saf=0.433384698,
#   acure_carb_bb_ems_bnh=0.488765958,
#   acure_carb_bb_ems_rnh=0.772684396,
#   acure_carb_bb_ems_rsh=0.247772811,
#   acure_carb_res_ems=1.0,
#   acure_carb_res_ems_chi=0.162009191,
#   acure_carb_res_ems_asi=0.067471795,
#   acure_carb_res_ems_afr=0.562002103,
#   acure_carb_res_ems_lat=0.44216481,
#   acure_carb_res_ems_r=0.517220087,
#   acure_carb_ff_diam=0.080640414,
#   acure_carb_bb_diam=0.283142722,
#   acure_carb_res_diam=0.377899013,
#   acure_prim_so4_diam=0.792391483,
#   acure_sea_spray=0.607071783,
#   acure_anth_so2=1.0,
#   acure_anth_so2_chi=0.139324542,
#   acure_anth_so2_asi=0.043222707,
#   acure_anth_so2_eur=0.837181081,
#   acure_anth_so2_nam=0.229608438,
#   acure_anth_so2_r=0.406849743,
#   acure_volc_so2=0.746781273,
#   acure_bvoc_soa=0.009957702,
#   acure_dms=0.781630575,
#   acure_prim_moc=0.566879374,
#   acure_dry_dep_ait=0.666108048,
#   acure_dry_dep_acc=0.407896466,
#   acure_dry_dep_so2=0.93593,
#   acure_kappa_oc=0.775025027,
#   acure_sig_w=0.336168972,
#   acure_rain_frac=0.551248664,
#   acure_cloud_ice_thresh=0.941851166,
#   acure_convective_plume_scavenging=0.85372491,
#   acure_scav_diam=0.987848532,
#   acure_bc_ri=0.190369,
#   acure_oxidants_oh=0.851094458,
#   acure_oxidants_o3=0.010731055,
#   bparam=0.950732185,
#   two_d_fsd_factor=0.90253632,
#   c_r_correl=0.780156704,
#   acure_autoconv_exp_lwp=0.267909727,
#   acure_autoconv_exp_nd=0.018570342,
#   dbsdtbs_turb_0=0.10689266,
#   ai=0.21830828,
#   m_ci=0.163326967,
#   a_ent_1_rp=0.936031151),
#  c3.SimulationModelParameters(
#   id='EnsNo_1_SimNo_101',
#   meta=c3.Meta(
#          tenantTagId=151,
#          tenant='dev',
#          tag='tc02d',
#          created=datetime.datetime(2021, 10, 15, 18, 7, 43, tzinfo=datetime.timezone.utc),
#          createdBy='provisioner',
#          updated=datetime.datetime(2021, 10, 15, 18, 7, 43, tzinfo=datetime.timezone.utc),
#          updatedBy='provisioner',
#          timestamp=datetime.datetime(2021, 10, 15, 18, 7, 43, tzinfo=datetime.timezone.utc),
#          fetchInclude='[]',
#          fetchType='SimulationModelParameters'),
# ...

# %%
tensor = c3.Tensor(parameters)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-375e26c35ed0> in <module>
# ----> 1 tensor = c3.Tensor(parameters)
#
# Z10ac078826d8534179d455db1588a325M_/TypeSystemBase.py in __init__wrapped(*args, **kwargs)
#
# Z10ac078826d8534179d455db1588a325M_/TypeSystemBase.py in __init__wrapped(*args, **kwargs)
#
# TypeError: __init__() takes 1 positional argument but 2 were given
