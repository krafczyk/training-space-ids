# %%
kernel = c3.SklearnGPRKernelMatern(lengthScale=[2,3.14,4,5.22,6], coefficient=1.0, nu=2).build()
print(kernel)

python_kernel = c3.PythonSerialization.deserialize(serialized=kernel.kernel.pickledKernel)
print(type(python_kernel))
print(python_kernel.get_params())
# Out:
# c3.SklearnGPRKernelMatern(
#  lengthScale=c3.Arry<double>([2.0, 3.14, 4.0, 5.22, 6.0]),
#  coefficient=1.0,
#  nu=2.0,
#  kernel=c3.SklearnGPRKernel(
#           name='Matern',
#           hyperParameters=c3.Mapp<string, any>({'coefficient': 1.0,
#                             'lengthScale': c3.Arry<double>([2.0,
#                                             3.14,
#                                             4.0,
#                                             5.22,
#                                             6.0]),
#                             'nu': 2.0}),
#           pickledKernel=''))
# <class 'sklearn.gaussian_process.kernels.Product'>
# {'k1': 1**2, 'k2': Matern(length_scale=[2, 3.14, 4, 5.22, 6], nu=2), 'k1__constant_value': 1.0, 'k1__constant_value_bounds': (1e-05, 100000.0), 'k2__length_scale': [2.0, 3.14, 4.0, 5.22, 6.0], 'k2__length_scale_bounds': (1e-05, 100000.0), 'k2__nu': 2.0}
