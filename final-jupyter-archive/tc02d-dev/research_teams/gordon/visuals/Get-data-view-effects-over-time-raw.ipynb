# %%
# %run ../methods/Get-data.ipynb
# %run ../methods/raw_data/Get-data-raw.ipynb
# %run ../methods/GP-emulation.ipynb

# %% [markdown]
# # Sudan sample (8.125, 38.4375)

# %%
data = compile_output(ensem_membs=ensemble, region=[38, 38.5, 8, 8.5], date='0716', one_time=0)

# %%
for tm in times:
    data_at_one_time = data[data.time == tm]
    data_at_one_time["total"] = data_at_one_time["soluble_accumulation_mode"] + data_at_one_time["soluble_coarse_mode"] + data_at_one_time["soluble_aitken_mode"] + data_at_one_time["dust"]
    
    #plt.scatter(data_at_one_time["acure_sea_spray"], data_at_one_time["soluble_accumulation_mode"])
    #plt.show()

    plt.scatter(data_at_one_time["acure_sea_spray"], data_at_one_time["total"])
    plt.ylim((0, 2))
    plt.show()
# Out:
# /home/c3/.conda/envs/py-gordon_2_0_0/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
for tm in times:
    data_at_one_time = data[data.time == tm]
    data_at_one_time["total"] = data_at_one_time["soluble_accumulation_mode"] + data_at_one_time["soluble_coarse_mode"] + data_at_one_time["soluble_aitken_mode"] + data_at_one_time["dust"]
    
    #plt.scatter(data_at_one_time["acure_sea_spray"], data_at_one_time["soluble_accumulation_mode"])
    #plt.show()

    plt.scatter(data_at_one_time["acure_dry_dep_acc"], data_at_one_time["total"])
    plt.ylim((0, 2))
    plt.show()
# Out:
# /home/c3/.conda/envs/py-gordon_2_0_0/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# # Mid-ocean sample (-29.375, -27.1875)

# %%
data = compile_output(ensem_membs=ensemble, region=[-27.5, -27, -29.5, -29], date='0716', one_time=0)

# %%
for tm in times:
    data_at_one_time = data[data.time == tm]
    data_at_one_time["total"] = data_at_one_time["soluble_accumulation_mode"] + data_at_one_time["soluble_coarse_mode"] + data_at_one_time["soluble_aitken_mode"] + data_at_one_time["dust"]
    
    #plt.scatter(data_at_one_time["acure_sea_spray"], data_at_one_time["soluble_accumulation_mode"])
    #plt.show()

    plt.scatter(data_at_one_time["acure_sea_spray"], data_at_one_time["total"])
    plt.ylim((0, 2))
    plt.show()
# Out:
# /home/c3/.conda/envs/py-gordon_2_0_0/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
for tm in times:
    data_at_one_time = data[data.time == tm]
    data_at_one_time["total"] = data_at_one_time["soluble_accumulation_mode"] + data_at_one_time["soluble_coarse_mode"] + data_at_one_time["soluble_aitken_mode"] + data_at_one_time["dust"]
    
    #plt.scatter(data_at_one_time["acure_sea_spray"], data_at_one_time["soluble_accumulation_mode"])
    #plt.show()

    plt.scatter(data_at_one_time["acure_dry_dep_acc"], data_at_one_time["total"])
    plt.ylim((0, 2))
    plt.show()
# Out:
# /home/c3/.conda/envs/py-gordon_2_0_0/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
