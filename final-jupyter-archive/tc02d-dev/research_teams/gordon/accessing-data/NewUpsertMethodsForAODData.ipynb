# %%
import pandas as pd
import numpy as np
import datetime as dt

# %%
variable_names = {
            "dust" : "atmosphere_optical_thickness_due_to_dust_ambient_aerosol",
            "solubleAitkenMode" : "atmosphere_optical_thickness_due_to_soluble_aitken_mode_ambient_aerosol",
            "solubleAccumulationMode" : "atmosphere_optical_thickness_due_to_soluble_accumulation_mode_ambient_aerosol",
            "solubleCoarseMode" : "atmosphere_optical_thickness_due_to_soluble_coarse_mode_ambient_aerosol",
            "insolubleAitkenMode" : "atmosphere_optical_thickness_due_to_insoluble_aitken_mode_ambient_aerosol"
}

# %%
file_name = "azure://aod-3hourly/" + "jul" + "/bs714a.pb2017" + "0701" + ".pp_" + "076" + ".nc"

# %%
sample = c3.NetCDFUtil.openFile(file_name)

# %%
simulationSample = c3.SimulationSample.get("EnsNo_1_SimNo_76")

# %%
df_var = pd.DataFrame()
for var in variable_names.items():
    tensor = sample[var[1]][:][2,:,:,:]
    tensor = np.array(tensor).flatten()
    df_var[var[0]] = tensor
    # include simulation sample
df_var["simulationSample"] = simulationSample

# %%
df_var
# Out:
#             dust  solubleAitkenMode  solubleAccumulationMode  \
# 0       0.000034           0.001151                 0.018691
# 1       0.000034           0.001146                 0.018701
# 2       0.000034           0.001136                 0.018989
# 3       0.000034           0.001137                 0.018981
# 4       0.000034           0.001144                 0.018959
# ...          ...                ...                      ...
# 221179  0.001510           0.003016                 0.213217
# 221180  0.001510           0.003093                 0.232110
# 221181  0.001510           0.003100                 0.219623
# 221182  0.001511           0.003116                 0.217278
# 221183  0.001511           0.002979                 0.216901
#
#         solubleCoarseMode  insolubleAitkenMode  \
# 0                0.003606             0.000252
# 1                0.003601             0.000252
# 2                0.003596             0.000252
# 3                0.003591             0.000252
# 4                0.003609             0.000252
# ...                   ...                  ...
# 221179           0.000271             0.003203
# 221180           0.000273             0.003193
# 221181           0.000271             0.003195
# 221182           0.000273             0.003191
# 221183           0.000274             0.003184
#
#                                          simulationSample
# 0       c3.SimulationSample(\n id='EnsNo_1_SimNo_76',\...
# 1       c3.SimulationSample(\n id='EnsNo_1_SimNo_76',\...
# 2       c3.SimulationSample(\n id='EnsNo_1_SimNo_76',\...
# 3       c3.SimulationSample(\n id='EnsNo_1_SimNo_76',\...
# 4       c3.SimulationSample(\n id='EnsNo_1_SimNo_76',\...
# ...                                                   ...
# 221179  c3.SimulationSample(\n id='EnsNo_1_SimNo_76',\...
# 221180  c3.SimulationSample(\n id='EnsNo_1_SimNo_76',\...
# 221181  c3.SimulationSample(\n id='EnsNo_1_SimNo_76',\...
# 221182  c3.SimulationSample(\n id='EnsNo_1_SimNo_76',\...
# 221183  c3.SimulationSample(\n id='EnsNo_1_SimNo_76',\...
#
# [221184 rows x 6 columns]

# %%
df_st = pd.DataFrame()
lat = sample["latitude"][:]
lon = [x*(x < 180) + (x - 360)*(x >= 180) for x in sample["longitude"][:]]
tim = sample["time"][:]
zero_time = dt.datetime(1970,1,1,0,0)
times = []
for t in tim:
    target_time = zero_time + dt.timedelta(hours=t)
    times.append(target_time)
df_st["time"] = [t for t in times for n in range(0, len(lat)*len(lon))]
df_st["latitude"] = [l for l in lat for n in range(0, len(lon))]*len(times)
df_st["longitude"] = [l for l in lon]*len(times)*len(lat)
ids = round(df_st["latitude"],3).astype(str) + "_" + round(df_st["longitude"],3).astype(str) + "_" + df_st["time"].astype(str).apply(lambda x: x.replace(" ", 'T'))

# %%
def make_gstp(objId):
    return c3.GeoSurfaceTimePoint(id=objId)

# %%
objs = ids.apply(make_gstp)

# %%
df_batch = pd.DataFrame(df_var)

# %%
df_batch["geoSurfaceTimePoint"] = objs

# %%
output_records = df_batch.to_dict(orient="records")

# %%
c3.Simulation3HourlyAODOutput.upsertBatch(objs=output_records)
# Out:
# c3.ObjList<Simulation3HourlyAODOutput>(
#  stats=c3.Stats(
#          createdObjCount=221184,
#          updatedObjCount=0,
#          removedObjCount=0,
#          failedObjCount=0,
#          objCount=221184,
#          dbWait=0.0,
#          time=655.989,
#          dbTime=551.814295415,
#          objsPerSecond=337.17638557963625,
#          dbObjsPerSecond=400.8305001117366),
#  objs=c3.Arry<Simulation3HourlyAODOutput>([c3.Simulation3HourlyAODOutput(
#          id='-89.375_0.938_2017-07-01T00:20:00#DNXFPOR',
#          meta=c3.Meta(
#                 created=datetime.datetime(2022, 6, 2, 17, 25, 15, tzinfo=datetime.timezone.utc),
#                 updated=datetime.datetime(2022, 6, 2, 17, 25, 15, tzinfo=datetime.timezone.utc),
#                 timestamp=datetime.datetime(2022, 6, 2, 17, 25, 15, tzinfo=datetime.timezone.utc)),
#          version=1),
#         c3.Simulation3HourlyAODOutput(
#          id='-89.375_2.812_2017-07-01T00:20:00#DNXFPOS',
#          meta=c3.Meta(
#                 created=datetime.datetime(2022, 6, 2, 17, 25, 15, tzinfo=datetime.timezone.utc),
#                 updated=datetime.datetime(2022, 6, 2, 17, 25, 15, tzinfo=datetime.timezone.utc),
#                 timestamp=datetime.datetime(2022, 6, 2, 17, 25, 15, tzinfo=datetime.timezone.utc)),
#          version=1),
#         c3.Simulation3HourlyAODOutput(
#          id='-89.375_4.688_2017-07-01T00:20:00#DNXFPOT',
#          meta=c3.Meta(
#                 created=datetime.datetime(2022, 6, 2, 17, 25, 15, tzinfo=datetime.timezone.utc),
#                 updated=datetime.datetime(2022, 6, 2, 17, 25, 15, tzinfo=datetime.timezone.utc),
#                 timestamp=datetime.datetime(2022, 6, 2, 17, 25, 15, tzinfo=datetime.timezone.utc)),
#          version=1),
#         ...,
#         c3.Simulation3HourlyAODOutput(
#          id='89.375_-4.688_2017-07-01T21:20:00#DNXMHOO',
#          meta=c3.Meta(
#                 created=datetime.datetime(2022, 6, 2, 17, 25, 15, tzinfo=datetime.timezone.utc),
#                 updated=datetime.datetime(2022, 6, 2, 17, 25, 15, tzinfo=datetime.timezone.utc),
#                 timestamp=datetime.datetime(2022, 6, 2, 17, 25, 15, tzinfo=datetime.timezone.utc)),
#          version=1),
#         c3.Simulation3HourlyAODOutput(
#          id='89.375_-2.812_2017-07-01T21:20:00#DNXMHOP',
#          meta=c3.Meta(
#                 created=datetime.datetime(2022, 6, 2, 17, 25, 15, tzinfo=datetime.timezone.utc),
#                 updated=datetime.datetime(2022, 6, 2, 17, 25, 15, tzinfo=datetime.timezone.utc),
#                 timestamp=datetime.datetime(2022, 6, 2, 17, 25, 15, tzinfo=datetime.timezone.utc)),
#          version=1),
#         c3.Simulation3HourlyAODOutput(
#          id='89.375_-0.938_2017-07-01T21:20:00#DNXMHOQ',
#          meta=c3.Meta(
#                 created=datetime.datetime(2022, 6, 2, 17, 25, 15, tzinfo=datetime.timezone.utc),
#                 updated=datetime.datetime(2022, 6, 2, 17, 25, 15, tzinfo=datetime.timezone.utc),
#                 timestamp=datetime.datetime(2022, 6, 2, 17, 25, 15, tzinfo=datetime.timezone.utc)),
#          version=1)]))
