# %%
# %run Get-data-raw.ipynb
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /opt/conda/lib/python3.8/site-packages/IPython/core/magics/execution.py in run(self, parameter_s, runner, file_finder)
#     702             fpath = arg_lst[0]
# --> 703             filename = file_finder(fpath)
#     704         except IndexError:
#
# /opt/conda/lib/python3.8/site-packages/IPython/utils/path.py in get_py_filename(name, force_win32)
#     108     else:
# --> 109         raise IOError('File `%r` not found.' % name)
#     110
#
# OSError: File `'../Get-data.ipynb.py'` not found.
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# ~/jupyter_root_dir/research_teams/gordon/methods/raw_data/Get-data-raw.ipynb in <module>
# ----> 1 get_ipython().run_line_magic('run', '../Get-data.ipynb')
#
# ...

# %% [markdown]
# # Sample (a): Coastal (-0.625, -0.9375)

# %%
coastal = compile_output(ensem_membs=ensemble, region=[-1, -0.5, -1, -0.5], date='0801', one_time=0)

# %%
coastal2 = compile_output(ensem_membs=ensemble, region=[-1, -0.5, -1, -0.5], date='0826', one_time=0)

# %% [markdown]
# # Sample (c): Sudan (8.125, 38.4375)

# %%
sudan = compile_output(ensem_membs=ensemble, region=[38, 38.5, 8, 8.5], date='0801', one_time=0)

# %%
sudan2 = compile_output(ensem_membs=ensemble, region=[38, 38.5, 8, 8.5], date='0826', one_time=0)

# %% [markdown]
# # Sample (e): Mid-ocean (-29.375, -27.1875)

# %%
midocean = compile_output(ensem_membs=ensemble, region=[-27.5, -27, -29.5, -29], date='0801', one_time=0)

# %%
midocean2 = compile_output(ensem_membs=ensemble, region=[-27.5, -27, -29.5, -29], date='0826', one_time=0)

# %% [markdown]
# # Checks

# %%
"""
input_name = 'acure_sea_spray'
input_col = dfparams_of_interest.pop(input_name)

# print(dfparams_of_interest, input_col)

dfparams_of_interest.insert(0, input_name, input_col)

fig, ax = plt.subplots(figsize=(10, 10))
cor = ax.matshow(dfparams_of_interest.corr())
_ = fig.colorbar(cor)
"""

# %%
"""
def minMax(x):
    return [(np.min(x) >= 0), (np.max(x) <= 1)]

for col in range(5, 64):
    print(dfparams.columns[col], minMax(dfparams.iloc[:,col]))
"""

# %%
# july_dates = ["0" + str(int("0701") + k*int("0001")) for k in range(0, 31)]

# %%
"""
for date in july_dates:
    open_sat_sim(month = "jul", date = date, member = "000")
    print(date)
"""
# Out:
# 0701
# 0702
# 0703
# 0704
# 0705
# 0706
# 0707
# 0708
# 0709
# 0710
# 0711
# 0712
# 0713
# 0714
# 0715
# 0716
# 0717
# 0718
# 0719
# 0720
# 0721
# 0722
# 0723
# 0724
# 0725
# 0726
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# FileNotFoundError: [Errno 2] No such file or directory: b'/tmp/bs714a.pb20170727.pp_000.nc'
#
# The above exception was the direct cause of the following exception:
#
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-412a61674657> in <module>
#       1 for date in july_dates:
# ----> 2     open_sat_sim(month = "jul", date = date, member = "000")
#       3     print(date)
#
# <ipython-input-1-e8ffe72cb083> in open_sat_sim(month, date, member)
#      18     file_name = "azure://aod-3hourly/" + month + "/bs714a.pb2017" + date + ".pp_" + member + ".nc"
#      19
# ...

# %%
"""
for member in ensemble:
    open_sat_sim(month = "jul", date = "0715", member = member)
    print(member)
"""
# Out:
# 000
# 001
# 002
# 003
# 004
# 005
# 006
# 007
# 008
# 009
# 010
# 011
# 012
# 013
# 014
# 015
# 016
# 017
# 018
# 019
# 020
# 021
# 022
# 023
# 024
# 025
# 026
# 027
# 028
# 029
# 030
# 031
# 032
# 033
# 034
# 035
# 036
# 037
# 038
# 039
# 040
# 041
# 042
# 043
# 044
# 045
# 046
# 047
# 048
# 049
# 050
# 051
# 052
# 053
# 054
# 055
# 056
# 057
# 058
# 059
# 060
# 061
# 062
# 063
# 064
# 065
# 066
# 067
# 068
# 069
# 070
# 071
# 072
# 073
# 074
# 075
# 076
# 077
# 078
# 079
# 080
# 081
# 082
# 083
# 084
# 085
# 086
# 087
# 088
# 089
# 090
# 091
# 092
# 093
# 094
# 095
# 096
# 097
# 098
# 099
# 100
# 101
# 102
# 103
# 104
# 105
# 106
# 107
# 108
# 109
# 110
# 111
# 112
# 113
# 114
# 115
# 116
# 117
# 118
# 119
# 120
# 121
# 122
# 123
# 124
# 125
# 126
# 127
# 128
# 129
# 130
# 131
# 132
# 133
# 134
# 135
# 136
# 137
# 138
# 139
# 140
# 141
# 142
# 143
# 144
# 145
# 146
# 147
# 148
# 149
# 150
# 151
# 152
# 153
# 154
# 155
# 156
# 157
# 158
# 159
# 160
# 161
# 162
# 163
# 164
# 165
# ...
