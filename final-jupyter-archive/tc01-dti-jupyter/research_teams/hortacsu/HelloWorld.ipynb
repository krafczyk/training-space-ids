# %% [markdown]
# # Trying out the notebook!
#
# ### Learning the System Todos
# - How do I make it work with GIT (bitbucket in particular)?
# - Can you run stuff in R
# - How do I setup document types?

# %%
print("hello world")
# Out:
# hello world
