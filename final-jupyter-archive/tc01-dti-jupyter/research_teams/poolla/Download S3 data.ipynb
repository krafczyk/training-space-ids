# %%
import pandas as pd 
import requests
import pyarrow.parquet as pq 
from pyarrow.parquet import ParquetDataset
import boto3
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_4512/616338070.py in <module>
#       3 import pyarrow.parquet as pq
#       4 from pyarrow.parquet import ParquetDataset
# ----> 5 import boto3
#
# ModuleNotFoundError: No module named 'boto3'

# %%
bldg = pd.read_parquet('100005-0.parquet')

# %%
resp = requests.get("https://oedi-data-lake.s3.amazonaws.com/nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2021/comstock_amy2018_release_1/timeseries_individual_buildings/by_state/upgrade=0/state=CA/100005-0.parquet")
print(resp.status_code)
# Out:
# 200

# %%
# df = pq.read_table(resp.content).to_pandas()
# df = pd.read_parquet(resp.content)



dataset = ParquetDataset("https://oedi-data-lake.s3.amazonaws.com/nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2021/comstock_amy2018_release_1/timeseries_individual_buildings/by_state/upgrade=0/state=CA/100005-0.parquet")
table = dataset.read()
df = table.to_pandas()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /tmp/ipykernel_4512/998494887.py in <module>
#       4
#       5
# ----> 6 dataset = ParquetDataset("https://oedi-data-lake.s3.amazonaws.com/nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2021/comstock_amy2018_release_1/timeseries_individual_buildings/by_state/upgrade=0/state=CA/100005-0.parquet")
#       7 table = dataset.read()
#       8 df = table.to_pandas()
#
# ~/.conda/envs/py-utkarsha/lib/python3.7/site-packages/pyarrow/parquet.py in __init__(self, path_or_paths, filesystem, schema, metadata, split_row_groups, validate_schema, filters, metadata_nthreads, read_dictionary, memory_map, buffer_size, partitioning, use_legacy_dataset)
#    1270          self.metadata_path) = _make_manifest(
#    1271              path_or_paths, self.fs, metadata_nthreads=metadata_nthreads,
# ...
