# %%
import os

# %%
## before sync ##
os.listdir()
# Out:
# ['.ipynb_checkpoints', 'empty_folder_test.ipynb']

# %%
## before sync ##
os.path.isdir('empty_test_folder')
# Out:
# False

# %%
## after sync ##
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '503-1291-warp.tif',
#  'empty_folder_test.ipynb',
#  'model_ckpt']

# %%
## after sync ##
os.path.isdir('empty_test_folder')
# Out:
# False

# %%
## after sync ##
os.path.isdir('model_ckpt')
# Out:
# True
