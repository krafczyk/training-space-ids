# %% [markdown]
# # Set kernel to: `py-pythonEnv`
# If this kernel is not available, see the Kernel Installation Instructions section located in at the bottom of this Notebook.

# %% [markdown]
# # Import libraries used in this notebook:

# %%
from datetime import datetime
import pandas as pd

# %% [markdown]
# # Table of Contents

# %% [markdown]
# * [C3 Python Basics](#1)
#     * [Fetch and Filter in Python](#1.1)
#         * [A. Comon Comands](#1.1A)
#         * [B. View Type Dcumentation](#1.1B)
#         * [C. Fetch Method in Python](#1.1C)
#         * [D. Evaluate Method in Python](#1.1D)
#         * [E. Other Useful Operations](#1.1E)
#     * [Prototype Method Functions in Python](#1.2)
#         * [A. Write code](#1.2A)
#         * [A. Test code](#1.2B)
#
# [Appendix - Kernel Installation Instructions](#apdx)

# %% [markdown]
# # C3 Python Basics <a class="anchor" id="1">

# %% [markdown]
# ## Fetch and Filter in Python <a class="anchor" id="1.1">

# %% [markdown]
# ### A. Comon Commands <a class="anchor" id="1.1A">
# Some useful operations/commands for Jupyter Notebooks and the JS Console.

# %% [markdown]
# #### Generic Type System Calls:
# -  `c3.Type.action(...)`
#
# | Use Case | Jupyter Notebook Command | JS Console Command |
# | --- | --- | --- |
# |View Documentation on `MyType` | help(c3.MyType) | c3ShowType(MyType) |
#     |View Documentation on a `MyType` method | help(c3.MyType.myMethod) | N/A |
# | Find the number `MyType` records| c3.MyType.fetchCount() | c3Count(MyType) |
# | Fetch `MyType` records| c3.MyType.fetch()| MyType.fetch() |
# | Fetch `MyType` records in a table| pd.DataFrame(c3.MyType.fetch().objs.toJson()) ${^\dagger}$ | c3Grid(MyType.fetch())|
# | Fetch `MyType` records in a table with filters | c3.MyType.fetch(spec={'filter':" ... "})${^\ddagger}$ | c3Grid(MyType.fetch({filter: " ... "})) |
#
# > ${^\dagger}$ - Instead of using a C3 function, you can use a `pandas` `DataFrame`.
#
# > ${^\ddagger}$ - Notice the extra single-quote around `filter`, and assigning the variable `spec` in the JSON-object, this is the `FetchSpec`. Run `help(c3.FetchSpec)` in Jupyter for more details.

# %% [markdown]
# ### B. View Type Dcumentation:<a class="anchor" id="1.1B">
# Use `help(c3.MyType)` to see Type Documentation.

# %%
help(c3.FetchSpec)

# %% [markdown]
# #### View Method Documentation:
# Use `help(c3.MyType.myMethod)` to view documentation for a specific method for a Type.

# %%
help(c3.Persistable.fetch)

# %% [markdown]
# ### C. Fetch Method in Python <a class='anchor' id='1.1C'>

# %% [markdown]
# #### Simple Fetch:
# Use `c3.MyType.fetch()` to get data with the standard fields

# %%
c3.Unit.fetchCount()

# %% [markdown]
# #### Fetch and Dislpay in a Pandas DataFrame:
# Use `.objs.toJson()` to get a fetch result in an array for a json and
#
# wrap that with `pd.DataFrame` to plot a table as a pandas dataframe
#
# Some of the common FetchSpec fields are shown.

# %%
myFetchResult = c3.Unit.fetch(spec={
#                                   'limit': 15,
                                  #'include': 'this, myField',
                                  #'offset': 5,
                                  #'order': "ascending(myField)",
                                  #'filter': "myField == 'myString' && myOtherField == 'myOtherString'"
                                 })

pd.DataFrame(myFetchResult.objs.toJson())
# Out:
#      type                                               meta  \
# 0    Unit  {'type': 'Meta', 'tenantTagId': 154, 'tenant':...
# 1    Unit  {'type': 'Meta', 'tenantTagId': 154, 'tenant':...
# 2    Unit  {'type': 'Meta', 'tenantTagId': 154, 'tenant':...
# 3    Unit  {'type': 'Meta', 'tenantTagId': 154, 'tenant':...
# 4    Unit  {'type': 'Meta', 'tenantTagId': 154, 'tenant':...
# ..    ...                                                ...
# 540  Unit  {'type': 'Meta', 'tenantTagId': 154, 'tenant':...
# 541  Unit  {'type': 'Meta', 'tenantTagId': 154, 'tenant':...
# 542  Unit  {'type': 'Meta', 'tenantTagId': 154, 'tenant':...
# 543  Unit  {'type': 'Meta', 'tenantTagId': 154, 'tenant':...
# 544  Unit  {'type': 'Meta', 'tenantTagId': 154, 'tenant':...
#
#                                        id           name  version  symbol  \
# 0    2ef365e3-6554-410e-ba0d-5d7a8fd183f4         Erlang        1  erlang
# 1    423b6dca-5e7e-452f-be68-fdd163733c14            kVA        1     kVA
# 2    44bfe88f-565b-44c3-9ee3-846b6a4be8c8      OM annual        1    $/yr
# 3    64479410-86e0-4d95-9206-4be43c3ddbc1  BTU per litre        1   BTU/l
# 4    840416bd-0ebb-4ed5-aada-cd535bd2c800             Ah        1      Ah
# ..                                    ...            ...      ...     ...
# 540                                  week           week        1      wk
# 541                              wk_per_d   week per day        1    wk/d
# 542                                  yard           yard        1      yd
# 543                                  year           year        1      yr
# 544                                 years           year        1      yr
#
#               concept                                         components
# 0     Network Traffic                                                NaN
# 1                Load                                                NaN
# 2           OM annual                                                NaN
# 3       energy/volume  [{'type': 'UnitComponent', 'unit': {'type': 'U...
# 4    Battery Capacity                                                NaN
# ..                ...                                                ...
# 540              time  [{'type': 'UnitComponent', 'unit': {'type': 'U...
# 541      week per day  [{'type': 'UnitComponent', 'unit': {'type': 'U...
# 542            length  [{'type': 'UnitComponent', 'unit': {'type': 'U...
# 543              time  [{'type': 'UnitComponent', 'unit': {'type': 'U...
# 544              time  [{'type': 'UnitComponent', 'unit': {'type': 'U...
#
# [545 rows x 8 columns]

# %% [markdown]
# ### Use This Space for "CHALLENGE: Fetch and Filter in Jupyter"
#
#     Add additional cells as needed.

# %% [markdown]
# ### D. Evaluate Method in Python <a class="anchor" id="1.1D">

# %% [markdown]
# Use `c3.MyType.evaluate(spec={'projection':"myField, myFunction"}).tuples`
#
# to evaluate Type data as tuples. Projection is required.

# %%
c3.Unit.evaluate(spec = {'projection':"name, symbol, concept",
                         #'filter': "myField == 'myString' && myOtherField == 'myOtherString'"
                         #'group':"myField",
                         #"order":"ascending(name)",
                         #'limit': 10
                         #'offset': 5
                        }).tuples
# Out:
# c3.Arry<Tuple>([c3.Tuple(
#   cells=c3.Arry<Cell>([c3.Cell(str='Erlang'),
#           c3.Cell(str='erlang'),
#           c3.Cell(str='Network Traffic')])),
#  c3.Tuple(
#   cells=c3.Arry<Cell>([c3.Cell(str='kVA'),
#           c3.Cell(str='kVA'),
#           c3.Cell(str='Load')])),
#  c3.Tuple(
#   cells=c3.Arry<Cell>([c3.Cell(str='OM annual'),
#           c3.Cell(str='$/yr'),
#           c3.Cell(str='OM annual')])),
#  c3.Tuple(
#   cells=c3.Arry<Cell>([c3.Cell(str='BTU per litre'),
#           c3.Cell(str='BTU/l'),
#           c3.Cell(str='energy/volume')])),
#  c3.Tuple(
#   cells=c3.Arry<Cell>([c3.Cell(str='Ah'),
#           c3.Cell(str='Ah'),
#           c3.Cell(str='Battery Capacity')])),
#  c3.Tuple(
#   cells=c3.Arry<Cell>([c3.Cell(str='Diesel Consumption for Generator'),
#           c3.Cell(str='l/hrs'),
#           c3.Cell(str='Diesel in Litre / Hour')])),
#  c3.Tuple(
#   cells=c3.Arry<Cell>([c3.Cell(str='UAE Dirham'),
#           c3.Cell(str='د.إ'),
#           c3.Cell(str='currency')])),
#  c3.Tuple(
#   cells=c3.Arry<Cell>([c3.Cell(str='Dirhams per employee'),
#           c3.Cell(str='د.إ/employee'),
#           c3.Cell(str='monetary intensity')])),
#  c3.Tuple(
#   cells=c3.Arry<Cell>([c3.Cell(str='Dirhams per kilowatt hour'),
#           c3.Cell(str='د.إ/kWh'),
#           c3.Cell(str='monetary intensity')])),
#  c3.Tuple(
#   cells=c3.Arry<Cell>([c3.Cell(str='Dirhams per square meter'),
#           c3.Cell(str='د.إ/m²'),
#           c3.Cell(str='monetary intensity')])),
#  c3.Tuple(
#   cells=c3.Arry<Cell>([c3.Cell(str='byte'),
#           c3.Cell(str='B'),
#           c3.Cell(str='network traffic')])),
#  c3.Tuple(
#   cells=c3.Arry<Cell>([c3.Cell(str='Bangladeshi Taka'),
#           c3.Cell(str='BDT'),
#           c3.Cell(str='monetary currency')])),
#  c3.Tuple(
#   cells=c3.Arry<Cell>([c3.Cell(str='Bangladeshi Taka per kilowatt hour'),
#           c3.Cell(str='BDT/kWh'),
#           c3.Cell(str='monetary intensity')])),
#  c3.Tuple(
#   cells=c3.Arry<Cell>([c3.Cell(str='Bangladeshi Taka per litre'),
#           c3.Cell(str='BDT/L'),
#           c3.Cell(str='monetary intensity')])),
#  c3.Tuple(
#   cells=c3.Arry<Cell>([c3.Cell(str='BTU per hour'),
#           c3.Cell(str='BTU/hr'),
#           c3.Cell(str='energy rate')])),
#  c3.Tuple(
#   cells=c3.Arry<Cell>([c3.Cell(str='BTU per kilogram'),
#           c3.Cell(str='BTU/kg'),
#           c3.Cell(str='energy/mass')])),
#  c3.Tuple(
#   cells=c3.Arry<Cell>([c3.Cell(str='BTU per kilowatt hour'),
#           c3.Cell(str='BTU/kWh'),
#           c3.Cell(str='energy/energy')])),
#  c3.Tuple(
#   cells=c3.Arry<Cell>([c3.Cell(str='BTU per minute'),
#           c3.Cell(str='BTU/min'),
#           c3.Cell(str='energy rate')])),
#  c3.Tuple(
#   cells=c3.Arry<Cell>([c3.Cell(str='BTU per second'),
#           c3.Cell(str='BTU/s'),
#           c3.Cell(str='energy rate')])),
#  c3.Tuple(
#   cells=c3.Arry<Cell>([c3.Cell(str='BTU per cubic foot'),
#           c3.Cell(str='BTU/SCF'),
#           c3.Cell(str='energy/volume')])),
#  c3.Tuple(
#   cells=c3.Arry<Cell>([c3.Cell(str='CAD'),
#           c3.Cell(str='$'),
#           c3.Cell(str='monetary currency')])),
#  c3.Tuple(
#   cells=c3.Arry<Cell>([c3.Cell(str='United States Dollar'),
#           c3.Cell(str='$'),
#           c3.Cell(str='currency')])),
#  c3.Tuple(
#   cells=c3.Arry<Cell>([c3.Cell(str='gigabyte'),
#           c3.Cell(str='GB'),
#           c3.Cell(str='network traffic')])),
#  c3.Tuple(
#   cells=c3.Arry<Cell>([c3.Cell(str='British Pound Sterling'),
#           c3.Cell(str='£'),
#           c3.Cell(str='currency')])),
#  c3.Tuple(
#   cells=c3.Arry<Cell>([c3.Cell(str='British Pound Sterling per kilowatt hour'),
#           c3.Cell(str='£/kWh'),
#           c3.Cell(str='monetary intensity')])),
#  c3.Tuple(
#   cells=c3.Arry<Cell>([c3.Cell(str='gigajoule per tonne'),
#           c3.Cell(str='GJ/t'),
#           c3.Cell(str='energy/mass')])),
#  c3.Tuple(
#   cells=c3.Arry<Cell>([c3.Cell(str='Hazen'),
#           c3.Cell(str='Hazen'),
#           c3.Cell(str='color')])),
#  c3.Tuple(
#   cells=c3.Arry<Cell>([c3.Cell(str='megabyte'),
#           c3.Cell(str='MB'),
#           c3.Cell(str='network traffic')])),
#  c3.Tuple(
#   cells=c3.Arry<Cell>([c3.Cell(str='megajoule per kilogram'),
#           c3.Cell(str='MJ/kg'),
#           c3.Cell(str='energy/mass')])),
#  c3.Tuple(
#   cells=c3.Arry<Cell>([c3.Cell(str='million BTU per gallon'),
#           c3.Cell(str='MMBTU/gallon'),
#           c3.Cell(str='energy/volume')])),
#  c3.Tuple(
#   cells=c3.Arry<Cell>([c3.Cell(str='million BTU per cubic foot'),
#           c3.Cell(str='MMBTU/SCF'),
#           c3.Cell(str='energy/volume')])),
#  c3.Tuple(
#   cells=c3.Arry<Cell>([c3.Cell(str='million BTU per short ton'),
#           c3.Cell(str='MMBTU/STU'),
#           c3.Cell(str='energy/mass')])),
#  c3.Tuple(
#   cells=c3.Arry<Cell>([c3.Cell(str='millions of cubic feet'),
#           c3.Cell(str='MMCF'),
#           c3.Cell(str='volume')])),
#  c3.Tuple(
#   cells=c3.Arry<Cell>([c3.Cell(str='millions of gallons'),
#           c3.Cell(str='MMgal'),
#           c3.Cell(str='volume')])),
#  c3.Tuple(
#   cells=c3.Arry<Cell>([c3.Cell(str='megagram'),
#           c3.Cell(str='Mg'),
#           c3.Cell(str='mass')])),
#  c3.Tuple(
#   cells=c3.Arry<Cell>([c3.Cell(str='thousands of gallons'),
#           c3.Cell(str='Mgal'),
#           c3.Cell(str='volume')])),
#  c3.Tuple(
#   cells=c3.Arry<Cell>([c3.Cell(str='unknown'),
#           c3.Cell(str='PCU'),
#           c3.Cell(str='unknown')])),
#  c3.Tuple(
#   cells=c3.Arry<Cell>([c3.Cell(str='Rows'),
#           c3.Cell(str='Rows'),
#           c3.Cell(str='count')])),
#  c3.Tuple(
#   cells=c3.Arry<Cell>([c3.Cell(str='Rows per second'),
#           c3.Cell(str='Rows/s'),
#           c3.Cell(str='count')])),
#  c3.Tuple(
#   cells=c3.Arry<Cell>([c3.Cell(str='terabyte'),
#           c3.Cell(str='TB'),
#           c3.Cell(str='network traffic')])),
#  c3.Tuple(
#   cells=c3.Arry<Cell>([c3.Cell(str='terajoule per gigagram'),
#           c3.Cell(str='TJ/Gg'),
#           c3.Cell(str='energy/mass')])),
#  c3.Tuple(
#   cells=c3.Arry<Cell>([c3.Cell(str='USD'),
#           c3.Cell(str='$'),
#           c3.Cell(str='monetary currency')])),
#  c3.Tuple(
#   cells=c3.Arry<Cell>([c3.Cell(str='USD per kilowatt hour'),
#           c3.Cell(str='$/kwh'),
#           c3.Cell(str='monetary intensity')])),
#  c3.Tuple(
#   cells=c3.Arry<Cell>([c3.Cell(str='USD per Litre'),
#           c3.Cell(str='$/L'),
#           c3.Cell(str='monetary intensity')])),
#  c3.Tuple(
#   cells=c3.Arry<Cell>([c3.Cell(str='USD per Tonne'),
#           c3.Cell(str='$/tonne'),
#           c3.Cell(str='monetary intensity')])),
#  c3.Tuple(
#   cells=c3.Arry<Cell>([c3.Cell(str='acre'),
#           c3.Cell(str='acre'),
#           c3.Cell(str='area')])),
#  c3.Tuple(
#   cells=c3.Arry<Cell>([c3.Cell(str='Dirhams per cubic meter'),
#           c3.Cell(str='د.إ/m³'),
#           c3.Cell(str='monetary intensity')])),
#  c3.Tuple(
#   cells=c3.Arry<Cell>([c3.Cell(str='ampere'),
#           c3.Cell(str='A'),
#           c3.Cell(str='current')])),
#  c3.Tuple(
#   cells=c3.Arry<Cell>([c3.Cell(str='acid producing bacteria'),
#           c3.Cell(str='APB'),
#           c3.Cell(str='bacteria')])),
#  c3.Tuple(
#   cells=c3.Arry<Cell>([c3.Cell(str='acid producing bacteria per millilitre'),
#           c3.Cell(str='APB/mL'),
#           c3.Cell(str='bacteria')])),
#  c3.Tuple(
#   cells=c3.Arry<Cell>([c3.Cell(str='are'),
#           c3.Cell(str='are'),
#           c3.Cell(str='area')])),
#  c3.Tuple(
#   cells=c3.Arry<Cell>([c3.Cell(str='atmosphere'),
#           c3.Cell(str='atm'),
#           c3.Cell(str='pressure')])),
#  c3.Tuple(
#   cells=c3.Arry<Cell>([c3.Cell(str='ton'),
#           c3.Cell(str='ton'),
#           c3.Cell(str='mass')])),
#  c3.Tuple(
#   cells=c3.Arry<Cell>([c3.Cell(str='bar'),
#           c3.Cell(str='bar'),
#           c3.Cell(str='pressure')])),
#  c3.Tuple(
#   cells=c3.Arry<Cell>([c3.Cell(str='barrel (liquid)'),
#           c3.Cell(str='bbl-l'),
#           c3.Cell(str='volume')])),
#  c3.Tuple(
#   cells=c3.Arry<Cell>([c3.Cell(str='barrels per day'),
#           c3.Cell(str='barrel/day'),
#           c3.Cell(str='flow rate')])),
#  c3.Tuple(
#   cells=c3.Arry<Cell>([c3.Cell(str='barrel (petroleum)'),
#           c3.Cell(str='bbl-p'),
#           c3.Cell(str='volume')])),
#  c3.Tuple(
#   cells=c3.Arry<Cell>([c3.Cell(str='barrels per day'),
#           c3.Cell(str='barrel/day'),
#           c3.Cell(str='flow rate')])),
#  c3.Tuple(
#   cells=c3.Arry<Cell>([c3.Cell(str='barrel per square foot'),
#           c3.Cell(str='bbl-p/ft²'),
#           c3.Cell(str='volume intensity')])),
#  c3.Tuple(
#   cells=c3.Arry<Cell>([c3.Cell(str='Bed'),
#           c3.Cell(str='Bed'),
#           c3.Cell(str='count')])),
#  c3.Tuple(
#   cells=c3.Arry<Cell>([c3.Cell(str='brake horsepower'),
#           c3.Cell(str='bhp'),
#           c3.Cell(str='power')])),
#  c3.Tuple(
#   cells=c3.Arry<Cell>([c3.Cell(str='boiler horsepower'),
#           c3.Cell(str='hp(S)'),
#           c3.Cell(str='power')])),
#  c3.Tuple(
#   cells=c3.Arry<Cell>([c3.Cell(str='becquerel'),
#           c3.Cell(str='Bq'),
#           c3.Cell(str='radioactivity')])),
#  c3.Tuple(
#   cells=c3.Arry<Cell>([c3.Cell(str='becquerel per litre'),
#           c3.Cell(str='Bq/L'),
#           c3.Cell(str='radioactivity')])),
#  c3.Tuple(
#   cells=c3.Arry<Cell>([c3.Cell(str='bushel'),
#           c3.Cell(str='bsh'),
#           c3.Cell(str='volume')])),
#  c3.Tuple(
#   cells=c3.Arry<Cell>([c3.Cell(str='BTU per MMBTU'),
#           c3.Cell(str='BTU/MMBTU'),
#           c3.Cell(str='energy fraction')])),
#  c3.Tuple(
#   cells=c3.Arry<Cell>([c3.Cell(str='BTU per month'),
#           c3.Cell(str='btu/mo'),
#           c3.Cell(str='energy rate')])),
#  c3.Tuple(
#   cells=c3.Arry<Cell>([c3.Cell(str='BTU per ton-hour'),
#           c3.Cell(str='BTU/t-hr'),
#           c3.Cell(str='refrigeration')])),
#  c3.Tuple(
#   cells=c3.Arry<Cell>([c3.Cell(str='BTU per year'),
#           c3.Cell(str='btu/yr'),
#           c3.Cell(str='energy rate')])),
#  c3.Tuple(
#   cells=c3.Arry<Cell>([c3.Cell(str='BTU per gallon'),
#           c3.Cell(str='BTU/gal'),
#           c3.Cell(str='energy/volume')])),
#  c3.Tuple(
#   cells=c3.Arry<Cell>([c3.Cell(str='BTU per MMBTU'),
#           c3.Cell(str='BTU/MMBTU'),
#           c3.Cell(str='energy/energy')])),
#  c3.Tuple(
#   cells=c3.Arry<Cell>([c3.Cell(str='BTU per pound'),
#           c3.Cell(str='BTU/lb'),
#       ...

# %% [markdown]
# ## Use This Space for "CHALLENGE: Evaluate Method in Jupyter"
#
#     Add additional cells as needed.

# %% [markdown]
# ### E. Other Useful Operations <a class="anchor" id="1.1E">
# use `c3.MyType.listMetrics()` to get a list of metrics for a given srcType.

# %%
metrics = c3.WeatherAware.listMetrics().toJson()
pd.DataFrame(metrics)

# %% [markdown]
# ## Prototype Method Functions in Python <a class="anchor" id="1.1B">

# %% [markdown]
# ### A. Write Code <a class="anchor" id="1.2A">

# %% [markdown]
# Provsion running code in package.
#
# Declare Python methods in types with this syntax:
#
# ``` js
# // Method takes myInput (a string) and returns a double
# @py(env='myActionRuntime')
# myPythonMethod: function(myInput: string): double
# ```

# %% [markdown]
# The .py file needs its own package imports.

# %% [markdown]
# ### Use This Cell for "CHALLENGE: Build Methods"

# %%
import datetime as dt
import pandas as pd

def myPythonMethod(myInput):
    # foo

    return myOutput

# %% [markdown]
# ### Test Code <a class="anchor" id="1.2B">

# %% [markdown]
# After provisioning, test code from the static console or Jypyter
#
# Use `c3.MyType.myPythonMethod(myInput)` to get the output of the function as it's been provisioned onto your tag.

# %% [markdown]
# ### Use This Cell to Test that Your Code Has Provisioned And Is Available on the Platform

# %% [markdown]
# # Make sure to SYNC your notebook to the server, then CLOSE AND HALT this notebook when you leave.
# To sync: go to the File menu, Save and Checkpoint your notebook, and then select "Upload Notebook to C3.ai", or select the notebook in the tree view (check the box) and hit the "Sync" button.

# %% [markdown]
# ## Appendix - Kernel Installation Instructions <a class="anchor" id="apdx">
#
# If the `py-pythonEnv` kernel is not available, perform the following:
# 1. Select the 'Kernel' tab at the top of this notebook, then select 'Manage Kernels';
# 2. Scroll to find `py-pythonEnv`, and click the 'Install' button. This may take a few minutes.
# 3. Once the new kernel is installed, reload your bwoser tab.
# 4. Navigate to the Kernel tab, then select 'Change Kernel' and select the appropriate option.
