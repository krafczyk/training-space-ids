# %%
jobOptions = c3.StressTestJobOptions(
**{
    'numJobs': 16,
    'batchSize': 16,
    'computePi_n': 5000
  }
)

job = c3.StressTestJob(
    **{
        'options': jobOptions
    }

).upsert()

# %%
job.start()
# Out:
# c3.BatchJobStatus(
#  started=datetime.datetime(2021, 9, 20, 20, 24, 53, tzinfo=datetime.timezone.utc),
#  startedby='dadams@illinois.edu',
#  status='running')

# %%
job.status()
# Out:
# c3.BatchJobStatus(
#  started=datetime.datetime(2021, 9, 20, 20, 24, 53, tzinfo=datetime.timezone.utc),
#  startedby='dadams@illinois.edu',
#  completed=datetime.datetime(2021, 9, 21, 1, 55, 9, tzinfo=datetime.timezone.utc),
#  status='completed',
#  newBatchSubmitted=False)
