# %% [markdown]
# # Hycom Download Demo

# %% [markdown]
# ## Download a batch of FMRC Files
# Once a `HycomDataset` entry has been defined from the Hycom catalog, the `updateFMRCData` method takes care of identifying avaiable FMRCs as well as staging and downloading the Data files.
# Below is a demonstration using default options except for `limit` which is set to 12 to avoid creating an uncessasary server load.

# %% [markdown]
# ### Expore Options For Download Jobs
#
# A series of types have been created to specify options:
# `FMRCSubsetOptions` - Hycom related options for the Thredds server
# `FMRCDownloadOptions` - Options realted to how to request files from the server
# `FMRCDownloadJobOptions` - C3 Batch Job Options for managing the downloads
# The next cell displays the default settings for each option type.

# %%
# Default subset options
print(c3.FMRCSubsetOptions())
# Default download options
print(c3.FMRCDownloadOptions())
#print(dlo)
# Use default download options
print(c3.FMRCDownloadJobOptions())
# Out:
# c3.FMRCSubsetOptions(
#  timeStride=1,
#  vars='surf_el,salinity,water_temp,water_u,water_v',
#  disableLLSubset='on',
#  disableProjSubset='on',
#  horizStride=1,
#  vertStride=1,
#  addLatLon='false',
#  accept='netcdf4')
# c3.FMRCDownloadOptions(
#  externalDir='hycom-data',
#  maxTimesPerFile=1,
#  maxForecastDepth=-1,
#  defaultHycomDatasetId='GOMu0.04_901m000_FMRC_1.0.1')
# c3.FMRCDownloadJobOptions(batchSize=4, limit=-1)

# %% [markdown]
# ### Update FMRC's and submit the Download Job

# %%
# Ensure we have a Dataset entry for the desired catalog
cat_url = "https://tds.hycom.org/thredds/catalog/GOMu0.04/expt_90.1m000/FMRC/runs/catalog.xml"
gom_dataset = c3.HycomDataset.upsertHycomDatasetFromCatalog(url = cat_url)

# Create an updateFMRCData job.
# Use defaults for Subset ond download options
# Limit # of files downloaded for demo

data_dir = 'hycom-test'

job = c3.HycomFMRC.updateFMRCData(
    fmrcSubsetOptions = c3.FMRCSubsetOptions(),
    fmrcDownloadOptions = c3.FMRCDownloadOptions(
        **{
            'externalDir': data_dir
        }
    ),
    fmrcDownloadJobOptions = c3.FMRCDownloadJobOptions(
        **{
            'batchSize': 4,
            'limit': 20
        }
    )
)
job.status()
# Out:
# c3.BatchJobStatus(
#  started=datetime.datetime(2021, 9, 29, 21, 32, 11, tzinfo=datetime.timezone.utc),
#  startedby='podolsky@berkeley.edu',
#  status='running',
#  newBatchSubmitted=True)

# %%
# Monitor the job status until completed and display total # of files downloaded
import time
from IPython.display import clear_output
status = job.status()
while status.status == 'running':
    time.sleep(2)
    clear_output()
    status = job.status()
    gom_dataset = c3.HycomDataset.fetch().objs[0]
    filecount = c3.FMRCFile.fetchCount(spec={'filter':"status=='downloaded'"})
    print(f"FMRC Archive Size: {round(gom_dataset.fmrcArchiveSize/(1024**3),2)} GiB")
    print(f"Download count: {filecount}")
    print (status)
# Out:
# FMRC Archive Size: 3.5 GiB
# Download count: 99
# c3.BatchJobStatus(
#  started=datetime.datetime(2021, 9, 29, 21, 32, 11, tzinfo=datetime.timezone.utc),
#  startedby='podolsky@berkeley.edu',
#  completed=datetime.datetime(2021, 9, 30, 20, 53, 55, tzinfo=datetime.timezone.utc),
#  status='failed',
#  errors=c3.Arry<JobRunErrorDetail>([c3.JobRunErrorDetail(
#            failedActionId='1966.1187849',
#            errorMsg='Error executing command: '
#                      '/usr/local/share/c3/condaEnvs/dev/tc01d/py-hycom_1_0_0/bin/python '
#                      '/tmp/pythonActionSourceCache605507753435165592/FMRCDownloadJob_processBatch.py\n'
#                      'p_logger=main url=http://dev-dti-app-w-001:8080 '
#                      'connector=null mode="thick" Action failed!\n'
#                      'Traceback (most recent call last):\n'
#                      '  File '
#                      '"/tmp/pythonActionSourceCache605507753435165592/FMRCDownloadJob_processBatch.py", '
#                      'line 379, in _c3_remote_bootstrap__run_c3_action\n'
#                      '    _c3_result = _action()\n'
#                      '  File '
#                      '"/tmp/pythonActionSourceCache605507753435165592/FMRCDownloadJob_processBatch.py", '
#                      'line 505, in <lambda>\n'
#                      '    action=lambda: processBatch(batch = '
#                      "_c3_inputs.get('batch'),job = "
#                      "_c3_inputs.get('job'),options = "
#                      "_c3_inputs.get('options')),\n"
#                      '  File '
#                      '"/tmp/pythonActionSourceCache605507753435165592/FMRCDownloadJob_processBatch.py", '
#                      'line 500, in processBatch\n'
#                      '    '
#                      'file.download(file.dataArchive.downloadOptions.externalDir)\n'
#                      '  File '
#                      '"Z66e905400b22b25861b4c6184de6e7d5M_.TypeSystemBase", '
#                      'line 956, in download\n'
#                      '  File '
#                      '"Z66e905400b22b25861b4c6184de6e7d5M_.TypeSystemBase", '
#                      'line 930, in _c3_member_impl\n'
#                      '  File '
#                      '"Z66e905400b22b25861b4c6184de6e7d5M_.TypeSystemBase", '
#                      'line 2845, in _box_and_request_json\n'
#                      '  File '
#                      '"Z66e905400b22b25861b4c6184de6e7d5M_.TypeSystemBase", '
#                      'line 2860, in _request_json\n'
#                      '  File '
#                      '"Z66e905400b22b25861b4c6184de6e7d5M_.ServerConnection", '
#                      'line 358, in _request_json\n'
#                      'Z66e905400b22b25861b4c6184de6e7d5M_.ServerConnection.C3RuntimeException: '
#                      '500 - NotClassified - c3.love.util.OsUtil_err2 '
#                      '[3431.103]\n'
#                      'message: "Error executing command: '
#                      '/usr/local/share/c3/condaEnvs/dev/tc01d/py-hycom_1_0_0/bin/python '
#                      '/tmp/pythonActionSourceCache3421857284996091928/FMRCFile_download.py\n'
#                      'p_logger=main url=http://dev-dti-app-w-001:8080 '
#                      'connector=null mode="thick" Action failed!\n'
#                      'requests.exceptions.HTTPError: 404 Client Error: 404 for '
#                      'url: '
#                      'https://ncss.hycom.org/thredds/ncss/GOMu0.04/expt_90.1m000/FMRC/runs/GOMu0.04_901m000_FMRC_RUN_2021-09-22T12:00:00Z?var=surf_el&var=salinity&var=water_temp&var=water_u&var=water_v&disableLLSubset=on&disableProjSubset=on&horizStride=1&timeStride=1&vertStride=1&addLatLon=false&accept=netcdf4&time=2021-09-24T04%3A00%3A00Z\n'
#                      '\n'
#                      'The above exception was the direct cause of the '
#                      'following exception:\n'
#                      '\n'
#                      'Traceback (most recent call last):\n'
#                      '  File '
#                      '"/tmp/pythonActionSourceCache3421857284996091928/FMRCFile_download.py", '
#                      'line 379, in _c3_remote_bootstrap__run_c3_action\n'
#                      '    _c3_result = _action()\n'
#                      '  File '
#                      '"/tmp/pythonActionSourceCache3421857284996091928/FMRCFile_download.py", '
#                      'line 575, in <lambda>\n'
#                      '    action=lambda: download(this = '
#                      "_c3_inputs.get('this'),extDir = "
#                      "_c3_inputs.get('extDir')),\n"
#                      '  File '
#                      '"/tmp/pythonActionSourceCache3421857284996091928/FMRCFile_download.py", '
#                      'line 568, in download\n'
#                      '    raise e\n'
#                      '  File '
#                      '"/tmp/pythonActionSourceCache3421857284996091928/FMRCFile_download.py", '
#                      'line 550, in download\n'
#                      '    extPath = c3.HycomUtil.downloadToExternal(url, '
#                      'this.id, extDir)\n'
#                      '  File '
#                      '"Z66e905400b22b25861b4c6184de6e7d5M_.TypeSystemBase", '
#                      'line 1128, in downloadToExternal\n'
#                      '  File '
#                      '"Z66e905400b22b25861b4c6184de6e7d5M_.TypeSystemBase", '
#                      'line 1113, in _c3_static_inline_impl\n'
#                      '  File '
#                      '"Z66e905400b22b25861b4c6184de6e7d5M_.TypeSystemBase", '
#                      'line 1101, in inline_traceback_impl\n'
#                      'requests.exceptions.HTTPError: 404 Client Error: 404 for '
#                      'url: '
#                      'https://ncss.hycom.org/thredds/ncss/GOMu0.04/expt_90.1m000/FMRC/runs/GOMu0.04_901m000_FMRC_RUN_2021-09-22T12:00:00Z?var=surf_el&var=salinity&var=water_temp&var=water_u&var=water_v&disableLLSubset=on&disableProjSubset=on&horizStride=1&timeStride=1&vertStride=1&addLatLon=false&accept=netcdf4&time=2021-09-24T04%3A00%3A00Z\n'
#                      '\n'
#                      'The traceback for the inline method is:\n'
#                      '  File '
#                      '"Z66e905400b22b25861b4c6184de6e7d5M_.TypeSystemBase", '
#                      'line 1014, in inline_traceback_impl\n'
#                      '  File "HycomUtil.py", line 8, in downloadToExternal\n'
#                      '    r.raise_for_status()\n'
#                      '  File '
#                      '"/usr/local/share/c3/condaEnvs/dev/tc01d/py-hycom_1_0_0/lib/python3.6/site-packages/requests/models.py", '
#                      'line 943, in raise_for_status\n'
#                      '    raise HTTPError(http_error_msg, response=self)\n'
#                      '"\n'
#                      'JSON: {"extDir": "hycom-test", "this": {"type": '
#                      '"FMRCFile", "id": "GOMu...',
#            errorCodes='NotClassified',
#            errorLog='c3.love.exceptions.C3RuntimeException: Error executing '
#                      'command: '
#                      '/usr/local/share/c3/condaEnvs/dev/tc01d/py-hycom_1_0_0/bin/python '
#                      '/tmp/pythonActionSourceCache605507753435165592/FMRCDownloadJob_processBatch.py\n'
#                      'p_logger=main url=http://dev-dti-app-w-001:8080 '
#                      'connector=null mode="thick" Action failed!\n'
#                      'Traceback (most recent call last):\n'
#                      '  File '
#                      '"/tmp/pythonActionSourceCache605507753435165592/FMRCDownloadJob_processBatch.py", '
#                      'line 379, in _c3_remote_bootstrap__run_c3_action\n'
#                      '    _c3_result = _action()\n'
#                      '  File '
#                      '"/tmp/pythonActionSourceCache605507753435165592/FMRCDownloadJob_processBatch.py", '
#                      'line 505, in <lambda>\n'
#                      '    action=lambda: processBatch(batch = '
#                      "_c3_inputs.get('batch'),job = "
#                      "_c3_inputs.get('job'),options = "
#                      "_c3_inputs.get('options')),\n"
#                      '  File '
#                      '"/tmp/pythonActionSourceCache605507753435165592/FMRCDownloadJob_processBatch.py", '
#                      'line 500, in processBatch\n'
#                      '    '
#                      'file.download(file.dataArchive.downloadOptions.externalDir)\n'
#                      '  File '
#                      '"Z66e905400b22b25861b4c6184de6e7d5M_.TypeSystemBase", '
#                      'line 956, in download\n'
#                      '  File '
#                      '"Z66e905400b22b25861b4c6184de6e7d5M_.TypeSystemBase", '
#                      'line 930, in _c3_member_impl\n'
#                      '  File '
#                      '"Z66e905400b22b25861b4c6184de6e7d5M_.TypeSystemBase", '
#                      'line 2845, in _box_and_request_json\n'
#                      '  File '
#                      '"Z66e905400b22b25861b4c6184de6e7d5M_.TypeSystemBase", '
#                      'line 2860, in _request_json\n'
#                      '  File '
#                      '"Z66e905400b22b25861b4c6184de6e7d5M_.ServerConnection", '
#                      'line 358, in _request_json\n'
#                      'Z66e905400b22b25861b4c6184de6e7d5M_.ServerConnection.C3RuntimeException: '
#                      '500 - NotClassified - c3.love.util.OsUtil_err2 '
#                      '[3431.103]\n'
#                      'message: "Error executing command: '
#                      '/usr/local/share/c3/condaEnvs/dev/tc01d/py-hycom_1_0_0/bin/python '
#                      '/tmp/pythonActionSourceCache3421857284996091928/FMRCFile_download.py\n'
#                      'p_logger=main url=http://dev-dti-app-w-001:8080 '
#                      'connector=null mode="thick" Action failed!\n'
#                      'requests.exceptions.HTTPError: 404 Client Error: 404 for '
#                      'url: '
#                      'https://ncss.hycom.org/thredds/ncss/GOMu0.04/expt_90.1m000/FMRC/runs/GOMu0.04_901m000_FMRC_RUN_2021-09-22T12:00:00Z?var=surf_el&var=salinity&var=water_temp&var=water_u&var=water_v&disableLLSubset=on&disableProj...

# %%
#job.status()

# %% [markdown]
# ## Open NetCDF files from Archive

# %%
# Pick the first avalable file, open it and print the NetCDF metadata
file = c3.FMRCFile.fetch().objs[1]
ds = c3.HycomUtil.nc_open(file.file.url,'/tmp')
print(ds)
c3.HycomUtil.nc_close(ds, file.file.url, '/tmp')
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     classification_level: UNCLASSIFIED
#     distribution_statement: Approved for public release. Distribution unlimited.
#     downgrade_date: not applicable
#     classification_authority: not applicable
#     institution: Naval Oceanographic Office
#     source: HYCOM archive file
#     history: archv2ncdf3z ;
# FMRC Run 2021-09-10T12:00:00Z Dataset
#     field_type: instantaneous
#     Conventions: CF-1.4, NAVO_netcdf_v1.1
#     cdm_data_type: GRID
#     featureType: GRID
#     location: Proto fmrc:GOMu0.04_901m000_FMRC
#     History: Translated to CF-1.0 Conventions by Netcdf-Java CDM (CFGridWriter2)
# Original Dataset = fmrc:GOMu0.04_901m000_FMRC; Translation Date = 2021-09-16T18:12:30.911Z
#     geospatial_lat_min: 18.1200008392334
#     geospatial_lat_max: 31.920000076293945
#     geospatial_lon_min: -98.0
#     geospatial_lon_max: -76.4000244140625
#     dimensions(sizes): time(1), lat(346), lon(541), depth(40)
#     variables(dimensions): float32 surf_el(time,lat,lon), float64 time(time), float64 lat(lat), float64 lon(lon), float32 salinity(time,depth,lat,lon), float64 depth(depth), float32 water_temp(time,depth,lat,lon), float32 water_u(time,depth,lat,lon), float32 water_v(time,depth,lat,lon)
#     groups:
# 1

# %% [markdown]
# ## Cleanup Records and Files Created for this Demo

# %%
# Cleanup
#print(f"Removed {c3.HycomFMRCFile.removeAll()} HycomFMRCFile records.")
print(f"Removed {c3.FMRCFile.removeAll()} FMRCFile records.")
print(f"Removed {c3.FMRCDataArchive.removeAll()} FMRCDataArchive records.")
print(f"Removed {c3.HycomFMRC.removeAll()} HycomFMRC records.")
print(f"Removed {c3.HycomDataset.removeAll()} HycomDataset records")
files = c3.FileSystem.inst().listFiles(data_dir)
if files.files:
    print(f"Deleting {len(files.files)} files")
    c3.FileSystem.inst().deleteFilesBatch(files.files)
print("Done.")
# Out:
# Removed 0 FMRCFile records.
# Removed 0 FMRCDataArchive records.
# Removed 0 HycomFMRC records.
# Removed 0 HycomDataset records
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-a740b0fd9422> in <module>
#       5 print(f"Removed {c3.HycomFMRC.removeAll()} HycomFMRC records.")
#       6 print(f"Removed {c3.HycomDataset.removeAll()} HycomDataset records")
# ----> 7 files = c3.FileSystem.inst().listFiles(data_dir)
#       8 if files.files:
#       9     print(f"Deleting {len(files.files)} files")
#
# NameError: name 'data_dir' is not defined

# %% [markdown]
# ## Testing

# %%
# Check for errors
errors = c3.FMRCFile.fetchCount(spec={'filter':"status=='error'"})
print(errors)

# %%
# Grab a dataArchive record
da = c3.FMRCDataArchive.fetch(spec = {'include': 'this,dataFiles'}).objs[0]
da

# %%
# Check the total size of the files in this archive
print(f"Archive Size: {round(da.archiveSize/(1024**3),2)} GiB")

# %%
# Check the total Size of All FMRC Data
gom_dataset = c3.HycomDataset.fetch().objs[0] # The HycomFMRC is the first on only record here, now.
print(f"FMRC Archive Size: {round(gom_dataset.fmrcArchiveSize/(1024**3),2)} GiB")

# %%
from some_package.some_module import hey
hey()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-3a8bbd29aae3> in <module>
# ----> 1 from some_package.some_module import hey
#       2 hey()
#
# ModuleNotFoundError: No module named 'some_package'

# %%
c3.FileSystem.inst().listFiles("hycom-data")
# Out:
# c3.ListFilesResult(
#  files=c3.Arry<File>([c3.AzureFile(
#           contentLength=39715517,
#           contentLocation='fs/dti/mpodolsky/hycom-data/GOMu0.04_901m000_FMRC_RUN_2021-09-10T12:00:00Z-2021-09-10T12:00:00Z.nc',
#           eTag='"0x8D9793D8BE260F2"',
#           lastModified=datetime.datetime(2021, 9, 16, 18, 12, 29, tzinfo=datetime.timezone.utc),
#           contentMD5='Ty6OY12e3zZ3I/M9350wXw==',
#           hasMetadata=False,
#           url='azure://dev-dti/fs/dti/mpodolsky/hycom-data/GOMu0.04_901m000_FMRC_RUN_2021-09-10T12:00:00Z-2021-09-10T12:00:00Z.nc',
#           blobType='BLOCK_BLOB'),
#          c3.AzureFile(
#           contentLength=39704070,
#           contentLocation='fs/dti/mpodolsky/hycom-data/GOMu0.04_901m000_FMRC_RUN_2021-09-10T12:00:00Z-2021-09-10T13:00:00Z.nc',
#           eTag='"0x8D9793D94E13207"',
#           lastModified=datetime.datetime(2021, 9, 16, 18, 12, 44, tzinfo=datetime.timezone.utc),
#           contentMD5='wouV/KyZIdN/gFFTPR1ZHA==',
#           hasMetadata=False,
#           url='azure://dev-dti/fs/dti/mpodolsky/hycom-data/GOMu0.04_901m000_FMRC_RUN_2021-09-10T12:00:00Z-2021-09-10T13:00:00Z.nc',
#           blobType='BLOCK_BLOB'),
#          c3.AzureFile(
#           contentLength=39694762,
#           contentLocation='fs/dti/mpodolsky/hycom-data/GOMu0.04_901m000_FMRC_RUN_2021-09-10T12:00:00Z-2021-09-10T14:00:00Z.nc',
#           eTag='"0x8D9793D9D01FDDB"',
#           lastModified=datetime.datetime(2021, 9, 16, 18, 12, 58, tzinfo=datetime.timezone.utc),
#           contentMD5='m4bXfSQQDx2xSle6+BRNpA==',
#           hasMetadata=False,
#           url='azure://dev-dti/fs/dti/mpodolsky/hycom-data/GOMu0.04_901m000_FMRC_RUN_2021-09-10T12:00:00Z-2021-09-10T14:00:00Z.nc',
#           blobType='BLOCK_BLOB'),
#          c3.AzureFile(
#           contentLength=39697431,
#           contentLocation='fs/dti/mpodolsky/hycom-data/GOMu0.04_901m000_FMRC_RUN_2021-09-10T12:00:00Z-2021-09-10T15:00:00Z.nc',
#           eTag='"0x8D9793DA24AE21E"',
#           lastModified=datetime.datetime(2021, 9, 16, 18, 13, 7, tzinfo=datetime.timezone.utc),
#           contentMD5='ZyQCNUSoIGZFtESMKmRNCw==',
#           hasMetadata=False,
#           url='azure://dev-dti/fs/dti/mpodolsky/hycom-data/GOMu0.04_901m000_FMRC_RUN_2021-09-10T12:00:00Z-2021-09-10T15:00:00Z.nc',
#           blobType='BLOCK_BLOB'),
#          c3.AzureFile(
#           contentLength=39707687,
#           contentLocation='fs/dti/mpodolsky/hycom-data/GOMu0.04_901m000_FMRC_RUN_2021-09-10T12:00:00Z-2021-09-10T16:00:00Z.nc',
#           eTag='"0x8D9793E5C6D321E"',
#           lastModified=datetime.datetime(2021, 9, 16, 18, 18, 19, tzinfo=datetime.timezone.utc),
#           contentMD5='7t7dokCDXNvuu4Z9EeiQ5w==',
#           hasMetadata=False,
#           url='azure://dev-dti/fs/dti/mpodolsky/hycom-data/GOMu0.04_901m000_FMRC_RUN_2021-09-10T12:00:00Z-2021-09-10T16:00:00Z.nc',
#           blobType='BLOCK_BLOB'),
#          c3.AzureFile(
#           contentLength=39719625,
#           contentLocation='fs/dti/mpodolsky/hycom-data/GOMu0.04_901m000_FMRC_RUN_2021-09-10T12:00:00Z-2021-09-10T17:00:00Z.nc',
#           eTag='"0x8D9793E655DAC5F"',
#           lastModified=datetime.datetime(2021, 9, 16, 18, 18, 34, tzinfo=datetime.timezone.utc),
#           contentMD5='1n+r4O2897YkIB1IC9xWEQ==',
#           hasMetadata=False,
#           url='azure://dev-dti/fs/dti/mpodolsky/hycom-data/GOMu0.04_901m000_FMRC_RUN_2021-09-10T12:00:00Z-2021-09-10T17:00:00Z.nc',
#           blobType='BLOCK_BLOB'),
#          c3.AzureFile(
#           contentLength=39729720,
#           contentLocation='fs/dti/mpodolsky/hycom-data/GOMu0.04_901m000_FMRC_RUN_2021-09-10T12:00:00Z-2021-09-10T18:00:00Z.nc',
#           eTag='"0x8D9793E6D2352AE"',
#           lastModified=datetime.datetime(2021, 9, 16, 18, 18, 47, tzinfo=datetime.timezone.utc),
#           contentMD5='T7NWbZvtCbPtC5qJQjqjsA==',
#           hasMetadata=False,
#           url='azure://dev-dti/fs/dti/mpodolsky/hycom-data/GOMu0.04_901m000_FMRC_RUN_2021-09-10T12:00:00Z-2021-09-10T18:00:00Z.nc',
#           blobType='BLOCK_BLOB'),
#          c3.AzureFile(
#           contentLength=39731776,
#           contentLocation='fs/dti/mpodolsky/hycom-data/GOMu0.04_901m000_FMRC_RUN_2021-09-10T12:00:00Z-2021-09-10T19:00:00Z.nc',
#           eTag='"0x8D9793E74CE3FD9"',
#           lastModified=datetime.datetime(2021, 9, 16, 18, 19, tzinfo=datetime.timezone.utc),
#           contentMD5='Mfnznw9OeTGmCzb7cCKXwg==',
#           hasMetadata=False,
#           url='azure://dev-dti/fs/dti/mpodolsky/hycom-data/GOMu0.04_901m000_FMRC_RUN_2021-09-10T12:00:00Z-2021-09-10T19:00:00Z.nc',
#           blobType='BLOCK_BLOB'),
#          c3.AzureFile(
#           contentLength=39733416,
#           contentLocation='fs/dti/mpodolsky/hycom-data/GOMu0.04_901m000_FMRC_RUN_2021-09-10T12:00:00Z-2021-09-10T20:00:00Z.nc',
#           eTag='"0x8D9793E7C40AD89"',
#           lastModified=datetime.datetime(2021, 9, 16, 18, 19, 12, tzinfo=datetime.timezone.utc),
#           contentMD5='kDW+7o+rUHjx3qKUzKf4pw==',
#           hasMetadata=False,
#           url='azure://dev-dti/fs/dti/mpodolsky/hycom-data/GOMu0.04_901m000_FMRC_RUN_2021-09-10T12:00:00Z-2021-09-10T20:00:00Z.nc',
#           blobType='BLOCK_BLOB'),
#          c3.AzureFile(
#           contentLength=39723835,
#           contentLocation='fs/dti/mpodolsky/hycom-data/GOMu0.04_901m000_FMRC_RUN_2021-09-10T12:00:00Z-2021-09-10T21:00:00Z.nc',
#           eTag='"0x8D9793E843449DA"',
#           lastModified=datetime.datetime(2021, 9, 16, 18, 19, 26, tzinfo=datetime.timezone.utc),
#           contentMD5='+vrIUynNVmJMQi17X2fq0g==',
#           hasMetadata=False,
#           url='azure://dev-dti/fs/dti/mpodolsky/hycom-data/GOMu0.04_901m000_FMRC_RUN_2021-09-10T12:00:00Z-2021-09-10T21:00:00Z.nc',
#           blobType='BLOCK_BLOB'),
#          c3.AzureFile(
#           contentLength=39720895,
#           contentLocation='fs/dti/mpodolsky/hycom-data/GOMu0.04_901m000_FMRC_RUN_2021-09-10T12:00:00Z-2021-09-10T22:00:00Z.nc',
#           eTag='"0x8D9793E8CC9C228"',
#           lastModified=datetime.datetime(2021, 9, 16, 18, 19, 40, tzinfo=datetime.timezone.utc),
#           contentMD5='8MwxC+3Ta5cYHqh6dsjsmQ==',
#           hasMetadata=False,
#           url='azure://dev-dti/fs/dti/mpodolsky/hycom-data/GOMu0.04_901m000_FMRC_RUN_2021-09-10T12:00:00Z-2021-09-10T22:00:00Z.nc',
#           blobType='BLOCK_BLOB'),
#          c3.AzureFile(
#           contentLength=39706494,
#           contentLocation='fs/dti/mpodolsky/hycom-data/GOMu0.04_901m000_FMRC_RUN_2021-09-10T12:00:00Z-2021-09-10T23:00:00Z.nc',
#           eTag='"0x8D9793E96044B5A"',
#           lastModified=datetime.datetime(2021, 9, 16, 18, 19, 56, tzinfo=datetime.timezone.utc),
#           contentMD5='nPcYdMuQkSTJN62y/9We2g==',
#           hasMetadata=False,
#           url='azure://dev-dti/fs/dti/mpodolsky/hycom-data/GOMu0.04_901m000_FMRC_RUN_2021-09-10T12:00:00Z-2021-09-10T23:00:00Z.nc',
#           blobType='BLOCK_BLOB'),
#          c3.AzureFile(
#           contentLength=39703466,
#           contentLocation='fs/dti/mpodolsky/hycom-data/GOMu0.04_901m000_FMRC_RUN_2021-09-10T12:00:00Z-2021-09-11T00:00:00Z.nc',
#           eTag='"0x8D9793E9E4EA316"',
#           lastModified=datetime.datetime(2021, 9, 16, 18, 20, 10, tzinfo=datetime.timezone.utc),
#           contentMD5='wRexzl2qMnTDoo6LPLYWbg==',
#           hasMetadata=False,
#           url='azure://dev-dti/fs/dti/mpodolsky/hycom-data/GOMu0.04_901m000_FMRC_RUN_2021-09-10T12:00:00Z-2021-09-11T00:00:00Z.nc',
#           blobType='BLOCK_BLOB'),
#          c3.AzureFile(
#           contentLength=39692591,
#           contentLocation='fs/dti/mpodolsky/hycom-data/GOMu0.04_901m000_FMRC_RUN_2021-09-10T12:00:00Z-2021-09-11T01:00:00Z.nc',
#           eTag='"0x8D9793EA5E9AED9"',
#           lastModified=datetime.datetime(2021, 9, 16, 18, 20, 22, tzinfo=datetime.timezone.utc),
#           contentMD5='D1keVlpP4au1pL8OBWVsiw==',
#           hasMetadata=False,
#           url='azure://dev-dti/fs/dti/mpodolsky/hycom-data/GOMu0.04_901m000_FMRC_RUN_2021-09-10T12:00:00Z-2021-09-11T01:00:00Z.nc',
#           blobType='BLOCK_BLOB'),
#          c3.AzureFile(
#           contentLength=39682729,
#           contentLocation='fs/dti/mpodolsky/hycom-data/GOMu0.04_901m000_FMRC_RUN_2021-09-10T12:00:00Z-2021-09-11T02:00:00Z.nc',
#           eTag='"0x8D9793EADA1BDCF"',
#           lastModified=datetime.datetime(2021, 9, 16, 18, 20, 35, tzinfo=datetime.timezone.utc),
#           contentMD5='nfG0LjE1o30rLxuXVtQEow==',
#           hasMetadata=False,
#           url='azure://dev-dti/fs/dti/mpodolsky/hycom-data/GOMu0.04_901m000_FMRC_RUN_2021-09-10T12:00:00Z-2021-09-11T02:00:00Z.nc',
#           blobType='BLOCK_BLOB'),
#          c3.AzureFile(
#           contentLength=39673825,
#           contentLocation='fs/dti/mpodolsky/hycom-data/GOMu0.04_901m000_FMRC_RUN_2021-09-10T12:00:00Z-2021-09-11T03:00:00Z.nc',
#           eTag='"0x8D9793EB525BAE7"',
#           lastModified=datetime.datetime(2021, 9, 16, 18, 20, 48, tzinfo=datetime.timezone.utc),
#           contentMD5='d3CzdDga5hk6uuqC1E03iQ==',
#           hasMetadata=False,
#           url='azure://dev-dti/fs/dti/mpodolsky/hycom-data/GOMu0.04_901m000_FMRC_RUN_2021-09-10T12:00:00Z-2021-09-11T03:00:00Z.nc',
#           blobType='BLOCK_BLOB'),
#          c3.AzureFile(
#           contentLength=39673714,
#           contentLocation='fs/dti/mpodolsky/hycom-data/GOMu0.04_901m000_FMRC_RUN_2021-09-10T12:00:00Z-2021-09-11T04:00:00Z.nc',
#           eTag='"0x8D9793EBD7B115A"',
#           lastModified=datetime.datetime(2021, 9, 16, 18, 21, 2, tzinfo=datetime.timezone.utc),
#           contentMD5='rjMcbpaunlOS2UAr+b4s+g==',
#           hasMetadata=False,
#           url='azure://dev-dti/fs/dti/mpodolsky/hycom-data/GOMu0.04_901m000_FMRC_RUN_2021-09-10T12:00:00Z-2021-09-11T04:00:00Z.nc',
#           blobType='BLOCK_BLOB'),
#          c3.AzureFile(
#           contentLength=39678152,
#           contentLocation='fs/dti/mpodolsky/hycom-data/GOMu0.04_901m000_FMRC_RUN_2021-09-10T12:00:00Z-2021-09-11T05:00:00Z.nc',
#           eTag='"0x8D9793EC8A4CD24"',
#           lastModified=datetime.datetime(2021, 9, 16, 18, 21, 21, tzinfo=datetime.timezone.utc),
#           contentMD5='JF5WsiSA/O+8vx7Tj70fSA==',
#           has...
