# %% [markdown]
# # Hycom Download Demo
#
# ## Requirements
# * For all cells to properly execute install and run the `py-hycom_1_0_0` kernel.

# %% [markdown]
# ## Download Hindcast Data

# %% [markdown]
# ### 0. Populate Hindcast Entries
# - To ne an `afterCreate` method for HycomDataset

# %%
import requests
import xmltodict
import os
import datetime
gom_dataset = c3.HycomDataset.get("GOMu0.04/expt_90.1m000")
def upsertHindcasts(this):
        
    with requests.get(this.catalogUrl) as r:
            doc = xmltodict.parse(r.text)

    hindcasts = []
    # Traverse the set of hincast collections in the catalog
    # Skip the FMRC and all collections
    for ds in doc['catalog']['dataset']['dataset']['dataset']:
        if 'ALL' in ds['@name'] or 'FMRC' in ds['@name']: # restrict to Hindcast
            continue
        # Parse the year off the end of the path and convert to integer 
        year = int(os.path.basename(ds["@urlPath"]))
        
        hc = c3.HycomHindcast(
            **{
                "id": ds['@ID'],
                "dataset": {"id": "GOMu0.04_901m000_FMRC_1.0.1"},
                "name":ds['@ID'],
                "description": ds['@name'],
                "urlPath": ds['@urlPath'],
                "timeCoverage": c3.TimeRange(
                    **{
                        "start": datetime.datetime(year,1,1,12),
                        "end": datetime.datetime(year+1,1,1,11)
                    }
                ).toJson()

              }
        )
        hindcasts.append(hc)
        c3.HycomHindcast.upsertBatch(hindcasts)
    return hindcasts
hindcasts = upsertHindcasts(gom_dataset)
hindcasts
# Out:
# [c3.HycomHindcast(
#  id='GOMu0.04-expt_90.1m000-2021',
#  name='GOMu0.04-expt_90.1m000-2021',
#  dataset=c3.HycomDataset(id='GOMu0.04_901m000_FMRC_1.0.1'),
#  description='(2021) Hindcast Data (1-hrly)',
#  urlPath='GOMu0.04/expt_90.1m000/data/hindcasts/2021',
#  timeCoverage=c3.TimeRange(
#                 start=datetime.datetime(2021, 1, 1, 12, 0),
#                 end=datetime.datetime(2022, 1, 1, 11, 0))),
#  c3.HycomHindcast(
#  id='GOMu0.04-expt_90.1m000-2020',
#  name='GOMu0.04-expt_90.1m000-2020',
#  dataset=c3.HycomDataset(id='GOMu0.04_901m000_FMRC_1.0.1'),
#  description='(2020) Hindcast Data (1-hrly)',
#  urlPath='GOMu0.04/expt_90.1m000/data/hindcasts/2020',
#  timeCoverage=c3.TimeRange(
#                 start=datetime.datetime(2020, 1, 1, 12, 0),
#                 end=datetime.datetime(2021, 1, 1, 11, 0))),
#  c3.HycomHindcast(
#  id='GOMu0.04-expt_90.1m000-2019',
#  name='GOMu0.04-expt_90.1m000-2019',
#  dataset=c3.HycomDataset(id='GOMu0.04_901m000_FMRC_1.0.1'),
#  description='(2019) Hindcast Data (1-hrly)',
#  urlPath='GOMu0.04/expt_90.1m000/data/hindcasts/2019',
#  timeCoverage=c3.TimeRange(
#                 start=datetime.datetime(2019, 1, 1, 12, 0),
#                 end=datetime.datetime(2020, 1, 1, 11, 0)))]

# %% [markdown]
# ### 1. Create Archive Entry
# - A `HindcastArchive` describes a set of Hindcast files to be retrived using a particular set of `HycomSubsetOption`s and `HycomDownloadOption`s.

# %%
import datetime
# Example: Define archive for surface `water_u` and `water_v` on a lat-long subset for the month of September 2021
hcast = c3.HycomHindcast.get("GOMu0.04-expt_90.1m000-2021")
archv = c3.HindcastArchive(
    **{
        "hindcast": hcast,
        "description": "Test subset from 9/2021",
        "subsetOptions": c3.HycomSubsetOptions(
            **{
                "timeRange": {
                    "start": datetime.datetime(2021,9,1,12),
                    "end": datetime.datetime(2021,10,1,11)
                },
                "vars": "water_u,water_v",
                "disableLLSubset": "off",
                "geospatialCoverage": {
                    "start": {
                        "latitude": 22.3,
                        "longitude": -96.5
                        },
                    "end": {
                        "latitude": 28.6,
                        "longitude": -85.5
                        }
                    }
            }
        ).toJson(),
        "downloadOptions": c3.HycomDownloadOptions(
            **{
                'externalDir': 'hycom-test'
            }
        ).toJson()
        
    }
)
archv.upsert()
archv
# Out:
# c3.HindcastArchive(
#  hindcast=c3.HycomHindcast(
#             id='GOMu0.04-expt_90.1m000-2021',
#             name='GOMu0.04-expt_90.1m000-2021',
#             meta=c3.Meta(
#                    tenantTagId=150,
#                    tenant='dev',
#                    tag='tc01d',
#                    created=datetime.datetime(2021, 10, 13, 23, 56, 36, tzinfo=datetime.timezone.utc),
#                    createdBy='dadams@illinois.edu',
#                    updated=datetime.datetime(2021, 10, 13, 23, 56, 36, tzinfo=datetime.timezone.utc),
#                    updatedBy='dadams@illinois.edu',
#                    timestamp=datetime.datetime(2021, 10, 13, 23, 56, 36, tzinfo=datetime.timezone.utc),
#                    fetchInclude='[]',
#                    fetchType='HycomHindcast'),
#             version=1,
#             dataset=c3.HycomDataset(id='GOMu0.04_901m000_FMRC_1.0.1'),
#             description='(2021) Hindcast Data (1-hrly)',
#             urlPath='GOMu0.04/expt_90.1m000/data/hindcasts/2021',
#             timeCoverage=c3.TimeRange(
#                            start=datetime.datetime(2021, 1, 1, 12, 0),
#                            end=datetime.datetime(2022, 1, 1, 11, 0))),
#  description='Test subset from 9/2021',
#  subsetOptions=c3.HycomSubsetOptions(
#                  timeRange=c3.TimeRange(
#                              start=datetime.datetime(2021, 9, 1, 12, 0),
#                              end=datetime.datetime(2021, 10, 1, 11, 0)),
#                  timeStride=1,
#                  vars='water_u,water_v',
#                  disableLLSubset='off',
#                  geospatialCoverage=c3.GeospatialCoverage(
#                                       start=c3.LatLong(
#                                               latitude=22.3,
#                                               longitude=-96.5),
#                                       end=c3.LatLong(
#                                             latitude=28.6,
#                                             longitude=-85.5)),
#                  disableProjSubset='on',
#                  horizStride=1,
#                  vertStride=1,
#                  addLatLon='false',
#                  accept='netcdf4'),
#  downloadOptions=c3.HycomDownloadOptions(
#                    externalDir='hycom-test',
#                    maxTimesPerFile=1,
#                    maxForecastDepth=-1))

# %% [markdown]
# ### 2. Create `HindcastFile` entries
# - To be automated in `afterCreate` and `afterUpdate`

# %%
archv = c3.HindcastArchive.get("3d4d45b7-e420-40dd-aab2-eb35db744147")
stat = archv.stageFiles()
stat
# Out:
# c3.ObjList<HindcastFile>(
#  stats=c3.Stats(
#          createdObjCount=720,
#          updatedObjCount=0,
#          removedObjCount=0,
#          failedObjCount=0,
#          objCount=720,
#          dbWait=0.0,
#          time=1.764,
#          dbTime=0.146635657,
#          objsPerSecond=408.16326530612247,
#          dbObjsPerSecond=4910.129055445225),
#  objs=c3.Arry<HindcastFile>([c3.HindcastFile(
#          id='c41de1e6-90f4-4d55-b246-5d0f851b524b',
#          name='GOMu0.04-expt_90.1m000-2021-2021-09-01T12:00:00Z.nc',
#          meta=c3.Meta(
#                 created=datetime.datetime(2021, 10, 14, 0, 57, 56, tzinfo=datetime.timezone.utc),
#                 updated=datetime.datetime(2021, 10, 14, 0, 57, 56, tzinfo=datetime.timezone.utc),
#                 timestamp=datetime.datetime(2021, 10, 14, 0, 57, 56, tzinfo=datetime.timezone.utc)),
#          version=1),
#         c3.HindcastFile(
#          id='c8b1d034-4899-4fd8-8ec1-827188381d1e',
#          name='GOMu0.04-expt_90.1m000-2021-2021-09-01T13:00:00Z.nc',
#          meta=c3.Meta(
#                 created=datetime.datetime(2021, 10, 14, 0, 57, 56, tzinfo=datetime.timezone.utc),
#                 updated=datetime.datetime(2021, 10, 14, 0, 57, 56, tzinfo=datetime.timezone.utc),
#                 timestamp=datetime.datetime(2021, 10, 14, 0, 57, 56, tzinfo=datetime.timezone.utc)),
#          version=1),
#         c3.HindcastFile(
#          id='dcad97ad-18cf-4932-be96-ec0a5edc2519',
#          name='GOMu0.04-expt_90.1m000-2021-2021-09-01T14:00:00Z.nc',
#          meta=c3.Meta(
#                 created=datetime.datetime(2021, 10, 14, 0, 57, 56, tzinfo=datetime.timezone.utc),
#                 updated=datetime.datetime(2021, 10, 14, 0, 57, 56, tzinfo=datetime.timezone.utc),
#                 timestamp=datetime.datetime(2021, 10, 14, 0, 57, 56, tzinfo=datetime.timezone.utc)),
#          version=1),
#         c3.HindcastFile(
#          id='4ba46555-1621-45b4-93e2-9c59b4fc896a',
#          name='GOMu0.04-expt_90.1m000-2021-2021-09-01T15:00:00Z.nc',
#          meta=c3.Meta(
#                 created=datetime.datetime(2021, 10, 14, 0, 57, 56, tzinfo=datetime.timezone.utc),
#                 updated=datetime.datetime(2021, 10, 14, 0, 57, 56, tzinfo=datetime.timezone.utc),
#                 timestamp=datetime.datetime(2021, 10, 14, 0, 57, 56, tzinfo=datetime.timezone.utc)),
#          version=1),
#         c3.HindcastFile(
#          id='1244fae4-ca23-4cd7-abb7-f81290541212',
#          name='GOMu0.04-expt_90.1m000-2021-2021-09-01T16:00:00Z.nc',
#          meta=c3.Meta(
#                 created=datetime.datetime(2021, 10, 14, 0, 57, 56, tzinfo=datetime.timezone.utc),
#                 updated=datetime.datetime(2021, 10, 14, 0, 57, 56, tzinfo=datetime.timezone.utc),
#                 timestamp=datetime.datetime(2021, 10, 14, 0, 57, 56, tzinfo=datetime.timezone.utc)),
#          version=1),
#         c3.HindcastFile(
#          id='f4ec2797-ca6d-4363-a83a-67332bf48427',
#          name='GOMu0.04-expt_90.1m000-2021-2021-09-01T17:00:00Z.nc',
#          meta=c3.Meta(
#                 created=datetime.datetime(2021, 10, 14, 0, 57, 56, tzinfo=datetime.timezone.utc),
#                 updated=datetime.datetime(2021, 10, 14, 0, 57, 56, tzinfo=datetime.timezone.utc),
#                 timestamp=datetime.datetime(2021, 10, 14, 0, 57, 56, tzinfo=datetime.timezone.utc)),
#          version=1),
#         c3.HindcastFile(
#          id='2cc1ca2b-65d7-4522-ba7a-d814c0e9c19f',
#          name='GOMu0.04-expt_90.1m000-2021-2021-09-01T18:00:00Z.nc',
#          meta=c3.Meta(
#                 created=datetime.datetime(2021, 10, 14, 0, 57, 56, tzinfo=datetime.timezone.utc),
#                 updated=datetime.datetime(2021, 10, 14, 0, 57, 56, tzinfo=datetime.timezone.utc),
#                 timestamp=datetime.datetime(2021, 10, 14, 0, 57, 56, tzinfo=datetime.timezone.utc)),
#          version=1),
#         c3.HindcastFile(
#          id='b41f6c53-8651-404e-9550-39f5fbd9715f',
#          name='GOMu0.04-expt_90.1m000-2021-2021-09-01T19:00:00Z.nc',
#          meta=c3.Meta(
#                 created=datetime.datetime(2021, 10, 14, 0, 57, 56, tzinfo=datetime.timezone.utc),
#                 updated=datetime.datetime(2021, 10, 14, 0, 57, 56, tzinfo=datetime.timezone.utc),
#                 timestamp=datetime.datetime(2021, 10, 14, 0, 57, 56, tzinfo=datetime.timezone.utc)),
#          version=1),
#         c3.HindcastFile(
#          id='81765d0c-f4b0-4954-a851-ee720300ce27',
#          name='GOMu0.04-expt_90.1m000-2021-2021-09-01T20:00:00Z.nc',
#          meta=c3.Meta(
#                 created=datetime.datetime(2021, 10, 14, 0, 57, 56, tzinfo=datetime.timezone.utc),
#                 updated=datetime.datetime(2021, 10, 14, 0, 57, 56, tzinfo=datetime.timezone.utc),
#                 timestamp=datetime.datetime(2021, 10, 14, 0, 57, 56, tzinfo=datetime.timezone.utc)),
#          version=1),
#         c3.HindcastFile(
#          id='844495b8-9fec-4559-a3de-d732fc1d0f98',
#          name='GOMu0.04-expt_90.1m000-2021-2021-09-01T21:00:00Z.nc',
#          meta=c3.Meta(
#                 created=datetime.datetime(2021, 10, 14, 0, 57, 56, tzinfo=datetime.timezone.utc),
#                 updated=datetime.datetime(2021, 10, 14, 0, 57, 56, tzinfo=datetime.timezone.utc),
#                 timestamp=datetime.datetime(2021, 10, 14, 0, 57, 56, tzinfo=datetime.timezone.utc)),
#          version=1),
#         c3.HindcastFile(
#          id='6d62f1ce-2448-4a58-9f26-b9ef7a7f7276',
#          name='GOMu0.04-expt_90.1m000-2021-2021-09-01T22:00:00Z.nc',
#          meta=c3.Meta(
#                 created=datetime.datetime(2021, 10, 14, 0, 57, 56, tzinfo=datetime.timezone.utc),
#                 updated=datetime.datetime(2021, 10, 14, 0, 57, 56, tzinfo=datetime.timezone.utc),
#                 timestamp=datetime.datetime(2021, 10, 14, 0, 57, 56, tzinfo=datetime.timezone.utc)),
#          version=1),
#         c3.HindcastFile(
#          id='0fdc34a9-0281-4ba1-ab3f-924dfcc5c6e2',
#          name='GOMu0.04-expt_90.1m000-2021-2021-09-01T23:00:00Z.nc',
#          meta=c3.Meta(
#                 created=datetime.datetime(2021, 10, 14, 0, 57, 56, tzinfo=datetime.timezone.utc),
#                 updated=datetime.datetime(2021, 10, 14, 0, 57, 56, tzinfo=datetime.timezone.utc),
#                 timestamp=datetime.datetime(2021, 10, 14, 0, 57, 56, tzinfo=datetime.timezone.utc)),
#          version=1),
#         c3.HindcastFile(
#          id='2e8eb668-474d-40a8-89e7-58cab0e4f2f2',
#          name='GOMu0.04-expt_90.1m000-2021-2021-09-02T00:00:00Z.nc',
#          meta=c3.Meta(
#                 created=datetime.datetime(2021, 10, 14, 0, 57, 56, tzinfo=datetime.timezone.utc),
#                 updated=datetime.datetime(2021, 10, 14, 0, 57, 56, tzinfo=datetime.timezone.utc),
#                 timestamp=datetime.datetime(2021, 10, 14, 0, 57, 56, tzinfo=datetime.timezone.utc)),
#          version=1),
#         c3.HindcastFile(
#          id='2a1a00f6-5602-43af-88ec-60fa663fadfd',
#          name='GOMu0.04-expt_90.1m000-2021-2021-09-02T01:00:00Z.nc',
#          meta=c3.Meta(
#                 created=datetime.datetime(2021, 10, 14, 0, 57, 56, tzinfo=datetime.timezone.utc),
#                 updated=datetime.datetime(2021, 10, 14, 0, 57, 56, tzinfo=datetime.timezone.utc),
#                 timestamp=datetime.datetime(2021, 10, 14, 0, 57, 56, tzinfo=datetime.timezone.utc)),
#          version=1),
#         c3.HindcastFile(
#          id='07fd20f7-e38e-470b-939b-96a345cb922a',
#          name='GOMu0.04-expt_90.1m000-2021-2021-09-02T02:00:00Z.nc',
#          meta=c3.Meta(
#                 created=datetime.datetime(2021, 10, 14, 0, 57, 56, tzinfo=datetime.timezone.utc),
#                 updated=datetime.datetime(2021, 10, 14, 0, 57, 56, tzinfo=datetime.timezone.utc),
#                 timestamp=datetime.datetime(2021, 10, 14, 0, 57, 56, tzinfo=datetime.timezone.utc)),
#          version=1),
#         c3.HindcastFile(
#          id='fffaad96-ec17-4d5c-984d-e0a7f93f475d',
#          name='GOMu0.04-expt_90.1m000-2021-2021-09-02T03:00:00Z.nc',
#          meta=c3.Meta(
#                 created=datetime.datetime(2021, 10, 14, 0, 57, 56, tzinfo=datetime.timezone.utc),
#                 updated=datetime.datetime(2021, 10, 14, 0, 57, 56, tzinfo=datetime.timezone.utc),
#                 timestamp=datetime.datetime(2021, 10, 14, 0, 57, 56, tzinfo=datetime.timezone.utc)),
#          version=1),
#         c3.HindcastFile(
#          id='4edfe143-631e-4b84-942b-9958db3a9580',
#          name='GOMu0.04-expt_90.1m000-2021-2021-09-02T04:00:00Z.nc',
#          meta=c3.Meta(
#                 created=datetime.datetime(2021, 10, 14, 0, 57, 56, tzinfo=datetime.timezone.utc),
#                 updated=datetime.datetime(2021, 10, 14, 0, 57, 56, tzinfo=datetime.timezone.utc),
#                 timestamp=datetime.datetime(2021, 10, 14, 0, 57, 56, tzinfo=datetime.timezone.utc)),
#          version=1),
#         c3.HindcastFile(
#          id='cedb9018-1b83-488f-85c4-e66fe5a549df',
#          name='GOMu0.04-expt_90.1m000-2021-2021-09-02T05:00:00Z.nc',
#          meta=c3.Meta(
#                 created=datetime.datetime(2021, 10, 14, 0, 57, 56, tzinfo=datetime.timezone.utc),
#                 updated=datetime.datetime(2021, 10, 14, 0, 57, 56, tzinfo=datetime.timezone.utc),
#                 timestamp=datetime.datetime(2021, 10, 14, 0, 57, 56, tzinfo=datetime.timezone.utc)),
#          version=1),
#         c3.HindcastFile(
#          id='c222d871-1b24-4470-a498-5fe4c1977367',
#          name='GOMu0.04-expt_90.1m000-2021-2021-09-02T06:00:00Z.nc',
#          meta=c3.Meta(
#                 created=datetime.datetime(2021, 10, 14, 0, 57, 56, tzinfo=datetime.timezone.utc),
#                 updated=datetime.datetime(2021, 10, 14, 0, 57, 56, tzinfo=datetime.timezone.utc),
#                 timestamp=datetime.datetime(2021, 10, 14, 0, 57, 56, tzinfo=datetime.timezone.utc)),
#          version=1),
#         c3.HindcastFile(
#          id='b0abe15e-3748-4c1e-9be9-46268b4c77fc',
#          name='GOMu0.04-expt_90.1m000-2021-2021-09-02T07:00:00Z.nc',
#          meta=c3.Meta(
#                 created=datetime.datetime(2021, 10, 14, 0, 57, 56, tzinfo=datetime.timezone.utc),
#                 updated=datetime.datetime(2021, 10, 14, 0, 57, 56, tzinfo=datetime.timezone.utc),
#                 time...

# %%
file_id = "0033cdfe-6b50-4c9f-a5da-76381220ec38"
fr = c3.HindcastFile.get(file_id)
file = fr.download()
file
# Out:
# c3.File(
#  contentLength=3240897,
#  contentLocation='fs/dti/mpodolsky/hycom-test/hindcast/3d4d45b7-e420-40dd-aab2-eb35db744147/GOMu0.04-expt_90.1m000-2021-2021-09-25T01:00:00Z.nc',
#  contentType='application/json',
#  eTag='"0x8D98F021466F425"',
#  contentMD5='BZsYMlsElLnelKy78vIQuA==',
#  hasMetadata=True,
#  url='hycom-test/hindcast/3d4d45b7-e420-40dd-aab2-eb35db744147/GOMu0.04-expt_90.1m000-2021-2021-09-25T01:00:00Z.nc')

# %%
ds = c3.HycomUtil.nc_open(file.url,'/tmp')
print(ds)
print(ds.variables['time'][:])
c3.HycomUtil.nc_close(ds, file.url, '/tmp')
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     classification_level: UNCLASSIFIED
#     distribution_statement: Approved for public release. Distribution unlimited.
#     downgrade_date: not applicable
#     classification_authority: not applicable
#     institution: Naval Oceanographic Office
#     source: HYCOM archive file
#     history: archv2ncdf3z
#     field_type: instantaneous
#     Conventions: CF-1.6 NAVO_netcdf_v1.1
#     History: Translated to CF-1.0 Conventions by Netcdf-Java CDM (CFGridWriter2)
# Original Dataset = GOMu0.04/expt_90.1m000/data/hindcasts/2021; Translation Date = 2021-10-14T11:02:12.029Z
#     geospatial_lat_min: 22.280000686645508
#     geospatial_lat_max: 28.600000381469727
#     geospatial_lon_min: -96.47998046875
#     geospatial_lon_max: -85.47998046875
#     dimensions(sizes): time(1), depth(40), lat(159), lon(276)
#     variables(dimensions): int16 water_u(time,depth,lat,lon), float64 time(time), float64 depth(depth), float64 lat(lat), float64 lon(lon), int16 water_v(time,depth,lat,lon)
#     groups:
#
# [190513.]
# 1

# %%
file = c3.HindcastFile.get("053a31bf-fea6-4295-9f16-6be21233c78e")
def deleteFile(this):
    updated = c3.HindcastFile(**{'id':this.id})
    updated.status = 'not_downloaded'
    this.file.delete()
    this.file.clearMetadata()
    this.file.clearContentMetadata()
    updated.merge()
deleteFile(file)
file = c3.HindcastFile.get("053a31bf-fea6-4295-9f16-6be21233c78e")
file
# Out:
# c3.HindcastFile(
#  id='053a31bf-fea6-4295-9f16-6be21233c78e',
#  name='GOMu0.04-expt_90.1m000-2021-2021-09-06T09:00:00Z.nc',
#  meta=c3.Meta(
#         tenantTagId=150,
#         tenant='dev',
#         tag='tc01d',
#         created=datetime.datetime(2021, 10, 13, 18, 31, 27, tzinfo=datetime.timezone.utc),
#         createdBy='dadams@illinois.edu',
#         updated=datetime.datetime(2021, 10, 13, 21, 37, 57, tzinfo=datetime.timezone.utc),
#         updatedBy='dadams@illinois.edu',
#         timestamp=datetime.datetime(2021, 10, 13, 21, 37, 57, tzinfo=datetime.timezone.utc),
#         fetchInclude='[]',
#         fetchType='HindcastFile'),
#  version=4,
#  hindcastArchive=c3.HindcastArchive(id='fa69b83f-3584-4899-8118-6420929e0ca4'),
#  subsetOptions=c3.HycomSubsetOptions(
#                  timeRange=c3.TimeRange(
#                              start=datetime.datetime(2021, 9, 6, 9, 0),
#                              end=datetime.datetime(2021, 9, 6, 9, 0)),
#                  timeStride=1,
#                  vars='water_u,water_v',
#                  disableLLSubset='off',
#                  geospatialCoverage=c3.GeospatialCoverage(
#                                       start=c3.LatLong(
#                                               latitude=22.3,
#                                               longitude=-96.5),
#                                       end=c3.LatLong(
#                                             latitude=28.6,
#                                             longitude=-85.5)),
#                  disableProjSubset='on',
#                  horizStride=1,
#                  vertStride=1,
#                  addLatLon='false',
#                  accept='netcdf4'),
#  status='not_downloaded',
#  file=c3.File(
#         contentLength=3250032,
#         contentLocation='fs/dti/mpodolsky/hycom-data/hindcast/fa69b83f-3584-4899-8118-6420929e0ca4/GOMu0.04-expt_90.1m000-2021-2021-09-06T09:00:00Z.nc',
#         contentType='application/json',
#         eTag='"0x8D98E8AA41BEC03"',
#         contentMD5='ppfJVnSE0ejd5wkiBjXohw==',
#         hasMetadata=True,
#         url='hycom-data/hindcast/fa69b83f-3584-4899-8118-6420929e0ca4/GOMu0.04-expt_90.1m000-2021-2021-09-06T09:00:00Z.nc'))

# %%
files = c3.FileSystem.inst().listFiles("hycom-data/hindcast")
files
# Out:
# c3.ListFilesResult()

# %% [markdown]
# ## Download a batch of FMRC Files
# Once a `HycomDataset` entry has been defined from the Hycom catalog, the `updateFMRCData` method takes care of identifying avaiable FMRCs as well as staging and downloading the Data files.
# Below is a demonstration using default options except for `limit` which is set to 12 to avoid creating an uncessasary server load.
# Notes:
# * The `HycomDataset` is the Parent type at the top of the hierarchy.  The original concept is for each record in HycomDataset to define a dataset from anywhere on the hycom server (hindcast, etc.)
#   - However, much initial emphisis was placed on FMRC data, so some retooling may be in order to more generally support Hindcast downloads.
#   - For example the `upsertFMRC` method should really be generic and determine what data is being "upserted basec on the record
# * The data archiving step, illustrated here, is preliminary to processing of the data within the netCDF file into a C3 timeseries datastore.

# %% [markdown]
# ### Explore Options For Download Jobs
#
# A series of types have been created to specify options:
# `HycomSubsetOptions` - Hycom related options for the Thredds server
# `FMRCDownloadOptions` - Options realted to how to request files from the server
# `FMRCDownloadJobOptions` - C3 Batch Job Options for managing the downloads
# The next cell displays the default settings for each option type.

# %%
# Default subset options
print(c3.HycomSubsetOptions())
# Default download options
print(c3.FMRCDownloadOptions())
# Use default download options
print(c3.FMRCDownloadJobOptions())
data_dir = 'hycom-test'
# Out:
# c3.HycomSubsetOptions(
#  timeStride=1,
#  vars='surf_el,salinity,water_temp,water_u,water_v',
#  disableLLSubset='on',
#  geospatialCoverage=c3.GeospatialCoverage(
#                       start=c3.LatLong(
#                               latitude=18.1200008392334,
#                               longitude=-98.0),
#                       end=c3.LatLong(
#                             latitude=31.92000007629394,
#                             longitude=-76.4000244140625)),
#  disableProjSubset='on',
#  horizStride=1,
#  vertStride=1,
#  addLatLon='false',
#  accept='netcdf4')
# c3.FMRCDownloadOptions(
#  externalDir='hycom-data',
#  maxTimesPerFile=1,
#  maxForecastDepth=-1,
#  defaultHycomDatasetId='GOMu0.04_901m000_FMRC_1.0.1')
# c3.FMRCDownloadJobOptions(batchSize=4, limit=-1)

# %% [markdown]
# ### Update FMRC's and submit the Download Job

# %%
# Ensure we have a Dataset entry for the desired catalog
#cat_url = "https://tds.hycom.org/thredds/catalog/GOMu0.04/expt_90.1m000/FMRC/runs/catalog.xml"
#gom_dataset = c3.HycomDataset.upsertHycomDatasetFromCatalog(url = cat_url)

# Create an updateFMRCData job.
# Use test location to store files
# Limit # of files downloaded for demo

gom_dataset = c3.HycomDataset.get("GOMu0.04/expt_90.1m000")
job = gom_dataset.updateFMRCData(
    hycomSubsetOptions = c3.HycomSubsetOptions(),
    fmrcDownloadOptions = c3.FMRCDownloadOptions(
        **{
            'externalDir': data_dir
        }
    ),
    fmrcDownloadJobOptions = c3.FMRCDownloadJobOptions(
        **{
            'batchSize': 4,
            'limit': 4
        }
    )
)
job.status()
# Out:
# c3.BatchJobStatus(
#  started=datetime.datetime(2021, 10, 11, 14, 22, 17, tzinfo=datetime.timezone.utc),
#  startedby='dti-devops@lists.berkeley.edu',
#  status='running')

# %%
# Monitor the job status until completed and display total # of files downloaded
import time
from IPython.display import clear_output
status = job.status()
while status.status == 'running':
    time.sleep(5)
    clear_output()
    status = job.status()
    gom_dataset = c3.HycomDataset.fetch(spec={'include':"this,fmrcArchiveSize"}).objs[0]
    print (gom_dataset)
    filecount = c3.FMRCFile.fetchCount(spec={'filter':"status=='downloaded'"})
    print(f"FMRC Archive Size: {round(gom_dataset.fmrcArchiveSize/(1024**3),2)} GiB")
    print(f"Download count: {filecount}")
    print (status)
# Out:
# c3.HycomDataset(
#  id='GOMu0.04/expt_90.1m000',
#  name='GOMu0.04/expt_90.1m000',
#  meta=c3.Meta(
#         tenantTagId=150,
#         tenant='dev',
#         tag='tc01d',
#         created=datetime.datetime(2021, 10, 7, 23, 10, 40, tzinfo=datetime.timezone.utc),
#         createdBy='provisioner',
#         updated=datetime.datetime(2021, 10, 7, 23, 20, 22, tzinfo=datetime.timezone.utc),
#         updatedBy='provisioner',
#         timestamp=datetime.datetime(2021, 10, 11, 14, 23, 4, tzinfo=datetime.timezone.utc),
#         fetchInclude='[]',
#         fetchType='HycomDataset'),
#  version=1900546,
#  hycomVersion='1.0.1',
#  description='HYCOM + NCODA Gulf of Mexico 1/25° Analysis (NRL)',
#  geospatialCoverage=c3.GeospatialCoverage(
#                       start=c3.LatLong(
#                               latitude=18.1200008392334,
#                               longitude=-98.0),
#                       end=c3.LatLong(
#                             latitude=31.920000076293945,
#                             longitude=-76.4000244140625)),
#  geospatialResolution=c3.GeospatialResolution(
#                         latResolution=0.04,
#                         lonResolution=0.04),
#  catalogUrl='https://tds.hycom.org/thredds/catalogs/GOMu0.04/expt_90.1m000.xml',
#  fmrcCatalogUrl='https://tds.hycom.org/thredds/catalog/GOMu0.04/expt_90.1m000/FMRC/runs/catalog.xml',
#  fmrcArchiveSize=314982826)
# FMRC Archive Size: 0.29 GiB
# Download count: 8
# c3.BatchJobStatus(
#  started=datetime.datetime(2021, 10, 11, 14, 22, 17, tzinfo=datetime.timezone.utc),
#  startedby='dti-devops@lists.berkeley.edu',
#  completed=datetime.datetime(2021, 10, 11, 14, 23, 4, tzinfo=datetime.timezone.utc),
#  status='completed',
#  newBatchSubmitted=False)

# %%
gom_dataset
# Out:
# c3.HycomDataset(
#  id='GOMu0.04/expt_90.1m000',
#  name='GOMu0.04/expt_90.1m000',
#  meta=c3.Meta(
#         tenantTagId=150,
#         tenant='dev',
#         tag='tc01d',
#         created=datetime.datetime(2021, 10, 7, 23, 10, 40, tzinfo=datetime.timezone.utc),
#         createdBy='provisioner',
#         updated=datetime.datetime(2021, 10, 7, 23, 20, 22, tzinfo=datetime.timezone.utc),
#         updatedBy='provisioner',
#         timestamp=datetime.datetime(2021, 10, 9, 16, 29, 52, tzinfo=datetime.timezone.utc),
#         fetchInclude='[]',
#         fetchType='HycomDataset'),
#  version=1376258,
#  hycomVersion='1.0.1',
#  description='HYCOM + NCODA Gulf of Mexico 1/25° Analysis (NRL)',
#  geospatialCoverage=c3.GeospatialCoverage(
#                       start=c3.LatLong(
#                               latitude=18.1200008392334,
#                               longitude=-98.0),
#                       end=c3.LatLong(
#                             latitude=31.920000076293945,
#                             longitude=-76.4000244140625)),
#  geospatialResolution=c3.GeospatialResolution(
#                         latResolution=0.04,
#                         lonResolution=0.04),
#  catalogUrl='https://tds.hycom.org/thredds/catalogs/GOMu0.04/expt_90.1m000.xml',
#  fmrcCatalogUrl='https://tds.hycom.org/thredds/catalog/GOMu0.04/expt_90.1m000/FMRC/runs/catalog.xml')

# %%
job.status()
# Out:
# c3.BatchJobStatus(
#  started=datetime.datetime(2021, 10, 11, 13, 30, 18, tzinfo=datetime.timezone.utc),
#  startedby='dti-devops@lists.berkeley.edu',
#  completed=datetime.datetime(2021, 10, 11, 13, 34, 43, tzinfo=datetime.timezone.utc),
#  status='completed',
#  newBatchSubmitted=False)

# %%
pd.DataFrame(c3.FileSystem.inst().listFiles(data_dir).toJson())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-207c88cd380c> in <module>
# ----> 1 pd.DataFrame(c3.FileSystem.inst().listFiles(data_dir).toJson())
#
# NameError: name 'pd' is not defined

# %% [markdown]
# ## Quick check: Open NetCDF files from Archive

# %%
# Pick the first avalable file, open it and print the NetCDF metadata
file = c3.FMRCFile.fetch().objs[1]
ds = c3.HycomUtil.nc_open(file.file.url,'/tmp')
print(ds)
c3.HycomUtil.nc_close(ds, file.file.url, '/tmp')
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     classification_level: UNCLASSIFIED
#     distribution_statement: Approved for public release. Distribution unlimited.
#     downgrade_date: not applicable
#     classification_authority: not applicable
#     institution: Naval Oceanographic Office
#     source: HYCOM archive file
#     history: archv2ncdf3z ;
# FMRC Run 2021-09-22T12:00:00Z Dataset
#     field_type: instantaneous
#     Conventions: CF-1.4, NAVO_netcdf_v1.1
#     cdm_data_type: GRID
#     featureType: GRID
#     location: Proto fmrc:GOMu0.04_901m000_FMRC
#     History: Translated to CF-1.0 Conventions by Netcdf-Java CDM (CFGridWriter2)
# Original Dataset = fmrc:GOMu0.04_901m000_FMRC; Translation Date = 2021-09-29T20:34:03.021Z
#     geospatial_lat_min: 18.1200008392334
#     geospatial_lat_max: 31.920000076293945
#     geospatial_lon_min: -98.0
#     geospatial_lon_max: -76.4000244140625
#     dimensions(sizes): time(1), lat(346), lon(541), depth(40)
#     variables(dimensions): float32 surf_el(time,lat,lon), float64 time(time), float64 lat(lat), float64 lon(lon), float32 salinity(time,depth,lat,lon), float64 depth(depth), float32 water_temp(time,depth,lat,lon), float32 water_u(time,depth,lat,lon), float32 water_v(time,depth,lat,lon)
#     groups:
# 1

# %% [markdown]
# ## More Detail: Dig into the C3 Types and data Records

# %%
help(c3.HycomFMRC)
# Out:
# <div id="type:HycomFMRC" class="structure type root">
# <h1 class="type root">Type <span class="name">HycomFMRC</span></h1>
# <p class="description">HycomFMRC.c3typ
# A collection of Hycom Forcast Model Runs.  Each record is a single
# FMR from the Hycom website catalog.xml</p>
# <p class="mixes">Mixes Persistable&lt;HycomFMRC&gt;</p>
# <div class="declaration"><p>Declaration</p><pre class="declaration">/**
#  * HycomFMRC.c3typ
#  * A collection of Hycom Forcast Model Runs.  Each record is a single
#  * FMR from the Hycom website catalog.xml
#  */
# entity type HycomFMRC schema name 'HC_FMRC'
# </pre></div><div class="annotationDoc"><div class="annotations"><p>Annotations:</p>
# <ul class="annotations">
# <li class="annotation">@db</li>
# <li class="annotation">@schema</li>
# </ul></div>
# <pre class="annotation annotation-decl code nohighlight"><code>@db(persistable=true)
# @schema(name='HC_FMRC')
# </code></pre>
# </div><h2 class="section data-section">Fields</h2>
# <div id="data-field:HycomFMRC.dataset" class="structure data-field">
# <h3><span class="name">dataset</span>: HycomDataset <span class="attributes"><span class="required">required</span></span></h3>
# <p class="description">The name of the HycomDataset that this FMRC is based on</p>
# <div class="declaration"><p>Declaration</p><pre class="declaration">// The name of the {@link HycomDataset} that this FMRC is based on
# dataset: !HycomDataset
# </pre></div><div class="annotationDoc"><p class="annotation">Annotation @constraint</p>
# <pre class="annotation annotation-decl code nohighlight"><code>@constraint(required=true)
# </code></pre>
# </div></div>
# <div id="data-field:HycomFMRC.run" class="structure data-field">
# <h3><span class="name">run</span>: string <span class="attributes"><span class="required">required</span></span></h3>
# <p class="description">Run Id indicating the date of the forecast run</p>
# <div class="declaration"><p>Declaration</p><pre class="declaration">// Run Id indicating the date of the forecast run
# run: !string
# </pre></div><div class="annotationDoc"><p class="annotation">Annotation @constraint</p>
# <pre class="annotation annotation-decl code nohighlight"><code>@constraint(required=true)
# </code></pre>
# </div></div>
# <div id="data-field:HycomFMRC.urlPath" class="structure data-field">
# <h3><span class="name">urlPath</span>: string <span class="attributes"><span class="required">required</span></span></h3>
# <p class="description">The urlPath for subsequent data download</p>
# <div class="declaration"><p>Declaration</p><pre class="declaration">// The urlPath for subsequent data download
# urlPath: !string
# </pre></div><div class="annotationDoc"><p class="annotation">Annotation @constraint</p>
# <pre class="annotation annotation-decl code nohighlight"><code>@constraint(required=true)
# </code></pre>
# </div></div>
# <div id="data-field:HycomFMRC.timeCoverage" class="structure data-field">
# <h3><span class="name">timeCoverage</span>: TimeRange <span class="attributes"><span class="required">required</span></span></h3>
# <p class="description">The time coverage of this forecast run</p>
# <div class="declaration"><p>Declaration</p><pre class="declaration">// The time coverage of this forecast run
# timeCoverage: !TimeRange
# </pre></div><div class="annotationDoc"><p class="annotation">Annotation @constraint</p>
# <pre class="annotation annotation-decl code nohighlight"><code>@constraint(required=true)
# </code></pre>
# </div></div>
# <div id="data-field:HycomFMRC.geospatialCoverage" class="structure data-field">
# <h3><span class="name">geospatialCoverage</span>: GeospatialCoverage</h3>
# <p class="description">The geospatial extent of the forecast run.  Defaults to the dataset's full extent.</p>
# <div class="declaration"><p>Declaration</p><pre class="declaration">// The geospatial extent of the forecast run.  Defaults to the dataset's full extent.
# geospatialCoverage: GeospatialCoverage post default 'dataset.geospatialCoverage'
# </pre></div><div class="annotationDoc"><p class="annotation">Annotation @db</p>
# <pre class="annotation annotation-decl code nohighlight"><code>@db(postDefault='dataset.geospatialCoverage')
# </code></pre>
# </div></div>
# <div id="data-field:HycomFMRC.fmrcDataArchive" class="structure data-field">
# <h3><span class="name">fmrcDataArchive</span>: FMRCDataArchive</h3>
# <p class="description">The Data archive for this FMRC containing the data files</p>
# <p class="foreignkey">Foreign key: on FMRCDataArchive.fmrc from <a class="data-field documentation" data-to-id="data-field:HycomFMRC.id" title="field id" href="#data-field:HycomFMRC.id">id</a></p><div class="declaration"><p>Declaration</p><pre class="declaration">// The Data archive for this FMRC containing the data files
# fmrcDataArchive: FMRCDataArchive(fmrc, id)
# </pre></div><div class="annotationDoc"><p class="annotation">Annotation @db</p>
# <pre class="annotation annotation-decl code nohighlight"><code>@db(fkey='fmrc', key='id')
# </code></pre>
# </div></div>
# <div id="data-field:HycomFMRC.expired" class="structure data-field">
# <h3><span class="name">expired</span>: boolean <span class="attributes"><span class="required">required</span></span></h3>
# <p class="description">Whether data are still available in hycom catalog</p>
# <div class="declaration"><p>Declaration</p><pre class="declaration">// Whether data are still available in hycom catalog
# expired: !boolean post default 'false'
# </pre></div><div class="annotationDoc"><div class="annotations"><p>Annotations:</p>
# <ul class="annotations">
# <li class="annotation">@constraint</li>
# <li class="annotation">@db</li>
# </ul></div>
# <pre class="annotation annotation-decl code nohighlight"><code>@constraint(required=true)
# @db(postDefault='false')
# </code></pre>
# </div></div>
# <h2 class="section data-section inherited">Fields from Persistable</h2>
# <div id="data-field:HycomFMRC.id" class="structure data-field inherited">
# <h3><span class="name">id</span>: string <span class="attributes"><span class="inherited">inherited</span></span></h3>
# <p class="description">Unique id that can either be manually specified or automatically generated during object creation.  Can't be
# changed once instance is persisted.</p>
# <p class="inherited-from">Inherited from Persistable&lt;HycomFMRC&gt;</p>
# <div class="declaration"><p>Declaration</p><pre class="declaration">id: string
# </pre></div></div>
# <div id="data-field:HycomFMRC.versionEdits" class="structure data-field inherited private">
# <h3><span class="name">versionEdits</span>: [ VersionEdit ] <span class="attributes"><span class="private">private</span><span class="inherited">inherited</span></span></h3>
# <div class="description">
# <p>Version history.  Only populated when version history is enabled.  Used for retrieving earlier versions of an Obj.
# </p>
# <p>Completely and automatically managed by the system.</p>
# </div>
# <p class="private-info">Private</p><p class="inherited-from">Inherited from Persistable&lt;HycomFMRC&gt;</p>
# <div class="declaration"><p>Declaration</p><pre class="declaration">versionEdits: [VersionEdit]
# </pre></div><p class="see">See Ann.Db.versionHistory</p>
# </div>
# <div id="data-field:HycomFMRC.name" class="structure data-field inherited">
# <h3><span class="name">name</span>: string <span class="attributes"><span class="inherited">inherited</span></span></h3>
# <p class="description">Name of the Obj instance</p>
# <p class="inherited-from">Inherited from Persistable&lt;HycomFMRC&gt;</p>
# <div class="declaration"><p>Declaration</p><pre class="declaration">name: string
# </pre></div></div>
# <div id="data-field:HycomFMRC.meta" class="structure data-field inherited">
# <h3><span class="name">meta</span>: Meta <span class="attributes"><span class="inherited">inherited</span></span></h3>
# <p class="description">Various system fields.</p>
# <p class="inherited-from">Inherited from Persistable&lt;HycomFMRC&gt;</p>
# <div class="declaration"><p>Declaration</p><pre class="declaration">meta: Meta
# </pre></div></div>
# <div id="data-field:HycomFMRC.version" class="structure data-field inherited">
# <h3><span class="name">version</span>: int <span class="attributes"><s

# %%
# Look at all of the currently recorded FMRC data entries
# Each record in this table corresponds to a catalog entry from the xml
import pandas as pd
myFetchResult = c3.HycomFMRC.fetch(spec={
#                                   'limit': 15,
                                  #'include': 'this, myField',
                                  #'offset': 5,
                                  #'order': "ascending(myField)",
                                  #'filter': "myField == 'myString' && myOtherField == 'myOtherString'"
                                 })

pd.DataFrame(myFetchResult.objs.toJson())
# Out:
#         type                                                 id  \
# 0  HycomFMRC  GOMu0.04/expt_90.1m000/FMRC/runs/GOMu0.04_901m...
# 1  HycomFMRC  GOMu0.04/expt_90.1m000/FMRC/runs/GOMu0.04_901m...
# 2  HycomFMRC  GOMu0.04/expt_90.1m000/FMRC/runs/GOMu0.04_901m...
# 3  HycomFMRC  GOMu0.04/expt_90.1m000/FMRC/runs/GOMu0.04_901m...
# 4  HycomFMRC  GOMu0.04/expt_90.1m000/FMRC/runs/GOMu0.04_901m...
# 5  HycomFMRC  GOMu0.04/expt_90.1m000/FMRC/runs/GOMu0.04_901m...
# 6  HycomFMRC  GOMu0.04/expt_90.1m000/FMRC/runs/GOMu0.04_901m...
# 7  HycomFMRC  GOMu0.04/expt_90.1m000/FMRC/runs/GOMu0.04_901m...
#
#                                                 meta  version  \
# 0  {'type': 'Meta', 'tenantTagId': 150, 'tenant':...        2
# 1  {'type': 'Meta', 'tenantTagId': 150, 'tenant':...        1
# 2  {'type': 'Meta', 'tenantTagId': 150, 'tenant':...        1
# 3  {'type': 'Meta', 'tenantTagId': 150, 'tenant':...        1
# 4  {'type': 'Meta', 'tenantTagId': 150, 'tenant':...        1
# 5  {'type': 'Meta', 'tenantTagId': 150, 'tenant':...        1
# 6  {'type': 'Meta', 'tenantTagId': 150, 'tenant':...        1
# 7  {'type': 'Meta', 'tenantTagId': 150, 'tenant':...        1
#
#                                              dataset  \
# 0  {'type': 'HycomDataset', 'id': 'GOMu0.04_901m0...
# 1  {'type': 'HycomDataset', 'id': 'GOMu0.04_901m0...
# 2  {'type': 'HycomDataset', 'id': 'GOMu0.04_901m0...
# 3  {'type': 'HycomDataset', 'id': 'GOMu0.04_901m0...
# 4  {'type': 'HycomDataset', 'id': 'GOMu0.04_901m0...
# 5  {'type': 'HycomDataset', 'id': 'GOMu0.04_901m0...
# 6  {'type': 'HycomDataset', 'id': 'GOMu0.04_901m0...
# 7  {'type': 'HycomDataset', 'id': 'GOMu0.04_901m0...
#
#                                               run  \
# 0  GOMu0.04_901m000_FMRC_RUN_2021-09-22T12:00:00Z
# 1  GOMu0.04_901m000_FMRC_RUN_2021-09-23T12:00:00Z
# 2  GOMu0.04_901m000_FMRC_RUN_2021-09-24T12:00:00Z
# 3  GOMu0.04_901m000_FMRC_RUN_2021-09-25T12:00:00Z
# 4  GOMu0.04_901m000_FMRC_RUN_2021-09-26T12:00:00Z
# 5  GOMu0.04_901m000_FMRC_RUN_2021-09-27T12:00:00Z
# 6  GOMu0.04_901m000_FMRC_RUN_2021-09-28T12:00:00Z
# 7  GOMu0.04_901m000_FMRC_RUN_2021-09-29T12:00:00Z
#
#                                              urlPath  \
# 0  GOMu0.04/expt_90.1m000/FMRC/runs/GOMu0.04_901m...
# 1  GOMu0.04/expt_90.1m000/FMRC/runs/GOMu0.04_901m...
# 2  GOMu0.04/expt_90.1m000/FMRC/runs/GOMu0.04_901m...
# 3  GOMu0.04/expt_90.1m000/FMRC/runs/GOMu0.04_901m...
# 4  GOMu0.04/expt_90.1m000/FMRC/runs/GOMu0.04_901m...
# 5  GOMu0.04/expt_90.1m000/FMRC/runs/GOMu0.04_901m...
# 6  GOMu0.04/expt_90.1m000/FMRC/runs/GOMu0.04_901m...
# 7  GOMu0.04/expt_90.1m000/FMRC/runs/GOMu0.04_901m...
#
#                                         timeCoverage  \
# 0  {'type': 'TimeRange', 'start': '2021-09-22T12:...
# 1  {'type': 'TimeRange', 'start': '2021-09-23T12:...
# 2  {'type': 'TimeRange', 'start': '2021-09-24T12:...
# 3  {'type': 'TimeRange', 'start': '2021-09-25T12:...
# 4  {'type': 'TimeRange', 'start': '2021-09-26T12:...
# 5  {'type': 'TimeRange', 'start': '2021-09-27T12:...
# 6  {'type': 'TimeRange', 'start': '2021-09-28T12:...
# 7  {'type': 'TimeRange', 'start': '2021-09-29T12:...
#
#                                   geospatialCoverage  expired
# 0  {'type': 'GeospatialCoverage', 'start': {'type...     True
# 1  {'type': 'GeospatialCoverage', 'start': {'type...    False
# 2  {'type': 'GeospatialCoverage', 'start': {'type...    False
# 3  {'type': 'GeospatialCoverage', 'start': {'type...    False
# 4  {'type': 'GeospatialCoverage', 'start': {'type...    False
# 5  {'type': 'GeospatialCoverage', 'start': {'type...    False
# 6  {'type': 'GeospatialCoverage', 'start': {'type...    False
# 7  {'type': 'GeospatialCoverage', 'start': {'type...    False

# %%
help(c3.FMRCDataArchive)
# Out:
# <div id="type:FMRCDataArchive" class="structure type root">
# <h1 class="type root">Type <span class="name">FMRCDataArchive</span></h1>
# <p class="description">FMRCDataArchive.c3typ
# A Data archive for a HycomFMRC containing associated FMRCFiles.</p>
# <p class="mixes">Mixes Persistable&lt;FMRCDataArchive&gt;</p>
# <div class="declaration"><p>Declaration</p><pre class="declaration">/**
#  * FMRCDataArchive.c3typ
#  * A Data archive for a {@link HycomFMRC} containing associated {@link FMRCFile}s.
#  */
# entity type FMRCDataArchive schema name 'FMRC_DT_ARCHV'
# </pre></div><div class="annotationDoc"><div class="annotations"><p>Annotations:</p>
# <ul class="annotations">
# <li class="annotation">@db</li>
# <li class="annotation">@schema</li>
# </ul></div>
# <pre class="annotation annotation-decl code nohighlight"><code>@db(persistable=true)
# @schema(name='FMRC_DT_ARCHV')
# </code></pre>
# </div><h2 class="section data-section">Fields</h2>
# <div id="data-field:FMRCDataArchive.fmrc" class="structure data-field">
# <h3><span class="name">fmrc</span>: HycomFMRC <span class="attributes"><span class="required">required</span></span></h3>
# <p class="description">The HycomFMRC associated with this archive.</p>
# <div class="declaration"><p>Declaration</p><pre class="declaration">// The {@link HycomFMRC} associated with this archive.
# fmrc: !HycomFMRC
# </pre></div><div class="annotationDoc"><p class="annotation">Annotation @constraint</p>
# <pre class="annotation annotation-decl code nohighlight"><code>@constraint(required=true)
# </code></pre>
# </div></div>
# <div id="data-field:FMRCDataArchive.subsetOptions" class="structure data-field">
# <h3><span class="name">subsetOptions</span>: FMRCSubsetOptions <span class="attributes"><span class="required">required</span></span></h3>
# <p class="description">The FMRCSubsetOptions options for this archive.</p>
# <div class="declaration"><p>Declaration</p><pre class="declaration">// The {@link FMRCSubsetOptions} options for this archive.
# subsetOptions: !FMRCSubsetOptions
# </pre></div><div class="annotationDoc"><p class="annotation">Annotation @constraint</p>
# <pre class="annotation annotation-decl code nohighlight"><code>@constraint(required=true)
# </code></pre>
# </div></div>
# <div id="data-field:FMRCDataArchive.downloadOptions" class="structure data-field">
# <h3><span class="name">downloadOptions</span>: FMRCDownloadOptions <span class="attributes"><span class="required">required</span></span></h3>
# <p class="description">The FMRCDownloadOptions for how to retrive the files that make up the dataset</p>
# <div class="declaration"><p>Declaration</p><pre class="declaration">// The {@link FMRCDownloadOptions} for how to retrive the files that make up the dataset
# downloadOptions: !FMRCDownloadOptions
# </pre></div><div class="annotationDoc"><p class="annotation">Annotation @constraint</p>
# <pre class="annotation annotation-decl code nohighlight"><code>@constraint(required=true)
# </code></pre>
# </div></div>
# <div id="data-field:FMRCDataArchive.dataFiles" class="structure data-field">
# <h3><span class="name">dataFiles</span>: [ FMRCFile ]</h3>
# <p class="description">Collection of FMRCFiles associated with this archive.</p>
# <p class="foreignkey">Foreign key: on FMRCFile.dataArchive from <a class="data-field documentation" data-to-id="data-field:FMRCDataArchive.id" title="field id" href="#data-field:FMRCDataArchive.id">id</a></p><div class="declaration"><p>Declaration</p><pre class="declaration">// Collection of {@link FMRCFile}s associated with this archive.
# dataFiles: [FMRCFile](dataArchive, id)
# </pre></div><div class="annotationDoc"><p class="annotation">Annotation @db</p>
# <pre class="annotation annotation-decl code nohighlight"><code>@db(fkey='dataArchive', key='id')
# </code></pre>
# </div></div>
# <div id="data-field:FMRCDataArchive.archiveSize" class="structure data-field">
# <h3><span class="name">archiveSize</span>: int <span class="attributes"><span class="calculated">calculated</span></span></h3>
# <p class="description">Whether FMRCFiles have been staged for download.
# Commented out due to unknown "extraneous property" error
# staged: boolean post default false
# Total size of the FMRCFiles in bytes.</p>
# <p class="calculated">Stored calculated: <code>sum(dataFiles.file.contentLength)</code></p><div class="declaration"><p>Declaration</p><pre class="declaration">/*
#  * Whether {@link FMRCFile}s have been staged for download.
#  * Commented out due to unknown "extraneous property" error
#  * staged: boolean post default false
#  * Total size of the {@link FMRCFile}s in bytes.
#  */
# archiveSize: int stored calc 'sum(dataFiles.file.contentLength)'
# </pre></div><div class="annotationDoc"><p class="annotation">Annotation @db</p>
# <pre class="annotation annotation-decl code nohighlight"><code>@db(calculated='sum(dataFiles.file.contentLength)')
# </code></pre>
# </div></div>
# <h2 class="section data-section inherited">Fields from Persistable</h2>
# <div id="data-field:FMRCDataArchive.id" class="structure data-field inherited">
# <h3><span class="name">id</span>: string <span class="attributes"><span class="inherited">inherited</span></span></h3>
# <p class="description">Unique id that can either be manually specified or automatically generated during object creation.  Can't be
# changed once instance is persisted.</p>
# <p class="inherited-from">Inherited from Persistable&lt;FMRCDataArchive&gt;</p>
# <div class="declaration"><p>Declaration</p><pre class="declaration">id: string
# </pre></div></div>
# <div id="data-field:FMRCDataArchive.versionEdits" class="structure data-field inherited private">
# <h3><span class="name">versionEdits</span>: [ VersionEdit ] <span class="attributes"><span class="private">private</span><span class="inherited">inherited</span></span></h3>
# <div class="description">
# <p>Version history.  Only populated when version history is enabled.  Used for retrieving earlier versions of an Obj.
# </p>
# <p>Completely and automatically managed by the system.</p>
# </div>
# <p class="private-info">Private</p><p class="inherited-from">Inherited from Persistable&lt;FMRCDataArchive&gt;</p>
# <div class="declaration"><p>Declaration</p><pre class="declaration">versionEdits: [VersionEdit]
# </pre></div><p class="see">See Ann.Db.versionHistory</p>
# </div>
# <div id="data-field:FMRCDataArchive.name" class="structure data-field inherited">
# <h3><span class="name">name</span>: string <span class="attributes"><span class="inherited">inherited</span></span></h3>
# <p class="description">Name of the Obj instance</p>
# <p class="inherited-from">Inherited from Persistable&lt;FMRCDataArchive&gt;</p>
# <div class="declaration"><p>Declaration</p><pre class="declaration">name: string
# </pre></div></div>
# <div id="data-field:FMRCDataArchive.meta" class="structure data-field inherited">
# <h3><span class="name">meta</span>: Meta <span class="attributes"><span class="inherited">inherited</span></span></h3>
# <p class="description">Various system fields.</p>
# <p class="inherited-from">Inherited from Persistable&lt;FMRCDataArchive&gt;</p>
# <div class="declaration"><p>Declaration</p><pre class="declaration">meta: Meta
# </pre></div></div>
# <div id="data-field:FMRCDataArchive.version" class="structure data-field inherited">
# <h3><span class="name">version</span>: int <span class="attributes"><span class="inherited">inherited</span></span></h3>
# <div class="description">
# <p>Version number used for optimistic concurrency.  Automatically managed by the system.
# </p>
# <p>Updating an Obj with a null or 0 value for version will cause the concurrency check to be skipped and should only
# be done with great caution.</p>
# </div>
# <p class="inherited-from">Inherited from Persistable&lt;FMRCDataArchive&gt;</p>
# <div class="declaration"><p>Declaration</p><pre class="declaration">version: int
# </pre></div></div>
# <h2 class="section method-section">Methods</h2>
# <div id="method-field:FMRCDataArchive.stageFMRCFiles" class="structure method-field">
# <h3><span class="name">stageFMRCFiles</span>(): [ FMRCFile ] <span class="attributes"><span class="member">member</span></span></h3>
# <p class="description">Method t

# %%
myFetchResult = c3.FMRCDataArchive.fetch(spec={
#                                   'limit': 15,
                                  #'include': 'this, myField',
                                  #'offset': 5,
                                  #'order': "ascending(myField)",
                                  #'filter': "myField == 'myString' && myOtherField == 'myOtherString'"
                                 })

pd.DataFrame(myFetchResult.objs.toJson())
# Out:
#               type                                                 id  \
# 0  FMRCDataArchive  GOMu0.04/expt_90.1m000/FMRC/runs/GOMu0.04_901m...
# 1  FMRCDataArchive  GOMu0.04/expt_90.1m000/FMRC/runs/GOMu0.04_901m...
# 2  FMRCDataArchive  GOMu0.04/expt_90.1m000/FMRC/runs/GOMu0.04_901m...
# 3  FMRCDataArchive  GOMu0.04/expt_90.1m000/FMRC/runs/GOMu0.04_901m...
# 4  FMRCDataArchive  GOMu0.04/expt_90.1m000/FMRC/runs/GOMu0.04_901m...
# 5  FMRCDataArchive  GOMu0.04/expt_90.1m000/FMRC/runs/GOMu0.04_901m...
# 6  FMRCDataArchive  GOMu0.04/expt_90.1m000/FMRC/runs/GOMu0.04_901m...
# 7  FMRCDataArchive  GOMu0.04/expt_90.1m000/FMRC/runs/GOMu0.04_901m...
#
#                                                 meta  version  \
# 0  {'type': 'Meta', 'tenantTagId': 150, 'tenant':...  2555905
# 1  {'type': 'Meta', 'tenantTagId': 150, 'tenant':...  3604481
# 2  {'type': 'Meta', 'tenantTagId': 150, 'tenant':...        1
# 3  {'type': 'Meta', 'tenantTagId': 150, 'tenant':...        1
# 4  {'type': 'Meta', 'tenantTagId': 150, 'tenant':...        1
# 5  {'type': 'Meta', 'tenantTagId': 150, 'tenant':...        1
# 6  {'type': 'Meta', 'tenantTagId': 150, 'tenant':...        1
# 7  {'type': 'Meta', 'tenantTagId': 150, 'tenant':...        1
#
#                                                 fmrc  \
# 0  {'type': 'HycomFMRC', 'id': 'GOMu0.04/expt_90....
# 1  {'type': 'HycomFMRC', 'id': 'GOMu0.04/expt_90....
# 2  {'type': 'HycomFMRC', 'id': 'GOMu0.04/expt_90....
# 3  {'type': 'HycomFMRC', 'id': 'GOMu0.04/expt_90....
# 4  {'type': 'HycomFMRC', 'id': 'GOMu0.04/expt_90....
# 5  {'type': 'HycomFMRC', 'id': 'GOMu0.04/expt_90....
# 6  {'type': 'HycomFMRC', 'id': 'GOMu0.04/expt_90....
# 7  {'type': 'HycomFMRC', 'id': 'GOMu0.04/expt_90....
#
#                                        subsetOptions  \
# 0  {'type': 'FMRCSubsetOptions', 'timeRange': {'t...
# 1  {'type': 'FMRCSubsetOptions', 'timeRange': {'t...
# 2  {'type': 'FMRCSubsetOptions', 'timeRange': {'t...
# 3  {'type': 'FMRCSubsetOptions', 'timeRange': {'t...
# 4  {'type': 'FMRCSubsetOptions', 'timeRange': {'t...
# 5  {'type': 'FMRCSubsetOptions', 'timeRange': {'t...
# 6  {'type': 'FMRCSubsetOptions', 'timeRange': {'t...
# 7  {'type': 'FMRCSubsetOptions', 'timeRange': {'t...
#
#                                      downloadOptions   archiveSize
# 0  {'type': 'FMRCDownloadOptions', 'externalDir':...  1.615932e+09
# 1  {'type': 'FMRCDownloadOptions', 'externalDir':...  2.147484e+09
# 2  {'type': 'FMRCDownloadOptions', 'externalDir':...           NaN
# 3  {'type': 'FMRCDownloadOptions', 'externalDir':...           NaN
# 4  {'type': 'FMRCDownloadOptions', 'externalDir':...           NaN
# 5  {'type': 'FMRCDownloadOptions', 'externalDir':...           NaN
# 6  {'type': 'FMRCDownloadOptions', 'externalDir':...           NaN
# 7  {'type': 'FMRCDownloadOptions', 'externalDir':...           NaN

# %%
help(c3.FMRCFile)
# Out:
# <div id="type:FMRCFile" class="structure type root">
# <h1 class="type root">Type <span class="name">FMRCFile</span></h1>
# <p class="description">FRMCFile.c3typ
# Files comprising a FMRCDataArchive.</p>
# <p class="mixes">Mixes Persistable&lt;FMRCFile&gt;</p>
# <div class="declaration"><p>Declaration</p><pre class="declaration">/**
#  * FRMCFile.c3typ
#  * Files comprising a {@link FMRCDataArchive}.
#  */
# entity type FMRCFile schema name 'FRMC_FL'
# </pre></div><div class="annotationDoc"><div class="annotations"><p>Annotations:</p>
# <ul class="annotations">
# <li class="annotation">@db</li>
# <li class="annotation">@schema</li>
# </ul></div>
# <pre class="annotation annotation-decl code nohighlight"><code>@db(persistable=true)
# @schema(name='FRMC_FL')
# </code></pre>
# </div><h2 class="section data-section">Fields</h2>
# <div id="data-field:FMRCFile.dataArchive" class="structure data-field">
# <h3><span class="name">dataArchive</span>: FMRCDataArchive <span class="attributes"><span class="required">required</span></span></h3>
# <p class="description">The HycomFRMC that these files belong to.</p>
# <div class="declaration"><p>Declaration</p><pre class="declaration">// The {@link HycomFRMC} that these files belong to.
# dataArchive: !FMRCDataArchive
# </pre></div><div class="annotationDoc"><p class="annotation">Annotation @constraint</p>
# <pre class="annotation annotation-decl code nohighlight"><code>@constraint(required=true)
# </code></pre>
# </div></div>
# <div id="data-field:FMRCFile.fileName" class="structure data-field">
# <h3><span class="name">fileName</span>: string</h3>
# <p class="description">FRMC file name</p>
# <div class="declaration"><p>Declaration</p><pre class="declaration">// FRMC file name
# fileName: string post default 'id'
# </pre></div><div class="annotationDoc"><p class="annotation">Annotation @db</p>
# <pre class="annotation annotation-decl code nohighlight"><code>@db(postDefault='id')
# </code></pre>
# </div></div>
# <div id="data-field:FMRCFile.timeCoverage" class="structure data-field">
# <h3><span class="name">timeCoverage</span>: TimeRange <span class="attributes"><span class="required">required</span></span></h3>
# <p class="description">Time coverage for this file</p>
# <div class="declaration"><p>Declaration</p><pre class="declaration">// Time coverage for this file
# timeCoverage: !TimeRange
# </pre></div><div class="annotationDoc"><p class="annotation">Annotation @constraint</p>
# <pre class="annotation annotation-decl code nohighlight"><code>@constraint(required=true)
# </code></pre>
# </div></div>
# <div id="data-field:FMRCFile.timeStride" class="structure data-field">
# <h3><span class="name">timeStride</span>: int <span class="attributes"><span class="required">required</span></span></h3>
# <p class="description">Time stride for this file</p>
# <div class="declaration"><p>Declaration</p><pre class="declaration">// Time stride for this file
# timeStride: !int
# </pre></div><div class="annotationDoc"><p class="annotation">Annotation @constraint</p>
# <pre class="annotation annotation-decl code nohighlight"><code>@constraint(required=true)
# </code></pre>
# </div></div>
# <div id="data-field:FMRCFile.timeStrideUOM" class="structure data-field">
# <h3><span class="name">timeStrideUOM</span>: Unit</h3>
# <p class="description">TimeStride units for this file</p>
# <div class="declaration"><p>Declaration</p><pre class="declaration">// TimeStride units for this file
# timeStrideUOM: Unit post default "{id:'hour'}"
# </pre></div><div class="annotationDoc"><p class="annotation">Annotation @db</p>
# <pre class="annotation annotation-decl code nohighlight"><code>@db(postDefault="{id:'hour'}")
# </code></pre>
# </div></div>
# <div id="data-field:FMRCFile.geospatialCoverage" class="structure data-field">
# <h3><span class="name">geospatialCoverage</span>: GeospatialCoverage <span class="attributes"><span class="required">required</span></span></h3>
# <p class="description">Geospatial coverage for this file</p>
# <div class="declaration"><p>Declaration</p><pre class="declaration">// Geospatial coverage for this file
# geospatialCoverage: !GeospatialCoverage
# </pre></div><div class="annotationDoc"><p class="annotation">Annotation @constraint</p>
# <pre class="annotation annotation-decl code nohighlight"><code>@constraint(required=true)
# </code></pre>
# </div></div>
# <div id="data-field:FMRCFile.geospatialResolution" class="structure data-field">
# <h3><span class="name">geospatialResolution</span>: GeospatialResolution</h3>
# <p class="description">Geospatial resolution for this file</p>
# <div class="declaration"><p>Declaration</p><pre class="declaration">// Geospatial resolution for this file
# geospatialResolution: GeospatialResolution post default 'dataArchive.fmrc.dataset.geospatialResolution'
# </pre></div><div class="annotationDoc"><p class="annotation">Annotation @db</p>
# <pre class="annotation annotation-decl code nohighlight"><code>@db(postDefault='dataArchive.fmrc.dataset.geospatialResolution')
# </code></pre>
# </div></div>
# <div id="data-field:FMRCFile.vars" class="structure data-field">
# <h3><span class="name">vars</span>: string <span class="attributes"><span class="required">required</span></span></h3>
# <p class="description">the varaibles contained in this file</p>
# <div class="declaration"><p>Declaration</p><pre class="declaration">// the varaibles contained in this file
# vars: !string
# </pre></div><div class="annotationDoc"><p class="annotation">Annotation @constraint</p>
# <pre class="annotation annotation-decl code nohighlight"><code>@constraint(required=true)
# </code></pre>
# </div></div>
# <div id="data-field:FMRCFile.fileType" class="structure data-field">
# <h3><span class="name">fileType</span>: string <span class="attributes"><span class="required">required</span><span class="enum">enum</span></span></h3>
# <p class="description">FRMC file type</p>
# <p class="enum">Enum: <code>netcdf4</code>, <code>netcdf</code></p><div class="declaration"><p>Declaration</p><pre class="declaration">// FRMC file type
# fileType: !string enum('netcdf4', 'netcdf')
# </pre></div><div class="annotationDoc"><p class="annotation">Annotation @constraint</p>
# <pre class="annotation annotation-decl code nohighlight"><code>@constraint(required=true, possible=['netcdf4', 'netcdf'])
# </code></pre>
# </div></div>
# <div id="data-field:FMRCFile.status" class="structure data-field">
# <h3><span class="name">status</span>: string <span class="attributes"><span class="enum">enum</span></span></h3>
# <p class="description">Status of the data download</p>
# <p class="enum">Enum: <code>downloaded</code>, <code>not_downloaded</code>, <code>downloading</code>, <code>error</code></p><div class="declaration"><p>Declaration</p><pre class="declaration">// Status of the data download
# status: string enum('downloaded', 'not_downloaded', 'downloading', 'error') post default '"not_downloaded"'
# </pre></div><div class="annotationDoc"><div class="annotations"><p>Annotations:</p>
# <ul class="annotations">
# <li class="annotation">@constraint</li>
# <li class="annotation">@db</li>
# </ul></div>
# <pre class="annotation annotation-decl code nohighlight"><code>@constraint(possible=['downloaded', 'not_downloaded', 'downloading', 'error'])
# @db(postDefault='"not_downloaded"')
# </code></pre>
# </div></div>
# <div id="data-field:FMRCFile.file" class="structure data-field">
# <h3><span class="name">file</span>: File</h3>
# <p class="description">The File object for this file</p>
# <div class="declaration"><p>Declaration</p><pre class="declaration">// The {@link File} object for this file
# file: File
# </pre></div></div>
# <h2 class="section data-section inherited">Fields from Persistable</h2>
# <div id="data-field:FMRCFile.id" class="structure data-field inherited">
# <h3><span class="name">id</span>: string <span class="attributes"><span class="inherited">inherited</span></span></h3>
# <p class="description">Unique id that can either be manually specified or automatically generated during object creation.  Can't be
# changed once instance is persisted.</p>
# <p class="inherited-from">Inherited from Persistable&lt;FMRCFile&gt;</p>
# <div class="declaration"><p>Declaration</p><pre

# %%
myFetchResult = c3.FMRCFile.fetch(spec={
#                                   'limit': 15,
                                  #'include': 'this, myField',
                                  #'offset': 5,
                                  #'order': "ascending(myField)",
                                  #'filter': "myField == 'myString' && myOtherField == 'myOtherString'"
                                 })

pd.DataFrame(myFetchResult.objs.toJson())
# Out:
#           type                                                 id  \
# 0     FMRCFile  GOMu0.04_901m000_FMRC_RUN_2021-09-22T12:00:00Z...
# 1     FMRCFile  GOMu0.04_901m000_FMRC_RUN_2021-09-22T12:00:00Z...
# 2     FMRCFile  GOMu0.04_901m000_FMRC_RUN_2021-09-22T12:00:00Z...
# 3     FMRCFile  GOMu0.04_901m000_FMRC_RUN_2021-09-22T12:00:00Z...
# 4     FMRCFile  GOMu0.04_901m000_FMRC_RUN_2021-09-22T12:00:00Z...
# ...        ...                                                ...
# 1059  FMRCFile  GOMu0.04_901m000_FMRC_RUN_2021-09-29T12:00:00Z...
# 1060  FMRCFile  GOMu0.04_901m000_FMRC_RUN_2021-09-29T12:00:00Z...
# 1061  FMRCFile  GOMu0.04_901m000_FMRC_RUN_2021-09-29T12:00:00Z...
# 1062  FMRCFile  GOMu0.04_901m000_FMRC_RUN_2021-09-29T12:00:00Z...
# 1063  FMRCFile  GOMu0.04_901m000_FMRC_RUN_2021-09-29T12:00:00Z...
#
#                                                    meta  version  \
# 0     {'type': 'Meta', 'tenantTagId': 150, 'tenant':...        3
# 1     {'type': 'Meta', 'tenantTagId': 150, 'tenant':...        3
# 2     {'type': 'Meta', 'tenantTagId': 150, 'tenant':...        3
# 3     {'type': 'Meta', 'tenantTagId': 150, 'tenant':...        3
# 4     {'type': 'Meta', 'tenantTagId': 150, 'tenant':...        3
# ...                                                 ...      ...
# 1059  {'type': 'Meta', 'tenantTagId': 150, 'tenant':...        1
# 1060  {'type': 'Meta', 'tenantTagId': 150, 'tenant':...        1
# 1061  {'type': 'Meta', 'tenantTagId': 150, 'tenant':...        1
# 1062  {'type': 'Meta', 'tenantTagId': 150, 'tenant':...        1
# 1063  {'type': 'Meta', 'tenantTagId': 150, 'tenant':...        1
#
#                                             dataArchive  \
# 0     {'type': 'FMRCDataArchive', 'id': 'GOMu0.04/ex...
# 1     {'type': 'FMRCDataArchive', 'id': 'GOMu0.04/ex...
# 2     {'type': 'FMRCDataArchive', 'id': 'GOMu0.04/ex...
# 3     {'type': 'FMRCDataArchive', 'id': 'GOMu0.04/ex...
# 4     {'type': 'FMRCDataArchive', 'id': 'GOMu0.04/ex...
# ...                                                 ...
# 1059  {'type': 'FMRCDataArchive', 'id': 'GOMu0.04/ex...
# 1060  {'type': 'FMRCDataArchive', 'id': 'GOMu0.04/ex...
# 1061  {'type': 'FMRCDataArchive', 'id': 'GOMu0.04/ex...
# 1062  {'type': 'FMRCDataArchive', 'id': 'GOMu0.04/ex...
# 1063  {'type': 'FMRCDataArchive', 'id': 'GOMu0.04/ex...
#
#                                                fileName  \
# 0     GOMu0.04_901m000_FMRC_RUN_2021-09-22T12:00:00Z...
# 1     GOMu0.04_901m000_FMRC_RUN_2021-09-22T12:00:00Z...
# 2     GOMu0.04_901m000_FMRC_RUN_2021-09-22T12:00:00Z...
# 3     GOMu0.04_901m000_FMRC_RUN_2021-09-22T12:00:00Z...
# 4     GOMu0.04_901m000_FMRC_RUN_2021-09-22T12:00:00Z...
# ...                                                 ...
# 1059  GOMu0.04_901m000_FMRC_RUN_2021-09-29T12:00:00Z...
# 1060  GOMu0.04_901m000_FMRC_RUN_2021-09-29T12:00:00Z...
# 1061  GOMu0.04_901m000_FMRC_RUN_2021-09-29T12:00:00Z...
# 1062  GOMu0.04_901m000_FMRC_RUN_2021-09-29T12:00:00Z...
# 1063  GOMu0.04_901m000_FMRC_RUN_2021-09-29T12:00:00Z...
#
#                                            timeCoverage  timeStride  \
# 0     {'type': 'TimeRange', 'start': '2021-09-22T12:...           1
# 1     {'type': 'TimeRange', 'start': '2021-09-22T13:...           1
# 2     {'type': 'TimeRange', 'start': '2021-09-22T14:...           1
# 3     {'type': 'TimeRange', 'start': '2021-09-22T15:...           1
# 4     {'type': 'TimeRange', 'start': '2021-09-22T16:...           1
# ...                                                 ...         ...
# 1059  {'type': 'TimeRange', 'start': '2021-10-04T20:...           1
# 1060  {'type': 'TimeRange', 'start': '2021-10-04T21:...           1
# 1061  {'type': 'TimeRange', 'start': '2021-10-04T22:...           1
# 1062  {'type': 'TimeRange', 'start': '2021-10-04T23:...           1
# 1063  {'type': 'TimeRange', 'start': '2021-10-05T00:...           1
#
#                        timeStrideUOM  \
# 0     {'type': 'Unit', 'id': 'hour'}
# 1     {'type': 'Unit', 'id': 'hour'}
# 2     {'type': 'Unit', 'id': 'hour'}
# 3     {'type': 'Unit', 'id': 'hour'}
# 4     {'type': 'Unit', 'id': 'hour'}
# ...                              ...
# 1059  {'type': 'Unit', 'id': 'hour'}
# 1060  {'type': 'Unit', 'id': 'hour'}
# 1061  {'type': 'Unit', 'id': 'hour'}
# 1062  {'type': 'Unit', 'id': 'hour'}
# 1063  {'type': 'Unit', 'id': 'hour'}
#
#                                      geospatialCoverage  \
# 0     {'type': 'GeospatialCoverage', 'start': {'type...
# 1     {'type': 'GeospatialCoverage', 'start': {'type...
# 2     {'type': 'GeospatialCoverage', 'start': {'type...
# 3     {'type': 'GeospatialCoverage', 'start': {'type...
# 4     {'type': 'GeospatialCoverage', 'start': {'type...
# ...                                                 ...
# 1059  {'type': 'GeospatialCoverage', 'start': {'type...
# 1060  {'type': 'GeospatialCoverage', 'start': {'type...
# 1061  {'type': 'GeospatialCoverage', 'start': {'type...
# 1062  {'type': 'GeospatialCoverage', 'start': {'type...
# 1063  {'type': 'GeospatialCoverage', 'start': {'type...
#
#                                              vars fileType          status  \
# 0     surf_el,salinity,water_temp,water_u,water_v  netcdf4      downloaded
# 1     surf_el,salinity,water_temp,water_u,water_v  netcdf4      downloaded
# 2     surf_el,salinity,water_temp,water_u,water_v  netcdf4      downloaded
# 3     surf_el,salinity,water_temp,water_u,water_v  netcdf4      downloaded
# 4     surf_el,salinity,water_temp,water_u,water_v  netcdf4      downloaded
# ...                                           ...      ...             ...
# 1059  surf_el,salinity,water_temp,water_u,water_v  netcdf4  not_downloaded
# 1060  surf_el,salinity,water_temp,water_u,water_v  netcdf4  not_downloaded
# 1061  surf_el,salinity,water_temp,water_u,water_v  netcdf4  not_downloaded
# 1062  surf_el,salinity,water_temp,water_u,water_v  netcdf4  not_downloaded
# 1063  surf_el,salinity,water_temp,water_u,water_v  netcdf4  not_downloaded
#
#                                                    file
# 0     {'type': 'File', 'contentLength': 39457863, 'c...
# 1     {'type': 'File', 'contentLength': 39448241, 'c...
# 2     {'type': 'File', 'contentLength': 39450453, 'c...
# 3     {'type': 'File', 'contentLength': 39456732, 'c...
# 4     {'type': 'File', 'contentLength': 39462205, 'c...
# ...                                                 ...
# 1059                                                NaN
# 1060                                                NaN
# 1061                                                NaN
# 1062                                                NaN
# 1063                                                NaN
#
# [1064 rows x 14 columns]

# %% [markdown]
# ## Cleanup Records and Files Created for this Demo

# %%
# Cleanup
#print(f"Removed {c3.HycomFMRCFile.removeAll()} HycomFMRCFile records.")
print(f"Removed {c3.FMRCFile.removeAll()} FMRCFile records.")
#print(f"Removed {c3.FMRCDataArchive.removeAll()} FMRCDataArchive records.")
print(f"Removed {c3.HycomFMRC.removeAll()} HycomFMRC records.")
#print(f"Removed {c3.HycomDataset.removeAll()} HycomDataset records")
print(f"Removed {c3.HindcastFile.removeAll()} HindcastFile records.")
print(f"Removed {c3.HindcastArchive.removeAll()} HindcastArchive records.")
print(f"Removed {c3.HycomHindcast.removeAll()} HycomHindCast records.")

files = c3.FileSystem.inst().listFiles(data_dir+'/hindcast')
if files.files:
    print(f"Deleting {len(files.files)} files")
    c3.FileSystem.inst().deleteFilesBatch(files.files)
print("Done.")
# Out:
# Removed 0 FMRCFile records.
# Removed 0 HycomFMRC records.
# Removed 3 HycomHindCast records.
# Removed 1 HindcastArchive records.
# Removed 720 HindcastFile records.
# Deleting 1 files
# Done.

# %% [markdown]
# ## Testing

# %%
# Check for errors
errors = c3.FMRCFile.fetchCount(spec={'filter':"status=='error'"})
print(errors)

# %%
# Grab a dataArchive record
da = c3.FMRCDataArchive.fetch(spec = {'include': 'this,dataFiles'}).objs[0]
da

# %%
# Check the total size of the files in this archive
print(f"Archive Size: {round(da.archiveSize/(1024**3),2)} GiB")

# %%
# Check the total Size of All FMRC Data
gom_dataset = c3.HycomDataset.fetch().objs[0] # The HycomFMRC is the first on only record here, now.
print(f"FMRC Archive Size: {round(gom_dataset.fmrcArchiveSize/(1024**3),2)} GiB")

# %%
import requests
import xmltodict
import os
import datetime
gom_dataset = c3.HycomDataset.get("GOMu0.04/expt_90.1m000")
def upsertHindcasts(this):
        
    with requests.get(this.catalogUrl) as r:
            doc = xmltodict.parse(r.text)

    hindcasts = []
    # Traverse the set of hincast collections in the catalog
    # Skip the FMRC and all collections
    for ds in doc['catalog']['dataset']['dataset']['dataset']:
        if 'ALL' in ds['@name'] or 'FMRC' in ds['@name']: # restrict to Hindcast
            continue
        # Parse the year off the end of the path and convert to integer 
        year = int(os.path.basename(ds["@urlPath"]))
        
        hc = c3.HycomHindcast(
            **{
                "id": ds['@ID'],
                "dataset": {"id": "GOMu0.04_901m000_FMRC_1.0.1"},
                "name":ds['@ID'],
                "description": ds['@name'],
                "urlPath": ds['@urlPath'],
                "timeCoverage": c3.TimeRange(
                    **{
                        "start": datetime.datetime(year,1,1,12),
                        "end": datetime.datetime(year+1,1,1,11)
                    }
                ).toJson()

              }
        )
        hindcasts.append(hc)
        
    
    return hindcasts
hindcasts = upsertHindcasts(gom_dataset)
hindcasts
# Out:
# [c3.HycomHindcast(
#  id='GOMu0.04-expt_90.1m000-2021',
#  name='GOMu0.04-expt_90.1m000-2021',
#  dataset=c3.HycomDataset(id='GOMu0.04_901m000_FMRC_1.0.1'),
#  description='(2021) Hindcast Data (1-hrly)',
#  urlPath='GOMu0.04/expt_90.1m000/data/hindcasts/2021',
#  timeCoverage=c3.TimeRange(
#                 start=datetime.datetime(2021, 1, 1, 12, 0),
#                 end=datetime.datetime(2022, 1, 1, 11, 0))),
#  c3.HycomHindcast(
#  id='GOMu0.04-expt_90.1m000-2020',
#  name='GOMu0.04-expt_90.1m000-2020',
#  dataset=c3.HycomDataset(id='GOMu0.04_901m000_FMRC_1.0.1'),
#  description='(2020) Hindcast Data (1-hrly)',
#  urlPath='GOMu0.04/expt_90.1m000/data/hindcasts/2020',
#  timeCoverage=c3.TimeRange(
#                 start=datetime.datetime(2020, 1, 1, 12, 0),
#                 end=datetime.datetime(2021, 1, 1, 11, 0))),
#  c3.HycomHindcast(
#  id='GOMu0.04-expt_90.1m000-2019',
#  name='GOMu0.04-expt_90.1m000-2019',
#  dataset=c3.HycomDataset(id='GOMu0.04_901m000_FMRC_1.0.1'),
#  description='(2019) Hindcast Data (1-hrly)',
#  urlPath='GOMu0.04/expt_90.1m000/data/hindcasts/2019',
#  timeCoverage=c3.TimeRange(
#                 start=datetime.datetime(2019, 1, 1, 12, 0),
#                 end=datetime.datetime(2020, 1, 1, 11, 0)))]

# %%
datetime.datetime(2021,1,1)
# Out:
# datetime.datetime(2021, 1, 1, 0, 0)

# %% [markdown]
# ## Create Lat-Long Pair Records

# %%
gom_dataset = c3.HycomDataset.get("GOMu0.04/expt_90.1m000")

# This function can become a member function of `HycomDataset`
def createLatLongPairs(this):
    xgrid_objs = c3.HycomXGrid.fetch(spec={
        'include': "longitude,index",
        'order': "ascending(index)"
    }).objs

    ygrid_objs = c3.HycomYGrid.fetch(spec={
        'include': "latitude,index",
        'order': "ascending(index)"
    }).objs


    pairs = [
        c3.HycomLatLongPair(
            **{
                'id' : this.region + '_' + str(i) + '-' + str(j),
                'i': i,
                'j': j,
                'lat': ygrid_objs[j].latitude,
                'lon': xgrid_objs[i].longitude,
                'pair': c3.LatLong(
                    **{
                        'latitude': ygrid_objs[j].latitude,
                        'longitude': xgrid_objs[i].longitude
                    }
                )
            }
        )
        for i in range(0,len(xgrid_objs)-1)
        for j in range(0,len(ygrid_objs)-1)
    ]
    c3. HycomLatLongPair.upsertBatch(pairs)
    return pairs
pairs = createLatLongPairs(gom_dataset)
pairs
# Out:
# [c3.HycomLatLongPair(
#  id='GOMu0.04_0-0',
#  i=0,
#  j=0,
#  lat=18.1200008392334,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=18.1200008392334, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-1',
#  i=0,
#  j=1,
#  lat=18.15999984741211,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=18.15999984741211, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-2',
#  i=0,
#  j=2,
#  lat=18.200000762939453,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=18.200000762939453, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-3',
#  i=0,
#  j=3,
#  lat=18.239999771118164,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=18.239999771118164, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-4',
#  i=0,
#  j=4,
#  lat=18.280000686645508,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=18.280000686645508, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-5',
#  i=0,
#  j=5,
#  lat=18.31999969482422,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=18.31999969482422, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-6',
#  i=0,
#  j=6,
#  lat=18.360000610351562,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=18.360000610351562, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-7',
#  i=0,
#  j=7,
#  lat=18.399999618530273,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=18.399999618530273, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-8',
#  i=0,
#  j=8,
#  lat=18.440000534057617,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=18.440000534057617, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-9',
#  i=0,
#  j=9,
#  lat=18.479999542236328,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=18.479999542236328, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-10',
#  i=0,
#  j=10,
#  lat=18.520000457763672,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=18.520000457763672, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-11',
#  i=0,
#  j=11,
#  lat=18.559999465942383,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=18.559999465942383, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-12',
#  i=0,
#  j=12,
#  lat=18.600000381469727,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=18.600000381469727, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-13',
#  i=0,
#  j=13,
#  lat=18.639999389648438,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=18.639999389648438, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-14',
#  i=0,
#  j=14,
#  lat=18.68000030517578,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=18.68000030517578, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-15',
#  i=0,
#  j=15,
#  lat=18.719999313354492,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=18.719999313354492, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-16',
#  i=0,
#  j=16,
#  lat=18.760000228881836,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=18.760000228881836, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-17',
#  i=0,
#  j=17,
#  lat=18.799999237060547,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=18.799999237060547, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-18',
#  i=0,
#  j=18,
#  lat=18.84000015258789,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=18.84000015258789, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-19',
#  i=0,
#  j=19,
#  lat=18.8799991607666,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=18.8799991607666, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-20',
#  i=0,
#  j=20,
#  lat=18.920000076293945,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=18.920000076293945, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-21',
#  i=0,
#  j=21,
#  lat=18.959999084472656,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=18.959999084472656, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-22',
#  i=0,
#  j=22,
#  lat=19.0,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=19.0, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-23',
#  i=0,
#  j=23,
#  lat=19.040000915527344,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=19.040000915527344, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-24',
#  i=0,
#  j=24,
#  lat=19.079999923706055,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=19.079999923706055, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-25',
#  i=0,
#  j=25,
#  lat=19.1200008392334,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=19.1200008392334, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-26',
#  i=0,
#  j=26,
#  lat=19.15999984741211,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=19.15999984741211, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-27',
#  i=0,
#  j=27,
#  lat=19.200000762939453,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=19.200000762939453, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-28',
#  i=0,
#  j=28,
#  lat=19.239999771118164,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=19.239999771118164, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-29',
#  i=0,
#  j=29,
#  lat=19.280000686645508,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=19.280000686645508, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-30',
#  i=0,
#  j=30,
#  lat=19.31999969482422,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=19.31999969482422, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-31',
#  i=0,
#  j=31,
#  lat=19.360000610351562,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=19.360000610351562, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-32',
#  i=0,
#  j=32,
#  lat=19.399999618530273,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=19.399999618530273, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-33',
#  i=0,
#  j=33,
#  lat=19.440000534057617,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=19.440000534057617, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-34',
#  i=0,
#  j=34,
#  lat=19.479999542236328,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=19.479999542236328, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-35',
#  i=0,
#  j=35,
#  lat=19.520000457763672,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=19.520000457763672, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-36',
#  i=0,
#  j=36,
#  lat=19.559999465942383,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=19.559999465942383, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-37',
#  i=0,
#  j=37,
#  lat=19.600000381469727,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=19.600000381469727, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-38',
#  i=0,
#  j=38,
#  lat=19.639999389648438,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=19.639999389648438, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-39',
#  i=0,
#  j=39,
#  lat=19.68000030517578,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=19.68000030517578, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-40',
#  i=0,
#  j=40,
#  lat=19.719999313354492,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=19.719999313354492, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-41',
#  i=0,
#  j=41,
#  lat=19.760000228881836,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=19.760000228881836, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-42',
#  i=0,
#  j=42,
#  lat=19.799999237060547,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=19.799999237060547, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-43',
#  i=0,
#  j=43,
#  lat=19.84000015258789,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=19.84000015258789, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-44',
#  i=0,
#  j=44,
#  lat=19.8799991607666,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=19.8799991607666, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-45',
#  i=0,
#  j=45,
#  lat=19.920000076293945,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=19.920000076293945, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-46',
#  i=0,
#  j=46,
#  lat=19.959999084472656,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=19.959999084472656, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-47',
#  i=0,
#  j=47,
#  lat=20.0,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=20.0, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-48',
#  i=0,
#  j=48,
#  lat=20.040000915527344,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=20.040000915527344, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-49',
#  i=0,
#  j=49,
#  lat=20.079999923706055,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=20.079999923706055, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-50',
#  i=0,
#  j=50,
#  lat=20.1200008392334,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=20.1200008392334, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-51',
#  i=0,
#  j=51,
#  lat=20.15999984741211,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=20.15999984741211, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-52',
#  i=0,
#  j=52,
#  lat=20.200000762939453,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=20.200000762939453, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-53',
#  i=0,
#  j=53,
#  lat=20.239999771118164,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=20.239999771118164, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-54',
#  i=0,
#  j=54,
#  lat=20.280000686645508,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=20.280000686645508, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-55',
#  i=0,
#  j=55,
#  lat=20.31999969482422,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=20.31999969482422, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-56',
#  i=0,
#  j=56,
#  lat=20.360000610351562,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=20.360000610351562, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-57',
#  i=0,
#  j=57,
#  lat=20.399999618530273,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=20.399999618530273, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-58',
#  i=0,
#  j=58,
#  lat=20.440000534057617,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=20.440000534057617, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-59',
#  i=0,
#  j=59,
#  lat=20.479999542236328,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=20.479999542236328, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-60',
#  i=0,
#  j=60,
#  lat=20.520000457763672,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=20.520000457763672, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-61',
#  i=0,
#  j=61,
#  lat=20.559999465942383,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=20.559999465942383, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-62',
#  i=0,
#  j=62,
#  lat=20.600000381469727,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=20.600000381469727, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-63',
#  i=0,
#  j=63,
#  lat=20.639999389648438,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=20.639999389648438, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-64',
#  i=0,
#  j=64,
#  lat=20.68000030517578,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=20.68000030517578, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-65',
#  i=0,
#  j=65,
#  lat=20.719999313354492,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=20.719999313354492, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-66',
#  i=0,
#  j=66,
#  lat=20.760000228881836,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=20.760000228881836, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-67',
#  i=0,
#  j=67,
#  lat=20.799999237060547,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=20.799999237060547, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-68',
#  i=0,
#  j=68,
#  lat=20.84000015258789,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=20.84000015258789, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-69',
#  i=0,
#  j=69,
#  lat=20.8799991607666,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=20.8799991607666, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-70',
#  i=0,
#  j=70,
#  lat=20.920000076293945,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=20.920000076293945, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-71',
#  i=0,
#  j=71,
#  lat=20.959999084472656,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=20.959999084472656, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-72',
#  i=0,
#  j=72,
#  lat=21.0,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=21.0, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-73',
#  i=0,
#  j=73,
#  lat=21.040000915527344,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=21.040000915527344, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-74',
#  i=0,
#  j=74,
#  lat=21.079999923706055,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=21.079999923706055, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-75',
#  i=0,
#  j=75,
#  lat=21.1200008392334,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=21.1200008392334, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-76',
#  i=0,
#  j=76,
#  lat=21.15999984741211,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=21.15999984741211, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-77',
#  i=0,
#  j=77,
#  lat=21.200000762939453,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=21.200000762939453, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-78',
#  i=0,
#  j=78,
#  lat=21.239999771118164,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=21.239999771118164, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-79',
#  i=0,
#  j=79,
#  lat=21.280000686645508,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=21.280000686645508, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-80',
#  i=0,
#  j=80,
#  lat=21.31999969482422,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=21.31999969482422, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-81',
#  i=0,
#  j=81,
#  lat=21.360000610351562,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=21.360000610351562, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-82',
#  i=0,
#  j=82,
#  lat=21.399999618530273,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=21.399999618530273, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-83',
#  i=0,
#  j=83,
#  lat=21.440000534057617,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=21.440000534057617, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-84',
#  i=0,
#  j=84,
#  lat=21.479999542236328,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=21.479999542236328, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-85',
#  i=0,
#  j=85,
#  lat=21.520000457763672,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=21.520000457763672, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-86',
#  i=0,
#  j=86,
#  lat=21.559999465942383,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=21.559999465942383, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-87',
#  i=0,
#  j=87,
#  lat=21.600000381469727,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=21.600000381469727, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-88',
#  i=0,
#  j=88,
#  lat=21.639999389648438,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=21.639999389648438, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-89',
#  i=0,
#  j=89,
#  lat=21.68000030517578,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=21.68000030517578, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-90',
#  i=0,
#  j=90,
#  lat=21.719999313354492,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=21.719999313354492, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-91',
#  i=0,
#  j=91,
#  lat=21.760000228881836,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=21.760000228881836, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-92',
#  i=0,
#  j=92,
#  lat=21.799999237060547,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=21.799999237060547, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-93',
#  i=0,
#  j=93,
#  lat=21.84000015258789,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=21.84000015258789, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-94',
#  i=0,
#  j=94,
#  lat=21.8799991607666,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=21.8799991607666, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-95',
#  i=0,
#  j=95,
#  lat=21.920000076293945,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=21.920000076293945, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-96',
#  i=0,
#  j=96,
#  lat=21.959999084472656,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=21.959999084472656, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-97',
#  i=0,
#  j=97,
#  lat=22.0,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=22.0, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-98',
#  i=0,
#  j=98,
#  lat=22.040000915527344,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=22.040000915527344, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-99',
#  i=0,
#  j=99,
#  lat=22.079999923706055,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=22.079999923706055, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-100',
#  i=0,
#  j=100,
#  lat=22.1200008392334,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=22.1200008392334, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-101',
#  i=0,
#  j=101,
#  lat=22.15999984741211,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=22.15999984741211, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-102',
#  i=0,
#  j=102,
#  lat=22.200000762939453,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=22.200000762939453, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-103',
#  i=0,
#  j=103,
#  lat=22.239999771118164,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=22.239999771118164, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-104',
#  i=0,
#  j=104,
#  lat=22.280000686645508,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=22.280000686645508, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-105',
#  i=0,
#  j=105,
#  lat=22.31999969482422,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=22.31999969482422, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-106',
#  i=0,
#  j=106,
#  lat=22.360000610351562,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=22.360000610351562, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-107',
#  i=0,
#  j=107,
#  lat=22.399999618530273,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=22.399999618530273, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-108',
#  i=0,
#  j=108,
#  lat=22.440000534057617,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=22.440000534057617, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-109',
#  i=0,
#  j=109,
#  lat=22.479999542236328,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=22.479999542236328, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-110',
#  i=0,
#  j=110,
#  lat=22.520000457763672,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=22.520000457763672, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-111',
#  i=0,
#  j=111,
#  lat=22.559999465942383,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=22.559999465942383, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-112',
#  i=0,
#  j=112,
#  lat=22.600000381469727,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=22.600000381469727, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-113',
#  i=0,
#  j=113,
#  lat=22.639999389648438,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=22.639999389648438, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-114',
#  i=0,
#  j=114,
#  lat=22.68000030517578,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=22.68000030517578, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-115',
#  i=0,
#  j=115,
#  lat=22.719999313354492,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=22.719999313354492, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-116',
#  i=0,
#  j=116,
#  lat=22.760000228881836,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=22.760000228881836, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-117',
#  i=0,
#  j=117,
#  lat=22.799999237060547,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=22.799999237060547, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-118',
#  i=0,
#  j=118,
#  lat=22.84000015258789,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=22.84000015258789, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-119',
#  i=0,
#  j=119,
#  lat=22.8799991607666,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=22.8799991607666, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-120',
#  i=0,
#  j=120,
#  lat=22.920000076293945,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=22.920000076293945, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-121',
#  i=0,
#  j=121,
#  lat=22.959999084472656,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=22.959999084472656, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-122',
#  i=0,
#  j=122,
#  lat=23.0,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=23.0, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-123',
#  i=0,
#  j=123,
#  lat=23.040000915527344,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=23.040000915527344, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-124',
#  i=0,
#  j=124,
#  lat=23.079999923706055,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=23.079999923706055, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-125',
#  i=0,
#  j=125,
#  lat=23.1200008392334,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=23.1200008392334, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-126',
#  i=0,
#  j=126,
#  lat=23.15999984741211,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=23.15999984741211, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-127',
#  i=0,
#  j=127,
#  lat=23.200000762939453,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=23.200000762939453, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-128',
#  i=0,
#  j=128,
#  lat=23.239999771118164,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=23.239999771118164, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-129',
#  i=0,
#  j=129,
#  lat=23.280000686645508,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=23.280000686645508, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-130',
#  i=0,
#  j=130,
#  lat=23.31999969482422,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=23.31999969482422, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-131',
#  i=0,
#  j=131,
#  lat=23.360000610351562,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=23.360000610351562, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-132',
#  i=0,
#  j=132,
#  lat=23.399999618530273,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=23.399999618530273, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-133',
#  i=0,
#  j=133,
#  lat=23.440000534057617,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=23.440000534057617, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-134',
#  i=0,
#  j=134,
#  lat=23.479999542236328,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=23.479999542236328, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-135',
#  i=0,
#  j=135,
#  lat=23.520000457763672,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=23.520000457763672, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-136',
#  i=0,
#  j=136,
#  lat=23.559999465942383,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=23.559999465942383, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-137',
#  i=0,
#  j=137,
#  lat=23.600000381469727,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=23.600000381469727, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-138',
#  i=0,
#  j=138,
#  lat=23.639999389648438,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=23.639999389648438, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-139',
#  i=0,
#  j=139,
#  lat=23.68000030517578,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=23.68000030517578, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-140',
#  i=0,
#  j=140,
#  lat=23.719999313354492,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=23.719999313354492, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-141',
#  i=0,
#  j=141,
#  lat=23.760000228881836,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=23.760000228881836, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-142',
#  i=0,
#  j=142,
#  lat=23.799999237060547,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=23.799999237060547, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-143',
#  i=0,
#  j=143,
#  lat=23.84000015258789,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=23.84000015258789, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-144',
#  i=0,
#  j=144,
#  lat=23.8799991607666,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=23.8799991607666, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-145',
#  i=0,
#  j=145,
#  lat=23.920000076293945,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=23.920000076293945, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-146',
#  i=0,
#  j=146,
#  lat=23.959999084472656,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=23.959999084472656, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-147',
#  i=0,
#  j=147,
#  lat=24.0,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=24.0, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-148',
#  i=0,
#  j=148,
#  lat=24.040000915527344,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=24.040000915527344, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-149',
#  i=0,
#  j=149,
#  lat=24.079999923706055,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=24.079999923706055, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-150',
#  i=0,
#  j=150,
#  lat=24.1200008392334,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=24.1200008392334, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-151',
#  i=0,
#  j=151,
#  lat=24.15999984741211,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=24.15999984741211, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-152',
#  i=0,
#  j=152,
#  lat=24.200000762939453,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=24.200000762939453, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-153',
#  i=0,
#  j=153,
#  lat=24.239999771118164,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=24.239999771118164, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-154',
#  i=0,
#  j=154,
#  lat=24.280000686645508,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=24.280000686645508, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-155',
#  i=0,
#  j=155,
#  lat=24.31999969482422,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=24.31999969482422, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-156',
#  i=0,
#  j=156,
#  lat=24.360000610351562,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=24.360000610351562, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-157',
#  i=0,
#  j=157,
#  lat=24.399999618530273,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=24.399999618530273, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-158',
#  i=0,
#  j=158,
#  lat=24.440000534057617,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=24.440000534057617, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-159',
#  i=0,
#  j=159,
#  lat=24.479999542236328,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=24.479999542236328, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-160',
#  i=0,
#  j=160,
#  lat=24.520000457763672,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=24.520000457763672, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-161',
#  i=0,
#  j=161,
#  lat=24.559999465942383,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=24.559999465942383, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-162',
#  i=0,
#  j=162,
#  lat=24.600000381469727,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=24.600000381469727, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-163',
#  i=0,
#  j=163,
#  lat=24.639999389648438,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=24.639999389648438, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-164',
#  i=0,
#  j=164,
#  lat=24.68000030517578,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=24.68000030517578, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-165',
#  i=0,
#  j=165,
#  lat=24.719999313354492,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=24.719999313354492, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-166',
#  i=0,
#  j=166,
#  lat=24.760000228881836,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=24.760000228881836, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-167',
#  i=0,
#  j=167,
#  lat=24.799999237060547,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=24.799999237060547, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-168',
#  i=0,
#  j=168,
#  lat=24.84000015258789,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=24.84000015258789, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-169',
#  i=0,
#  j=169,
#  lat=24.8799991607666,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=24.8799991607666, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-170',
#  i=0,
#  j=170,
#  lat=24.920000076293945,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=24.920000076293945, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-171',
#  i=0,
#  j=171,
#  lat=24.959999084472656,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=24.959999084472656, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-172',
#  i=0,
#  j=172,
#  lat=25.0,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=25.0, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-173',
#  i=0,
#  j=173,
#  lat=25.040000915527344,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=25.040000915527344, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-174',
#  i=0,
#  j=174,
#  lat=25.079999923706055,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=25.079999923706055, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-175',
#  i=0,
#  j=175,
#  lat=25.1200008392334,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=25.1200008392334, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-176',
#  i=0,
#  j=176,
#  lat=25.15999984741211,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=25.15999984741211, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-177',
#  i=0,
#  j=177,
#  lat=25.200000762939453,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=25.200000762939453, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-178',
#  i=0,
#  j=178,
#  lat=25.239999771118164,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=25.239999771118164, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-179',
#  i=0,
#  j=179,
#  lat=25.280000686645508,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=25.280000686645508, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-180',
#  i=0,
#  j=180,
#  lat=25.31999969482422,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=25.31999969482422, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-181',
#  i=0,
#  j=181,
#  lat=25.360000610351562,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=25.360000610351562, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-182',
#  i=0,
#  j=182,
#  lat=25.399999618530273,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=25.399999618530273, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-183',
#  i=0,
#  j=183,
#  lat=25.440000534057617,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=25.440000534057617, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-184',
#  i=0,
#  j=184,
#  lat=25.479999542236328,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=25.479999542236328, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-185',
#  i=0,
#  j=185,
#  lat=25.520000457763672,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=25.520000457763672, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-186',
#  i=0,
#  j=186,
#  lat=25.559999465942383,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=25.559999465942383, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-187',
#  i=0,
#  j=187,
#  lat=25.600000381469727,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=25.600000381469727, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-188',
#  i=0,
#  j=188,
#  lat=25.639999389648438,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=25.639999389648438, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-189',
#  i=0,
#  j=189,
#  lat=25.68000030517578,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=25.68000030517578, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-190',
#  i=0,
#  j=190,
#  lat=25.719999313354492,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=25.719999313354492, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-191',
#  i=0,
#  j=191,
#  lat=25.760000228881836,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=25.760000228881836, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-192',
#  i=0,
#  j=192,
#  lat=25.799999237060547,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=25.799999237060547, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-193',
#  i=0,
#  j=193,
#  lat=25.84000015258789,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=25.84000015258789, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-194',
#  i=0,
#  j=194,
#  lat=25.8799991607666,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=25.8799991607666, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-195',
#  i=0,
#  j=195,
#  lat=25.920000076293945,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=25.920000076293945, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-196',
#  i=0,
#  j=196,
#  lat=25.959999084472656,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=25.959999084472656, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-197',
#  i=0,
#  j=197,
#  lat=26.0,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=26.0, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-198',
#  i=0,
#  j=198,
#  lat=26.040000915527344,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=26.040000915527344, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-199',
#  i=0,
#  j=199,
#  lat=26.079999923706055,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=26.079999923706055, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-200',
#  i=0,
#  j=200,
#  lat=26.1200008392334,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=26.1200008392334, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-201',
#  i=0,
#  j=201,
#  lat=26.15999984741211,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=26.15999984741211, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-202',
#  i=0,
#  j=202,
#  lat=26.200000762939453,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=26.200000762939453, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-203',
#  i=0,
#  j=203,
#  lat=26.239999771118164,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=26.239999771118164, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-204',
#  i=0,
#  j=204,
#  lat=26.280000686645508,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=26.280000686645508, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-205',
#  i=0,
#  j=205,
#  lat=26.31999969482422,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=26.31999969482422, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-206',
#  i=0,
#  j=206,
#  lat=26.360000610351562,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=26.360000610351562, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-207',
#  i=0,
#  j=207,
#  lat=26.399999618530273,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=26.399999618530273, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-208',
#  i=0,
#  j=208,
#  lat=26.440000534057617,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=26.440000534057617, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-209',
#  i=0,
#  j=209,
#  lat=26.479999542236328,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=26.479999542236328, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-210',
#  i=0,
#  j=210,
#  lat=26.520000457763672,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=26.520000457763672, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-211',
#  i=0,
#  j=211,
#  lat=26.559999465942383,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=26.559999465942383, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-212',
#  i=0,
#  j=212,
#  lat=26.600000381469727,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=26.600000381469727, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-213',
#  i=0,
#  j=213,
#  lat=26.639999389648438,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=26.639999389648438, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-214',
#  i=0,
#  j=214,
#  lat=26.68000030517578,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=26.68000030517578, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-215',
#  i=0,
#  j=215,
#  lat=26.719999313354492,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=26.719999313354492, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-216',
#  i=0,
#  j=216,
#  lat=26.760000228881836,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=26.760000228881836, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-217',
#  i=0,
#  j=217,
#  lat=26.799999237060547,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=26.799999237060547, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-218',
#  i=0,
#  j=218,
#  lat=26.84000015258789,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=26.84000015258789, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-219',
#  i=0,
#  j=219,
#  lat=26.8799991607666,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=26.8799991607666, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-220',
#  i=0,
#  j=220,
#  lat=26.920000076293945,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=26.920000076293945, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-221',
#  i=0,
#  j=221,
#  lat=26.959999084472656,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=26.959999084472656, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-222',
#  i=0,
#  j=222,
#  lat=27.0,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=27.0, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-223',
#  i=0,
#  j=223,
#  lat=27.040000915527344,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=27.040000915527344, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-224',
#  i=0,
#  j=224,
#  lat=27.079999923706055,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=27.079999923706055, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-225',
#  i=0,
#  j=225,
#  lat=27.1200008392334,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=27.1200008392334, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-226',
#  i=0,
#  j=226,
#  lat=27.15999984741211,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=27.15999984741211, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-227',
#  i=0,
#  j=227,
#  lat=27.200000762939453,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=27.200000762939453, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-228',
#  i=0,
#  j=228,
#  lat=27.239999771118164,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=27.239999771118164, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-229',
#  i=0,
#  j=229,
#  lat=27.280000686645508,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=27.280000686645508, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-230',
#  i=0,
#  j=230,
#  lat=27.31999969482422,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=27.31999969482422, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-231',
#  i=0,
#  j=231,
#  lat=27.360000610351562,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=27.360000610351562, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-232',
#  i=0,
#  j=232,
#  lat=27.399999618530273,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=27.399999618530273, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-233',
#  i=0,
#  j=233,
#  lat=27.440000534057617,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=27.440000534057617, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-234',
#  i=0,
#  j=234,
#  lat=27.479999542236328,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=27.479999542236328, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-235',
#  i=0,
#  j=235,
#  lat=27.520000457763672,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=27.520000457763672, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-236',
#  i=0,
#  j=236,
#  lat=27.559999465942383,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=27.559999465942383, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-237',
#  i=0,
#  j=237,
#  lat=27.600000381469727,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=27.600000381469727, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-238',
#  i=0,
#  j=238,
#  lat=27.639999389648438,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=27.639999389648438, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-239',
#  i=0,
#  j=239,
#  lat=27.68000030517578,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=27.68000030517578, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-240',
#  i=0,
#  j=240,
#  lat=27.719999313354492,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=27.719999313354492, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-241',
#  i=0,
#  j=241,
#  lat=27.760000228881836,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=27.760000228881836, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-242',
#  i=0,
#  j=242,
#  lat=27.799999237060547,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=27.799999237060547, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-243',
#  i=0,
#  j=243,
#  lat=27.84000015258789,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=27.84000015258789, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-244',
#  i=0,
#  j=244,
#  lat=27.8799991607666,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=27.8799991607666, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-245',
#  i=0,
#  j=245,
#  lat=27.920000076293945,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=27.920000076293945, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-246',
#  i=0,
#  j=246,
#  lat=27.959999084472656,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=27.959999084472656, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-247',
#  i=0,
#  j=247,
#  lat=28.0,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=28.0, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-248',
#  i=0,
#  j=248,
#  lat=28.040000915527344,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=28.040000915527344, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-249',
#  i=0,
#  j=249,
#  lat=28.079999923706055,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=28.079999923706055, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-250',
#  i=0,
#  j=250,
#  lat=28.1200008392334,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=28.1200008392334, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-251',
#  i=0,
#  j=251,
#  lat=28.15999984741211,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=28.15999984741211, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-252',
#  i=0,
#  j=252,
#  lat=28.200000762939453,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=28.200000762939453, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-253',
#  i=0,
#  j=253,
#  lat=28.239999771118164,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=28.239999771118164, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-254',
#  i=0,
#  j=254,
#  lat=28.280000686645508,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=28.280000686645508, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-255',
#  i=0,
#  j=255,
#  lat=28.31999969482422,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=28.31999969482422, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-256',
#  i=0,
#  j=256,
#  lat=28.360000610351562,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=28.360000610351562, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-257',
#  i=0,
#  j=257,
#  lat=28.399999618530273,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=28.399999618530273, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-258',
#  i=0,
#  j=258,
#  lat=28.440000534057617,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=28.440000534057617, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-259',
#  i=0,
#  j=259,
#  lat=28.479999542236328,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=28.479999542236328, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-260',
#  i=0,
#  j=260,
#  lat=28.520000457763672,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=28.520000457763672, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-261',
#  i=0,
#  j=261,
#  lat=28.559999465942383,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=28.559999465942383, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-262',
#  i=0,
#  j=262,
#  lat=28.600000381469727,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=28.600000381469727, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-263',
#  i=0,
#  j=263,
#  lat=28.639999389648438,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=28.639999389648438, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-264',
#  i=0,
#  j=264,
#  lat=28.68000030517578,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=28.68000030517578, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-265',
#  i=0,
#  j=265,
#  lat=28.719999313354492,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=28.719999313354492, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-266',
#  i=0,
#  j=266,
#  lat=28.760000228881836,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=28.760000228881836, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-267',
#  i=0,
#  j=267,
#  lat=28.799999237060547,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=28.799999237060547, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-268',
#  i=0,
#  j=268,
#  lat=28.84000015258789,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=28.84000015258789, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-269',
#  i=0,
#  j=269,
#  lat=28.8799991607666,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=28.8799991607666, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-270',
#  i=0,
#  j=270,
#  lat=28.920000076293945,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=28.920000076293945, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-271',
#  i=0,
#  j=271,
#  lat=28.959999084472656,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=28.959999084472656, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-272',
#  i=0,
#  j=272,
#  lat=29.0,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=29.0, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-273',
#  i=0,
#  j=273,
#  lat=29.040000915527344,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=29.040000915527344, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-274',
#  i=0,
#  j=274,
#  lat=29.079999923706055,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=29.079999923706055, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-275',
#  i=0,
#  j=275,
#  lat=29.1200008392334,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=29.1200008392334, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-276',
#  i=0,
#  j=276,
#  lat=29.15999984741211,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=29.15999984741211, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-277',
#  i=0,
#  j=277,
#  lat=29.200000762939453,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=29.200000762939453, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-278',
#  i=0,
#  j=278,
#  lat=29.239999771118164,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=29.239999771118164, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-279',
#  i=0,
#  j=279,
#  lat=29.280000686645508,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=29.280000686645508, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-280',
#  i=0,
#  j=280,
#  lat=29.31999969482422,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=29.31999969482422, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-281',
#  i=0,
#  j=281,
#  lat=29.360000610351562,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=29.360000610351562, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-282',
#  i=0,
#  j=282,
#  lat=29.399999618530273,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=29.399999618530273, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-283',
#  i=0,
#  j=283,
#  lat=29.440000534057617,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=29.440000534057617, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-284',
#  i=0,
#  j=284,
#  lat=29.479999542236328,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=29.479999542236328, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-285',
#  i=0,
#  j=285,
#  lat=29.520000457763672,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=29.520000457763672, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-286',
#  i=0,
#  j=286,
#  lat=29.559999465942383,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=29.559999465942383, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-287',
#  i=0,
#  j=287,
#  lat=29.600000381469727,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=29.600000381469727, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-288',
#  i=0,
#  j=288,
#  lat=29.639999389648438,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=29.639999389648438, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-289',
#  i=0,
#  j=289,
#  lat=29.68000030517578,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=29.68000030517578, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-290',
#  i=0,
#  j=290,
#  lat=29.719999313354492,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=29.719999313354492, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-291',
#  i=0,
#  j=291,
#  lat=29.760000228881836,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=29.760000228881836, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-292',
#  i=0,
#  j=292,
#  lat=29.799999237060547,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=29.799999237060547, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-293',
#  i=0,
#  j=293,
#  lat=29.84000015258789,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=29.84000015258789, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-294',
#  i=0,
#  j=294,
#  lat=29.8799991607666,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=29.8799991607666, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-295',
#  i=0,
#  j=295,
#  lat=29.920000076293945,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=29.920000076293945, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-296',
#  i=0,
#  j=296,
#  lat=29.959999084472656,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=29.959999084472656, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-297',
#  i=0,
#  j=297,
#  lat=30.0,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=30.0, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-298',
#  i=0,
#  j=298,
#  lat=30.040000915527344,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=30.040000915527344, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-299',
#  i=0,
#  j=299,
#  lat=30.079999923706055,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=30.079999923706055, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-300',
#  i=0,
#  j=300,
#  lat=30.1200008392334,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=30.1200008392334, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-301',
#  i=0,
#  j=301,
#  lat=30.15999984741211,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=30.15999984741211, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-302',
#  i=0,
#  j=302,
#  lat=30.200000762939453,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=30.200000762939453, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-303',
#  i=0,
#  j=303,
#  lat=30.239999771118164,
#  lon=-98.0,
#  pair=c3.LatLong(latitude=30.239999771118164, longitude=-98.0)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_0-304',
#  i=0,
#  j=304,
#  lat=30.280000686645508,
#  lon=-98.0,
# ...
#  j=223,
#  lat=27.040000915527344,
#  lon=-97.91998291015625,
#  pair=c3.LatLong(latitude=27.040000915527344, longitude=-97.91998291015625)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_2-224',
#  i=2,
#  j=224,
#  lat=27.079999923706055,
#  lon=-97.91998291015625,
#  pair=c3.LatLong(latitude=27.079999923706055, longitude=-97.91998291015625)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_2-225',
#  i=2,
#  j=225,
#  lat=27.1200008392334,
#  lon=-97.91998291015625,
#  pair=c3.LatLong(latitude=27.1200008392334, longitude=-97.91998291015625)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_2-226',
#  i=2,
#  j=226,
#  lat=27.15999984741211,
#  lon=-97.91998291015625,
#  pair=c3.LatLong(latitude=27.15999984741211, longitude=-97.91998291015625)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_2-227',
#  i=2,
#  j=227,
#  lat=27.200000762939453,
#  lon=-97.91998291015625,
#  pair=c3.LatLong(latitude=27.200000762939453, longitude=-97.91998291015625)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_2-228',
#  i=2,
#  j=228,
#  lat=27.239999771118164,
#  lon=-97.91998291015625,
#  pair=c3.LatLong(latitude=27.239999771118164, longitude=-97.91998291015625)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_2-229',
#  i=2,
#  j=229,
#  lat=27.280000686645508,
#  lon=-97.91998291015625,
#  pair=c3.LatLong(latitude=27.280000686645508, longitude=-97.91998291015625)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_2-230',
#  i=2,
#  j=230,
#  lat=27.31999969482422,
#  lon=-97.91998291015625,
#  pair=c3.LatLong(latitude=27.31999969482422, longitude=-97.91998291015625)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_2-231',
#  i=2,
#  j=231,
#  lat=27.360000610351562,
#  lon=-97.91998291015625,
#  pair=c3.LatLong(latitude=27.360000610351562, longitude=-97.91998291015625)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_2-232',
#  i=2,
#  j=232,
#  lat=27.399999618530273,
#  lon=-97.91998291015625,
#  pair=c3.LatLong(latitude=27.399999618530273, longitude=-97.91998291015625)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_2-233',
#  i=2,
#  j=233,
#  lat=27.440000534057617,
#  lon=-97.91998291015625,
#  pair=c3.LatLong(latitude=27.440000534057617, longitude=-97.91998291015625)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_2-234',
#  i=2,
#  j=234,
#  lat=27.479999542236328,
#  lon=-97.91998291015625,
#  pair=c3.LatLong(latitude=27.479999542236328, longitude=-97.91998291015625)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_2-235',
#  i=2,
#  j=235,
#  lat=27.520000457763672,
#  lon=-97.91998291015625,
#  pair=c3.LatLong(latitude=27.520000457763672, longitude=-97.91998291015625)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_2-236',
#  i=2,
#  j=236,
#  lat=27.559999465942383,
#  lon=-97.91998291015625,
#  pair=c3.LatLong(latitude=27.559999465942383, longitude=-97.91998291015625)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_2-237',
#  i=2,
#  j=237,
#  lat=27.600000381469727,
#  lon=-97.91998291015625,
#  pair=c3.LatLong(latitude=27.600000381469727, longitude=-97.91998291015625)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_2-238',
#  i=2,
#  j=238,
#  lat=27.639999389648438,
#  lon=-97.91998291015625,
#  pair=c3.LatLong(latitude=27.639999389648438, longitude=-97.91998291015625)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_2-239',
#  i=2,
#  j=239,
#  lat=27.68000030517578,
#  lon=-97.91998291015625,
#  pair=c3.LatLong(latitude=27.68000030517578, longitude=-97.91998291015625)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_2-240',
#  i=2,
#  j=240,
#  lat=27.719999313354492,
#  lon=-97.91998291015625,
#  pair=c3.LatLong(latitude=27.719999313354492, longitude=-97.91998291015625)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_2-241',
#  i=2,
#  j=241,
#  lat=27.760000228881836,
#  lon=-97.91998291015625,
#  pair=c3.LatLong(latitude=27.760000228881836, longitude=-97.91998291015625)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_2-242',
#  i=2,
#  j=242,
#  lat=27.799999237060547,
#  lon=-97.91998291015625,
#  pair=c3.LatLong(latitude=27.799999237060547, longitude=-97.91998291015625)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_2-243',
#  i=2,
#  j=243,
#  lat=27.84000015258789,
#  lon=-97.91998291015625,
#  pair=c3.LatLong(latitude=27.84000015258789, longitude=-97.91998291015625)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_2-244',
#  i=2,
#  j=244,
#  lat=27.8799991607666,
#  lon=-97.91998291015625,
#  pair=c3.LatLong(latitude=27.8799991607666, longitude=-97.91998291015625)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_2-245',
#  i=2,
#  j=245,
#  lat=27.920000076293945,
#  lon=-97.91998291015625,
#  pair=c3.LatLong(latitude=27.920000076293945, longitude=-97.91998291015625)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_2-246',
#  i=2,
#  j=246,
#  lat=27.959999084472656,
#  lon=-97.91998291015625,
#  pair=c3.LatLong(latitude=27.959999084472656, longitude=-97.91998291015625)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_2-247',
#  i=2,
#  j=247,
#  lat=28.0,
#  lon=-97.91998291015625,
#  pair=c3.LatLong(latitude=28.0, longitude=-97.91998291015625)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_2-248',
#  i=2,
#  j=248,
#  lat=28.040000915527344,
#  lon=-97.91998291015625,
#  pair=c3.LatLong(latitude=28.040000915527344, longitude=-97.91998291015625)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_2-249',
#  i=2,
#  j=249,
#  lat=28.079999923706055,
#  lon=-97.91998291015625,
#  pair=c3.LatLong(latitude=28.079999923706055, longitude=-97.91998291015625)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_2-250',
#  i=2,
#  j=250,
#  lat=28.1200008392334,
#  lon=-97.91998291015625,
#  pair=c3.LatLong(latitude=28.1200008392334, longitude=-97.91998291015625)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_2-251',
#  i=2,
#  j=251,
#  lat=28.15999984741211,
#  lon=-97.91998291015625,
#  pair=c3.LatLong(latitude=28.15999984741211, longitude=-97.91998291015625)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_2-252',
#  i=2,
#  j=252,
#  lat=28.200000762939453,
#  lon=-97.91998291015625,
#  pair=c3.LatLong(latitude=28.200000762939453, longitude=-97.91998291015625)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_2-253',
#  i=2,
#  j=253,
#  lat=28.239999771118164,
#  lon=-97.91998291015625,
#  pair=c3.LatLong(latitude=28.239999771118164, longitude=-97.91998291015625)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_2-254',
#  i=2,
#  j=254,
#  lat=28.280000686645508,
#  lon=-97.91998291015625,
#  pair=c3.LatLong(latitude=28.280000686645508, longitude=-97.91998291015625)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_2-255',
#  i=2,
#  j=255,
#  lat=28.31999969482422,
#  lon=-97.91998291015625,
#  pair=c3.LatLong(latitude=28.31999969482422, longitude=-97.91998291015625)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_2-256',
#  i=2,
#  j=256,
#  lat=28.360000610351562,
#  lon=-97.91998291015625,
#  pair=c3.LatLong(latitude=28.360000610351562, longitude=-97.91998291015625)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_2-257',
#  i=2,
#  j=257,
#  lat=28.399999618530273,
#  lon=-97.91998291015625,
#  pair=c3.LatLong(latitude=28.399999618530273, longitude=-97.91998291015625)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_2-258',
#  i=2,
#  j=258,
#  lat=28.440000534057617,
#  lon=-97.91998291015625,
#  pair=c3.LatLong(latitude=28.440000534057617, longitude=-97.91998291015625)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_2-259',
#  i=2,
#  j=259,
#  lat=28.479999542236328,
#  lon=-97.91998291015625,
#  pair=c3.LatLong(latitude=28.479999542236328, longitude=-97.91998291015625)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_2-260',
#  i=2,
#  j=260,
#  lat=28.520000457763672,
#  lon=-97.91998291015625,
#  pair=c3.LatLong(latitude=28.520000457763672, longitude=-97.91998291015625)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_2-261',
#  i=2,
#  j=261,
#  lat=28.559999465942383,
#  lon=-97.91998291015625,
#  pair=c3.LatLong(latitude=28.559999465942383, longitude=-97.91998291015625)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_2-262',
#  i=2,
#  j=262,
#  lat=28.600000381469727,
#  lon=-97.91998291015625,
#  pair=c3.LatLong(latitude=28.600000381469727, longitude=-97.91998291015625)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_2-263',
#  i=2,
#  j=263,
#  lat=28.639999389648438,
#  lon=-97.91998291015625,
#  pair=c3.LatLong(latitude=28.639999389648438, longitude=-97.91998291015625)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_2-264',
#  i=2,
#  j=264,
#  lat=28.68000030517578,
#  lon=-97.91998291015625,
#  pair=c3.LatLong(latitude=28.68000030517578, longitude=-97.91998291015625)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_2-265',
#  i=2,
#  j=265,
#  lat=28.719999313354492,
#  lon=-97.91998291015625,
#  pair=c3.LatLong(latitude=28.719999313354492, longitude=-97.91998291015625)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_2-266',
#  i=2,
#  j=266,
#  lat=28.760000228881836,
#  lon=-97.91998291015625,
#  pair=c3.LatLong(latitude=28.760000228881836, longitude=-97.91998291015625)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_2-267',
#  i=2,
#  j=267,
#  lat=28.799999237060547,
#  lon=-97.91998291015625,
#  pair=c3.LatLong(latitude=28.799999237060547, longitude=-97.91998291015625)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_2-268',
#  i=2,
#  j=268,
#  lat=28.84000015258789,
#  lon=-97.91998291015625,
#  pair=c3.LatLong(latitude=28.84000015258789, longitude=-97.91998291015625)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_2-269',
#  i=2,
#  j=269,
#  lat=28.8799991607666,
#  lon=-97.91998291015625,
#  pair=c3.LatLong(latitude=28.8799991607666, longitude=-97.91998291015625)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_2-270',
#  i=2,
#  j=270,
#  lat=28.920000076293945,
#  lon=-97.91998291015625,
#  pair=c3.LatLong(latitude=28.920000076293945, longitude=-97.91998291015625)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_2-271',
#  i=2,
#  j=271,
#  lat=28.959999084472656,
#  lon=-97.91998291015625,
#  pair=c3.LatLong(latitude=28.959999084472656, longitude=-97.91998291015625)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_2-272',
#  i=2,
#  j=272,
#  lat=29.0,
#  lon=-97.91998291015625,
#  pair=c3.LatLong(latitude=29.0, longitude=-97.91998291015625)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_2-273',
#  i=2,
#  j=273,
#  lat=29.040000915527344,
#  lon=-97.91998291015625,
#  pair=c3.LatLong(latitude=29.040000915527344, longitude=-97.91998291015625)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_2-274',
#  i=2,
#  j=274,
#  lat=29.079999923706055,
#  lon=-97.91998291015625,
#  pair=c3.LatLong(latitude=29.079999923706055, longitude=-97.91998291015625)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_2-275',
#  i=2,
#  j=275,
#  lat=29.1200008392334,
#  lon=-97.91998291015625,
#  pair=c3.LatLong(latitude=29.1200008392334, longitude=-97.91998291015625)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_2-276',
#  i=2,
#  j=276,
#  lat=29.15999984741211,
#  lon=-97.91998291015625,
#  pair=c3.LatLong(latitude=29.15999984741211, longitude=-97.91998291015625)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_2-277',
#  i=2,
#  j=277,
#  lat=29.200000762939453,
#  lon=-97.91998291015625,
#  pair=c3.LatLong(latitude=29.200000762939453, longitude=-97.91998291015625)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_2-278',
#  i=2,
#  j=278,
#  lat=29.239999771118164,
#  lon=-97.91998291015625,
#  pair=c3.LatLong(latitude=29.239999771118164, longitude=-97.91998291015625)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_2-279',
#  i=2,
#  j=279,
#  lat=29.280000686645508,
#  lon=-97.91998291015625,
#  pair=c3.LatLong(latitude=29.280000686645508, longitude=-97.91998291015625)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_2-280',
#  i=2,
#  j=280,
#  lat=29.31999969482422,
#  lon=-97.91998291015625,
#  pair=c3.LatLong(latitude=29.31999969482422, longitude=-97.91998291015625)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_2-281',
#  i=2,
#  j=281,
#  lat=29.360000610351562,
#  lon=-97.91998291015625,
#  pair=c3.LatLong(latitude=29.360000610351562, longitude=-97.91998291015625)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_2-282',
#  i=2,
#  j=282,
#  lat=29.399999618530273,
#  lon=-97.91998291015625,
#  pair=c3.LatLong(latitude=29.399999618530273, longitude=-97.91998291015625)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_2-283',
#  i=2,
#  j=283,
#  lat=29.440000534057617,
#  lon=-97.91998291015625,
#  pair=c3.LatLong(latitude=29.440000534057617, longitude=-97.91998291015625)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_2-284',
#  i=2,
#  j=284,
#  lat=29.479999542236328,
#  lon=-97.91998291015625,
#  pair=c3.LatLong(latitude=29.479999542236328, longitude=-97.91998291015625)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_2-285',
#  i=2,
#  j=285,
#  lat=29.520000457763672,
#  lon=-97.91998291015625,
#  pair=c3.LatLong(latitude=29.520000457763672, longitude=-97.91998291015625)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_2-286',
#  i=2,
#  j=286,
#  lat=29.559999465942383,
#  lon=-97.91998291015625,
#  pair=c3.LatLong(latitude=29.559999465942383, longitude=-97.91998291015625)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_2-287',
#  i=2,
#  j=287,
#  lat=29.600000381469727,
#  lon=-97.91998291015625,
#  pair=c3.LatLong(latitude=29.600000381469727, longitude=-97.91998291015625)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_2-288',
#  i=2,
#  j=288,
#  lat=29.639999389648438,
#  lon=-97.91998291015625,
#  pair=c3.LatLong(latitude=29.639999389648438, longitude=-97.91998291015625)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_2-289',
#  i=2,
#  j=289,
#  lat=29.68000030517578,
#  lon=-97.91998291015625,
#  pair=c3.LatLong(latitude=29.68000030517578, longitude=-97.91998291015625)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_2-290',
#  i=2,
#  j=290,
#  lat=29.719999313354492,
#  lon=-97.91998291015625,
#  pair=c3.LatLong(latitude=29.719999313354492, longitude=-97.91998291015625)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_2-291',
#  i=2,
#  j=291,
#  lat=29.760000228881836,
#  lon=-97.91998291015625,
#  pair=c3.LatLong(latitude=29.760000228881836, longitude=-97.91998291015625)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_2-292',
#  i=2,
#  j=292,
#  lat=29.799999237060547,
#  lon=-97.91998291015625,
#  pair=c3.LatLong(latitude=29.799999237060547, longitude=-97.91998291015625)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_2-293',
#  i=2,
#  j=293,
#  lat=29.84000015258789,
#  lon=-97.91998291015625,
#  pair=c3.LatLong(latitude=29.84000015258789, longitude=-97.91998291015625)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_2-294',
#  i=2,
#  j=294,
#  lat=29.8799991607666,
#  lon=-97.91998291015625,
#  pair=c3.LatLong(latitude=29.8799991607666, longitude=-97.91998291015625)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_2-295',
#  i=2,
#  j=295,
#  lat=29.920000076293945,
#  lon=-97.91998291015625,
#  pair=c3.LatLong(latitude=29.920000076293945, longitude=-97.91998291015625)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_2-296',
#  i=2,
#  j=296,
#  lat=29.959999084472656,
#  lon=-97.91998291015625,
#  pair=c3.LatLong(latitude=29.959999084472656, longitude=-97.91998291015625)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_2-297',
#  i=2,
#  j=297,
#  lat=30.0,
#  lon=-97.91998291015625,
#  pair=c3.LatLong(latitude=30.0, longitude=-97.91998291015625)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_2-298',
#  i=2,
#  j=298,
#  lat=30.040000915527344,
#  lon=-97.91998291015625,
#  pair=c3.LatLong(latitude=30.040000915527344, longitude=-97.91998291015625)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_2-299',
#  i=2,
#  j=299,
#  lat=30.079999923706055,
#  lon=-97.91998291015625,
#  pair=c3.LatLong(latitude=30.079999923706055, longitude=-97.91998291015625)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_2-300',
#  i=2,
#  j=300,
#  lat=30.1200008392334,
#  lon=-97.91998291015625,
#  pair=c3.LatLong(latitude=30.1200008392334, longitude=-97.91998291015625)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_2-301',
#  i=2,
#  j=301,
#  lat=30.15999984741211,
#  lon=-97.91998291015625,
#  pair=c3.LatLong(latitude=30.15999984741211, longitude=-97.91998291015625)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_2-302',
#  i=2,
#  j=302,
#  lat=30.200000762939453,
#  lon=-97.91998291015625,
#  pair=c3.LatLong(latitude=30.200000762939453, longitude=-97.91998291015625)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_2-303',
#  i=2,
#  j=303,
#  lat=30.239999771118164,
#  lon=-97.91998291015625,
#  pair=c3.LatLong(latitude=30.239999771118164, longitude=-97.91998291015625)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_2-304',
#  i=2,
#  j=304,
#  lat=30.280000686645508,
#  lon=-97.91998291015625,
#  pair=c3.LatLong(latitude=30.280000686645508, longitude=-97.91998291015625)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_2-305',
#  i=2,
#  j=305,
#  lat=30.31999969482422,
#  lon=-97.91998291015625,
#  pair=c3.LatLong(latitude=30.31999969482422, longitude=-97.91998291015625)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_2-306',
#  i=2,
#  j=306,
#  lat=30.360000610351562,
#  lon=-97.91998291015625,
#  pair=c3.LatLong(latitude=30.360000610351562, longitude=-97.91998291015625)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_2-307',
#  i=2,
#  j=307,
#  lat=30.399999618530273,
#  lon=-97.91998291015625,
#  pair=c3.LatLong(latitude=30.399999618530273, longitude=-97.91998291015625)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_2-308',
#  i=2,
#  j=308,
#  lat=30.440000534057617,
#  lon=-97.91998291015625,
#  pair=c3.LatLong(latitude=30.440000534057617, longitude=-97.91998291015625)),
#  c3.HycomLatLongPair(
#  id='GOMu0.04_2-309',
#  i=2,
#  j=309,
#  lat=30.479999542236328,
#  lon=-97.91998291015625,
#  pair=c3.LatLong(latitude=30.479999542236328, longitude=-97.91998291015625)),
#  ...]
