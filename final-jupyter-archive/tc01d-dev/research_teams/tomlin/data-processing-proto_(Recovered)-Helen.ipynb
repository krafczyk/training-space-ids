# %%
save_file1 = c3.HindcastFile.get('007e2816-3905-434b-b957-f7b0d0b03f46')
save_file2 = c3.HindcastFile.get('007e88f7-b86d-4379-a194-a73e2d003afb')

# %%
# hycom_file = c3.HycomUtil.nc_open(save_file.file.url)
# # save_file.file

# %%
# from datetime import datetime, timedelta
# # hycom_file['time']

# time_origin = datetime.strptime(hycom_file.variables['time'].__dict__['time_origin'] + ' +0000',
#                                         '%Y-%m-%d %H:%M:%S %z')

# %%
f1 = c3.HycomUtil.nc_open(save_file1.file.url)
f2 = c3.HycomUtil.nc_open(save_file1.file.url)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-e10b8593102b> in <module>
# ----> 1 f1 = c3.HycomUtil.nc_open(save_file1.file.url)
#       2 f2 = c3.HycomUtil.nc_open(save_file1.file.url)
#
# AttributeError: 'NoneType' object has no attribute 'file'

# %%
# Prototype for prosessing hindcast files
from datetime import datetime, timedelta

def process(this):
    """ Process a single Hindcast NetCDF file into the Hindcast__Data types"""
    # extract surface data for a variable
    hycom_file = c3.HycomUtil.nc_open(this.file.url)
    time_origin = datetime.strptime(hycom_file.variables['time'].__dict__['time_origin'] + ' +0000',
                                        '%Y-%m-%d %H:%M:%S %z')
    
    # extract lat-long, or derive this from types
    # Not yet done:determine the offset for each based on the subsetOptions for this file
    # Note: for now it's just an integer list
 
    longitudes = range(len(hycom_file['lon']))
    time = time_origin + timedelta(hours=hycom_file.variables['time'][:][0])

    # Create list of instantiated SurfaceHindcastData types
    # Create a parent id for each lat-long pair in the file.
    # use lat-long indicies to create a string parent id

    data_records = [
        c3.SurfaceHindcastData( # look at the code to understand, TimeDataPoint (Check out Type)
            **{
                'start': time,
                'parent': 'HNDCST_SRFC_' + str(i) + '-' + str(j),
                'name': 'water_u',  # variable
                'for': time,           # timestamp
                'water_u': hycom_file.variables['water_u'][:].data[0,0,i,j],
                'water_v': hycom_file.variables['water_v'][:].data[0,0,i,j]
            }
        )
        for i in latitudes[:1]
            for j in longitudes[:1]
    ]
    # upsert to data store
    c3.SurfaceHindcastData.upsertBatch(data_records)

    # close the file ds, url
    c3.HycomUtil.nc_close(ds=hycom_file, url=this.file.url)
    
    # aggregation in space is possible but a bit more complex

# %%
f = c3.HindcastFile.get('9438b440-e200-4764-b6fe-ee6a278aff55/GOMu0.04-expt_90.1m000-2021-2021-09-02T00:00:00Z-2021-09-02T23:00:00Z.nc')
# Out:
# 'hycom-test/hindcast/9438b440-e200-4764-b6fe-ee6a278aff55/GOMu0.04-expt_90.1m000-2021-2021-09-02T00:00:00Z-2021-09-02T23:00:00Z.nc'

# %%
hycom_file = c3.HycomUtil.nc_open(f.file.url)
time_origin = datetime.strptime(hycom_file.variables['time'].__dict__['time_origin'] + ' +0000','%Y-%m-%d %H:%M:%S %z')
hycom_file.variables['water_u'][:].shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-797ac0b17692> in <module>
# ----> 1 hycom_file = c3.HycomUtil.nc_open(f.file.url)
#       2 time_origin = datetime.strptime(hycom_file.variables['time'].__dict__['time_origin'] + ' +0000','%Y-%m-%d %H:%M:%S %z')
#       3 hycom_file.variables['water_u'][:].shape
#
# AttributeError: '_io.TextIOWrapper' object has no attribute 'file'

# %%
time = time_origin + timedelta(hours=hycom_file.variables['time'][:][23])
hycom_file.variables['lat'][:]
# Out:
# masked_array(data=[18.12000084, 18.15999985, 18.20000076, 18.23999977,
#                    18.28000069, 18.31999969, 18.36000061, 18.39999962,
#                    18.44000053, 18.47999954, 18.52000046, 18.55999947,
#                    18.60000038, 18.63999939, 18.68000031, 18.71999931,
#                    18.76000023, 18.79999924, 18.84000015, 18.87999916,
#                    18.92000008, 18.95999908, 19.        , 19.04000092,
#                    19.07999992, 19.12000084, 19.15999985, 19.20000076,
#                    19.23999977, 19.28000069, 19.31999969, 19.36000061,
#                    19.39999962, 19.44000053, 19.47999954, 19.52000046,
#                    19.55999947, 19.60000038, 19.63999939, 19.68000031,
#                    19.71999931, 19.76000023, 19.79999924, 19.84000015,
#                    19.87999916, 19.92000008, 19.95999908, 20.        ,
#                    20.04000092, 20.07999992, 20.12000084, 20.15999985,
#                    20.20000076, 20.23999977, 20.28000069, 20.31999969,
#                    20.36000061, 20.39999962, 20.44000053, 20.47999954,
#                    20.52000046, 20.55999947, 20.60000038, 20.63999939,
#                    20.68000031, 20.71999931, 20.76000023, 20.79999924,
#                    20.84000015, 20.87999916, 20.92000008, 20.95999908,
#                    21.        , 21.04000092, 21.07999992, 21.12000084,
#                    21.15999985, 21.20000076, 21.23999977, 21.28000069,
#                    21.31999969, 21.36000061, 21.39999962, 21.44000053,
#                    21.47999954, 21.52000046, 21.55999947, 21.60000038,
#                    21.63999939, 21.68000031, 21.71999931, 21.76000023,
#                    21.79999924, 21.84000015, 21.87999916, 21.92000008,
#                    21.95999908, 22.        , 22.04000092, 22.07999992,
#                    22.12000084, 22.15999985, 22.20000076, 22.23999977,
#                    22.28000069, 22.31999969, 22.36000061, 22.39999962,
#                    22.44000053, 22.47999954, 22.52000046, 22.55999947,
#                    22.60000038, 22.63999939, 22.68000031, 22.71999931,
#                    22.76000023, 22.79999924, 22.84000015, 22.87999916,
#                    22.92000008, 22.95999908, 23.        , 23.04000092,
#                    23.07999992, 23.12000084, 23.15999985, 23.20000076,
#                    23.23999977, 23.28000069, 23.31999969, 23.36000061,
#                    23.39999962, 23.44000053, 23.47999954, 23.52000046,
#                    23.55999947, 23.60000038, 23.63999939, 23.68000031,
#                    23.71999931, 23.76000023, 23.79999924, 23.84000015,
#                    23.87999916, 23.92000008, 23.95999908, 24.        ,
#                    24.04000092, 24.07999992, 24.12000084, 24.15999985,
#                    24.20000076, 24.23999977, 24.28000069, 24.31999969,
#                    24.36000061, 24.39999962, 24.44000053, 24.47999954,
#                    24.52000046, 24.55999947, 24.60000038, 24.63999939,
#                    24.68000031, 24.71999931, 24.76000023, 24.79999924,
#                    24.84000015, 24.87999916, 24.92000008, 24.95999908,
#                    25.        , 25.04000092, 25.07999992, 25.12000084,
#                    25.15999985, 25.20000076, 25.23999977, 25.28000069,
#                    25.31999969, 25.36000061, 25.39999962, 25.44000053,
#                    25.47999954, 25.52000046, 25.55999947, 25.60000038,
#                    25.63999939, 25.68000031, 25.71999931, 25.76000023,
#                    25.79999924, 25.84000015, 25.87999916, 25.92000008,
#                    25.95999908, 26.        , 26.04000092, 26.07999992,
#                    26.12000084, 26.15999985, 26.20000076, 26.23999977,
#                    26.28000069, 26.31999969, 26.36000061, 26.39999962,
#                    26.44000053, 26.47999954, 26.52000046, 26.55999947,
#                    26.60000038, 26.63999939, 26.68000031, 26.71999931,
#                    26.76000023, 26.79999924, 26.84000015, 26.87999916,
#                    26.92000008, 26.95999908, 27.        , 27.04000092,
#                    27.07999992, 27.12000084, 27.15999985, 27.20000076,
#                    27.23999977, 27.28000069, 27.31999969, 27.36000061,
#                    27.39999962, 27.44000053, 27.47999954, 27.52000046,
#                    27.55999947, 27.60000038, 27.63999939, 27.68000031,
#                    27.71999931, 27.76000023, 27.79999924, 27.84000015,
#                    27.87999916, 27.92000008, 27.95999908, 28.        ,
#                    28.04000092, 28.07999992, 28.12000084, 28.15999985,
#                    28.20000076, 28.23999977, 28.28000069, 28.31999969,
#                    28.36000061, 28.39999962, 28.44000053, 28.47999954,
#                    28.52000046, 28.55999947, 28.60000038, 28.63999939,
#                    28.68000031, 28.71999931, 28.76000023, 28.79999924,
#                    28.84000015, 28.87999916, 28.92000008, 28.95999908,
#                    29.        , 29.04000092, 29.07999992, 29.12000084,
#                    29.15999985, 29.20000076, 29.23999977, 29.28000069,
#                    29.31999969, 29.36000061, 29.39999962, 29.44000053,
#                    29.47999954, 29.52000046, 29.55999947, 29.60000038,
#                    29.63999939, 29.68000031, 29.71999931, 29.76000023,
#                    29.79999924, 29.84000015, 29.87999916, 29.92000008,
#                    29.95999908, 30.        , 30.04000092, 30.07999992,
#                    30.12000084, 30.15999985, 30.20000076, 30.23999977,
#                    30.28000069, 30.31999969, 30.36000061, 30.39999962,
#                    30.44000053, 30.47999954, 30.52000046, 30.55999947,
#                    30.60000038, 30.63999939, 30.68000031, 30.71999931,
#                    30.76000023, 30.79999924, 30.84000015, 30.87999916,
#                    30.92000008, 30.95999908, 31.        , 31.04000092,
#                    31.07999992, 31.12000084, 31.15999985, 31.20000076,
#                    31.23999977, 31.28000069, 31.31999969, 31.36000061,
#                    31.39999962, 31.44000053, 31.47999954, 31.52000046,
#                    31.55999947, 31.60000038, 31.63999939, 31.68000031,
#                    31.71999931, 31.76000023, 31.79999924, 31.84000015,
#                    31.87999916, 31.92000008],
#              mask=False,
#        fill_value=1e+20)

# %%
data_records = [
        c3.SurfaceHindcastDataSeries(
            **{ 'id': 'HNDCST_SRFC_0-0',
                'latLongPair': 'GOMu0.04_1-1',
                
            }
        )
    ]

# %%
c3.SurfaceHindcastDataSeries.upsertBatch(data_records)
# Out:
# c3.ObjList<SurfaceHindcastDataSeries>(
#  stats=c3.Stats(
#          createdObjCount=1,
#          updatedObjCount=0,
#          removedObjCount=0,
#          failedObjCount=0,
#          objCount=1,
#          dbWait=0.0,
#          time=0.181,
#          dbTime=0.013696359,
#          objsPerSecond=5.524861878453039,
#          dbObjsPerSecond=73.012104895907),
#  objs=c3.Arry<SurfaceHindcastDataSeries>([c3.SurfaceHindcastDataSeries(
#          id='HNDCST_SRFC_1-1',
#          meta=c3.Meta(
#                 created=datetime.datetime(2021, 10, 15, 23, 48, 19, tzinfo=datetime.timezone.utc),
#                 updated=datetime.datetime(2021, 10, 15, 23, 48, 19, tzinfo=datetime.timezone.utc),
#                 timestamp=datetime.datetime(2021, 10, 15, 23, 48, 19, tzinfo=datetime.timezone.utc)),
#          version=1)]))

# %%
objs_list = c3.HycomLatLongPair.fetch(spec={"include": "id", "filter": "lat > 18 && lat < 19 && lon > -98 && lon < -97", "order": "j,i"}).objs

ids_list = [obj.id for obj in objs_list]
exp_ids_list = ['GOMu0.04_1-0']

# %%
ids_list
# Out:
# ['GOMu0.04_1-0',
#  'GOMu0.04_2-0',
#  'GOMu0.04_3-0',
#  'GOMu0.04_4-0',
#  'GOMu0.04_5-0',
#  'GOMu0.04_6-0',
#  'GOMu0.04_7-0',
#  'GOMu0.04_8-0',
#  'GOMu0.04_9-0',
#  'GOMu0.04_10-0',
#  'GOMu0.04_11-0',
#  'GOMu0.04_12-0',
#  'GOMu0.04_13-0',
#  'GOMu0.04_14-0',
#  'GOMu0.04_15-0',
#  'GOMu0.04_16-0',
#  'GOMu0.04_17-0',
#  'GOMu0.04_18-0',
#  'GOMu0.04_19-0',
#  'GOMu0.04_20-0',
#  'GOMu0.04_21-0',
#  'GOMu0.04_22-0',
#  'GOMu0.04_23-0',
#  'GOMu0.04_24-0',
#  'GOMu0.04_1-1',
#  'GOMu0.04_2-1',
#  'GOMu0.04_3-1',
#  'GOMu0.04_4-1',
#  'GOMu0.04_5-1',
#  'GOMu0.04_6-1',
#  'GOMu0.04_7-1',
#  'GOMu0.04_8-1',
#  'GOMu0.04_9-1',
#  'GOMu0.04_10-1',
#  'GOMu0.04_11-1',
#  'GOMu0.04_12-1',
#  'GOMu0.04_13-1',
#  'GOMu0.04_14-1',
#  'GOMu0.04_15-1',
#  'GOMu0.04_16-1',
#  'GOMu0.04_17-1',
#  'GOMu0.04_18-1',
#  'GOMu0.04_19-1',
#  'GOMu0.04_20-1',
#  'GOMu0.04_21-1',
#  'GOMu0.04_22-1',
#  'GOMu0.04_23-1',
#  'GOMu0.04_24-1',
#  'GOMu0.04_1-2',
#  'GOMu0.04_2-2',
#  'GOMu0.04_3-2',
#  'GOMu0.04_4-2',
#  'GOMu0.04_5-2',
#  'GOMu0.04_6-2',
#  'GOMu0.04_7-2',
#  'GOMu0.04_8-2',
#  'GOMu0.04_9-2',
#  'GOMu0.04_10-2',
#  'GOMu0.04_11-2',
#  'GOMu0.04_12-2',
#  'GOMu0.04_13-2',
#  'GOMu0.04_14-2',
#  'GOMu0.04_15-2',
#  'GOMu0.04_16-2',
#  'GOMu0.04_17-2',
#  'GOMu0.04_18-2',
#  'GOMu0.04_19-2',
#  'GOMu0.04_20-2',
#  'GOMu0.04_21-2',
#  'GOMu0.04_22-2',
#  'GOMu0.04_23-2',
#  'GOMu0.04_24-2',
#  'GOMu0.04_1-3',
#  'GOMu0.04_2-3',
#  'GOMu0.04_3-3',
#  'GOMu0.04_4-3',
#  'GOMu0.04_5-3',
#  'GOMu0.04_6-3',
#  'GOMu0.04_7-3',
#  'GOMu0.04_8-3',
#  'GOMu0.04_9-3',
#  'GOMu0.04_10-3',
#  'GOMu0.04_11-3',
#  'GOMu0.04_12-3',
#  'GOMu0.04_13-3',
#  'GOMu0.04_14-3',
#  'GOMu0.04_15-3',
#  'GOMu0.04_16-3',
#  'GOMu0.04_17-3',
#  'GOMu0.04_18-3',
#  'GOMu0.04_19-3',
#  'GOMu0.04_20-3',
#  'GOMu0.04_21-3',
#  'GOMu0.04_22-3',
#  'GOMu0.04_23-3',
#  'GOMu0.04_24-3',
#  'GOMu0.04_1-4',
#  'GOMu0.04_2-4',
#  'GOMu0.04_3-4',
#  'GOMu0.04_4-4',
#  'GOMu0.04_5-4',
#  'GOMu0.04_6-4',
#  'GOMu0.04_7-4',
#  'GOMu0.04_8-4',
#  'GOMu0.04_9-4',
#  'GOMu0.04_10-4',
#  'GOMu0.04_11-4',
#  'GOMu0.04_12-4',
#  'GOMu0.04_13-4',
#  'GOMu0.04_14-4',
#  'GOMu0.04_15-4',
#  'GOMu0.04_16-4',
#  'GOMu0.04_17-4',
#  'GOMu0.04_18-4',
#  'GOMu0.04_19-4',
#  'GOMu0.04_20-4',
#  'GOMu0.04_21-4',
#  'GOMu0.04_22-4',
#  'GOMu0.04_23-4',
#  'GOMu0.04_24-4',
#  'GOMu0.04_1-5',
#  'GOMu0.04_2-5',
#  'GOMu0.04_3-5',
#  'GOMu0.04_4-5',
#  'GOMu0.04_5-5',
#  'GOMu0.04_6-5',
#  'GOMu0.04_7-5',
#  'GOMu0.04_8-5',
#  'GOMu0.04_9-5',
#  'GOMu0.04_10-5',
#  'GOMu0.04_11-5',
#  'GOMu0.04_12-5',
#  'GOMu0.04_13-5',
#  'GOMu0.04_14-5',
#  'GOMu0.04_15-5',
#  'GOMu0.04_16-5',
#  'GOMu0.04_17-5',
#  'GOMu0.04_18-5',
#  'GOMu0.04_19-5',
#  'GOMu0.04_20-5',
#  'GOMu0.04_21-5',
#  'GOMu0.04_22-5',
#  'GOMu0.04_23-5',
#  'GOMu0.04_24-5',
#  'GOMu0.04_1-6',
#  'GOMu0.04_2-6',
#  'GOMu0.04_3-6',
#  'GOMu0.04_4-6',
#  'GOMu0.04_5-6',
#  'GOMu0.04_6-6',
#  'GOMu0.04_7-6',
#  'GOMu0.04_8-6',
#  'GOMu0.04_9-6',
#  'GOMu0.04_10-6',
#  'GOMu0.04_11-6',
#  'GOMu0.04_12-6',
#  'GOMu0.04_13-6',
#  'GOMu0.04_14-6',
#  'GOMu0.04_15-6',
#  'GOMu0.04_16-6',
#  'GOMu0.04_17-6',
#  'GOMu0.04_18-6',
#  'GOMu0.04_19-6',
#  'GOMu0.04_20-6',
#  'GOMu0.04_21-6',
#  'GOMu0.04_22-6',
#  'GOMu0.04_23-6',
#  'GOMu0.04_24-6',
#  'GOMu0.04_1-7',
#  'GOMu0.04_2-7',
#  'GOMu0.04_3-7',
#  'GOMu0.04_4-7',
#  'GOMu0.04_5-7',
#  'GOMu0.04_6-7',
#  'GOMu0.04_7-7',
#  'GOMu0.04_8-7',
#  'GOMu0.04_9-7',
#  'GOMu0.04_10-7',
#  'GOMu0.04_11-7',
#  'GOMu0.04_12-7',
#  'GOMu0.04_13-7',
#  'GOMu0.04_14-7',
#  'GOMu0.04_15-7',
#  'GOMu0.04_16-7',
#  'GOMu0.04_17-7',
#  'GOMu0.04_18-7',
#  'GOMu0.04_19-7',
#  'GOMu0.04_20-7',
#  'GOMu0.04_21-7',
#  'GOMu0.04_22-7',
#  'GOMu0.04_23-7',
#  'GOMu0.04_24-7',
#  'GOMu0.04_1-8',
#  'GOMu0.04_2-8',
#  'GOMu0.04_3-8',
#  'GOMu0.04_4-8',
#  'GOMu0.04_5-8',
#  'GOMu0.04_6-8',
#  'GOMu0.04_7-8',
#  'GOMu0.04_8-8',
#  'GOMu0.04_9-8',
#  'GOMu0.04_10-8',
#  'GOMu0.04_11-8',
#  'GOMu0.04_12-8',
#  'GOMu0.04_13-8',
#  'GOMu0.04_14-8',
#  'GOMu0.04_15-8',
#  'GOMu0.04_16-8',
#  'GOMu0.04_17-8',
#  'GOMu0.04_18-8',
#  'GOMu0.04_19-8',
#  'GOMu0.04_20-8',
#  'GOMu0.04_21-8',
#  'GOMu0.04_22-8',
#  'GOMu0.04_23-8',
#  'GOMu0.04_24-8',
#  'GOMu0.04_1-9',
#  'GOMu0.04_2-9',
#  'GOMu0.04_3-9',
#  'GOMu0.04_4-9',
#  'GOMu0.04_5-9',
#  'GOMu0.04_6-9',
#  'GOMu0.04_7-9',
#  'GOMu0.04_8-9',
#  'GOMu0.04_9-9',
#  'GOMu0.04_10-9',
#  'GOMu0.04_11-9',
#  'GOMu0.04_12-9',
#  'GOMu0.04_13-9',
#  'GOMu0.04_14-9',
#  'GOMu0.04_15-9',
#  'GOMu0.04_16-9',
#  'GOMu0.04_17-9',
#  'GOMu0.04_18-9',
#  'GOMu0.04_19-9',
#  'GOMu0.04_20-9',
#  'GOMu0.04_21-9',
#  'GOMu0.04_22-9',
#  'GOMu0.04_23-9',
#  'GOMu0.04_24-9',
#  'GOMu0.04_1-10',
#  'GOMu0.04_2-10',
#  'GOMu0.04_3-10',
#  'GOMu0.04_4-10',
#  'GOMu0.04_5-10',
#  'GOMu0.04_6-10',
#  'GOMu0.04_7-10',
#  'GOMu0.04_8-10',
#  'GOMu0.04_9-10',
#  'GOMu0.04_10-10',
#  'GOMu0.04_11-10',
#  'GOMu0.04_12-10',
#  'GOMu0.04_13-10',
#  'GOMu0.04_14-10',
#  'GOMu0.04_15-10',
#  'GOMu0.04_16-10',
#  'GOMu0.04_17-10',
#  'GOMu0.04_18-10',
#  'GOMu0.04_19-10',
#  'GOMu0.04_20-10',
#  'GOMu0.04_21-10',
#  'GOMu0.04_22-10',
#  'GOMu0.04_23-10',
#  'GOMu0.04_24-10',
#  'GOMu0.04_1-11',
#  'GOMu0.04_2-11',
#  'GOMu0.04_3-11',
#  'GOMu0.04_4-11',
#  'GOMu0.04_5-11',
#  'GOMu0.04_6-11',
#  'GOMu0.04_7-11',
#  'GOMu0.04_8-11',
#  'GOMu0.04_9-11',
#  'GOMu0.04_10-11',
#  'GOMu0.04_11-11',
#  'GOMu0.04_12-11',
#  'GOMu0.04_13-11',
#  'GOMu0.04_14-11',
#  'GOMu0.04_15-11',
#  'GOMu0.04_16-11',
#  'GOMu0.04_17-11',
#  'GOMu0.04_18-11',
#  'GOMu0.04_19-11',
#  'GOMu0.04_20-11',
#  'GOMu0.04_21-11',
#  'GOMu0.04_22-11',
#  'GOMu0.04_23-11',
#  'GOMu0.04_24-11',
#  'GOMu0.04_1-12',
#  'GOMu0.04_2-12',
#  'GOMu0.04_3-12',
#  'GOMu0.04_4-12',
#  'GOMu0.04_5-12',
#  'GOMu0.04_6-12',
#  'GOMu0.04_7-12',
#  'GOMu0.04_8-12',
#  'GOMu0.04_9-12',
#  'GOMu0.04_10-12',
#  'GOMu0.04_11-12',
#  'GOMu0.04_12-12',
#  'GOMu0.04_13-12',
#  'GOMu0.04_14-12',
#  'GOMu0.04_15-12',
#  'GOMu0.04_16-12',
#  'GOMu0.04_17-12',
#  'GOMu0.04_18-12',
#  'GOMu0.04_19-12',
#  'GOMu0.04_20-12',
#  'GOMu0.04_21-12',
#  'GOMu0.04_22-12',
#  'GOMu0.04_23-12',
#  'GOMu0.04_24-12',
#  'GOMu0.04_1-13',
#  'GOMu0.04_2-13',
#  'GOMu0.04_3-13',
#  'GOMu0.04_4-13',
#  'GOMu0.04_5-13',
#  'GOMu0.04_6-13',
#  'GOMu0.04_7-13',
#  'GOMu0.04_8-13',
#  'GOMu0.04_9-13',
#  'GOMu0.04_10-13',
#  'GOMu0.04_11-13',
#  'GOMu0.04_12-13',
#  'GOMu0.04_13-13',
#  'GOMu0.04_14-13',
#  'GOMu0.04_15-13',
#  'GOMu0.04_16-13',
#  'GOMu0.04_17-13',
#  'GOMu0.04_18-13',
#  'GOMu0.04_19-13',
#  'GOMu0.04_20-13',
#  'GOMu0.04_21-13',
#  'GOMu0.04_22-13',
#  'GOMu0.04_23-13',
#  'GOMu0.04_24-13',
#  'GOMu0.04_1-14',
#  'GOMu0.04_2-14',
#  'GOMu0.04_3-14',
#  'GOMu0.04_4-14',
#  'GOMu0.04_5-14',
#  'GOMu0.04_6-14',
#  'GOMu0.04_7-14',
#  'GOMu0.04_8-14',
#  'GOMu0.04_9-14',
#  'GOMu0.04_10-14',
#  'GOMu0.04_11-14',
#  'GOMu0.04_12-14',
#  'GOMu0.04_13-14',
#  'GOMu0.04_14-14',
#  'GOMu0.04_15-14',
#  'GOMu0.04_16-14',
#  'GOMu0.04_17-14',
#  'GOMu0.04_18-14',
#  'GOMu0.04_19-14',
#  'GOMu0.04_20-14',
#  'GOMu0.04_21-14',
#  'GOMu0.04_22-14',
#  'GOMu0.04_23-14',
#  'GOMu0.04_24-14',
#  'GOMu0.04_1-15',
#  'GOMu0.04_2-15',
#  'GOMu0.04_3-15',
#  'GOMu0.04_4-15',
#  'GOMu0.04_5-15',
#  'GOMu0.04_6-15',
#  'GOMu0.04_7-15',
#  'GOMu0.04_8-15',
#  'GOMu0.04_9-15',
#  'GOMu0.04_10-15',
#  'GOMu0.04_11-15',
#  'GOMu0.04_12-15',
#  'GOMu0.04_13-15',
#  'GOMu0.04_14-15',
#  'GOMu0.04_15-15',
#  'GOMu0.04_16-15',
#  'GOMu0.04_17-15',
#  'GOMu0.04_18-15',
#  'GOMu0.04_19-15',
#  'GOMu0.04_20-15',
#  'GOMu0.04_21-15',
#  'GOMu0.04_22-15',
#  'GOMu0.04_23-15',
#  'GOMu0.04_24-15',
#  'GOMu0.04_1-16',
#  'GOMu0.04_2-16',
#  'GOMu0.04_3-16',
#  'GOMu0.04_4-16',
#  'GOMu0.04_5-16',
#  'GOMu0.04_6-16',
#  'GOMu0.04_7-16',
#  'GOMu0.04_8-16',
#  'GOMu0.04_9-16',
#  'GOMu0.04_10-16',
#  'GOMu0.04_11-16',
#  'GOMu0.04_12-16',
#  'GOMu0.04_13-16',
#  'GOMu0.04_14-16',
#  'GOMu0.04_15-16',
#  'GOMu0.04_16-16',
#  'GOMu0.04_17-16',
#  'GOMu0.04_18-16',
#  'GOMu0.04_19-16',
#  'GOMu0.04_20-16',
#  'GOMu0.04_21-16',
#  'GOMu0.04_22-16',
#  'GOMu0.04_23-16',
#  'GOMu0.04_24-16',
#  'GOMu0.04_1-17',
#  'GOMu0.04_2-17',
#  'GOMu0.04_3-17',
#  'GOMu0.04_4-17',
#  'GOMu0.04_5-17',
#  'GOMu0.04_6-17',
#  'GOMu0.04_7-17',
#  'GOMu0.04_8-17',
#  'GOMu0.04_9-17',
#  'GOMu0.04_10-17',
#  'GOMu0.04_11-17',
#  'GOMu0.04_12-17',
#  'GOMu0.04_13-17',
#  'GOMu0.04_14-17',
#  'GOMu0.04_15-17',
#  'GOMu0.04_16-17',
#  'GOMu0.04_17-17',
#  'GOMu0.04_18-17',
#  'GOMu0.04_19-17',
#  'GOMu0.04_20-17',
#  'GOMu0.04_21-17',
#  'GOMu0.04_22-17',
#  'GOMu0.04_23-17',
#  'GOMu0.04_24-17',
#  'GOMu0.04_1-18',
#  'GOMu0.04_2-18',
#  'GOMu0.04_3-18',
#  'GOMu0.04_4-18',
#  'GOMu0.04_5-18',
#  'GOMu0.04_6-18',
#  'GOMu0.04_7-18',
#  'GOMu0.04_8-18',
#  'GOMu0.04_9-18',
#  'GOMu0.04_10-18',
#  'GOMu0.04_11-18',
#  'GOMu0.04_12-18',
#  'GOMu0.04_13-18',
#  'GOMu0.04_14-18',
#  'GOMu0.04_15-18',
#  'GOMu0.04_16-18',
#  'GOMu0.04_17-18',
#  'GOMu0.04_18-18',
#  'GOMu0.04_19-18',
#  'GOMu0.04_20-18',
#  'GOMu0.04_21-18',
#  'GOMu0.04_22-18',
#  'GOMu0.04_23-18',
#  'GOMu0.04_24-18',
#  'GOMu0.04_1-19',
#  'GOMu0.04_2-19',
#  'GOMu0.04_3-19',
#  'GOMu0.04_4-19',
#  'GOMu0.04_5-19',
#  'GOMu0.04_6-19',
#  'GOMu0.04_7-19',
#  'GOMu0.04_8-19',
#  'GOMu0.04_9-19',
#  'GOMu0.04_10-19',
#  'GOMu0.04_11-19',
#  'GOMu0.04_12-19',
#  'GOMu0.04_13-19',
#  'GOMu0.04_14-19',
#  'GOMu0.04_15-19',
#  'GOMu0.04_16-19',
#  'GOMu0.04_17-19',
#  'GOMu0.04_18-19',
#  'GOMu0.04_19-19',
#  'GOMu0.04_20-19',
#  'GOMu0.04_21-19',
#  'GOMu0.04_22-19',
#  'GOMu0.04_23-19',
#  'GOMu0.04_24-19',
#  'GOMu0.04_1-20',
#  'GOMu0.04_2-20',
#  'GOMu0.04_3-20',
#  'GOMu0.04_4-20',
#  'GOMu0.04_5-20',
#  'GOMu0.04_6-20',
#  'GOMu0.04_7-20',
#  'GOMu0.04_8-20',
#  'GOMu0.04_9-20',
#  'GOMu0.04_10-20',
#  'GOMu0.04_11-20',
#  'GOMu0.04_12-20',
#  'GOMu0.04_13-20',
#  'GOMu0.04_14-20',
#  'GOMu0.04_15-20',
#  'GOMu0.04_16-20',
#  'GOMu0.04_17-20',
#  'GOMu0.04_18-20',
#  'GOMu0.04_19-20',
#  'GOMu0.04_20-20',
#  'GOMu0.04_21-20',
#  'GOMu0.04_22-20',
#  'GOMu0.04_23-20',
#  'GOMu0.04_24-20',
#  'GOMu0.04_1-21',
#  'GOMu0.04_2-21',
#  'GOMu0.04_3-21',
#  'GOMu0.04_4-21',
#  'GOMu0.04_5-21',
#  'GOMu0.04_6-21',
#  'GOMu0.04_7-21',
#  'GOMu0.04_8-21',
#  'GOMu0.04_9-21',
#  'GOMu0.04_10-21',
#  'GOMu0.04_11-21',
#  'GOMu0.04_12-21',
#  'GOMu0.04_13-21',
#  'GOMu0.04_14-21',
#  'GOMu0.04_15-21',
#  'GOMu0.04_16-21',
#  'GOMu0.04_17-21',
#  'GOMu0.04_18-21',
#  'GOMu0.04_19-21',
#  'GOMu0.04_20-21',
#  'GOMu0.04_21-21',
#  'GOMu0.04_22-21',
#  'GOMu0.04_23-21',
#  'GOMu0.04_24-21']

# %%
# Define simple metric
my_metric = c3.SimpleMetric(id = "AverageWaterU_HycomLatLongPair",
                            name = "AverageWaterU",
                            description = "Calculates average surface X-velocity for the given interval",
                            srcType = "HycomLatLongPair",
                            path = "surfaceHindcastData",
                            #expression = "eval('water_u', (normalized.data.water_u * 1))"
                            expression = "avg(avg(normalized.data.water_u ))"
                           )

my_metric.toJson()
# Create EvalMetricsSpec
my_spec = c3.EvalMetricsSpec(
            ids = exp_ids_list,
            expressions = ["AverageWaterU"], # does this refer to the one above?
            start = "2021-09-01",
            end = "2021-09-30",
            interval = "DAY", )

# %%
#evalMetricsResult = c3.HycomLatLongPair.evalMetrics(spec=my_spec) #eventually swap for just evalMetrics function (less metadata)
evalMetricsResult = c3.HycomLatLongPair.evalMetricsWithMetadata(spec=my_spec,overrideMetrics=[my_metric])
# Out:
# 500 - NotClassified - c3.love.exceptions.C3RuntimeException_wrapIt [6241.3243]
# message: "wrapped RuntimeException: Field 'i' does not exist in expression: '[latLongPair, ascending(i), ascending(j)]' for type 'SurfaceHindcastDataSeries'."
# JSON: {"overrideMetrics": [{"type": "SimpleMetric", "name": "AverageWaterU", "expression": "avg(avg(normalized.data.water_u ))", "description": "Calculates average surface X-velocity for the given interval", "id": "AverageWaterU_HycomLatLongPair", "srcType": {"type": "TypeRef", "typeName": "HycomLatLongPair"}, "path": "surfaceHindcastData"}], "spec": {"type": "EvalMetricsSpec", "start": "2021-09-01T00:00:00", "end": "2021-09-30T00:00:00", "timeZone": "NONE", "interval": "DAY", "cache": false, "ids": ["GOMu0.04_1-0"], "expressions": ["AverageWaterU"], "continueOnError": false}}
# ---------------------------------------------------------------------------
# C3RuntimeException                        Traceback (most recent call last)
# <ipython-input-4-f06f1fc86fe6> in <module>
#       1 #evalMetricsResult = c3.HycomLatLongPair.evalMetrics(spec=my_spec) #eventually swap for just evalMetrics function (less metadata)
# ----> 2 evalMetricsResult = c3.HycomLatLongPair.evalMetricsWithMetadata(spec=my_spec,overrideMetrics=[my_metric])
#
# Z10ac078826d8534179d455db1588a325M_.TypeSystemBase in evalMetricsWithMetadata(_cls_f7f11c950a4e, spec, overrideMetrics)
#
# Z10ac078826d8534179d455db1588a325M_/TypeSystemBase.py in _c3_static_impl(_cls, typesys, ___args, method_name, defined_class_name, _overload_idx)
#
# Z10ac078826d8534179d455db1588a325M_/TypeSystemBase.py in _box_and_request_json(self, type_name, method_name, payload, validate_args, declared_type_name, current_class)
#
# Z10ac078826d8534179d455db1588a325M_/TypeSystemBase.py in _request_json(self, type_name, method_name, payload)
#
# Z10ac078826d8534179d455db1588a325M_/ServerConnection.py in _request_json(self, type_name, action_name, payload, extra_headers, encoder, client_side_type_inference)
#
# C3RuntimeException: 500 - NotClassified - c3.love.exceptions.C3RuntimeException_wrapIt [6241.3243]
# message: "wrapped RuntimeException: Field 'i' does not exist in expression: '[latLongPair, ascending(i), ascending(j)]' for type 'SurfaceHindcastDataSeries'."
# JSON: {"overrideMetrics": [{"type": "SimpleMetric", "name": "AverageWaterU", "expression": "avg(avg(normalized.data.water_u ))", "description": "Calculates average surface X-velocity for the given interval", "id": "AverageWaterU_HycomLatLongPair", "srcType": {"type": "TypeRef", "typeName": "HycomLatLongPair"}, "path": "surfaceHindcastData"}], "spec": {"type": "EvalMetricsSpec", "start": "2021-09-01T00:00:00", "end": "2021-09-30T00:00:00", "timeZone": "NONE", "interval": "DAY", "cache": false, "ids": ["GOMu0.04_1-0"], "expressions": ["AverageWaterU"], "continueOnError": false}}

# %%
a = evalMetricsResult.result["GOMu0.04_1-1"]["TestAverageWaterU"].m_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-3737b45ac9da> in <module>
# ----> 1 a = evalMetricsResult.result["GOMu0.04_1-1"]["TestAverageWaterU"].m_data
#
# NameError: name 'evalMetricsResult' is not defined

# %%
a[1]
# Out:
# 0.0

# %%
df = c3.EvalMetricsResult.toPandas(result=evalMetricsResult)
# Out:
#                                   TestAverageWaterU
# GOMu0.04_1-0_2021-09-01T00:00:00                0.0
# GOMu0.04_1-0_2021-09-02T00:00:00                0.0
# GOMu0.04_1-0_2021-09-03T00:00:00                0.0
# GOMu0.04_1-0_2021-09-04T00:00:00                0.0
# GOMu0.04_1-0_2021-09-05T00:00:00                0.0
# ...                                             ...
# GOMu0.04_9-9_2021-09-25T00:00:00                0.0
# GOMu0.04_9-9_2021-09-26T00:00:00                0.0
# GOMu0.04_9-9_2021-09-27T00:00:00                0.0
# GOMu0.04_9-9_2021-09-28T00:00:00                0.0
# GOMu0.04_9-9_2021-09-29T00:00:00                0.0
#
# [15312 rows x 1 columns]

# %%
# convert EvalMetricsResult to Pandas DataFrame
df = c3.EvalMetricsResult.toPandas(result=evalMetricsResult)
df
# Out:
#                                   AverageWaterU
# GOMu0.04_1-1_2021-09-01T00:00:00            0.0
# GOMu0.04_1-1_2021-09-01T01:00:00            0.0
# GOMu0.04_1-1_2021-09-01T02:00:00            0.0
# GOMu0.04_1-1_2021-09-01T03:00:00            0.0
# GOMu0.04_1-1_2021-09-01T04:00:00            0.0
# ...                                         ...
# GOMu0.04_1-1_2021-09-29T19:00:00            0.0
# GOMu0.04_1-1_2021-09-29T20:00:00            0.0
# GOMu0.04_1-1_2021-09-29T21:00:00            0.0
# GOMu0.04_1-1_2021-09-29T22:00:00            0.0
# GOMu0.04_1-1_2021-09-29T23:00:00            0.0
#
# [696 rows x 1 columns]

# %%
# Out:
# -0.2980000078678131

# %%
# Next Steps:
# 1) Understand the math functions and why it does what it does?
# 2) How can we do lat-lon filtering?
# 3) Implement full pipeline for a specific use-case and compare time-performance
